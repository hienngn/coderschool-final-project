# %%
import re
import cv2
import numpy as np
import pandas as pd
import shutil
import os
import random
import pytesseract
from pytesseract import Output
from matplotlib import pyplot as plt
# from google.colab.patches import cv2_imshow
try:
    from PIL import Image, ImageEnhance
except ImportError:
    import Image


import operator
import itertools
import gc
import pickle

from difflib import SequenceMatcher
from ast import literal_eval
from collections import Counter
from tqdm import tqdm

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
import re
import cv2
import numpy as np
import shutil
import pandas as pd
import os
import random
import pytesseract
from pytesseract import Output
from matplotlib import pyplot as plt

# %%
try:
    from PIL import Image, ImageEnhance
except ImportError:
    import Image

# %%
import operator
import itertools
import gc
import pickle

# %%
from difflib import SequenceMatcher
from ast import literal_eval
from collections import Counter
from tqdm import tqdm

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
sample = cv2.imread('../Sample_images/sample5.JPG')
cv2.imshow('sample', sample)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-66-3301c0c3ecde> in <module>
#       1 sample = cv2.imread('../Sample_images/sample5.JPG')
# ----> 2 cv2.imshow('sample', sample)
#       3 cv2.waitKey(0)
#       4 cv2.destroyAllWindows()
#
# error: OpenCV(4.4.0) ../modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.GaussianBlur(image, (5,5), 0)

# thresholding
def thresholding(image):
    return cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 7, 4)
                            
# return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# dilation: enhance the bright area
def dilate(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.dilate(image, kernel, iterations=1)

# erosion: enhance the dark area
def erode(image):
  kernel = np.ones((5,5), np.unint8)
  return cv2.erode(image, kernel, iterations=1)

# opening: erosion follow by a dilation
def opening(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

# closing: Dilation followed by Erosion. Removing black holes inside the object 
def closing(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.morphologyEx(opening(image), cv2.MORPH_CLOSE, kernel)

# canny
def canny(image):
      return cv2.Canny(image, 100, 200)

# deskew image
def deskew(image):
    coords = np.column_stack(np.where(image>0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

# template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

# %%
def preprocess_for_ocr(img, enhance=1):
    """
    @param img: image to which the pre-processing steps being applied
    """
    if enhance > 1:
        img = Image.fromarray(img)

        contrast = ImageEnhance.Contrast(img)

        img = contrast.enhance(enhance)

        img = np.asarray(img)
    
    
    gray = get_grayscale(img)
    blur = remove_noise(gray)
    res = thresholding(blur)

    img = cv2.cvtColor(res, cv2.COLOR_GRAY2BGR)

    return img

# %%
def get_bounding_box(txt):
    annotation = txt
    with open(annotation, "r") as file1:
        bounding_boxes = file1.read()
        
    bounding_boxes = bounding_boxes.split('\n')[:-1]
    boxes = [i.split(',')[:-1] for i in bounding_boxes]

    new_boxes = []
    for box in boxes:
        new_box = []
        for i, each in enumerate(box):
            num = int(each)
            if i in [0, 1, 3, 6]:
                num -= 3
            else: 
                num += 3
            new_box.append(num)
        new_boxes.append(new_box)
    new_boxes.sort(key=lambda x: x[1])
    
    return new_boxes

# %%
def crop_line(img_path, box):
    img = cv2.imread(img_path)
    img, (rh, rw) = resize_image(img)
    # points for test.jpg
    cnt = np.array([
            [[box[0], box[1]]],
            [[box[2], box[3]]],
            [[box[4], box[5]]],
            [[box[6], box[7]]]
        ])
    # print("shape of cnt: {}".format(cnt.shape))
    rect = cv2.minAreaRect(cnt)
#     print("rect: {}".format(rect))

    # the order of the box points: bottom left, top left, top right,
    # bottom right
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # print("bounding box: {}".format(box))
    cv2.drawContours(img, [box], 0, (0, 0, 255), 2)

    # get width and height of the detected rectangle
    width = int(rect[1][0])
    height = int(rect[1][1])
    angle = rect[2]

    src_pts = box.astype("float32")
    # coordinate of the points in box points after the rectangle has been
    # straightened
    dst_pts = np.array([[0, height+2],
                        [0, 0],
                        [width, 0],
                        [width, height+2]], dtype="float32")

    # the perspective transformation matrix
    M = cv2.getPerspectiveTransform(src_pts, dst_pts)

    # directly warp the rotated rectangle to get the straightened rectangle
    warped = cv2.warpPerspective(img, M, (width, height))

    # cv2.imwrite("crop_img.jpg", warped)
    
    # cv2.waitKey(0)
    if angle < -45:
      warped = np.transpose(warped,(1,0,2))
      warped = warped[::-1]

#     cv2.imshow('croped', warped)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()


    return warped

# %%
# I dont use this one anymore. Change to the function above 'crop_line()'
def crop_each_line(img_path, rect):
    img = cv2.imread(img_path)
    img, (rh, rw) = resize_image(img)
    cnt = np.array([
            [[rect[0], rect[1]]],
            [[rect[2], rect[3]]],
            [[rect[4],rect[5]]],
            [[rect[6], rect[7]]]
        ])
    # find the exact rectangle enclosing the text area
    # rect is a tuple consisting of 3 elements: the first element is the center
    # of the rectangle, the second element is the width, height, and the
    # third element is the detected rotation angle.
    # Example output: ((227.5, 187.50003051757812),
    # (94.57575225830078, 417.98736572265625), -36.982906341552734)
    rect = cv2.minAreaRect(cnt)
    print("rect: {}".format(rect))

    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # print("bounding box: {}".format(box))
    cv2.drawContours(img, [box], 0, (0, 0, 255), 1)

    # img_crop will the cropped rectangle, img_rot is the rotated image
    img_crop, img_rot = crop_rect(img, rect)
    cv2.imwrite("cropped_img.jpg", img)
    cv2.imshow('croped', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    return img_crop

def resize_image(img):
    img_size = img.shape
    im_size_min = np.min(img_size[0:2])
    im_size_max = np.max(img_size[0:2])

    im_scale = float(600) / float(im_size_min)
    if np.round(im_scale * im_size_max) > 1200:
        im_scale = float(1200) / float(im_size_max)
    new_h = int(img_size[0] * im_scale)
    new_w = int(img_size[1] * im_scale)

    new_h = new_h if new_h // 16 == 0 else (new_h // 16 + 1) * 16
    new_w = new_w if new_w // 16 == 0 else (new_w // 16 + 1) * 16

    re_im = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_LINEAR)
    return re_im, (new_h / img_size[0], new_w / img_size[1])

def crop_rect(img, rect):
    # get the parameter of the small rectangle
    center, size, angle = rect[0], rect[1], rect[2]
    center, size = tuple(map(int, center)), tuple(map(int, size))

    # get row and col num in img
    height, width = img.shape[0], img.shape[1]

    # calculate the rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, 1)
    # rotate the original image
    img_rot = cv2.warpAffine(img, M, (width, height))

    # now rotated rectangle becomes vertical, and we crop it
    img_crop = cv2.getRectSubPix(img_rot, size, center)

    return img_crop, img_rot

# %%
def ocr(img, oem=3, psm=6):
    """
    @param img: The image to be OCR'd
    @param oem: for specifying the type of Tesseract engine( default=1 for LSTM OCR Engine)
    """
    config = ('-l eng --oem {oem} --psm {psm}'.format(oem=oem,psm=psm))
    # config = ('-l eng --tessdata-dir "/usr/share/tesseract-ocr/tessdata" --oem {oem} -- psm {psm}'.format(oem=oem,psm=psm))

    try:
#         img = Image.fromarray(img)
        text = pytesseract.image_to_string(img, config=config)

        return text
    except:
        
        return ""

# %%
def ocr_metrics(predicts, ground_truth, norm_accentuation=False, norm_punctuation=False):
    """Calculate Character Error Rate (CER), Word Error Rate (WER) and Sequence Error Rate (SER)"""
    
    import string
    import unicodedata
    import editdistance

    if len(predicts) == 0 or len(ground_truth) == 0:
        return (1, 1, 1)

    cer, wer, ser = [], [], []

    for (pd, gt) in zip(predicts, ground_truth):

        if norm_accentuation:
            pd = unicodedata.normalize("NFKD", pd).encode("ASCII", "ignore").decode("ASCII")
            gt = unicodedata.normalize("NFKD", gt).encode("ASCII", "ignore").decode("ASCII")

        if norm_punctuation:
            pd = pd.translate(str.maketrans("", "", string.punctuation))
            gt = gt.translate(str.maketrans("", "", string.punctuation))

        pd_cer, gt_cer = list(pd.lower()), list(gt.lower())
        dist = editdistance.eval(pd_cer, gt_cer)
        cer.append(dist / (max(len(pd_cer), len(gt_cer))))

        pd_wer, gt_wer = pd.lower().split(), gt.lower().split()
        dist = editdistance.eval(pd_wer, gt_wer)
        wer.append(dist / (max(len(pd_wer), len(gt_wer))))

        pd_ser, gt_ser = [pd], [gt]
        dist = editdistance.eval(pd_ser, gt_ser)
        ser.append(dist / (max(len(pd_ser), len(gt_ser))))

    cer_f = sum(cer) / len(cer)
    wer_f = sum(wer) / len(wer)
    ser_f = sum(ser) / len(ser)
    
    evaluate = (cer_f, wer_f, ser_f)
    
    e_corpus = "\n".join([
    "Metrics:",
    "Character Error Rate: {}".format(evaluate[0]),
    "Word Error Rate:      {}".format(evaluate[1]),
    "Sequence Error Rate:  {}".format(evaluate[2]),
    ])

    return print(e_corpus)

# %%
def clean_string(string):
    pattern = "[\|\*\_\'\{}&]".format('"')
    regex = re.compile('\\\S*')
    text = re.sub(pattern, "", string)
    text = re.sub(",, ", ", ", text)
    text = re.sub(regex, " ", text)
    text = text.split(':')[1]
#     text = text.split('.')[0]
    text = text.strip()
#     split = [x.strip(' ').lower() for x in text.split(',')]

    return text

def string_to_list(text):
    pattern = "[\|\*\_\'\{}]".format('"')
    text = re.sub(pattern, "", text)
    text = text.replace('Aqua/Water/Eau', 'Aqua')
#     split = [x.strip(' ').lower() for x in text.split([\\.,]\\s)split('.')]
    split = [x.strip(' ').lower().replace('aqua/water/eau', 'aqua') for x in re.split("[,.]", text)]
    return split

# %%
# def check_for_label(text, words):
#     text = text.lower()
#     for i in range(len(text)):
#         if any(text[i:].startswith(word) for word in words):
#             return True
#     return False

# def clean_string(string):
#     pattern = "[\|\*\_\'\{}]".format('"')
#     text = re.sub(pattern, "", string)
#     text = re.sub(" I ", " / ", text)
#     text = re.sub("^I ", "", text)
#     text = re.sub("Omg", "0mg", text)
#     text = re.sub("Og", "0g", text)
#     text = re.sub('(?<=\d) (?=\w)', '', text)
#     text = change_to_g(text)
#     text = text.strip()
#     return text

# %%
def create_dict(ingredient_df, col_name):
    '''Generating rating_dict and category_dict
        ingredient_df: dataframe of the whole ingredient database
        col_name: name of column I want to generate (rating/category)
    '''
    col_dict = {name.strip(): row[col_name] for (idx, row) in ingredient_df.iterrows() for name in row['Ingredient_name'].split('/')} # .split('/')

    return col_dict

# %%
def find_matching_ingredient(my_ingredients, rating_dict, category_dict, thresh=0.25):
    ''' my_ingredients: list of product's ingredients
        Loop thru each ingredient in the ingredient list of the products
        then check if that ingredient appears in our ingredient list
        Calculate match_metric using SequenceMatcher and return the highest score and the best match
        Compare the match_metric with thresh > append to match_dict
    '''
    match_dict = {}
    for ingredient in tqdm(my_ingredients):
        if ingredient in match_dict.keys():
            continue
        match_metric = {key: SequenceMatcher(None, key, ingredient).ratio() for key in rating_dict.keys()}
        best_match, best_metric = max(match_metric.items(), key=operator.itemgetter(1)) # What is operator.itemgetter(1)
        if best_metric > thresh:
            match_dict[ingredient] = best_match
        else:
            match_dict[ingredient] = 'unknown'
    return match_dict

# %%
def lookup(ingredient_list, match_dict, rating_dict, rating_score_dict, irritancy_dict, 
           comedogenicity_dict, functions_dict, quick_facts_dict, details_dict, option=''):
    res = []
    for item in ingredient_list:
        key = match_dict.get(item, 'unknown')
        rating = rating_dict.get(key, 'unknown')
        rating_score = rating_score_dict.get(key, 'unknown')
        irritancy = irritancy_dict.get(key, 'unknown')
        comedogenicity = comedogenicity_dict.get(key, 'unknown')
        functions = functions_dict.get(key, [])
        quick_facts = quick_facts_dict.get(key, [])
        details = details_dict.get(key, [])

        if option == 'ingredient':
            res.append(key)
        elif option == 'rating':
            res.append(rating)
        elif option == 'rating_score':
            res.append(rating_score)   
        elif option == 'irritancy':
            res.append(irritancy)
        elif option == 'comedogenicity':
            res.append(comedogenicity) 
        elif option == 'functions':
            res.append(functions) 
        elif option == 'quick_facts':
            res.append(quick_facts)          
        elif option == 'details':
            res.append(details)
        else:
            res.extend([[key, rating, rating_score, irritancy, comedogenicity, functions, quick_facts, details]])

    return res

# %% [markdown]
# ## **Testing: English**

# %%
sample = cv2.imread('Sample_images/from_hien.jpg')
cv2.imshow('testing', sample)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = preprocess_for_ocr(sample, enhance=2)
cv2.imshow('testing', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Get bounding boxes which is result from CTPN
boxes = get_bounding_box('text-detection-ctpn/data/res/from_hien.txt')

# %%
boxes
# Out:
# [[77, 6, 995, 21, 995, 63, 76, 48],
#  [77, 45, 899, 60, 899, 100, 76, 85],
#  [77, 85, 1107, 102, 1107, 142, 76, 125],
#  [77, 124, 1123, 141, 1123, 181, 76, 164],
#  [77, 162, 739, 174, 739, 215, 76, 203],
#  [77, 202, 563, 210, 563, 249, 76, 241],
#  [77, 239, 611, 250, 611, 291, 76, 280],
#  [828, 273, 1027, 270, 1027, 342, 829, 344],
#  [77, 279, 691, 289, 691, 330, 76, 320],
#  [77, 316, 691, 329, 691, 370, 76, 357],
#  [77, 354, 547, 366, 547, 408, 76, 396],
#  [77, 392, 547, 403, 547, 444, 76, 434],
#  [77, 431, 675, 446, 675, 488, 76, 473],
#  [1012, 438, 1091, 429, 1099, 504, 1021, 513],
#  [77, 469, 643, 483, 643, 525, 76, 511]]

# %%
# Preprocess again before feeding into tesseract
img_ocr = preprocess_for_ocr(img)
cv2.imshow('testing', img_ocr)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Crop by bouding box > tesseract > result
text = ''
for box in tqdm(boxes):
    croped = crop_line('Sample_images/from_hien.jpg', box)
    string = ocr(croped)
    text = text + ', ' + str(string.strip('\n').strip('\x0c').strip())
# Out:
# 100%|██████████| 15/15 [00:05<00:00,  2.61it/s]

# %%
text
# Out:
# ', 20215024V01 - INGREDIENTS: AQUA/WATER/EAU, GLYCERIN,, PARAFFINUM LIQUIDUM/MINERAL OIL/HUILE MINERALE,, TRIETHANOLAMINE SALICYLIC ACID, GLYCERYL STEARATE, AMMONIUM, LACTATE, PEG-100 STEARATE, CETEARYL ALCOHOL, CETYL ALCOHOL, ZEA, MAYS OIL/CORN OIL, CERAMIDE NP, CERAMIDE, AP, CERAMIDE EOP, CARBOMER, BEHENTRIMONIUM METHOSULFATE, ee\nPas Oe, DIMETHICONE, METHYLPARABEN, SODIUM, LAUROYL LACTYLATE, CHOLECALCIFEROL,, CHOLESTEROL, DISODIUM EDTA,, PROPYLPARABEN. HYDROLYZED, HYALURONIC ACID. PHYTOSPHINGOSINE,, iu, XANTHAN GUM [CODE F.I.L. 0233015/1}'

# %%
string = clean_string(text)
ing_list = string_to_list(string)
ing_list
# Out:
# ['aqua',
#  'glycerin',
#  'paraffinum liquidum/mineral oil/huile minerale',
#  'triethanolamine salicylic acid',
#  'glyceryl stearate',
#  'ammonium',
#  'lactate',
#  'peg-100 stearate',
#  'cetearyl alcohol',
#  'cetyl alcohol',
#  'zea',
#  'mays oil/corn oil',
#  'ceramide np',
#  'ceramide',
#  'ap',
#  'ceramide eop',
#  'carbomer',
#  'behentrimonium methosulfate',
#  'ee\npas oe',
#  'dimethicone',
#  'methylparaben',
#  'sodium',
#  'lauroyl lactylate',
#  'cholecalciferol',
#  'cholesterol',
#  'disodium edta',
#  'propylparaben',
#  'hydrolyzed',
#  'hyaluronic acid',
#  'phytosphingosine',
#  'iu',
#  'xanthan gum [code f',
#  'i',
#  'l',
#  '0233015/1}']

# %%
# Import ingredient list
df_ingredient = pd.read_csv('Database/ingredient_inci_1570.csv')

# %%
df_ingredient.head()
# Out:
#         Ingredient_name                                               Link  \
# 0          Oubaku Ekisu  https://incidecoder.com/ingredients/phellodend...
# 1          Type of clay  https://incidecoder.com/ingredients/solum-full...
# 2            18:2 cis-9  https://incidecoder.com/ingredients/linoleic-acid
# 3   3-O-Ethyl Ascorbate  https://incidecoder.com/ingredients/ethyl-asco...
# 4                   ALA  https://incidecoder.com/ingredients/linolenic-...
#
#    Rating  Rating_score Irritancy Comedogenicity  \
# 0  goodie             2       NaN            NaN
# 1  goodie             2       NaN            NaN
# 2  goodie             2       NaN            NaN
# 3  goodie             2       NaN            NaN
# 4  goodie             2       NaN            NaN
#
#                                            Functions Quick_facts  \
# 0  {'soothing': '/ingredient-functions/soothing',...         NaN
# 1  {'viscosity controlling': '/ingredient-functio...         NaN
# 2  {'skin-identical ingredient': '/ingredient-fun...         NaN
# 3  {'antioxidant': '/ingredient-functions/antioxi...         NaN
# 4  {'skin-identical ingredient': '/ingredient-fun...         NaN
#
#                                              Details
# 0  ['A\xa0traditional East Asian medicine that ha...
# 1  ['Fuller\'s Earth describes types of clay\xa0t...
# 2  ['The famous\xa0omega-6 fatty acid,\xa0the mot...
# 3  ["A very stable and promising form of the skin...
# 4  ['The famous omega-3 fatty acid,\xa0the mother...

# %%
rating = create_dict(df_ingredient, 'Rating')
rating_score = create_dict(df_ingredient, 'Rating_score')
irritancy = create_dict(df_ingredient, 'Irritancy')
comedogenicity = create_dict(df_ingredient, 'Comedogenicity')
functions = create_dict(df_ingredient, 'Functions')
quick_facts = create_dict(df_ingredient, 'Quick_facts')
details = create_dict(df_ingredient, 'Details')

# %%
match_dict = find_matching_ingredient(ing_list, rating, functions)
# Out:
# 100%|██████████| 35/35 [00:02<00:00, 13.06it/s]

# %%
match_dict
# Out:
# {'aqua': 'Aqua',
#  'glycerin': 'Diglycerin',
#  'paraffinum liquidum/mineral oil/huile minerale': 'Paraffinum Liquidum',
#  'triethanolamine salicylic acid': 'Triethanolamine',
#  'glyceryl stearate': 'Glyceryl Stearate',
#  'ammonium': 'Ammonium Glycolate',
#  'lactate': 'Tea-Lactate',
#  'peg-100 stearate': 'PEG-100 Stearate',
#  'cetearyl alcohol': 'Cetearyl Alcohol',
#  'cetyl alcohol': 'Cetyl Alcohol',
#  'zea': 'Leaf',
#  'mays oil/corn oil': 'Castor Oil',
#  'ceramide np': 'Ceramide 1',
#  'ceramide': 'Ceramide 1',
#  'ap': 'Capric',
#  'ceramide eop': 'Ceramide 1',
#  'carbomer': 'Carbomer',
#  'behentrimonium methosulfate': 'Behentrimonium Methosulfate',
#  'ee\npas oe': 'Madecassoside',
#  'dimethicone': 'Dimethicone',
#  'methylparaben': 'Methylparaben',
#  'sodium': 'Disodium EDTA',
#  'lauroyl lactylate': 'Sodium Lauroyl Lactylate',
#  'cholecalciferol': 'Cholesterol',
#  'cholesterol': 'Cholesterol',
#  'disodium edta': 'Disodium EDTA',
#  'propylparaben': 'Propylparaben',
#  'hydrolyzed': 'Hydrolyzed Collagen',
#  'hyaluronic acid': 'Hyaluronic Acid',
#  'phytosphingosine': 'Phytosphingosine',
#  'iu': 'Hdi',
#  'xanthan gum [code f': 'Xanthan Gum',
#  'i': 'Hdi',
#  'l': 'Mel',
#  '0233015/1}': 'Al2O3'}

# %%
ing_analysize = lookup(ing_list, match_dict, rating, rating_score, irritancy, comedogenicity, functions, quick_facts, details)

# %%
ing_analysize
# Out:
# [['Aqua',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'solvent': '/ingredient-functions/solvent'}",
#   nan,
#   "['Good old water, aka H2O. The most common skincare ingredient of all. You can usually find it right in the very first spot of the ingredient list, meaning it’s the biggest thing out of all the stuff that makes up the product.', 'It’s mainly a solvent for ingredients that do not like to dissolve in oils but rather in water.', 'Once inside the skin, it hydrates, but not from the outside - putting pure water on the skin (hello long baths!) is drying.', 'One more thing: the water used in cosmetics is purified and deionized (it means that almost all of the mineral ions inside it is removed). Like this, the products can stay more stable over time.']"],
#  ['Diglycerin',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient', 'moisturizer/humectant': '/ingredient-functions/moisturizer-humectant'}",
#   nan,
#   '["The big brother of glycerin. It\'s also a natural moisturizing factor that reduces water evaporation from the upper layer of the skin and helps to keep water in the skin so that it stays nicely hydrated.", \'Compared to glycerin, it has a larger molecular structure (kind of a double glycerin). Thanks to this, it penetrates slower into the skin\\xa0but gives longer lasting moisture\\xa0and less sticky, better skin-feel.\']'],
#  ['Paraffinum Liquidum',
#   'No rating',
#   -1,
#   '0',
#   '0-2',
#   "{'emollient': '/ingredient-functions/emollient', 'solvent': '/ingredient-functions/solvent'}",
#   nan,
#   '[\'The famous or maybe rather infamous mineral oil. The clear oily liquid that is the "cheap by-product" of refining crude oil and the one that gets a lot of heat for its poor provenance. It is a very controversial ingredient with pros and cons and plenty of myths\\xa0around it. So let us see them:\', \'The pros of mineral oil\\rTrust us, if something is used for more than 100 years in cosmetic\\xa0products, it has\\xa0advantages. Chemically speaking, cosmetic grade mineral oil is a complex mixture of\\xa0highly refined saturated hydrocarbons with C15-50 chain length.\\xa0It is not merely a "by-product" but rather a specifically isolated part of petroleum that is very pure and inert.\', \'It is a great emollient and moisturizer working mainly by occlusivity.\\xa0Occlusivity is one of the basic mechanisms of how moisturizers work and it means that mineral oil\\xa0sits on top of the skin and hinders so-called trans-epidermal water loss, i.e water evaporating out of your skin. When compared to heavy-duty plant oil, extra virgin coconut oil, the two of them were equally efficient and safe as moisturizers in treating xerosis, a skin condition connected to very dry skin.\', \'The other thing that mineral oil is really good at is being non-irritating to the skin. The chemical composition of plant oils is more complex with many more possible allergens or irritating\\xa0components, while mineral oil is simple, pure\\xa0and sensitivity to it is extremely rare.\\xa0If you check out the classic French pharmacy brands and their moisturizers for the most sensitive, allergy prone skin, they usually contain\\xa0mineral oil. This is no coincidence.\', \'The cons of mineral oil\\rThe pros of mineral oil\\xa0can be interpreted as cons if we look at them from another perspective. Not penetrating the skin but mostly just sitting on top of it and not containing biologically active components, like nice fatty acids and vitamins mean\\xa0that mineral oil does not "nourish" the skin in the way plant oils do. Mineral oil does\\xa0not give the skin any extra goodness, it is simply a non-irritating moisturizer working mainly by occlusivity.\', \'The myths around mineral oil\\rBadmouthing mineral oil is a favorite sport of many, it is a cheap material and being connected to petrolatum makes it fairly easy to demonize.\', \'While it is true that industrial grade mineral oil contains carcinogenic components (so-called\\xa0polycyclic compounds), these are completely removed from cosmetic and food grade mineral oil and there is no scientific data showing that the pure, cosmetic grade version is carcinogenic.\', \'What is more, in terms of the general health effects of mineral oils used in cosmetics, a 2017\\xa0study reviewed the data on their skin penetration and concluded that "the cosmetic use of mineral oils and waxes does not present a risk to consumers due to a lack of systemic exposure."\', \'Another super common myth surrounding mineral oil is that it is comedogenic. A 2005 study titled\\xa0"Is mineral oil comedogenic?" examined this very question and guess what happened? The study concluded that\\xa0 "based on the animal and human data reported, along with the AAD recommendation, it would appear reasonable to conclude that mineral oil is noncomedogenic in humans."\', \'Overall, we feel that the scaremongering around mineral oil is not justified. For dry and super-sensitive skin types it is a great option. However, if you do not like its origin or its heavy feeling or anything else about it, avoiding it has never been easier. Mineral oil has such a bad reputation nowadays that cosmetic companies hardly dare to use it anymore.\']'],
#  ['Triethanolamine',
#   'No rating',
#   -1,
#   '0',
#   '2',
#   "{'buffering': '/ingredient-functions/buffering'}",
#   nan,
#   "['It’s a little helper ingredient that helps to set the pH of a cosmetic formulation to be just right. It’s very alkaline (you know the opposite of being very acidic): a 1% solution has a pH of around 10.', 'It does not have the very best safety reputation but in general, you do not have to worry about it.', 'What is true is that if a product contains so-called N-nitrogenating agents (e.g.: preservatives like 2-Bromo-2-Nitropropane-1,3-Diol, 5-Bromo-5-Nitro- 1,3-Dioxane or sodium nitrate - so look out for things with nitro, nitra in the name) that together with TEA can form some not nice carcinogenic stuff (that is called nitrosamines). But with proper formulation that does not happen, TEA in itself is not a bad guy.', 'But let’s assume a bad combination of ingredients were used and the nitrosamines formed. :( Even in that case you are probably fine because as far as we know it cannot penetrate the skin.', 'But to be on the safe side, if you see Triethanolamine in an INCI and also something with nitra, nitro in the name of it just skip the product, that cannot hurt.']"],
#  ['Glyceryl Stearate',
#   'No rating',
#   -1,
#   '0',
#   '2020-01-02 00:00:00',
#   "{'emollient': '/ingredient-functions/emollient', 'emulsifying': '/ingredient-functions/emulsifying'}",
#   nan,
#   '[\'A super common, waxy, white, solid stuff that helps water and oil to mix together, gives body to creams and leaves the skin feeling soft and smooth.\', \'Chemically speaking, it is the attachment of a glycerin molecule to the fatty acid called\\xa0stearic acid. It can be produced from most vegetable oils (in oils three fatty\\xa0acid\\xa0molecules are attached to glycerin instead of just one like here) in a pretty simple, "green" process that is similar to soap making. It\\\'s readily biodegradable.\', \'It also occurs naturally in our body and is used as a food additive. As cosmetic chemist\\xa0Colins writes it, "its safety really is beyond any doubt".\']'],
#  ['Ammonium Glycolate',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'buffering': '/ingredient-functions/buffering'}",
#   nan,
#   "['A synthetic form of famous \\xa0AHA, glycolic acid. Usually used as a pH adjuster to make sure the product has the right pH (usually pH 3-4) for exfoliation to do its magic.']"],
#  ['Tea-Lactate',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'moisturizer/humectant': '/ingredient-functions/moisturizer-humectant'}",
#   nan,
#   "['The salt form of lactic acid. It works as a moisturizer in skin care products.']"],
#  ['PEG-100 Stearate',
#   'No rating',
#   -1,
#   '0',
#   '0',
#   "{'surfactant/cleansing': '/ingredient-functions/surfactant-cleansing', 'emulsifying': '/ingredient-functions/emulsifying'}",
#   nan,
#   '[\'A very common water-loving surfactant and emulsifier that helps to keep water and oil mixed nicely\\xa0together.\', \'It\\\'s often paired with glyceryl stearate\\xa0- the two\\xa0together form\\xa0a super effective emulsifier duo that\\\'s salt and acid tolerant and works over a wide pH range. It also gives a "pleasing product aesthetics", so no wonder it\\\'s popular.\']'],
#  ['Cetearyl Alcohol',
#   'No rating',
#   -1,
#   '1',
#   '2',
#   "{'emollient': '/ingredient-functions/emollient', 'viscosity controlling': '/ingredient-functions/viscosity-controlling', 'emulsifying': '/ingredient-functions/emulsifying', 'surfactant/cleansing': '/ingredient-functions/surfactant-cleansing', 'emulsion stabilising': '/ingredient-functions/emulsion-stabilising'}",
#   nan,
#   "['An extremely common multitasker ingredient that gives your skin a nice soft feel (emollient) and gives body to creams and lotions. It also helps to stabilize oil-water mixes (emulsions), though it does not function as an emulsifier in itself. Its typical use level in most cream type formulas is 2-3%.', 'It’s a so-called fatty alcohol, a mix of cetyl and stearyl alcohol, other two emollient fatty alcohols. \\xa0Though chemically speaking, it is alcohol (as in, it has an -OH group in its molecule), its properties are totally different from the properties of low molecular weight or drying alcohols such as denat. alcohol. Fatty alcohols have a long oil-soluble (and thus emollient) tail\\xa0part that makes them absolutely\\xa0non-drying and non-irritating and are totally ok for the skin.']"],
#  ['Cetyl Alcohol',
#   'No rating',
#   -1,
#   '2',
#   '2',
#   "{'emollient': '/ingredient-functions/emollient', 'emulsifying': '/ingredient-functions/emulsifying', 'viscosity controlling': '/ingredient-functions/viscosity-controlling', 'surfactant/cleansing': '/ingredient-functions/surfactant-cleansing', 'emulsion stabilising': '/ingredient-functions/emulsion-stabilising'}",
#   nan,
#   "['A so-called\\xa0fatty (the good, non-drying kind of)\\xa0alcohol that does all kinds of things in a skincare product: it makes your skin feel smooth and nice (emollient), helps to thicken up products and also helps water and oil to blend (emulsifier). Can be derived from coconut or palm kernel oil.']"],
#  ['Leaf',
#   'icky',
#   0,
#   nan,
#   nan,
#   "{'perfuming': '/ingredient-functions/perfuming', 'moisturizer/humectant': '/ingredient-functions/moisturizer-humectant'}",
#   nan,
#   "['Read more about lavender essential oil in cosmetics here >>']"],
#  ['Castor Oil',
#   'No rating',
#   -1,
#   '0',
#   '0-1',
#   "{'emollient': '/ingredient-functions/emollient', 'perfuming': '/ingredient-functions/perfuming'}",
#   nan,
#   "['Castor oil is sourced from the castor bean plant native to tropical areas in Eastern Africa and the Mediterranean Basin. It is an age-old ingredient (it’s over 4,000 years old!) with many uses including as a shoe polish, food additive and motor lubricant. You would be reasonable to think that putting shoe polish on your face wouldn’t be the best idea, but it turns out castor oil has some unique properties that make it a stalwart in thick and gloss-giving formulas (think lipsticks and highlighters).', 'So what is so special about it? The answer is its main fatty acid, called ricinoleic acid (85-95%). \\xa0Unlike other fatty acids, ricinoleic acid has an extra water-loving part (aka -OH group) on its fatty chain that gives Castor Oil several unique properties. First, it is thicker than other oils, then its solubility is different (e.g. dissolves in alcohol but not in mineral oil), and it allows all kinds\\xa0of chemical modifications\\xa0other oils do not, hence the lots of\\xa0Castor oil-derived ingredients. It is also\\xa0more glossy than other oils, in fact,\\xa0it\\xa0creates the highest gloss of all natural oils when applied to the skin. Other than that, it is a very effective emollient and occlusive that reduces skin moisture loss so it is quite common in smaller amounts in moisturizers.', 'While it is very unlikely (and this is true for pretty much every ingredient), cases of reactions to castor oil have been reported, so if your skin is sensitive, it never hurts to patch test.']"],
#  ['Ceramide 1',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient'}",
#   nan,
#   '["Ceramides get quite a lot of hype recently and good news: there is a reason for that. But before we go into the details, let\'s just quickly define what the heck ceramides are:", \'They are waxy lipids that can be found naturally in the outer layer of the skin (called stratum corneum - SC). And they are there in big amounts! The goopy stuff between our skin cells is called extracellular matrix that consists mainly of lipids. And ceramides are about 50% of those lipids (the other important ones are cholesterol with 25% and fatty acids with 15%).\', \'Ok, so now we know what ceramides are, let\\\'s see what they do in our skin: research shows clearly that they play a super important role in keeping the skin barrier healthy and the skin hydrated. If ceramides in the skin are decreased, more water can evaporate from the skin and there is less water remaining in the skin. So ceramides form kind of a "water-proof" protecting layer\\xa0and make sure that our skin remains nice and hydrated.\', \'Now the question is only this: If we put ceramides all over our face do they\\xa0work as well as ceramides already naturally in our skin? Well, the answer is probably a no, but they do work to some extent. The BeautyBrains blog made a fantastic article about ceramides and they have listed a couple of examples about studies showing that ceramides - especially when used in certain ratios with cholesterol and fatty acids \\xa0- do hydrate the skin and can help to repair the skin barrier.\', "So far we were writing about ceramides in plural. It\'s because there are lots of different ceramides, a 2014\\xa0article writes that currently 12 base classes of ceramides are known with over 340 specific species.\\xa0Chemically speaking, ceramides are the connection of a fatty acid and a sphingoid base and both parts can have different variations that result in the different types of ceramides.", \'Our current one, Ceramide 1, or more\\xa0recently called Ceramide\\xa0EOP, was the first one that was identified in 1982 and it\\\'s a special snowflake. It contains the essential fatty acid, linoleic acid and has a unique structure. It\\\'s believed that ceramide 1 plays a "binding role" in the lipid layers of the extracellular matrix. Along with ceramides 4 and 7, they also play a vital role in epidermal integrity and serve as the main storage areas for linoleic acid (a fatty acid that\\\'s also\\xa0very important for barrier repair).\', \'Oh, and one more thing: alkaline pH inhibits enzymes that help ceramide synthesis in our skin. So if you use a soap and you notice your skin is becoming dry, now you know why.\']'],
#  ['Ceramide 1',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient'}",
#   nan,
#   '["Ceramides get quite a lot of hype recently and good news: there is a reason for that. But before we go into the details, let\'s just quickly define what the heck ceramides are:", \'They are waxy lipids that can be found naturally in the outer layer of the skin (called stratum corneum - SC). And they are there in big amounts! The goopy stuff between our skin cells is called extracellular matrix that consists mainly of lipids. And ceramides are about 50% of those lipids (the other important ones are cholesterol with 25% and fatty acids with 15%).\', \'Ok, so now we know what ceramides are, let\\\'s see what they do in our skin: research shows clearly that they play a super important role in keeping the skin barrier healthy and the skin hydrated. If ceramides in the skin are decreased, more water can evaporate from the skin and there is less water remaining in the skin. So ceramides form kind of a "water-proof" protecting layer\\xa0and make sure that our skin remains nice and hydrated.\', \'Now the question is only this: If we put ceramides all over our face do they\\xa0work as well as ceramides already naturally in our skin? Well, the answer is probably a no, but they do work to some extent. The BeautyBrains blog made a fantastic article about ceramides and they have listed a couple of examples about studies showing that ceramides - especially when used in certain ratios with cholesterol and fatty acids \\xa0- do hydrate the skin and can help to repair the skin barrier.\', "So far we were writing about ceramides in plural. It\'s because there are lots of different ceramides, a 2014\\xa0article writes that currently 12 base classes of ceramides are known with over 340 specific species.\\xa0Chemically speaking, ceramides are the connection of a fatty acid and a sphingoid base and both parts can have different variations that result in the different types of ceramides.", \'Our current one, Ceramide 1, or more\\xa0recently called Ceramide\\xa0EOP, was the first one that was identified in 1982 and it\\\'s a special snowflake. It contains the essential fatty acid, linoleic acid and has a unique structure. It\\\'s believed that ceramide 1 plays a "binding role" in the lipid layers of the extracellular matrix. Along with ceramides 4 and 7, they also play a vital role in epidermal integrity and serve as the main storage areas for linoleic acid (a fatty acid that\\\'s also\\xa0very important for barrier repair).\', \'Oh, and one more thing: alkaline pH inhibits enzymes that help ceramide synthesis in our skin. So if you use a soap and you notice your skin is becoming dry, now you know why.\']'],
#  ['Capric',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'emollient': '/ingredient-functions/emollient'}",
#   nan,
#   '["A vegetable origin emollient that has a similar consistency to lard (solid at room temperature) but melts rapidly upon contact with the skin. \\xa0It\'s claimed to have great skin compatibility, penetrates easily, does not feel tacky or heavy on the skin and does not leave a greasy shine."]'],
#  ['Ceramide 1',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient'}",
#   nan,
#   '["Ceramides get quite a lot of hype recently and good news: there is a reason for that. But before we go into the details, let\'s just quickly define what the heck ceramides are:", \'They are waxy lipids that can be found naturally in the outer layer of the skin (called stratum corneum - SC). And they are there in big amounts! The goopy stuff between our skin cells is called extracellular matrix that consists mainly of lipids. And ceramides are about 50% of those lipids (the other important ones are cholesterol with 25% and fatty acids with 15%).\', \'Ok, so now we know what ceramides are, let\\\'s see what they do in our skin: research shows clearly that they play a super important role in keeping the skin barrier healthy and the skin hydrated. If ceramides in the skin are decreased, more water can evaporate from the skin and there is less water remaining in the skin. So ceramides form kind of a "water-proof" protecting layer\\xa0and make sure that our skin remains nice and hydrated.\', \'Now the question is only this: If we put ceramides all over our face do they\\xa0work as well as ceramides already naturally in our skin? Well, the answer is probably a no, but they do work to some extent. The BeautyBrains blog made a fantastic article about ceramides and they have listed a couple of examples about studies showing that ceramides - especially when used in certain ratios with cholesterol and fatty acids \\xa0- do hydrate the skin and can help to repair the skin barrier.\', "So far we were writing about ceramides in plural. It\'s because there are lots of different ceramides, a 2014\\xa0article writes that currently 12 base classes of ceramides are known with over 340 specific species.\\xa0Chemically speaking, ceramides are the connection of a fatty acid and a sphingoid base and both parts can have different variations that result in the different types of ceramides.", \'Our current one, Ceramide 1, or more\\xa0recently called Ceramide\\xa0EOP, was the first one that was identified in 1982 and it\\\'s a special snowflake. It contains the essential fatty acid, linoleic acid and has a unique structure. It\\\'s believed that ceramide 1 plays a "binding role" in the lipid layers of the extracellular matrix. Along with ceramides 4 and 7, they also play a vital role in epidermal integrity and serve as the main storage areas for linoleic acid (a fatty acid that\\\'s also\\xa0very important for barrier repair).\', \'Oh, and one more thing: alkaline pH inhibits enzymes that help ceramide synthesis in our skin. So if you use a soap and you notice your skin is becoming dry, now you know why.\']'],
#  ['Carbomer',
#   'No rating',
#   -1,
#   '0',
#   '1',
#   "{'viscosity controlling': '/ingredient-functions/viscosity-controlling', 'emulsion stabilising': '/ingredient-functions/emulsion-stabilising'}",
#   nan,
#   "['A big molecule created from repeated subunits (a polymer of acrylic acid) that magically converts a liquid\\xa0into a nice gel formula.\\xa0 It usually has to be neutralized with a base (such as sodium hydroxide) for the thickening to occur and it creates viscous, clear gels that also feel nice and non-tacky on the skin. No wonder, it is a very popular and common ingredient.']"],
#  ['Behentrimonium Methosulfate',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'surfactant/cleansing': '/ingredient-functions/surfactant-cleansing'}",
#   nan,
#   '["In itself, it\'s an antistatic (stops your hair from flying around because of electricity), hair conditioning and softening ingredient used mainly in haircare products.", \'Coupled with\\xa0Cetearyl Alcohol, they form an easy to handle, super stable emulsifier duo that has\\xa0exceptional spreadability and gives a pleasant\\xa0final touch to the products.\']'],
#  ['Madecassoside',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'antioxidant': '/ingredient-functions/antioxidant', 'soothing': '/ingredient-functions/soothing'}",
#   nan,
#   '[\'One of the main biologically active components of the famous\\xa0medicinal plant, Centella Asiatica, aka Gotu Kola. It has pretty well established wound healing,\\xa0skin soothing and antioxidant activities.\', \'There is also a study by La Roche Posay (belongs to L\\\'Oreal) that examined the anti-aging effects of 5% Vitamin C combined with 0.1%\\xa0Madecassoside. They mention that " Madecassoside\\xa0is known to induce collagen expressionand ⁄ or to modulate inflammatory mediators thus might\\xa0 prevent and correct some signs of aging." The surprisingly\\xa0long, 6-month study observed "significant improvement of the clinical score for deep and superficial wrinkles, suppleness, firmness, roughness, and skin hydration", but Vitamin C in itself is already an anti-aging superstar, so it is hard to know how much\\xa0Madecassoside did.\', \'If you are into Gotu Kola, read more here >>\']'],
#  ['Dimethicone',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'viscosity controlling': '/ingredient-functions/viscosity-controlling'}",
#   nan,
#   "['A white, elastomeric silicone powder that gives a nice silky and powdery feel to the products. It also has some oil and sebum absorption\\xa0capabilities.']"],
#  ['Methylparaben',
#   'No rating',
#   -1,
#   '0',
#   '0',
#   "{'preservative': '/ingredient-functions/preservative'}",
#   nan,
#   '["The most common type of\\xa0feared-by-everyone-mostly-without-scientific-reason parabens. It\'s a cheap, effective and well-tolerated ingredient to make sure the cosmetic formula does not go wrong too soon.", \'Apart from the general controversy around parabens (we wrote about it more here), there is a 2006 in-vitro (made in the lab not on real people) research about methylparaben (MP) showing that when exposed to sunlight, MP treated skin cells suffered more harm than non-MP\\xa0treated skin cells. The study was not done with real people on real skin but still - using a good sunscreen next to MP containing products\\xa0is a good idea. (Well, in fact using a sunscreen is always a good idea. :))\']'],
#  ['Disodium EDTA',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'chelating': '/ingredient-functions/chelating', 'viscosity controlling': '/ingredient-functions/viscosity-controlling'}",
#   nan,
#   "['Super common little helper ingredient that\\xa0helps products to remain nice and stable for a longer time. It does so by neutralizing the metal ions in the formula (that usually get into there from water) that would otherwise cause some not so nice changes.']"],
#  ['Sodium Lauroyl Lactylate',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'emulsifying': '/ingredient-functions/emulsifying'}",
#   nan,
#   '["A helper ingredient that\'s used as a co-emulsifier (meaning next to other emulsifiers in the formula it helps water and oil to mix) and as a stabilization agent for foams. Also, has some antimicrobial activity so it can help to boost the effectiveness of the preservative system."]'],
#  ['Cholesterol',
#   'goodie',
#   2,
#   '0',
#   '0',
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient', 'emollient': '/ingredient-functions/emollient'}",
#   nan,
#   '["It\'s one of the important lipids that can be found naturally in the outer layer of the skin. About 25% of the goopy stuff between our skin cells consists of cholesterol. Together with ceramides and fatty acids, they play a vital role in having a healthy skin barrier and keeping the skin hydrated.", "Apart from being an important skin-identical ingredient, it\'s also an emollient and stabilizer."]'],
#  ['Cholesterol',
#   'goodie',
#   2,
#   '0',
#   '0',
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient', 'emollient': '/ingredient-functions/emollient'}",
#   nan,
#   '["It\'s one of the important lipids that can be found naturally in the outer layer of the skin. About 25% of the goopy stuff between our skin cells consists of cholesterol. Together with ceramides and fatty acids, they play a vital role in having a healthy skin barrier and keeping the skin hydrated.", "Apart from being an important skin-identical ingredient, it\'s also an emollient and stabilizer."]'],
#  ['Disodium EDTA',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'chelating': '/ingredient-functions/chelating', 'viscosity controlling': '/ingredient-functions/viscosity-controlling'}",
#   nan,
#   "['Super common little helper ingredient that\\xa0helps products to remain nice and stable for a longer time. It does so by neutralizing the metal ions in the formula (that usually get into there from water) that would otherwise cause some not so nice changes.']"],
#  ['Propylparaben',
#   'No rating',
#   -1,
#   '0',
#   '0',
#   "{'preservative': '/ingredient-functions/preservative', 'perfuming': '/ingredient-functions/perfuming'}",
#   nan,
#   '["A very common type of\\xa0feared-by-everyone-mostly-without-scientific-reason\\xa0parabens. It\'s a cheap, effective and well-tolerated ingredient to\\xa0make sure the cosmetic formula does not go wrong too soon."]'],
#  ['Hydrolyzed Collagen',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'emollient': '/ingredient-functions/emollient', 'moisturizer/humectant': '/ingredient-functions/moisturizer-humectant'}",
#   nan,
#   '[\'The chemically chopped up version of the big protein molecule, collagen. It is often derived from fish or bovine sources and works as a nice moisturizer and humectant that helps the skin to hold onto water.\', "To understand a bit more what\\xa0Hydrolyzed Collagen is, you have to know that proteins are large chains of amino acids connected with so-called peptide bonds. These bonds can be broken up when a water molecule is added and the resulting thing is a mix of shorter length amino acids, also called peptides. So\\xa0Hydrolyzed Collagen is not really collagen, it is rather an undefined and varying mix of largish peptides. Based on a manufacturer\'s data, the whole, soluble collagen has an average molecular weight of 300 000 Da, while this chopped up mixture\\xa0has an average MW of 12 000 Da (still pretty big).", \'The main thing of these largish peptides is to act as water-binding agents, and to\\xa0make the skin nice and smooth (aka emollient). Hydrolyzed Collagen\\xa0is also often used in cleansers as it can make harsh surfactants\\xa0milder and in hair conditioners as it improves the flexibility and manageability of hair.\', \'If you wanna know more about collagen in cosmetics, we have a shiny explanation about soluble collagen here >>\']'],
#  ['Hyaluronic Acid',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient', 'moisturizer/humectant': '/ingredient-functions/moisturizer-humectant'}",
#   "['It’s naturally in our skin and behaves there like a sponge                                                    It can bind up to 1000 times its own weight in water                                                    It is a big molecule from repeated subunits (polymer) so different molecular weight versions exist (unfortunately there is no way to determine MW from INCI list only)                                                    High-molecular-weight-HA (>500 kDa) is an excellent surface hydrator, skin protectant and can act as an osmotic pump helping water-soluble actives to penetrate deeper into the skin                                                    Low-molecular-weight-HA (< 500 kDa) can hydrate the skin somewhat deeper though it is still a big molecule and works mainly in the epidermis (outer layer of the skin)                                                    Low-molecular-weight-HA might also help the skin to repair itself by increasing its self-defense (~ 200kDa used in the study)                                                    Ultra-low-molecular-weight-HA (<50kDa) is a controversial ingredient and might work as a pro-inflammatory signal molecule                         .']",
#   '[\'Hyaluronic acid (HA) and its various forms are the current IT-moisturizers. So let’s see, what is hyaluronic acid and even more importantly what’s the big deal about it?\', \'HA is a nice big sugar molecule\\xa0from repeated subunits (polymer) that can be found naturally in our body. It’s the most dominant, and most important molecule in the liquidy stuff between our skin cells (the sciency name for it is the extracellular matrix or ECM). A 70 kg adult has about 15 g of HA in her body, and half of it is in the skin. Most of the skin HA is in the dermis (the deeper layer - about 0.5 mg/kg) but there is also some in the epidermis (the upper layer - about 0.1 mg/kg).\', \'Saying it’s a big molecule, doesn’t do it justice. By default, it’s a HUGE molecule. Its molecular weight can be up to 4 million Dalton (that is just the unit molecular weight is measured in). To compare, normal table sugar that you bake with has a molecular weight of 340 Dalton.\', \'Because HA is a polymer, its subunits can be repeated many times or just a few times and thus different molecular weight versions exist. There is not a super clear definition what counts as high molecular weight or low molecular weight, but it seems to be roughly like this:\', \'HMW-HA in the skin\\rFirst, you have to know that this is the version that can mostly be found in our skin. So what does it do?\', \'Think of it as a sponge.\\xa0HMW-HA has superstar water-binding abilities. It can bind 1000 times its own weight in water. Or to say it another way 1 gram of HA can bind up to 6 liters of water! That is a lot, and this makes HA pretty much the best water-binding ingredient we know today. It is really the sponge of our skin: it’s there in the outer layers\\xa0and helps our skin immensely to attract and retain its water content.\', "Not only that, but HA has lots of other\\xa0important biological functions. Apart from hydration, the skin-related functions include maintaining the skin\'s elasticity, reducing the skin\'s inflammatory response, regenerating the damaged skin barrier and plumping up water-loss related wrinkles. Essentially, helping the skin to look and feel healthy and young.", \'HMW-HA put on your face\\rAs for smearing\\xa0HMW-HA\\xa0all over our face,\\xa0you have to know that most probably it does not penetrate the skin. There is a lonely study from 1999 that thinks that HA can absorb into the skin through some active transport mechanism, however, we could not find anything to confirm this.\\xa0 What we could find is multiple expert opinions and newer studies that state\\xa0HMW-HA is a huge molecule that stays on top of the skin to give surface hydration and to form a protective barrier.\', \'Not only that, but it can also work as an "osmotic pump", meaning it can be a\\xa0penetration enhancer for water-soluble actives.\\xa0As the cosmetic chemist at Realize Beauty puts it, HA can be an "osmotic delivery system\\xa0that can push water-soluble actives deeper into the skin by forming a highly hydrated reservoir on the surface of the skin".\', \'LMW-HA in the skin\\rThe biological function of LMW-HA in the skin seems to be crazy complicated and different than that of HMW-HA. LMW-HA is mostly created when HMW-HA is chopped up into smaller pieces at sites of an injury and it is thought to be a\\xa0pro-inflammatory signal molecule that says "danger, danger, bring on some inflammation and repair yourself".\', "LMW-HA put on your face\\rBased on LMW-HA\'s biological role, the question is logical: is LMW-HA pro-inflammatory when we smear it on? Well, it is a good question and we do not have the surefire answer. Most evidence points so far to a no, at least when it comes to molecular weights in the 50kDa and up range.", \'First, LMW-HA is still a big-big molecule whose penetration is questionable. It might absorb a bit better than HMW-HA, but that still means working mostly in the epidermis, the uppermost layers of the skin.\', "Second, we found multiple studies show ...
#  ['Phytosphingosine',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'skin-identical ingredient': '/ingredient-functions/skin-identical-ingredient', 'cell-communicating ingredient': '/ingredient-functions/cell-communicating-ingredient', 'anti-acne': '/ingredient-functions/anti-acne', 'antimicrobial/antibacterial': '/ingredient-functions/antimicrobial-antibacterial'}",
#   nan,
#   '[\'It\\\'s a type of lipid, a so-called\\xa0sphingoid base that can be found naturally in the upper layer of the skin. It\\\'s found both in "free-form" and as part of famous skin lipids, ceramides.\', "There is emerging research about Phytosphingosine that shows that it has antimicrobial and cell-communicating properties and is considered part of the skin\'s natural defense system.", \'A 2007 study showed that\\xa0Phytosphingosine even works against\\xa0evil acne-causing bacteria,\\xa0Propionibacterium acnes and shows promise as a complementing active ingredient in treating acne-prone skin thanks to its anti-inflammatory and antimicrobial activities.\', \'A nice one to spot in the ingredient list. :)\']'],
#  ['Hdi',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   nan,
#   nan,
#   '["A handy\\xa0spherical powder that\'s often combined with fellow\\xa0spherical powder,\\xa0Polymethylsilsesquioxane to form a high-performing texturizing duo. The duo is claimed to provide excellent slip, fluidity and overall skin feel and gives soft focus and\\xa0wrinkle correction to the formula. It also has strong de-tackifying and anti-caking properties."]'],
#  ['Xanthan Gum',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'viscosity controlling': '/ingredient-functions/viscosity-controlling', 'emulsifying': '/ingredient-functions/emulsifying', 'surfactant/cleansing': '/ingredient-functions/surfactant-cleansing', 'emulsion stabilising': '/ingredient-functions/emulsion-stabilising'}",
#   nan,
#   '["It\'s one of the most commonly used thickeners and emulsion stabilizers. If the product is too runny, a little xanthan gum will make it more gel-like.\\xa0Used alone, it can make the formula sticky and it is a good team player so it is usually combined with other thickeners and so-called\\xa0rheology modifiers (helper ingredients that adjust the flow and thus the feel of the formula). The typical use level of Xantha Gum is below 1%, it is usually in the 0.1-0.5% range.", \'Btw, Xanthan gum is all natural, a chain of sugar molecules (polysaccharide) produced from individual sugar molecules (glucose and sucrose) via fermentation. It’s approved by Ecocert and also used in the food industry\\xa0(E415).\']'],
#  ['Hdi',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   nan,
#   nan,
#   '["A handy\\xa0spherical powder that\'s often combined with fellow\\xa0spherical powder,\\xa0Polymethylsilsesquioxane to form a high-performing texturizing duo. The duo is claimed to provide excellent slip, fluidity and overall skin feel and gives soft focus and\\xa0wrinkle correction to the formula. It also has strong de-tackifying and anti-caking properties."]'],
#  ['Mel',
#   'goodie',
#   2,
#   nan,
#   nan,
#   "{'soothing': '/ingredient-functions/soothing', 'moisturizer/humectant': '/ingredient-functions/moisturizer-humectant', 'antimicrobial/antibacterial': '/ingredient-functions/antimicrobial-antibacterial'}",
#   nan,
#   "['We all know honey as the sweet, gooey stuff that is lovely to sweeten a good cup of tea and we have good news about putting honey all over our skin. It is just as lovely on the skin as it is in the tea.', 'The great review article about honey in the Journal of Cosmetic Dermatology writes that it\\xa0is arguably the oldest skincare ingredient and evidence from around 4500 BC mentions honey in some eye cream recipes. Chemically speaking, it is a bee-derived, supersaturated sugar solution.\\xa0 About\\xa095%\\xa0of\\xa0honey\\xa0dry weight is sugar and the other 5% consists of a great number of other minor components including proteins, amino acids, vitamins, enzymes, and minerals.', 'This unique and complex chemical composition gives honey a bunch of nice skin care properties: it is very moisturizing, has soothing and antioxidant abilities as well as significant antibacterial and antifungal magic powers. There is also a lot of empirical evidence with emerging scientific backup that honey dressing promotes the healing of wounds and burns.', 'One tricky thing about honey though, is that it can have lots of different floral sources and different types of\\xa0honey\\xa0have a somewhat different composition and thus somewhat different properties. For example,\\xa0the darker the honey the richer it is in antioxidant phenolic compounds.\\xa0 Two special types of honey are\\xa0acacia and manuka. The former\\xa0is unique and popular because of its higher than usual fructose content that makes it more water-soluble and easier to stabilize in\\xa0cosmetic formulas. The latter comes from the Leptospermum Scoparium tree native to New Zeland and its special thing is its extra strong antibacterial power due to a unique component called methylglyoxal.', 'Overall, honey is a real skin-goodie in pretty much every shape and form, and it is a nice one to spot on the ingredient list.']"],
#  ['Al2O3',
#   'No rating',
#   -1,
#   nan,
#   nan,
#   "{'viscosity controlling': '/ingredient-functions/viscosity-controlling', 'abrasive/scrub': '/ingredient-functions/abrasive-scrub', 'absorbent/mattifier': '/ingredient-functions/absorbent-mattifier'}",
#   nan,
#   '["A multi-functional\\xa0helper ingredient that\'s used mainly as a pigment carrier.\\xa0 The pigment can be an inorganic sunscreen\\xa0(such as titanium dioxide) or a colorant that is blended with\\xa0alumina platelets and then often coated with some kind of silicone (such as triethoxycaprylylsilane). This special treatment enables pigments to be evenly dispersed in the formula\\xa0and to be spread out easily and evenly upon application. It is super useful both for mineral sunscreens as well as for makeup products.", \'Other than that, alumina can also be\\xa0used as an absorbent (sometimes combined with the mattifying powder called polymethylsilsesquioxane), a viscosity controlling or an opacifying (reduces the transparency of the formula) agent.\']']]

# %%
ingredient_analysing = pd.DataFrame(ing_analysize,columns=['Ingredient_name', 'Rating', 'Rating_score', 'Irritancy',
       'Comedogenicity', 'Functions', 'Quick_facts', 'Details'])

# %%
df_ingredient.columns.values
# Out:
# array(['Ingredient_name', 'Link', 'Rating', 'Rating_score', 'Irritancy',
#        'Comedogenicity', 'Functions', 'Quick_facts', 'Details'],
#       dtype=object)

# %%
ingredient_analysing
# Out:
#                 Ingredient_name     Rating  Rating_score Irritancy  \
# 0                          Aqua  No rating            -1       NaN
# 1                    Diglycerin     goodie             2       NaN
# 2           Paraffinum Liquidum  No rating            -1         0
# 3               Triethanolamine  No rating            -1         0
# 4             Glyceryl Stearate  No rating            -1         0
# 5            Ammonium Glycolate  No rating            -1       NaN
# 6                   Tea-Lactate  No rating            -1       NaN
# 7              PEG-100 Stearate  No rating            -1         0
# 8              Cetearyl Alcohol  No rating            -1         1
# 9                 Cetyl Alcohol  No rating            -1         2
# 10                         Leaf       icky             0       NaN
# 11                   Castor Oil  No rating            -1         0
# 12                   Ceramide 1     goodie             2       NaN
# 13                   Ceramide 1     goodie             2       NaN
# 14                       Capric  No rating            -1       NaN
# 15                   Ceramide 1     goodie             2       NaN
# 16                     Carbomer  No rating            -1         0
# 17  Behentrimonium Methosulfate  No rating            -1       NaN
# 18                Madecassoside     goodie             2       NaN
# 19                  Dimethicone  No rating            -1       NaN
# 20                Methylparaben  No rating            -1         0
# 21                Disodium EDTA  No rating            -1       NaN
# 22     Sodium Lauroyl Lactylate  No rating            -1       NaN
# 23                  Cholesterol     goodie             2         0
# 24                  Cholesterol     goodie             2         0
# 25                Disodium EDTA  No rating            -1       NaN
# 26                Propylparaben  No rating            -1         0
# 27          Hydrolyzed Collagen     goodie             2       NaN
# 28              Hyaluronic Acid     goodie             2       NaN
# 29             Phytosphingosine     goodie             2       NaN
# 30                          Hdi  No rating            -1       NaN
# 31                  Xanthan Gum  No rating            -1       NaN
# 32                          Hdi  No rating            -1       NaN
# 33                          Mel     goodie             2       NaN
# 34                        Al2O3  No rating            -1       NaN
#
#          Comedogenicity                                          Functions  \
# 0                   NaN       {'solvent': '/ingredient-functions/solvent'}
# 1                   NaN  {'skin-identical ingredient': '/ingredient-fun...
# 2                   0-2  {'emollient': '/ingredient-functions/emollient...
# 3                     2   {'buffering': '/ingredient-functions/buffering'}
# 4   2020-01-02 00:00:00  {'emollient': '/ingredient-functions/emollient...
# 5                   NaN   {'buffering': '/ingredient-functions/buffering'}
# 6                   NaN  {'moisturizer/humectant': '/ingredient-functio...
# 7                     0  {'surfactant/cleansing': '/ingredient-function...
# 8                     2  {'emollient': '/ingredient-functions/emollient...
# 9                     2  {'emollient': '/ingredient-functions/emollient...
# 10                  NaN  {'perfuming': '/ingredient-functions/perfuming...
# 11                  0-1  {'emollient': '/ingredient-functions/emollient...
# 12                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 13                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 14                  NaN   {'emollient': '/ingredient-functions/emollient'}
# 15                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 16                    1  {'viscosity controlling': '/ingredient-functio...
# 17                  NaN  {'surfactant/cleansing': '/ingredient-function...
# 18                  NaN  {'antioxidant': '/ingredient-functions/antioxi...
# 19                  NaN  {'viscosity controlling': '/ingredient-functio...
# 20                    0  {'preservative': '/ingredient-functions/preser...
# 21                  NaN  {'chelating': '/ingredient-functions/chelating...
# 22                  NaN  {'emulsifying': '/ingredient-functions/emulsif...
# 23                    0  {'skin-identical ingredient': '/ingredient-fun...
# 24                    0  {'skin-identical ingredient': '/ingredient-fun...
# 25                  NaN  {'chelating': '/ingredient-functions/chelating...
# 26                    0  {'preservative': '/ingredient-functions/preser...
# 27                  NaN  {'emollient': '/ingredient-functions/emollient...
# 28                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 29                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 30                  NaN                                                NaN
# 31                  NaN  {'viscosity controlling': '/ingredient-functio...
# 32                  NaN                                                NaN
# 33                  NaN  {'soothing': '/ingredient-functions/soothing',...
# 34                  NaN  {'viscosity controlling': '/ingredient-functio...
#
#                                           Quick_facts  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  ['It’s naturally in our skin and behaves there...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                               Details
# 0   ['Good old water, aka H2O. The most common ski...
# 1   ["The big brother of glycerin. It's also a nat...
# 2   ['The famous or maybe rather infamous mineral ...
# 3   ['It’s a little helper ingredient that helps t...
# 4   ['A super common, waxy, white, solid stuff tha...
# 5   ['A synthetic form of famous \xa0AHA, glycolic...
# 6   ['The salt form of lactic acid. It works as a ...
# 7   ['A very common water-loving surfactant and em...
# 8   ['An extremely common multitasker ingredient t...
# 9   ['A so-called\xa0fatty (the good, non-drying k...
# 10  ['Read more about lavender essential oil in co...
# 11  ['Castor oil is sourced from the castor bean p...
# 12  ["Ceramides get quite a lot of hype recently a...
# 13  ["Ceramides get quite a lot of hype recently a...
# 14  ["A vegetable origin emollient that has a simi...
# 15  ["Ceramides get quite a lot of hype recently a...
# 16  ['A big molecule created from repeated subunit...
# 17  ["In itself, it's an antistatic (stops your ha...
# 18  ['One of the main biologically active componen...
# 19  ['A white, elastomeric silicone powder that gi...
# 20  ["The most common type of\xa0feared-by-everyon...
# 21  ['Super common little helper ingredient that\x...
# 22  ["A helper ingredient that's used as a co-emul...
# 23  ["It's one of the important lipids that can be...
# 24  ["It's one of the important lipids that can be...
# 25  ['Super common little helper ingredient that\x...
# 26  ["A very common type of\xa0feared-by-everyone-...
# 27  ['The chemically chopped up version of the big...
# 28  ['Hyaluronic acid (HA) and its various forms a...
# 29  ['It\'s a type of lipid, a so-called\xa0sphing...
# 30  ["A handy\xa0spherical powder that's often com...
# 31  ["It's one of the most commonly used thickener...
# 32  ["A handy\xa0spherical powder that's often com...
# 33  ['We all know honey as the sweet, gooey stuff ...
# 34  ["A multi-functional\xa0helper ingredient that...

# %% [markdown]
# ## **End-to-end: using INCI in English**

# %%
def before_ctpn(img_path):
    img = cv2.imread(img_path)
    img_ctpn = preprocess_for_ocr(img, enhance=2)
    cv2.imwrite('./data/demo/img_ctpn.jpg', img_ctpn)
    
    return img_ctpn

# %%
import os
def run_ctpn():
    stream = os.popen('python ./main/demo.py')
    output = stream.read()
    return output

# %%
run_ctpn

# %%
def after_ctpn_inci(img_path, txt_path, ingredient_df_path):
    # Get annotations of bounding boxes
    boxes = get_bounding_box(txt_path)
    
    # Preprocess image for OCR:
    img = cv2.imread(img_path)
    img_ocr = preprocess_for_ocr(img)
    
    # doing OCR
    text = ''
    for box in tqdm(boxes):
        croped = crop_line(img_path, box)
        string = ocr(croped)
        text = text + ', ' + str(string.strip('\n').strip('\x0c').strip())
    
    # Cleaning result from OCR
    print(text)
    text_result = clean_string(text)
#     print(text_result)
    ing_list = string_to_list(text_result)
    
    # Loading ingredient dataframe
    df_ingredient = pd.read_csv(ingredient_df_path)
    
    # Create separated dict for constructing result df later
    rating = create_dict(df_ingredient, 'Rating')
    rating_score = create_dict(df_ingredient, 'Rating_score')
    irritancy = create_dict(df_ingredient, 'Irritancy')
    comedogenicity = create_dict(df_ingredient, 'Comedogenicity')
    functions = create_dict(df_ingredient, 'Functions')
    quick_facts = create_dict(df_ingredient, 'Quick_facts')
    details = create_dict(df_ingredient, 'Details')
    
    # Compare product ingredient list and database
    match_dict = find_matching_ingredient(ing_list, rating, functions)
    
    # Analyzing ingredient
    ing_analysize = lookup(ing_list, match_dict, rating, rating_score, irritancy, comedogenicity, functions, quick_facts, details)
    
    # Put everything into a dataframe
    df_res = pd.DataFrame(ing_analysize,columns=['Ingredient_name', 'Rating', 'Rating_score', 'Irritancy',
       'Comedogenicity', 'Functions', 'Quick_facts', 'Details'])
    
    return df_res

# %%
res = after_ctpn_inci('Sample_images/from_hien.jpg', 'text-detection-ctpn/data/res/from_hien.txt', 'Database/ingredient_inci_1570.csv')
# Out:
# 100%|██████████| 15/15 [00:05<00:00,  2.99it/s]
# , 20215024V01 - INGREDIENTS: AQUA/WATER/EAU, GLYCERIN,, PARAFFINUM LIQUIDUM/MINERAL OIL/HUILE MINERALE,, TRIETHANOLAMINE SALICYLIC ACID, GLYCERYL STEARATE, AMMONIUM, LACTATE, PEG-100 STEARATE, CETEARYL ALCOHOL, CETYL ALCOHOL, ZEA, MAYS OIL/CORN OIL, CERAMIDE NP, CERAMIDE, AP, CERAMIDE EOP, CARBOMER, BEHENTRIMONIUM METHOSULFATE, ee
# Pas Oe, DIMETHICONE, METHYLPARABEN, SODIUM, LAUROYL LACTYLATE, CHOLECALCIFEROL,, CHOLESTEROL, DISODIUM EDTA,, PROPYLPARABEN. HYDROLYZED, HYALURONIC ACID. PHYTOSPHINGOSINE,, iu, XANTHAN GUM [CODE F.I.L. 0233015/1}
# 100%|██████████| 35/35 [00:02<00:00, 13.80it/s]

# %%
res
# Out:
#                 Ingredient_name     Rating  Rating_score Irritancy  \
# 0                          Aqua  No rating            -1       NaN
# 1                    Diglycerin     goodie             2       NaN
# 2           Paraffinum Liquidum  No rating            -1         0
# 3               Triethanolamine  No rating            -1         0
# 4             Glyceryl Stearate  No rating            -1         0
# 5            Ammonium Glycolate  No rating            -1       NaN
# 6                   Tea-Lactate  No rating            -1       NaN
# 7              PEG-100 Stearate  No rating            -1         0
# 8              Cetearyl Alcohol  No rating            -1         1
# 9                 Cetyl Alcohol  No rating            -1         2
# 10                         Leaf       icky             0       NaN
# 11                   Castor Oil  No rating            -1         0
# 12                   Ceramide 1     goodie             2       NaN
# 13                   Ceramide 1     goodie             2       NaN
# 14                       Capric  No rating            -1       NaN
# 15                   Ceramide 1     goodie             2       NaN
# 16                     Carbomer  No rating            -1         0
# 17  Behentrimonium Methosulfate  No rating            -1       NaN
# 18                Madecassoside     goodie             2       NaN
# 19                  Dimethicone  No rating            -1       NaN
# 20                Methylparaben  No rating            -1         0
# 21                Disodium EDTA  No rating            -1       NaN
# 22     Sodium Lauroyl Lactylate  No rating            -1       NaN
# 23                  Cholesterol     goodie             2         0
# 24                  Cholesterol     goodie             2         0
# 25                Disodium EDTA  No rating            -1       NaN
# 26                Propylparaben  No rating            -1         0
# 27          Hydrolyzed Collagen     goodie             2       NaN
# 28              Hyaluronic Acid     goodie             2       NaN
# 29             Phytosphingosine     goodie             2       NaN
# 30                          Hdi  No rating            -1       NaN
# 31                  Xanthan Gum  No rating            -1       NaN
# 32                          Hdi  No rating            -1       NaN
# 33                          Mel     goodie             2       NaN
# 34                        Al2O3  No rating            -1       NaN
#
#          Comedogenicity                                          Functions  \
# 0                   NaN       {'solvent': '/ingredient-functions/solvent'}
# 1                   NaN  {'skin-identical ingredient': '/ingredient-fun...
# 2                   0-2  {'emollient': '/ingredient-functions/emollient...
# 3                     2   {'buffering': '/ingredient-functions/buffering'}
# 4   2020-01-02 00:00:00  {'emollient': '/ingredient-functions/emollient...
# 5                   NaN   {'buffering': '/ingredient-functions/buffering'}
# 6                   NaN  {'moisturizer/humectant': '/ingredient-functio...
# 7                     0  {'surfactant/cleansing': '/ingredient-function...
# 8                     2  {'emollient': '/ingredient-functions/emollient...
# 9                     2  {'emollient': '/ingredient-functions/emollient...
# 10                  NaN  {'perfuming': '/ingredient-functions/perfuming...
# 11                  0-1  {'emollient': '/ingredient-functions/emollient...
# 12                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 13                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 14                  NaN   {'emollient': '/ingredient-functions/emollient'}
# 15                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 16                    1  {'viscosity controlling': '/ingredient-functio...
# 17                  NaN  {'surfactant/cleansing': '/ingredient-function...
# 18                  NaN  {'antioxidant': '/ingredient-functions/antioxi...
# 19                  NaN  {'viscosity controlling': '/ingredient-functio...
# 20                    0  {'preservative': '/ingredient-functions/preser...
# 21                  NaN  {'chelating': '/ingredient-functions/chelating...
# 22                  NaN  {'emulsifying': '/ingredient-functions/emulsif...
# 23                    0  {'skin-identical ingredient': '/ingredient-fun...
# 24                    0  {'skin-identical ingredient': '/ingredient-fun...
# 25                  NaN  {'chelating': '/ingredient-functions/chelating...
# 26                    0  {'preservative': '/ingredient-functions/preser...
# 27                  NaN  {'emollient': '/ingredient-functions/emollient...
# 28                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 29                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 30                  NaN                                                NaN
# 31                  NaN  {'viscosity controlling': '/ingredient-functio...
# 32                  NaN                                                NaN
# 33                  NaN  {'soothing': '/ingredient-functions/soothing',...
# 34                  NaN  {'viscosity controlling': '/ingredient-functio...
#
#                                           Quick_facts  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  ['It’s naturally in our skin and behaves there...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                               Details
# 0   ['Good old water, aka H2O. The most common ski...
# 1   ["The big brother of glycerin. It's also a nat...
# 2   ['The famous or maybe rather infamous mineral ...
# 3   ['It’s a little helper ingredient that helps t...
# 4   ['A super common, waxy, white, solid stuff tha...
# 5   ['A synthetic form of famous \xa0AHA, glycolic...
# 6   ['The salt form of lactic acid. It works as a ...
# 7   ['A very common water-loving surfactant and em...
# 8   ['An extremely common multitasker ingredient t...
# 9   ['A so-called\xa0fatty (the good, non-drying k...
# 10  ['Read more about lavender essential oil in co...
# 11  ['Castor oil is sourced from the castor bean p...
# 12  ["Ceramides get quite a lot of hype recently a...
# 13  ["Ceramides get quite a lot of hype recently a...
# 14  ["A vegetable origin emollient that has a simi...
# 15  ["Ceramides get quite a lot of hype recently a...
# 16  ['A big molecule created from repeated subunit...
# 17  ["In itself, it's an antistatic (stops your ha...
# 18  ['One of the main biologically active componen...
# 19  ['A white, elastomeric silicone powder that gi...
# 20  ["The most common type of\xa0feared-by-everyon...
# 21  ['Super common little helper ingredient that\x...
# 22  ["A helper ingredient that's used as a co-emul...
# 23  ["It's one of the important lipids that can be...
# 24  ["It's one of the important lipids that can be...
# 25  ['Super common little helper ingredient that\x...
# 26  ["A very common type of\xa0feared-by-everyone-...
# 27  ['The chemically chopped up version of the big...
# 28  ['Hyaluronic acid (HA) and its various forms a...
# 29  ['It\'s a type of lipid, a so-called\xa0sphing...
# 30  ["A handy\xa0spherical powder that's often com...
# 31  ["It's one of the most commonly used thickener...
# 32  ["A handy\xa0spherical powder that's often com...
# 33  ['We all know honey as the sweet, gooey stuff ...
# 34  ["A multi-functional\xa0helper ingredient that...

# %%
res2 = after_ctpn_inci('text-detection-ctpn/data/demo/preprocessed.png', 'text-detection-ctpn/data/res/preprocessed.txt', 'Database/ingredient_inci_1570.csv')
# Out:
# , Hydrateert' de normale en gevoelige huld., FORMULE ZONDER SULFATEN* - DERMATOLOGISCH GETEST, Inarédlents : Aqua (Water), Lauryl Glucoside, Cocamidopropyi Betaine, Glycerin, Coco-Glucoside,, Glyceryl Oleate, Sodium Chloride, Benzyl Alcohol, Sodium Benzoale, Lactic Actd, Parfum, (Fragrance), Citric Acid, Aloe Barbadensis Leaf Juice Powder**, Benzyl salicylate, Hydrogenated, Palm Glycerides Citrate, Tocopherol, Sodium Hydroxide,, 1- Hydratation des couches supérieures de l’épiderme. / Hydration of the upper layers of the skin., Hydrotatie van de bovenste fagen van de opperhuid., * Sans tensioactif sulfaté. / Sulfate-free surfactant./ Zonder gesulfateerde opperviakteactieve stof., ** Inqrédients Issus de fagriculture biologique.
# 100%|██████████| 30/30 [00:02<00:00, 10.79it/s]

# %%
res2
# Out:
#                               Ingredient_name     Rating Rating_score  \
# 0                                    Squalane     goodie            2
# 1                            Lauryl Glucoside  No rating           -1
# 2                      Cocamidopropyl Betaine  No rating           -1
# 3                                  Diglycerin     goodie            2
# 4                              Coco-Glucoside  No rating           -1
# 5                             Glyceryl Oleate  No rating           -1
# 6                             Sodium Chloride  No rating           -1
# 7                              Benzyl Alcohol  No rating           -1
# 8                             Sodium Benzoate  No rating           -1
# 9                                 Lactic Acid  superstar            3
# 10                                     Parfum       icky            0
# 11                                  Fragrance       icky            0
# 12                                Citric Acid  No rating           -1
# 13         Aloe Barbadensis Leaf Juice Powder     goodie            2
# 14                          Benzyl Salicylate       icky            0
# 15                      Hydrogenated Lecithin     goodie            2
# 16                    Polyglyceryl-6 Stearate  No rating           -1
# 17                                 Tocopherol     goodie            2
# 18                           Sodium Hydroxide  No rating           -1
# 19             Carthamus Tinctorius Oleosomes     goodie            2
# 20  Liposomal Preparation of Apple Stem Cells  No rating           -1
# 21                                    unknown    unknown      unknown
# 22               Hydrogenated Coco-Glycerides  No rating           -1
# 23                                    unknown    unknown      unknown
# 24                          Magnesium Sulfate  No rating           -1
# 25                 Pulsatilla Koreana Extract  No rating           -1
# 26                 Hydrogenated Polyisobutene  No rating           -1
# 27                                    unknown    unknown      unknown
# 28           Lentinus Edodes Mycelium Extract     goodie            2
# 29                                    unknown    unknown      unknown
#
#    Irritancy Comedogenicity  \
# 0          0              1
# 1        NaN            NaN
# 2        NaN            NaN
# 3        NaN            NaN
# 4        NaN            NaN
# 5        NaN            NaN
# 6        NaN            NaN
# 7        NaN            NaN
# 8        NaN            NaN
# 9        NaN            NaN
# 10       NaN            NaN
# 11       NaN            NaN
# 12       NaN            NaN
# 13       NaN            NaN
# 14       NaN            NaN
# 15       NaN            NaN
# 16       NaN            NaN
# 17       0-3            0-3
# 18       NaN            NaN
# 19       NaN            NaN
# 20       NaN            NaN
# 21   unknown        unknown
# 22       NaN            NaN
# 23   unknown        unknown
# 24       NaN            NaN
# 25       NaN            NaN
# 26         2              1
# 27   unknown        unknown
# 28       NaN            NaN
# 29   unknown        unknown
#
#                                             Functions  \
# 0   {'skin-identical ingredient': '/ingredient-fun...
# 1   {'surfactant/cleansing': '/ingredient-function...
# 2   {'surfactant/cleansing': '/ingredient-function...
# 3   {'skin-identical ingredient': '/ingredient-fun...
# 4   {'surfactant/cleansing': '/ingredient-function...
# 5   {'emollient': '/ingredient-functions/emollient...
# 6   {'viscosity controlling': '/ingredient-functio...
# 7   {'preservative': '/ingredient-functions/preser...
# 8   {'preservative': '/ingredient-functions/preser...
# 9   {'exfoliant': '/ingredient-functions/exfoliant...
# 10   {'perfuming': '/ingredient-functions/perfuming'}
# 11   {'perfuming': '/ingredient-functions/perfuming'}
# 12   {'buffering': '/ingredient-functions/buffering'}
# 13  {'soothing': '/ingredient-functions/soothing',...
# 14   {'perfuming': '/ingredient-functions/perfuming'}
# 15  {'emollient': '/ingredient-functions/emollient...
# 16  {'emollient': '/ingredient-functions/emollient...
# 17  {'antioxidant': '/ingredient-functions/antioxi...
# 18   {'buffering': '/ingredient-functions/buffering'}
# 19  {'emollient': '/ingredient-functions/emollient...
# 20                                                NaN
# 21                                                 []
# 22   {'emollient': '/ingredient-functions/emollient'}
# 23                                                 []
# 24  {'viscosity controlling': '/ingredient-functio...
# 25  {'antimicrobial/antibacterial': '/ingredient-f...
# 26  {'emollient': '/ingredient-functions/emollient...
# 27                                                 []
# 28  {'skin brightening': '/ingredient-functions/sk...
# 29                                                 []
#
#                                           Quick_facts  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   ['It’s the second most researched AHA after gl...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  ['Primary fat-soluble antioxidant in our skin ...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                 []
# 22                                                NaN
# 23                                                 []
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                 []
# 28                                                NaN
# 29                                                 []
#
#                                               Details
# 0   ["It seems to us that squalane is in fashion a...
# 1   ["A 100% vegetable origin, biodegradable, mild...
# 2   ['Super common ingredient in all kinds of clea...
# 3   ["The big brother of glycerin. It's also a nat...
# 4   ["A vegetable origin (coconut/palm kernel oil,...
# 5   ['The attachment of glycerin and\xa0oleic acid...
# 6   ['Sodium chloride is the fancy name of salt. N...
# 7   ["It's one of those things that help your cosm...
# 8   ['A helper ingredient that helps to make\xa0th...
# 9   ["Lactic acid is the second most well-known an...
# 10  ['Exactly what it sounds: nice smelling stuff ...
# 11  ['Exactly what it sounds: nice smelling stuff ...
# 12  ['Citric acid comes from citrus fruits and is ...
# 13  ['A spray-dried or freeze-dried version of Alo...
# 14  ['It’s a common fragrance ingredient that has ...
# 15  ["It's the chemically chopped up version of no...
# 16  ['A glycerin and stearic acid based ingredient...
# 17  ['Vitamin E is the major fat-soluble antioxida...
# 18  ['The unfancy name for it is lye. It’s a solid...
# 19  ['In general, oleosomes\xa0\xa0\xa0are tiny-wi...
# 20  ['If you have already heard of the "plant\xa0s...
# 21                                                 []
# 22  ['A white, solid, vegetable-derived fat (meani...
# 23                                                 []
# 24  ['A helper ingredient that is used as a bulkin...
# 25  ['The extract of\xa0Korean Pasque Flower that ...
# 26  ['A synthetic liquid oil that can replace mine...
# 27                                                 []
# 28  ['The fermentation broth of the nice, edible m...
# 29                                                 []

# %%
img = before_ctpn('Sample_images/sample5.JPG')
cv2.imwrite('sample5_ctpn.jpg', img)
# Out:
# True

# %%
res_5 = after_ctpn_inci('Sample_images/sample5.JPG', 'text-detection-ctpn/data/res/sample5_ctpn.txt', 'Database/ingredient_inci_1570.csv')
# Out:
# , Ingredients / Ingrédients:, AQUA (WATER), CAPRYLIC/CAPRIC., TRIGLYCERIDE, CETYL ALCOHOL,, PROPANEDIOL, STEARYL, ALCOHOL, GLYCERIN, SODIUM, HYALURONATE, ARGININE,, ASPARTIC ACID, GLYCINE, ALANINE,, SERINE, VALINE, ISOLEUCINE,, PROLINE, THREONINE, HISTIDINE,, PHENYLALANINE, GLUCOSE,, MALTOSE, FRUCTOSE, TREHALOSE,, SODIUM PCA. PCA. SODIUM, LACTATE, UREA, ALLANTOIN,, LINOLEIC ACID, OLEIC ACID,, PHYTOSTERYL CANOLA, GLYCERIDES, PALMITIC ACID,, STEARIC ACID, LECITHIN, TRIOLEIN,, TOCOPHEROL, CARBOMER,, ISOCETETH-20, POLYSORBATE 60,, SODIUM CHLORIDE, CITRIC ACID,, TRISODIUM ETHYLENEDIAMINE, DISUCCINATE, PENTYLENE, GLYCOL. TRIETHANOLAMINE,, SODIUM HYDROXIDE,, PHENOXYETHANOL,, CHLORPHENESIN., eee ere
# 100%|██████████| 57/57 [00:05<00:00,  9.78it/s]

# %%
res_5
# Out:
#                           Ingredient_name     Rating Rating_score Irritancy  \
# 0                                 unknown    unknown      unknown   unknown
# 1                                Squalane     goodie            2         0
# 2                                Caprylic  No rating           -1       NaN
# 3                                 unknown    unknown      unknown   unknown
# 4                    Stearic Triglyceride  No rating           -1       NaN
# 5                           Cetyl Alcohol  No rating           -1         2
# 6                             Propanediol  No rating           -1       NaN
# 7                             Phytosteryl     goodie            2       NaN
# 8                                 Alcohol       icky            0       NaN
# 9                              Diglycerin     goodie            2       NaN
# 10                          Disodium EDTA  No rating           -1       NaN
# 11                     Sodium Hyaluronate     goodie            2         0
# 12                               Arginine     goodie            2       NaN
# 13                          Aspartic Acid     goodie            2       NaN
# 14                                Glycine     goodie            2       NaN
# 15                                Alanine     goodie            2       NaN
# 16                                 Serine     goodie            2       NaN
# 17                                 Valine     goodie            2       NaN
# 18                             Isoleucine     goodie            2       NaN
# 19                                Proline     goodie            2       NaN
# 20                              Threonine     goodie            2       NaN
# 21                              Histidine     goodie            2       NaN
# 22                          Phenylalanine     goodie            2       NaN
# 23                                Glucose     goodie            2       NaN
# 24                              Trehalose     goodie            2       NaN
# 25                               Fructose     goodie            2       NaN
# 26                              Trehalose     goodie            2       NaN
# 27                        Sodium Acrylate  No rating           -1       NaN
# 28                                    Pca     goodie            2       NaN
# 29                          Disodium EDTA  No rating           -1       NaN
# 30                            Tea-Lactate  No rating           -1       NaN
# 31                                   Urea     goodie            2       NaN
# 32                              Allantoin     goodie            2         0
# 33                          Linoleic Acid     goodie            2       NaN
# 34                             Oleic Acid  No rating           -1       NaN
# 35                            Phytosteryl     goodie            2       NaN
# 36                             Diglycerin     goodie            2       NaN
# 37                          Palmitic Acid  No rating           -1         0
# 38                           Stearic Acid  No rating           -1         0
# 39                               Lecithin     goodie            2       NaN
# 40                                Proline     goodie            2       NaN
# 41                             Tocopherol     goodie            2       0-3
# 42                               Carbomer  No rating           -1         0
# 43                           Isoceteth-20  No rating           -1       NaN
# 44                         Polysorbate 60  No rating           -1       NaN
# 45                        Sodium Chloride  No rating           -1       NaN
# 46                            Citric Acid  No rating           -1       NaN
# 47  Trisodium Ethylenediamine Disuccinate  No rating           -1       NaN
# 48                              Succinate  No rating           -1       NaN
# 49                               Butylene  No rating           -1       NaN
# 50                               Glycerol  superstar            3         0
# 51                        Triethanolamine  No rating           -1         0
# 52                       Sodium Hydroxide  No rating           -1       NaN
# 53                         Phenoxyethanol  No rating           -1       NaN
# 54                          Chlorphenesin  No rating           -1       NaN
# 55                                unknown    unknown      unknown   unknown
# 56                         Tea Tree Water  No rating           -1       NaN
#
#          Comedogenicity                                          Functions  \
# 0               unknown                                                 []
# 1                     1  {'skin-identical ingredient': '/ingredient-fun...
# 2                   NaN   {'emollient': '/ingredient-functions/emollient'}
# 3               unknown                                                 []
# 4                   NaN   {'emollient': '/ingredient-functions/emollient'}
# 5                     2  {'emollient': '/ingredient-functions/emollient...
# 6                   NaN  {'solvent': '/ingredient-functions/solvent', '...
# 7                   NaN   {'emollient': '/ingredient-functions/emollient'}
# 8                   NaN  {'antimicrobial/antibacterial': '/ingredient-f...
# 9                   NaN  {'skin-identical ingredient': '/ingredient-fun...
# 10                  NaN  {'chelating': '/ingredient-functions/chelating...
# 11                    0  {'skin-identical ingredient': '/ingredient-fun...
# 12                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 13                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 14                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 15                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 16                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 17                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 18                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 19                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 20                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 21                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 22                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 23                  NaN  {'moisturizer/humectant': '/ingredient-functio...
# 24                  NaN  {'moisturizer/humectant': '/ingredient-functio...
# 25                  NaN  {'moisturizer/humectant': '/ingredient-functio...
# 26                  NaN  {'moisturizer/humectant': '/ingredient-functio...
# 27                  NaN  {'viscosity controlling': '/ingredient-functio...
# 28                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 29                  NaN  {'chelating': '/ingredient-functions/chelating...
# 30                  NaN  {'moisturizer/humectant': '/ingredient-functio...
# 31                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 32                    0     {'soothing': '/ingredient-functions/soothing'}
# 33                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 34                  NaN  {'emollient': '/ingredient-functions/emollient...
# 35                  NaN   {'emollient': '/ingredient-functions/emollient'}
# 36                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 37                    2  {'skin-identical ingredient': '/ingredient-fun...
# 38  2020-02-03 00:00:00  {'emollient': '/ingredient-functions/emollient...
# 39                  NaN  {'emollient': '/ingredient-functions/emollient...
# 40                  NaN  {'skin-identical ingredient': '/ingredient-fun...
# 41                  0-3  {'antioxidant': '/ingredient-functions/antioxi...
# 42                    1  {'viscosity controlling': '/ingredient-functio...
# 43                  NaN  {'emulsifying': '/ingredient-functions/emulsif...
# 44                  NaN  {'emulsifying': '/ingredient-functions/emulsif...
# 45                  NaN  {'viscosity controlling': '/ingredient-functio...
# 46                  NaN   {'buffering': '/ingredient-functions/buffering'}
# 47                  NaN   {'chelating': '/ingredient-functions/chelating'}
# 48                  NaN  {'emulsifying': '/ingredient-functions/emulsif...
# 49                  NaN  {'viscosity controlling': '/ingredient-functio...
# 50                    0  {'skin-identical ingredient': '/ingredient-fun...
# 51                    2   {'buffering': '/ingredient-functions/buffering'}
# 52                  NaN   {'buffering': '/ingredient-functions/buffering'}
# 53                  NaN  {'preservative': '/ingredient-functions/preser...
# 54                  NaN  {'preservative': '/ingredient-functions/preser...
# 55              unknown                                                 []
# 56                  NaN  {'antimicrobial/antibacterial': '/ingredient-f...
#
#                                           Quick_facts  \
# 0                                                  []
# 1                                                 NaN
# 2                                                 NaN
# 3                                                  []
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41  ['Primary fat-soluble antioxidant in our skin ...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50  ['A natural moisturizer that’s also in our ski...
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                 []
# 56                                                NaN
#
#                                               Details
# 0                                                  []
# 1   ["It seems to us that squalane is in fashion a...
# 2   ["A vegetable origin emollient that has a simi...
# 3                                                  []
# 4   ["A vegetable origin emollient that has a simi...
# 5   ['A so-called\xa0fatty (the good, non-drying k...
# 6   ["Propanediol is a natural alternative for the...
# 7   ['An amino-acid (glutamic acid) derived molecu...
# 8   ["Simply alcohol refers to ethanol and it's a ...
# 9   ["The big brother of glycerin. It's also a nat...
# 10  ['Super common little helper ingredient that\x...
# 11  ["It’s the - sodium form - cousin of the famou...
# 12  ["A semi-essential (infants cannot synthesize ...
# 13  ['A non-essential\xa0amino acid \xa0(important...
# 14  ['A non-essential amino acid (the building blo...
# 15  ['A non-essential amino acid (a building block...
# 16  ["Serine is an amino acid that most often come...
# 17  ['An essential amino acid (a building block of...
# 18  ["A branch-chained, essential amino acid that ...
# 19  ["A non-essential amino acid (meaning that our...
# 20  ["An\xa0essential amino acid that's also a key...
# 21  ['A semi-essential amino acid meaning that eno...
# 22  ['An essential amino acid that the body cannot...
# 23  ['A so-called\xa0"Fermentoil" that is created ...
# 24  ['A type of sugar that has\xa0water-binding\xa...
# 25  ['Fancy name for fruit sugar. It has nice wate...
# 26  ['A type of sugar that has\xa0water-binding\xa...
# 27  ['A copolymer is a big molecule that consists ...
# 28  ["PCA stands for Pyrrolidone Carboxylic Acid a...
# 29  ['Super common little helper ingredient that\x...
# 30  ['The salt form of lactic acid. It works as a ...
# 31  ["Yes, it's the thing that can be found natura...
# 32  ["Super common soothing ingredient. It can be ...
# 33  ['The famous\xa0omega-6 fatty acid,\xa0the mot...
# 34  ['A common fatty acid that can be found in lot...
# 35  ['An amino-acid (glutamic acid) derived molecu...
# 36  ["The big brother of glycerin. It's also a nat...
# 37  ["A fatty acid that can be found naturally in ...
# 38  ['A common multi-tasker fatty acid. It makes y...
# 39  ["A very common ingredient that can be found i...
# 40  ["A non-essential amino acid (meaning that our...
# 41  ['Vitamin E is the major fat-soluble antioxida...
# 42  ['A big molecule created from repeated subunit...
# 43  ['A handy helper ingredient that works as an e...
# 44  ['A common little helper ingredient that\xa0he...
# 45  ['Sodium chloride is the fancy name of salt. N...
# 46  ['Citric acid comes from citrus fruits and is ...
# 47  ["A helper ingredient that helps to neutralize...
# 48  ['A naturally derived, Ecocert approved materi...
# 49  ["A helper ingredient that's used as a gelling...
# 50  ['Glycerin doesn’t sound very glamorous but it...
# 51  ['It’s a little helper ingredient that helps t...
# 52  ['The unfancy name for it is lye. It’s a solid...
# 53  ['It’s pretty much the current IT-preservative...
# 54  ["A little helper ingredient that works as a p...
# 55                                                 []
# 56  ['The much-much diluted version of the famous\...
