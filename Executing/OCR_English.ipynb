# %%
import re
import cv2
import numpy as np
import pandas as pd
import shutil
import os
import random
import pytesseract
from pytesseract import Output
from matplotlib import pyplot as plt
# from google.colab.patches import cv2_imshow
try:
    from PIL import Image, ImageEnhance
except ImportError:
    import Image

    import re

import operator
import itertools
import gc
import pickle

from difflib import SequenceMatcher
from ast import literal_eval
from collections import Counter
from tqdm import tqdm

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/macbookpro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/macbookpro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.GaussianBlur(image, (5,5), 0)

# thresholding
def thresholding(image):
    return cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 7, 4)
                            
# return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# dilation: enhance the bright area
def dilate(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.dilate(image, kernel, iterations=1)

# erosion: enhance the dark area
def erode(image):
  kernel = np.ones((5,5), np.unint8)
  return cv2.erode(image, kernel, iterations=1)

# opening: erosion follow by a dilation
def opening(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

# closing: Dilation followed by Erosion. Removing black holes inside the object 
def closing(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.morphologyEx(opening(image), cv2.MORPH_CLOSE, kernel)

# canny
def canny(image):
      return cv2.Canny(image, 100, 200)

# deskew image
def deskew(image):
    coords = np.column_stack(np.where(image>0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

# template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

# %%
def preprocess_for_ocr(img, enhance=1):
    """
    @param img: image to which the pre-processing steps being applied
    """
    if enhance > 1:
        img = Image.fromarray(img)

        contrast = ImageEnhance.Contrast(img)

        img = contrast.enhance(enhance)

        img = np.asarray(img)
    
    
    gray = get_grayscale(img)
    blur = remove_noise(gray)
    res = thresholding(blur)

    img = cv2.cvtColor(res, cv2.COLOR_GRAY2BGR)

    return img

# %%
def get_bounding_box(txt):
    annotation = txt
    with open(annotation, "r") as file1:
        bounding_boxes = file1.read()
        
    bounding_boxes = bounding_boxes.split('\n')[:-1]
    boxes = [i.split(',')[:-1] for i in bounding_boxes]

    new_boxes = []
    for box in boxes:
        new_box = []
        for i, each in enumerate(box):
            num = int(each)
            if i in [0, 1, 3, 6]:
                num -= 3
            else: 
                num += 3
            new_box.append(num)
        new_boxes.append(new_box)
    new_boxes.sort(key=lambda x: x[1])
    
    return new_boxes

# %%
def crop_line(img_path, box):
    img = cv2.imread(img_path)
    img, (rh, rw) = resize_image(img)
    # points for test.jpg
    cnt = np.array([
            [[box[0], box[1]]],
            [[box[2], box[3]]],
            [[box[4], box[5]]],
            [[box[6], box[7]]]
        ])
    # print("shape of cnt: {}".format(cnt.shape))
    rect = cv2.minAreaRect(cnt)
#     print("rect: {}".format(rect))

    # the order of the box points: bottom left, top left, top right,
    # bottom right
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # print("bounding box: {}".format(box))
    cv2.drawContours(img, [box], 0, (0, 0, 255), 2)

    # get width and height of the detected rectangle
    width = int(rect[1][0])
    height = int(rect[1][1])
    angle = rect[2]

    src_pts = box.astype("float32")
    # coordinate of the points in box points after the rectangle has been
    # straightened
    dst_pts = np.array([[0, height+2],
                        [0, 0],
                        [width, 0],
                        [width, height+2]], dtype="float32")

    # the perspective transformation matrix
    M = cv2.getPerspectiveTransform(src_pts, dst_pts)

    # directly warp the rotated rectangle to get the straightened rectangle
    warped = cv2.warpPerspective(img, M, (width, height))

    # cv2.imwrite("crop_img.jpg", warped)
    
    # cv2.waitKey(0)
    if angle < -45:
      warped = np.transpose(warped,(1,0,2))
      warped = warped[::-1]

#     cv2.imshow('croped', warped)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()


    return warped

# %%
def resize_image(img):
    img_size = img.shape
    im_size_min = np.min(img_size[0:2])
    im_size_max = np.max(img_size[0:2])

    im_scale = float(600) / float(im_size_min)
    if np.round(im_scale * im_size_max) > 1200:
        im_scale = float(1200) / float(im_size_max)
    new_h = int(img_size[0] * im_scale)
    new_w = int(img_size[1] * im_scale)

    new_h = new_h if new_h // 16 == 0 else (new_h // 16 + 1) * 16
    new_w = new_w if new_w // 16 == 0 else (new_w // 16 + 1) * 16

    re_im = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_LINEAR)
    return re_im, (new_h / img_size[0], new_w / img_size[1])

def crop_rect(img, rect):
    # get the parameter of the small rectangle
    center, size, angle = rect[0], rect[1], rect[2]
    center, size = tuple(map(int, center)), tuple(map(int, size))

    # get row and col num in img
    height, width = img.shape[0], img.shape[1]

    # calculate the rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, 1)
    # rotate the original image
    img_rot = cv2.warpAffine(img, M, (width, height))

    # now rotated rectangle becomes vertical, and we crop it
    img_crop = cv2.getRectSubPix(img_rot, size, center)

    return img_crop, img_rot

# %%
def ocr(img, oem=3, psm=6):
    """
    @param img: The image to be OCR'd
    @param oem: for specifying the type of Tesseract engine( default=1 for LSTM OCR Engine)
    """
    config = ('-l eng --oem {oem} --psm {psm}'.format(oem=oem,psm=psm))
    # config = ('-l eng --tessdata-dir "/usr/share/tesseract-ocr/tessdata" --oem {oem} -- psm {psm}'.format(oem=oem,psm=psm))

    try:
#         img = Image.fromarray(img)
        text = pytesseract.image_to_string(img, config=config)

        return text
    except:
        
        return ""

# %%
def ocr_metrics(predicts, ground_truth, norm_accentuation=False, norm_punctuation=False):
    """Calculate Character Error Rate (CER), Word Error Rate (WER) and Sequence Error Rate (SER)"""
    
    import string
    import unicodedata
    import editdistance

    if len(predicts) == 0 or len(ground_truth) == 0:
        return (1, 1, 1)

    cer, wer, ser = [], [], []

    for (pd, gt) in zip(predicts, ground_truth):

        if norm_accentuation:
            pd = unicodedata.normalize("NFKD", pd).encode("ASCII", "ignore").decode("ASCII")
            gt = unicodedata.normalize("NFKD", gt).encode("ASCII", "ignore").decode("ASCII")

        if norm_punctuation:
            pd = pd.translate(str.maketrans("", "", string.punctuation))
            gt = gt.translate(str.maketrans("", "", string.punctuation))

        pd_cer, gt_cer = list(pd.lower()), list(gt.lower())
        dist = editdistance.eval(pd_cer, gt_cer)
        cer.append(dist / (max(len(pd_cer), len(gt_cer))))

        pd_wer, gt_wer = pd.lower().split(), gt.lower().split()
        dist = editdistance.eval(pd_wer, gt_wer)
        wer.append(dist / (max(len(pd_wer), len(gt_wer))))

        pd_ser, gt_ser = [pd], [gt]
        dist = editdistance.eval(pd_ser, gt_ser)
        ser.append(dist / (max(len(pd_ser), len(gt_ser))))

    cer_f = sum(cer) / len(cer)
    wer_f = sum(wer) / len(wer)
    ser_f = sum(ser) / len(ser)
    
    evaluate = (cer_f, wer_f, ser_f)
    
    e_corpus = "\n".join([
    "Metrics:",
    "Character Error Rate: {}".format(evaluate[0]),
    "Word Error Rate:      {}".format(evaluate[1]),
    "Sequence Error Rate:  {}".format(evaluate[2]),
    ])

    return print(e_corpus)

# %%
# def clean_string(string):
# #     string = string + ' ' + str(string.strip('\n').strip('\x0c').strip())
#     text = string.replace('INACTIVE INGREDIENTS:', '') # added
#     text = text.replace('ACTIVE INGREDIENTS:', '') # added
#     text = text.split(':')[1]
#     text = text.strip()

#     return text

# def string_to_list(text):
#     pattern = "[\|\*\_\'\{}]".format('"')
#     text = re.sub(pattern, "", text)  
#     split = [remove_water(x) for x in text.split(',')]
    
#     return split

# %%
def clean_string(string):
    text = string.replace('INACTIVE INGREDIENTS:', '') # added
    text = text.replace('ACTIVE INGREDIENTS:', '') # added
    text = text.split(':')[1]
    
    pattern = "[\|\*\_\'\{}&]".format('"')
    regex = re.compile('\\\S+')
    
    text = re.sub(pattern, "", text)
    text = re.sub(",, ", ", ", text)
    text = re.sub(regex, " ", text)
    text = re.sub('\.', " ", text)
    text_tokens = word_tokenize(text)
    text_wo_sw = [w for w in text_tokens if not w in stopwords.words()]
    text = ' '.join(text_wo_sw)
    text = text.strip()

    return text

def string_to_list(text):
    pattern = "[\|\*\_\'\{}]".format('"')
    text = re.sub(pattern, "", text)
    split = [remove_water(x) for x in re.split("[,.]", text)]
    
    return split

# %%
def remove_water(string):
    water = ['WATER (AQUA)', 'AQUA', 'EAU', 'AQUA/WATER/EAU', 'AQUA / WATER / EAU', 
             'PURIFIED WATER', 'DISTILLED WATER', 'D.I. WATER', 'AQUA (WATER)', 'AQUA (PURIFIED)']
    text = string.upper()
    if text in water:
        text = 'WATER'
    text = text.strip('  ')
    
    return text

# %%
def clean_string_name(string):
    text = string.replace(' Size: 4 oz. * USDA Certified Organic Ingredient ** None remains after saponifying oils into soap and glycerin', '')
    pattern = "[\|\*\_\'\{}&]".format('"')
    regex1 = re.compile('\[.*]')
    regex2 = re.compile('\[.*}')
    text = re.sub(pattern, "", text)
    text = re.sub(regex1, "", text)
    text = re.sub(regex2, "", text)
    text = text.strip('\x0c')
    text = text.strip(' ')
    text = text.upper()
    text = text.replace('INACTIVE INGREDIENTS:', '')
    text = text.replace('ACTIVE INGREDIENTS:', '')

    return text

# %%
def find_matching_ingredient(my_ingredients, fd, thresh=0.25): # rating_dict, category_dict, 
    ''' my_ingredients: list of product's ingredients
        Loop thru each ingredient in the ingredient list of the products
        then check if that ingredient appears in our ingredient list
        Calculate match_metric using SequenceMatcher and return the highest score and the best match
        Compare the match_metric with thresh > append to match_dict
    '''
    match_dict = {}
    for ingredient in tqdm(my_ingredients):
        if ingredient in match_dict.keys():
            continue
#         match_metric = {key: SequenceMatcher(None, key, ingredient).ratio() for key in rating_dict.keys()}
        match_metric = {key: SequenceMatcher(None, key, ingredient).ratio() for key in fd}
        best_match, best_metric = max(match_metric.items(), key=operator.itemgetter(1)) # What is operator.itemgetter(1)
        if best_metric > thresh:
            match_dict[ingredient] = best_match
        else:
            match_dict[ingredient] = 'unknown'
    return match_dict

# %%
def create_dict_english(df_inci, df_cosing):
    rating_inci = {}
    irritancy_inci = {}
    comedogenicity_inci = {}
    function_inci = {}
    qfacts_inci = {}
    desc_inci = {}
    
    desc_cosing = {}
    function_cosing = {}
    
    for idx, row in tqdm(df_inci.iterrows()):
        for name in row['ingredient_name'].split('/'):
            chem_name = name.strip()
            rating_inci[chem_name] = row['rating']
            irritancy_inci[chem_name] = row['irritancy']
            comedogenicity_inci[chem_name] = row['comedogenicity']
            function_inci[chem_name] = row['functions']
            qfacts_inci[chem_name] = row['quick_facts']
            desc_inci[chem_name] = row['description']
            
    for idx, row in tqdm(df_cosing.iterrows()):
        for name in row['ingredient_name'].split('/'):
            desc_cosing[name] = row['description']
            function_cosing[name] = row['functions']    
    
    return rating_inci, irritancy_inci, comedogenicity_inci, function_inci, qfacts_inci, desc_inci, desc_cosing, function_cosing

# %%
df_inci = pd.read_csv('../Database/INCI/ingredient_inci_1570.csv') # '../Database/CALLMEDUY/ingredient_vietnamese_3818.csv'

# %%
df_inci
# Out:
#            ingredient_name                                               link  \
# 0             OUBAKU EKISU  https://incidecoder.com/ingredients/phellodend...
# 1             TYPE OF CLAY  https://incidecoder.com/ingredients/solum-full...
# 2               18:2 CIS-9  https://incidecoder.com/ingredients/linoleic-acid
# 3      3-O-ETHYL ASCORBATE  https://incidecoder.com/ingredients/ethyl-asco...
# 4                      ALA  https://incidecoder.com/ingredients/linolenic-...
# ...                    ...                                                ...
# 1565                MINIHA  https://incidecoder.com/ingredients/hydrolyzed...
# 1566      TEA OIL CAMELLIA  https://incidecoder.com/ingredients/camellia-o...
# 1567            VITAMIN B3    https://incidecoder.com/ingredients/niacinamide
# 1568              SS-WHITE  https://incidecoder.com/ingredients/oligopepti...
# 1569           Ω6 CERAMIDE  https://incidecoder.com/ingredients/safflower-...
#
#          rating  rating_score irritancy comedogenicity  \
# 0        GOODIE             2       NaN            NaN
# 1        GOODIE             2       NaN            NaN
# 2        GOODIE             2       NaN            NaN
# 3        GOODIE             2       NaN            NaN
# 4        GOODIE             2       NaN            NaN
# ...         ...           ...       ...            ...
# 1565  NO RATING            -1       NaN            NaN
# 1566     GOODIE             2       NaN            NaN
# 1567  SUPERSTAR             3       NaN            NaN
# 1568     GOODIE             2       NaN            NaN
# 1569     GOODIE             2       NaN            NaN
#
#                                               functions  \
# 0                                   SOOTHING, ANTI-ACNE
# 1            VISCOSITY CONTROLLING, ABSORBENT/MATTIFIER
# 2     SKIN-IDENTICAL INGREDIENT, EMOLLIENT, SURFACTA...
# 3                         ANTIOXIDANT, SKIN BRIGHTENING
# 4     SKIN-IDENTICAL INGREDIENT, EMOLLIENT, SURFACTA...
# ...                                                 ...
# 1565                              MOISTURIZER/HUMECTANT
# 1566                              ANTIOXIDANT, SOOTHING
# 1567  CELL-COMMUNICATING INGREDIENT, SKIN BRIGHTENIN...
# 1568                                   SKIN BRIGHTENING
# 1569                    SOOTHING, MOISTURIZER/HUMECTANT
#
#                                             quick_facts  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1565                                                NaN
# 1566                                                NaN
# 1567  ['A multi-functional skincare superstar with s...
# 1568                                                NaN
# 1569                                                NaN
#
#                                             description
# 0     A traditional East Asian medicine that has a c...
# 1     Fuller Earth describes types of clay that have...
# 2     The famous omega-6 fatty acid, the mother of a...
# 3     A very stable and promising form of the skinca...
# 4     The famous omega-3 fatty acid, the mother of a...
# ...                                                 ...
# 1565  It a super small, chemically chopped up versio...
# 1566  Camellia Oleifera is a type of green tea plant...
# 1567  Niacinamide, or as us normal people call it vi...
# 1568  A skin-brightening peptide that is claimed to ...
# 1569  A linoleic acid (aka omega-6 fatty acid) stabi...
#
# [1570 rows x 9 columns]

# %%
df_cosing = pd.read_csv('../Database/ingredient_cosing_37309.csv') #'../Database/ingredient_cosing_37309.csv'

# %%
df_cosing
# Out:
#        cosing_ref_no                                    ingredient_name  \
# 0            94753.0  DISODIUM TETRAMETHYLHEXADECENYLCYSTEINE FORMYL...
# 1            96229.0                    ASTROCARYUM VULGARE SEED BUTTER
# 2            89177.0                           BARLEY SH-POLYPEPTIDE-17
# 3            98580.0                  DAUCUS CAROTA SATIVA LEAF EXTRACT
# 4            89078.0                    GOSSYPIUM HIRSUTUM SEED EXTRACT
# ...              ...                                                ...
# 37304        90014.0                        PHELLODENDRON AMURENSE BARK
# 37305        90014.0                           LONICERA JAPONICA FLOWER
# 37306        90014.0                         CHAENOMELES SINENSIS FRUIT
# 37307        90014.0                             CAMELLIA SINENSIS LEAF
# 37308        90014.0        BRASSICA OLERACEA ITALICA FERMENT FILTRATE
#
#                                              description restriction  \
# 0      Disodium Tetramethylhexadecenylcysteine Formyl...         NaN
# 1      Astrocaryum Vulgare Seed Butter is the fat obt...         NaN
# 2      Barley sh-Polypeptide-17 is a single chain rec...         NaN
# 3      Daucus Carota Sativa (Carrot) Leaf Extract is ...         NaN
# 4       Gossypium Hirsutum Seed Extract is the extrac...         NaN
# ...                                                  ...         ...
# 37304  This is a filtrate of the product obtained by ...         NaN
# 37305  This is a filtrate of the product obtained by ...         NaN
# 37306  This is a filtrate of the product obtained by ...         NaN
# 37307  This is a filtrate of the product obtained by ...         NaN
# 37308  This is a filtrate of the product obtained by ...         NaN
#
#                                               functions
# 0                                       SKIN PROTECTING
# 1      SKIN CONDITIONING, SKIN CONDITIONING - EMOLLIENT
# 2                  HAIR CONDITIONING, SKIN CONDITIONING
# 3                     SKIN CONDITIONING - MISCELLANEOUS
# 4                                     SKIN CONDITIONING
# ...                                                 ...
# 37304     HUMECTANT, SKIN CONDITIONING, SKIN PROTECTING
# 37305     HUMECTANT, SKIN CONDITIONING, SKIN PROTECTING
# 37306     HUMECTANT, SKIN CONDITIONING, SKIN PROTECTING
# 37307     HUMECTANT, SKIN CONDITIONING, SKIN PROTECTING
# 37308     HUMECTANT, SKIN CONDITIONING, SKIN PROTECTING
#
# [37309 rows x 5 columns]

# %%
rating_inci, irritancy_inci, comedogenicity_inci, function_inci, qfacts_inci, desc_inci, desc_cosing, function_cosing = create_dict_english(df_inci, df_cosing)
# Out:
# 1570it [00:00, 3783.07it/s]
# 37309it [00:05, 6407.60it/s]

# %%
rating_inci
# Out:
# {'OUBAKU EKISU': 'GOODIE',
#  'TYPE OF CLAY': 'GOODIE',
#  '18:2 CIS-9': 'GOODIE',
#  '3-O-ETHYL ASCORBATE': 'GOODIE',
#  'ALA': 'GOODIE',
#  'ATIP': 'GOODIE',
#  'ACETYL GLUTAMYL HEPTAPEPTIDE-1': 'GOODIE',
#  'ACETYL HEXAPEPTIDE-3': 'GOODIE',
#  'ACID RED 92 PHLOXINE': 'NO RATING',
#  'AL2O3': 'NO RATING',
#  'ASCORBYL ISOTETRAPALMITATE': 'GOODIE',
#  'ASCORBYL TETRAISOPALMITATE': 'GOODIE',
#  'ASTRAGALI RADIX': 'GOODIE',
#  'BEMOTRIZINOL': 'GOODIE',
#  'BISDISULIZOLE DISODIUM': 'GOODIE',
#  'BISOCTRIZOLE': 'GOODIE',
#  'CHILEAN WINEBERRY OIL': 'GOODIE',
#  'CHINA CLAY': 'GOODIE',
#  'CHOPI': 'NO RATING',
#  'CITRUS SINENSIS OIL': 'ICKY',
#  'COCOCIN': 'GOODIE',
#  'COCONUT LIQUID ENDOSPERM': 'GOODIE',
#  'COLLOIDAL OATMEAL': 'GOODIE',
#  'COPPER PEPTIDE': 'GOODIE',
#  'CURCUMIN': 'GOODIE',
#  'D&C RED 33': 'NO RATING',
#  'DHHB': 'GOODIE',
#  'EAC': 'GOODIE',
#  'EGF': 'NO RATING',
#  'EPO': 'GOODIE',
#  'EDELWEISS STEM CELL EXTRACT': 'GOODIE',
#  'ELIX-IR': 'GOODIE',
#  'EUSOLEX 6007': 'ICKY',
#  'FGF1': 'NO RATING',
#  'FGF2': 'NO RATING',
#  'FERRIC AMMONIUM FERROCYANIDE': 'NO RATING',
#  'FILIPENDULA ULMARIA EXTRACT': 'GOODIE',
#  'FLAXSEED OIL': 'GOODIE',
#  'FORM OF RETINOIDS': 'GOODIE',
#  'FORM OF VITAMIN F': 'GOODIE',
#  'FORMERLY PALMITOYL PENTAPEPTIDE-3': 'GOODIE',
#  'FORMERLY ALSO PALMITOYL OLIGOPEPTIDE': 'GOODIE',
#  'GINSENG': 'GOODIE',
#  'GLASSWORT EXTRACT': 'GOODIE',
#  'GOLD-OF-PLEASURE OIL': 'GOODIE',
#  'GOLDEN EYE-GRASS ROOT EXTRACT': 'GOODIE',
#  'HDBM': 'GOODIE',
#  'HPR': 'GOODIE',
#  'IGF-1': 'NO RATING',
#  'INDIAN FIG': 'GOODIE',
#  'IRON BLUE': 'NO RATING',
#  'JAPANESE BLOODGRASS ROOT EXTRACT': 'GOODIE',
#  'KINNIKINNICK': 'GOODIE',
#  'KOLLAREN': 'GOODIE',
#  'KOREAN GINSENG': 'GOODIE',
#  'KOREAN PEPPER': 'NO RATING',
#  'L-ASCORBIC ACID': 'SUPERSTAR',
#  'LC-6': 'GOODIE',
#  'LEMON BALM LEAF OIL': 'ICKY',
#  'MAP': 'GOODIE',
#  'MANGO SEED BUTTER': 'GOODIE',
#  'MARIGOLD EXTRACT': 'GOODIE',
#  'MELALEUCA MINOR': 'ICKY',
#  'MEXORYL SX': 'GOODIE',
#  'NEO HELIOPAN E1000': 'NO RATING',
#  'NEROLI FLOWER WATER': 'NO RATING',
#  'NEROLI OIL': 'ICKY',
#  'NEUROMATRIX': 'GOODIE',
#  'NEUROVAX': 'GOODIE',
#  'NOPAL': 'GOODIE',
#  'OCTISALATE': 'NO RATING',
#  'OCTYL DIMETHYL PABA': 'ICKY',
#  'OCTYL METHOXYCINNAMATE': 'NO RATING',
#  'OCTYLTRIAZONE': 'GOODIE',
#  'PAL-GHK': 'GOODIE',
#  'PAL-GQPR': 'GOODIE',
#  'PAL-KTTKS': 'GOODIE',
#  'PALMITOYL OLIGOPEPTIDE (OLD NAME)': 'GOODIE',
#  'PARFUM': 'ICKY',
#  'PERSEA AMERICANA OIL': 'GOODIE',
#  'PHYTO RETINOL': 'GOODIE',
#  'PONGAMIA PINNATA OIL': 'NO RATING',
#  'POREAWAY': 'NO RATING',
#  'POTASSIUM ALUMINUM SULFATE': 'NO RATING',
#  'PREVIOUSLY PALMITOYL TETRAPEPTIDE-3': 'GOODIE',
#  'RED 27': 'NO RATING',
#  'RED 27 LAKE': 'NO RATING',
#  'RED 28 LAKE': 'NO RATING',
#  'RED 33 LAKE': 'NO RATING',
#  'RED SEAWEED': 'NO RATING',
#  'RENOVAGE': 'GOODIE',
#  'RETINALDEHYDE': 'SUPERSTAR',
#  'RETINOL ESTER': 'GOODIE',
#  'RETINOL-8': 'GOODIE',
#  'ROSA EGLANTERIA SEED OIL': 'GOODIE',
#  'ROSA MOSQUETA SEED OIL': 'GOODIE',
#  'ROSE HYDROSOL': 'NO RATING',
#  'ROSEHIP SEED OIL': 'GOODIE',
#  'SAP': 'GOODIE',
#  'SANSHŌ': 'NO RATING',
#  'SATSUMA ORANGE': 'NO RATING',
#  'SEAWEED EXTRACT': 'GOODIE',
#  'SIAM BENZOIN': 'ICKY',
#  'SNAIL MUCIN': 'GOODIE',
#  'STARFLOWER SEED OIL': 'GOODIE',
#  'THBG': 'GOODIE',
#  'TTO': 'GOODIE',
#  'TANGOR OIL': 'ICKY',
#  'TIGER GRASS': 'GOODIE',
#  'TIN DIOXIDE': 'NO RATING',
#  'TRI HYDROXY BENZOIC ACID ALPHA-GLUCOSIDES': 'GOODIE',
#  'UVASORB HEB': 'NO RATING',
#  'VEGF': 'NO RATING',
#  'VASELINE': 'NO RATING',
#  'VIRGIN PRUNUS OIL': 'GOODIE',
#  'YELLOW 5': 'NO RATING',
#  'NICOTINAMIDE': 'SUPERSTAR',
#  'OMEGA-3 FATTY ACID': 'GOODIE',
#  'OMEGA-6 FATTY ACID': 'GOODIE',
#  'PAL-VGVAPG': 'GOODIE',
#  'PART OF BIO-PLACENTA': 'NO RATING',
#  'RH-OLIGOPEPTIDE-1': 'NO RATING',
#  'RH-OLIGOPEPTIDE-2': 'NO RATING',
#  'RH-POLYPEPTIDE-1': 'NO RATING',
#  'RH-POLYPEPTIDE-11': 'NO RATING',
#  'RH-POLYPEPTIDE-9': 'NO RATING',
#  '1,2-HEXANEDIOL': 'NO RATING',
#  '12': 'GOODIE',
#  '4-METHYLBENZYLIDENE CAMPHOR': 'ICKY',
#  '4-T-BUTYLCYCLOHEXANOL': 'GOODIE',
#  'ACACIA DECURRENS FLOWER WAX': 'NO RATING',
#  'ACACIA DECURRENS': 'NO RATING',
#  'JOJOBA': 'NO RATING',
#  'SUNFLOWER SEED WAX POLYGLYCERYL-3 ESTERS': 'NO RATING',
#  'ACACIA SENEGAL GUM': 'NO RATING',
#  'ACER SACCHARUM EXTRACT': 'NO RATING',
#  'ACETAMIDOETHOXYETHANOL': 'GOODIE',
#  'ACETIC ACID': 'NO RATING',
#  'ACETUM': 'NO RATING',
#  'ACETYL DIPEPTIDE-1 CETYL ESTER': 'GOODIE',
#  'ACETYL GLUCOSAMINE': 'GOODIE',
#  'ACETYL GLYCYL BETA-ALANINE': 'GOODIE',
#  'ACETYL HEXAPEPTIDE-1': 'GOODIE',
#  'ACETYL HEXAPEPTIDE-8': 'GOODIE',
#  'ACETYL OCTAPEPTIDE-3': 'GOODIE',
#  'ACETYL TETRAPEPTIDE-2': 'GOODIE',
#  'ACETYL TETRAPEPTIDE-3': 'GOODIE',
#  'ACETYL TETRAPEPTIDE-5': 'GOODIE',
#  'ACETYLARGINYLTRYPTOPHYL DIPHENYLGLYCINE': 'GOODIE',
#  'ACIDIC FIBROBLAST GROWTH FACTOR': 'NO RATING',
#  'ACRYLATES COPOLYMER': 'NO RATING',
#  'ACRYLATES': 'NO RATING',
#  'C10-30 ALKYL ACRYLATE CROSSPOLYMER': 'NO RATING',
#  'C12-22 ALKYL METHACRYLATE COPOLYMER': 'NO RATING',
#  'DIMETHICONE COPOLYMER': 'NO RATING',
#  'ETHYLHEXYL ACRYLATE CROSSPOLYMER': 'NO RATING',
#  'ACRYLONITRILE': 'NO RATING',
#  'METHYL METHACRYLATE': 'NO RATING',
#  'VINYLIDENE CHLORIDE COPOLYMER': 'NO RATING',
#  'ACTICIRE': 'NO RATING',
#  'ADANSONIA DIGITATA SEED OIL': 'GOODIE',
#  'ADENOSINE': 'GOODIE',
#  'ADIPIC ACID': 'NO RATING',
#  'NEOPENTYL GLYCOL CROSSPOLYMER': 'NO RATING',
#  "ADIPOFILL'IN": 'GOODIE',
#  'AESCULUS HIPPOCASTANUM SEED EXTRACT': 'GOODIE',
#  'AGONIS FRAGRANS BRANCH': 'ICKY',
#  'LEAF OIL': 'ICKY',
#  'AHNFELTIA CONCINNA EXTRACT': 'GOODIE',
#  'ALANINE': 'GOODIE',
#  'ALCOHOL': 'ICKY',
#  'ALCOHOL DENAT.': 'ICKY',
#  'ALEURITES MOLUCCANA SEED OIL': 'GOODIE',
#  'ALGAE EXTRACT': 'GOODIE',
#  'ALGIN': 'NO RATING',
#  'ALL-TRANS-RETINOIC ACID': 'SUPERSTAR',
#  'ALLANTOIN': 'GOODIE',
#  'ALLIUM CEPA BULB EXTRACT': 'NO RATING',
#  'ALOE BARBADENSIS LEAF EXTRACT': 'GOODIE',
#  'ALOE BARBADENSIS LEAF JUICE': 'GOODIE',
#  'ALOE BARBADENSIS LEAF JUICE POWDER': 'GOODIE',
#  'ALOE LEAF EXTRACT': 'GOODIE',
#  'ALOE VERA': 'GOODIE',
#  'ALPHA-ARBUTIN': 'GOODIE',
#  'ALPHA-BISABOLOL': 'GOODIE',
#  'ALPHA-GLUCAN OLIGOSACCHARIDE': 'GOODIE',
#  'ALPHA-ISOMETHYL IONONE': 'ICKY',
#  'ALPHA-LIPOIC ACID': 'GOODIE',
#  'ALPHAFLOW': 'NO RATING',
#  'ALTEROMONAS FERMENT EXTRACT': 'GOODIE',
#  'ALTEROMONAS FERMENT FILTRATE': 'GOODIE',
#  'ALUMINA': 'NO RATING',
#  'ALUMINUM HYDROXIDE': 'NO RATING',
#  'ALUMINUM OXIDE': 'NO RATING',
#  'ALUMINUM STARCH OCTENYLSUCCINATE': 'NO RATING',
#  'AMARANTH SEED EXTRACT': 'GOODIE',
#  'AMARANTHUS CAUDATUS SEED EXTRACT': 'GOODIE',
#  'AMILOXATE': 'NO RATING',
#  'AMINOMETHYL PROPANOL': 'NO RATING',
#  'AMINOPROPYL ASCORBYL PHOSPHATE': 'GOODIE',
#  'AMMONIUM ACRYLOYLDIMETHYLTAURATE': 'NO RATING',
#  'VP COPOLYMER': 'NO RATING',
#  'AMMONIUM GLYCOLATE': 'NO RATING',
#  'AMMONIUM LAURYL SULFATE': 'NO RATING',
#  'AMMONIUM POLYACRYLOYLDIMETHYL TAURATE': 'NO RATING',
#  'AMMONIUM XYLENESULFONATE': 'NO RATING',
#  'AMODIMETHICONE': 'NO RATING',
#  'AMORPHOPHALLUS KONJAC ROOT POWDER': 'GOODIE',
#  'AMUR CORK TREE BARK EXTRACT': 'GOODIE',
#  'ANANAS SATIVUS FRUIT EXTRACT': 'GOODIE',
#  'ANHYDROXYLITOL': 'GOODIE',
#  'ANNATTO': 'NO RATING',
#  'ANTHEMIS NOBILIS FLOWER EXTRACT': 'GOODIE',
#  'ANTHEMIS NOBILIS FLOWER OIL': 'GOODIE',
#  'ANTHOCYANINS': 'NO RATING',
#  'APHANIZOMENON FLOS-AQUAE EXTRACT': 'GOODIE',
#  'APPLE FRUIT EXTRACT': 'GOODIE',
#  'APRICOT KERNEL OIL': 'GOODIE',
#  'AQUA': 'NO RATING',
#  'ARACHIDYL ALCOHOL': 'NO RATING',
#  'ARACHIDYL GLUCOSIDE': 'NO RATING',
#  'ARBUTIN': 'GOODIE',
#  'ARCTIUM LAPPA ROOT EXTRACT': 'GOODIE',
#  'ARCTOSTAPHYLOS UVA-URSI LEAF EXTRACT': 'GOODIE',
#  'ARGAN OIL': 'GOODIE',
#  'ARGANIA SPINOSA KERNEL OIL': 'GOODIE',
#  'ARGININE': 'GOODIE',
#  'ARGIRELINE': 'GOODIE',
#  'ARISTOFLEX AVC': 'NO RATING',
#  'ARISTOTELIA CHILENSIS OIL': 'GOODIE',
#  'ARNICA EXTRACT': 'ICKY',
#  'ARNICA MONTANA EXTRACT': 'ICKY',
#  'ARNICA MONTANA FLOWER EXTRACT': 'ICKY',
#  'ARONIA MELANOCARPA FRUIT EXTRACT': 'GOODIE',
#  'ASCORBIC ACID': 'SUPERSTAR',
#  'ASCORBYL GLUCOSIDE': 'GOODIE',
#  'ASCORBYL PALMITATE': 'ICKY',
#  'ASIATIC ACID': 'GOODIE',
#  'ASIATICOSIDE': 'GOODIE',
#  'ASPARTIC ACID': 'GOODIE',
#  'ASTAXANTHIN': 'GOODIE',
#  'ASTRAGALUS MEMBRANACEUS ROOT EXTRACT': 'GOODIE',
#  'AVENA SATIVA KERNEL EXTRACT': 'GOODIE',
#  'AVENA SATIVA KERNEL FLOUR': 'GOODIE',
#  'AVOBENZONE': 'GOODIE',
#  'AVOCADO OIL': 'GOODIE',
#  'AVOCADO OIL UNSAPONIFIABLES': 'GOODIE',
#  'AZELAIC ACID': 'SUPERSTAR',
#  'BHA': 'ICKY',
#  'BHT': 'NO RATING',
#  "BAKER'S YEAST": 'GOODIE',
#  'BAKUCHIOL': 'GOODIE',
#  'BALM MINT LEAF OIL': 'ICKY',
#  'BAMBOO ISOFLAVONES': 'GOODIE',
#  'BAOBAB SEED OIL': 'GOODIE',
#  'BARBERRY ROOT EXTRACT': 'GOODIE',
#  'BAROSMA BETULINA LEAF EXTRACT': 'GOODIE',
#  'BASIC FIBROBLAST GROWTH FACTOR': 'NO RATING',
#  'BEARBERRY': 'GOODIE',
#  'BEESWAX': 'NO RATING',
#  'BEET ROOT EXTRACT': 'GOODIE',
#  'BEHENTRIMONIUM METHOSULFATE': 'NO RATING',
#  'BEHENYL ALCOHOL': 'NO RATING',
#  'BENTONITE': 'GOODIE',
#  'BENZOIC ACID': 'NO RATING',
#  'BENZOIN RESIN': 'ICKY',
#  'BENZOPHENONE-3': 'ICKY',
#  'BENZOPHENONE-4': 'NO RATING',
#  'BENZOPHENONE-5': 'NO RATING',
#  'BENZOYL PEROXIDE': 'NO RATING',
#  'BENZYL ALCOHOL': 'NO RATING',
#  'BENZYL BENZOATE': 'ICKY',
#  'BENZYL SALICYLATE': 'ICKY',
#  'BERACLAY LIGHT RED': 'NO RATING',
#  'BERBERIS VULGARIS ROOT EXTRACT': 'GOODIE',
#  'BERGAMOT ESSENTIAL OIL': 'ICKY',
#  'BERGAMOT FRUIT OIL': 'ICKY',
#  'BETA VULGARIS ROOT EXTRACT': 'GOODIE',
#  'BETA-ARBUTIN': 'GOODIE',
#  'BETA-GLUCAN': 'GOODIE',
#  'BETAINE': 'GOODIE',
#  'BETAINE SALICYLATE': 'NO RATING',
#  'BETULA ALBA BARK EXTRACT': 'GOODIE',
#  'BIFIDA FERMENT LYSATE': 'GOODIE',
#  'BIOPEPTIDE EL': 'GOODIE',
#  'BIOSACCHARIDE GUM-1': 'GOODIE',
#  'BIOSACCHARIDE GUM-2': 'GOODIE',
#  'BIOTIN': 'NO RATING',
#  'BIOTINOYL TRIPEPTIDE-1': 'GOODIE',
#  'BIRCH BARK EXTRACT': 'GOODIE',
#  'BIS STEARYL ETHYLENEDIAMINE': 'NO RATING',
#  'NEOPENTYL GLYCOL': 'NO RATING',
#  'STEARYL HYDROGENATED DIMER DILINOLEATE COPOLYMER': 'NO RATING',
#  'BIS-DIGLYCERYL POLYACYLADIPATE-2': 'NO RATING',
#  'BIS-ETHYLHEXYL HYDROXYDIMETHOXY BENZYLMALONATE': 'GOODIE',
#  'BIS-ETHYLHEXYLOXYPHENOL METHOXYPHENYL TRIAZINE': 'GOODIE',
#  'BIS-PEG-18 METHYL ETHER DIMETHYL SILANE': 'NO RATING',
#  'BIS-PEG': 'NO RATING',
#  'PPG-14': 'NO RATING',
#  '14 DIMETHICONE': 'NO RATING',
#  'BISABOLOL': 'GOODIE',
#  'BISMUTH OXYCHLORIDE': 'NO RATING',
#  'BITTER ORANGE FLOWER OIL': 'ICKY',
#  'BITTER ORANGE FLOWER WATER': 'NO RATING',
#  'BLACK CHOKEBERRY': 'GOODIE',
#  'BLACK CUMIN OIL': 'GOODIE',
#  'BLACK TRUFFLE EXTRACT': 'GOODIE',
#  'BLACKBERRY SEED OIL': 'GOODIE',
#  'BLUE 1': 'NO RATING',
#  'BONT-L PEPTIDE': 'GOODIE',
#  'BORAGE LEAF EXTRACT': 'GOODIE',
#  'BORAGE SEED OIL': 'GOODIE',
#  'BORAGO OFFICINALIS LEAF EXTRACT': 'GOODIE',
#  'BORAGO OFFICINALIS SEED OIL': 'GOODIE',
#  'BORON NITRIDE': 'NO RATING',
#  'BOSWELLIA SERRATA EXTRACT': 'NO RATING',
#  'BRIGHTENYL': 'GOODIE',
#  'BUCHU LEAF EXTRACT': 'GOODIE',
#  'BUDDLEJA DAVIDII MERISTEM CELL CULTURE': 'GOODIE',
#  'BURDOCK ROOT': 'GOODIE',
#  'BUTANE': 'NO RATING',
#  'BUTCHER’S BROOM EXTRACT': 'GOODIE',
#  'BUTYL METHOXYDIBENZOYLMETHANE': 'GOODIE',
#  'BUTYLATED HYDROXY ANISOLE': 'ICKY',
#  'BUTYLATED HYDROXY TOLUENE': 'NO RATING',
#  'BUTYLENE GLYCOL': 'NO RATING',
#  'BUTYLENE': 'NO RATING',
#  'ETHYLENE': 'NO RATING',
#  'STYRENE COPOLYMER': 'NO RATING',
#  'BUTYLOCTYL SALICYLATE': 'NO RATING',
#  'BUTYLPHENYL METHYLPROPIONAL': 'ICKY',
#  'BUTYROSPERMUM PARKII BUTTER': 'GOODIE',
#  'C10-30 CHOLESTEROL': 'GOODIE',
#  'LANOSTEROL ESTERS': 'GOODIE',
#  'C12-14 PARETH-12': 'NO RATING',
#  'C12-15 ALKYL BENZOATE': 'NO RATING',
#  'C12-20 ALKYL GLUCOSIDE': 'NO RATING',
#  'C13-14 ISOPARAFFIN': 'NO RATING',
#  'C13-15 ALKANE': 'NO RATING',
#  'C14-22 ALCOHOLS': 'NO RATING',
#  'C20-40 PARETH-10': 'NO RATING',
#  'C30-45 ALKYL DIMETHICONE': 'NO RATING',
#  'CI 77019': 'NO RATING',
#  'CI 77861': 'NO RATING',
#  'CI 77947': 'NO RATING',
#  'CAFFEINE': 'GOODIE',
#  'CAFFEYL GLUCOSIDE': 'GOODIE',
#  'CAJEPUT ESSENTIAL OIL': 'ICKY',
#  'CALENDULA EXTRACT': 'GOODIE',
#  'CALENDULA OFFICINALIS EXTRACT': 'GOODIE',
#  'CALENDULA OFFICINALIS FLOWER EXTRACT': 'GOODIE',
#  'CALMOSENSINE': 'GOODIE',
#  'CALOPHYLLUM INOPHYLLUM SEED OIL': 'GOODIE',
#  'CALOPHYLLUM TACAMAHACA OIL': 'GOODIE',
#  'CAMELINA OIL': 'GOODIE',
#  'CAMELINA SATIVA SEED OIL': 'GOODIE',
#  'CAMELLIA OLEIFERA  LEAF EXTRACT': 'GOODIE',
#  'CAMELLIA OLEIFERA SEED OIL': 'GOODIE',
#  'CAMELLIA SINENSIS LEAF EXTRACT': 'SUPERSTAR',
#  'CANANGA ODORATA FLOWER OIL': 'ICKY',
#  'CANDELILLA CERA': 'NO RATING',
#  'CANDELILLA WAX': 'NO RATING',
#  'CANDELILLA': 'NO RATING',
#  'RICE BRAN POLYGLYCERYL-3 ESTERS': 'NO RATING',
#  'CANDLE TREE LEAF EXTRACT': 'GOODIE',
#  'CAPE CHAMOMILE OIL': 'NO RATING',
#  'CAPROOYL TETRAPEPTIDE-3': 'GOODIE',
#  'CAPRYLHYDROXAMIC ACID': 'NO RATING',
#  'CAPRYLIC': 'NO RATING',
#  'CAPRIC TRIGLYCERIDE': 'NO RATING',
#  'CAPRIC': 'NO RATING',
#  'MYRISTIC': 'NO RATING',
#  'STEARIC TRIGLYCERIDE': 'NO RATING',
#  'CAPRYLOYL GLYCERIN': 'NO RATING',
#  'SEBACIC ACID COPOLYMER': 'NO RATING',
#  'CAPRYLYL CAPRYLATE': 'NO RATING',
#  'CAPRATE': 'NO RATING',
#  'CAPRYLYL GLYCOL': 'NO RATING',
#  'CAPRYLYL METHICONE': 'NO RATING',
#  'CAPSICUM FRUTESCENS FRUIT EXTRACT': 'ICKY',
#  'CARAMEL': 'NO RATING',
#  'CARBAMIDE': 'GOODIE',
#  'CARBOMER': 'NO RATING',
#  'CARBOXYMETHYL CELLULOSE': 'NO RATING',
#  'CARMINE': 'NO RATING',
#  'CARNAUBA WAX': 'NO RATING',
#  'CARNOSINE': 'GOODIE',
#  'CARRAGEENAN': 'NO RATING',
#  'CARRAGEENAN EXTRACT': 'GOODIE',
#  'CARROT ROOT OIL': 'GOODIE',
#  'CARROT SEED OIL': 'NO RATING',
#  'CARTHAMUS TINCTORIUS OLEOSOMES': 'GOODIE',
#  'CARTHAMUS TINCTORIUS SEED OIL': 'GOODIE',
#  'CASSIA ALATA LEAF EXTRACT': 'GOODIE',
#  'CASTOR OIL': 'NO RATING',
#  'CAVIAR LIME FRUIT EXTRACT': 'NO RATING',
#  'CAYENNE PEPPER FRUIT EXTRACT': 'ICKY',
#  'CELLULOSE': 'NO RATING',
#  'CELLULOSE GUM': 'NO RATING',
#  'CENTAUREA CYANUS FLOWER WATER': 'GOODIE',
#  'CENTELLA ASIATICA EXTRACT': 'GOODIE',
#  'CERA ALBA': 'NO RATING',
#  'CERAMIDE 1': 'GOODIE',
#  'CERAMIDE 2': 'GOODIE',
#  'CERAMIDE 3': 'GOODIE',
#  'CERAMIDE 6 II': 'GOODIE',
#  'CERAMIDE AP': 'GOODIE',
#  'CERAMIDE EOP': 'GOODIE',
#  'CERAMIDE NG': 'GOODIE',
#  'CERAMIDE NP': 'GOODIE',
#  'CERESIN': 'NO RATING',
#  'CETEARETH-20': 'NO RATING',
#  'CETEARYL ALCOHOL': 'NO RATING',
#  'CETEARYL ETHYLHEXANOATE': 'NO RATING',
#  'CETEARYL GLUCOSIDE': 'NO RATING',
#  'CETEARYL ISONONANOATE': 'NO RATING',
#  'CETEARYL NONANOATE': 'NO RATING',
#  'CETEARYL OCTANOATE': 'NO RATING',
#  'CETEARYL OLIVATE': 'GOODIE',
#  'CETRARIA ISLANDICA THALLUS EXTRACT': 'GOODIE',
#  'CETYL ALCOHOL': 'NO RATING',
#  'CETYL DIMETHICONE': 'NO RATING',
#  'CETYL DIMETHICONE COPOLYOL': 'NO RATING',
#  'CETYL ETHYLHEXANOATE': 'NO RATING',
#  'CETYL HYDROXYETHYLCELLULOSE': 'NO RATING',
#  'CETYL PEG': 'NO RATING',
#  'PPG-10': 'NO RATING',
#  '1 DIMETHICONE': 'NO RATING',
#  'CETYL PALMITATE': 'NO RATING',
#  'CETYL PHOSPHATE': 'NO RATING',
#  'CETYLHYDROXYPROLINE PALMITAMIDE': 'GOODIE',
#  'CHAMOMILLA RECUTITA FLOWER EXTRACT': 'GOODIE',
#  'CHAMOMILLA RECUTITA FLOWER OIL': 'GOODIE',
#  'CHIA SEED OIL': 'GOODIE',
#  'CHLOROPHYLL': 'NO RATING',
#  'CHLORPHENESIN': 'NO RATING',
#  'CHOLESTEROL': 'GOODIE',
#  'CHOLESTERYL NONANOATE': 'NO RATING',
#  'CHOLESTERYL OLEYL CARBONATE': 'NO RATING',
#  'CHOLESTERYL STEARATE': 'NO RATING',
#  'CHONDRUS CRISPUS': 'NO RATING',
#  'CHONDRUS CRISPUS EXTRACT': 'GOODIE',
#  'CHRONOLINE': 'GOODIE',
#  'CHROMIUM OXIDE GREEN': 'NO RATING',
#  'CHROMIUM OXIDE GREENS': 'NO RATING',
#  'CHRONOCYCLIN': 'GOODIE',
#  'CI 14700': 'NO RATING',
#  'CI 17200': 'NO RATING',
#  'CI 19140': 'NO RATING',
#  'CI 42090': 'NO RATING',
#  'CI 45410': 'NO RATING',
#  'CI 75120': 'NO RATING',
#  'CI 75470': 'NO RATING',
#  'CI 77007': 'NO RATING',
#  'CI 77163': 'NO RATING',
#  'CI 77288': 'NO RATING',
#  'CI 77289': 'NO RATING',
#  'CI 77491': 'NO RATING',
#  '77492': 'NO RATING',
#  '77499': 'NO RATING',
#  'CI 77492': 'NO RATING',
#  'CI 77499': 'NO RATING',
#  'CI 77510': 'NO RATING',
#  'CI 77742': 'NO RATING',
#  'CI 77891': 'NO RATING',
#  'CITRAL': 'ICKY',
#  'CITRIC ACID': 'NO RATING',
#  'CITRONELLOL': 'ICKY',
#  'CITRULLUS LANATUS FRUIT EXTRACT': 'GOODIE',
#  'CITRUS AURANTIUM AMARA FLOWER OIL': 'ICKY',
#  'CITRUS AURANTIUM AMARA FLOWER WATER': 'NO RATING',
#  'CITRUS AURANTIUM BERGAMIA FRUIT OIL': 'ICKY',
#  'CITRUS AURANTIUM BERGAMIA PEEL OIL': 'ICKY',
#  'CITRUS AURANTIUM DULCIS FRUIT EXTRACT': 'NO RATING',
#  'CITRUS AURANTIUM DULCIS OIL': 'ICKY',
#  'CITRUS AURANTIUM DULCIS PEEL OIL': 'ICKY',
#  'CITRUS GRANDIS PEEL OIL': 'ICKY',
#  'CITRUS LIMON FRUIT EXTRACT': 'NO RATING',
#  'CITRUS LIMON PEEL OIL': 'ICKY',
#  'CITRUS NOBILIS OIL': 'ICKY',
#  'CITRUS NOBILIS PEEL OIL': 'ICKY',
#  'CITRUS PARADISI PEEL OIL': 'ICKY',
#  'CITRUS RETICULATA PEEL OIL': 'ICKY',
#  'CITRUS UNSHIU EXTRACT': 'NO RATING',
#  'CITRUS UNSHIU PEEL EXTRACT': 'NO RATING',
#  'COCAMIDE DEA': 'ICKY',
#  'COCAMIDE MEA': 'NO RATING',
#  'COCAMIDOPROPYL BETAINE': 'NO RATING',
#  'COCAMIDOPROPYL DIMETHYLAMINE': 'NO RATING',
#  'COCAMIDOPROPYL HYDROXYSULTAINE': 'NO RATING',
#  'COCAMIDOPROPYLAMINE OXIDE': 'NO RATING',
#  'COCETH-7': 'NO RATING',
#  'COCHLEARIA ARMORACIA ROOT EXTRACT': 'NO RATING',
#  'COCO-CAPRYLATE': 'NO RATING',
#  'COCO-GLUCOSIDE': 'NO RATING',
#  'COCOA SEED BUTTER': 'GOODIE',
#  'COCONUT ALKANES': 'NO RATING',
#  'COCONUT ENDOSPERM': 'GOODIE',
#  'COCONUT FRUIT EXTRACT': 'NO RATING',
#  'COCONUT OIL': 'GOODIE',
#  'COCONUT SHELL POWDER': 'NO RATING',
#  'COCONUT WATER': 'GOODIE',
#  'COCOS NUCIFERA FRUIT EXTRACT': 'NO RATING',
#  'COCOS NUCIFERA FRUIT JUICE': 'GOODIE',
#  'COCOS NUCIFERA OIL': 'GOODIE',
#  'COCOS NUCIFERA SHELL POWDER': 'NO RATING',
#  'COCOS NUCIFERA WATER': 'GOODIE',
#  'COENZYME Q10': 'GOODIE',
#  'COGON GRASS ROOT EXTRACT': 'GOODIE',
#  'COLLAGEN': 'GOODIE',
#  'COLLAGEN AMINO ACIDS': 'GOODIE',
#  'COMFREY ROOT EXTRACT': 'NO RATING',
#  'COMMIPHORA MYRRHA RESIN EXTRACT': 'ICKY',
#  'COPERNICIA CERIFERA WAX': 'NO RATING',
#  'COPPER CHLOROPHYLL': 'NO RATING',
#  'COPPER GLUCONATE': 'GOODIE',
#  'COPPER LYSINATE': 'GOODIE',
#  'PROLINATE': 'GOODIE',
#  'COPPER TRIPEPTIDE-1': 'GOODIE',
#  'COPTIS JAPONICA ROOT EXTRACT': 'GOODIE',
#  'CORN STARCH': 'NO RATING',
#  'CORNFLOWER FLOWER WATER': 'GOODIE',
#  'CORYLUS AVELLANA  SEED OIL': 'GOODIE',
#  'COUMARIN': 'ICKY',
#  'CRAMBE ABYSSINICA SEED OIL': 'GOODIE',
#  'CRAMBE OIL': 'GOODIE',
#  'CRANBERRY SEED OIL': 'GOODIE',
#  'CUCUMBER FRUIT EXTRACT': 'GOODIE',
#  'CUCUMBER OIL': 'GOODIE',
#  'CUCUMIS SATIVUS FRUIT EXTRACT': 'GOODIE',
#  'CUCUMIS SATIVUS SEED OIL': 'GOODIE',
#  'CURCULIGO ORCHIOIDES ROOT EXTRACT': 'GOODIE',
#  'CURCULIGO ROOT EXTRACT': 'GOODIE',
#  'CURCUMA LONGA ROOT EXTRACT': 'GOODIE',
#  'CYAMOPSIS TETRAGONOLOBA GUM': 'NO RATING',
#  'CYCLOASTRAGENOL': 'GOODIE',
#  'CYCLOHEXASILOXANE': 'NO RATING',
#  'CYCLOMETHICONE': 'NO RATING',
#  'CYCLOPENTASILOXANE': 'NO RATING',
#  'CYCLOTETRASILOXANE': 'NO RATING',
#  'CYPRIPEDIUM PUBESCENS EXTRACT': 'NO RATING',
#  'DAMASK ROSE FLOWER OIL': 'ICKY',
#  'DAMASK ROSE FLOWER WATER': 'NO RATING',
#  'DANDELION LEAF EXTRACT': 'NO RATING',
#  'DAUCUS CAROTA SATIVA ROOT EXTRACT': 'GOODIE',
#  'DAUCUS CAROTA SATIVA SEED OIL': 'NO RATING',
#  'DECAPEPTIDE-22': 'GOODIE',
#  'DECYL GLUCOSIDE': 'NO RATING',
#  'DEHYDROACETIC ACID': 'NO RATING',
#  'DEXTRIN': 'NO RATING',
#  'DIAZOLIDINYL UREA': 'ICKY',
#  'DIBUTYL ADIPATE': 'NO RATING',
#  'DIBUTYL ETHYLHEXANOYL GLUTAMIDE': 'NO RATING',
#  'DIBUTYL LAUROYL GLUTAMIDE': 'NO RATING',
#  'DICAPRYLYL CARBONATE': 'NO RATING',
#  'DICAPRYLYL ETHER': 'NO RATING',
#  'DIETHYLAMINO HYDROXYBENZOYL HEXYL BENZOATE': 'GOODIE',
#  'DIETHYLHEXYL 2,6-NAPHTHALATE': 'NO RATING',
#  'DIETHYLHEXYL BUTAMIDO TRIAZONE': 'NO RATING',
#  'DIETHYLHEXYL CARBONATE': 'NO RATING',
#  'DIETHYLHEXYL SYRINGYLIDENEMALONATE': 'NO RATING',
#  'DIGLUCOSYL GALLIC ACID': 'GOODIE',
#  'DIGLYCERIN': 'GOODIE',
#  'DIHEPTYL SUCCINATE': 'NO RATING',
#  'DIISOPROPYL ADIPATE': 'NO RATING',
#  'DIISOPROPYL SEBACATE': 'NO RATING',
#  'DIISOSTEAROYL POLYGLYCERYL-3 DIMER DILINOLEATE': 'NO RATING',
#  'DIMETHICONE': 'NO RATING',
#  'DIMETHICONE CROSSPOLYMER': 'NO RATING',
#  'PEG-10': 'NO RATING',
#  '15 CROSSPOLYMER': 'NO RATING',
#  'VINYL DIMETHICONE CROSSPOLYMER': 'NO RATING',
#  'DIMETHICONOL': 'NO RATING',
#  'DIMETHYL ISOSORBIDE': 'NO RATING',
#  'DIMETHYLACRYLAMIDE': 'NO RATING',
#  'ACRYLIC ACID': 'NO RATING',
#  'POLYSTYRENE ETHYL METHACRYLATE COPOLYMER': 'NO RATING',
#  'DIMETHYLMETHOXY CHROMANOL': 'GOODIE',
#  'DIPENTAERYTHRITYL HEXACAPRYLATE': 'NO RATING',
#  'HEXACAPRATE': 'NO RATING',
#  'DIPEPTIDE DIAMINOBUTYROYL BENZYLAMIDE DIACETATE': 'GOODIE',
#  'DIPEPTIDE-2': 'GOODIE',
#  'DIPOTASSIUM GLYCYRRHIZATE': 'GOODIE',
#  'DIPROPYLENE GLYCOL': 'NO RATING',
#  'DIPROPYLENE GLYCOL DIBENZOATE': 'NO RATING',
#  'DISILOXANE': 'NO RATING',
#  'DISODIUM ACETYL GLUCOSAMINE PHOSPHATE': 'GOODIE',
#  'DISODIUM CETEARYL SULFOSUCCINATE': 'NO RATING',
#  'DISODIUM COCO-GLUCOSIDE CITRATE': 'NO RATING',
#  'DISODIUM COCOAMPHODIACETATE': 'NO RATING',
#  'DISODIUM COCOAMPHODIPROPIONATE': 'NO RATING',
#  'DISODIUM EDTA': 'NO RATING',
#  'DISODIUM LAURETH SULFOSUCCINATE': 'NO RATING',
#  'DISODIUM LAURIMINODIPROPIONATE TOCOPHERYL PHOSPHATES': 'GOODIE',
#  'DISODIUM LAURYL SULFOSUCCINATE': 'NO RATING',
#  'DISODIUM PHENYL DIBENZIMIDAZOLE TETRASULFONATE': 'GOODIE',
#  'DISODIUM URIDINE PHOSPHATE': 'GOODIE',
#  'DISTEARDIMONIUM HECTORITE': 'NO RATING',
#  'DMDM HYDANTOIN': 'ICKY',
#  'DMPA': 'NO RATING',
#  'ISOPHTHALIC ACID': 'NO RATING',
#  'SMDI COPOLYMER': 'NO RATING',
#  'DODECANE': 'NO RATING',
#  'DOG-ROSE SEED OIL': 'GOODIE',
#  'DROMETRIZOLE TRISILOXANE': 'NO RATING',
#  'EDDS': 'NO RATING',
#  'EDTA': 'NO RATING',
#  'EGCG': 'SUPERSTAR',
#  'EUK-134': 'GOODIE',
#  'EYESERYL': 'GOODIE',
#  'ECAMSULE': 'GOODIE',
#  'ELFAMOIST AC': 'GOODIE',
#  'ENSULIZOLE': 'GOODIE',
#  'ENZACAMENE': 'ICKY',
#  'EPIDERMAL GROWTH FACTOR': 'NO RATING',
#  'EPIGALLOCATECHIN GALLATE': 'SUPERSTAR',
#  'EPIGALLOCATECHIN GALLATYL GLUCOSIDE': 'GOODIE',
#  'EPSOM SALT': 'NO RATING',
#  'ERIOCEPHALUS PUNCTULATUS OIL': 'NO RATING',
#  'ERYTHRULOSE': 'GOODIE',
#  'ETHANOL': 'ICKY',
#  'ETHOXYDIGLYCOL': 'NO RATING',
#  'ETHYL 2,2-DIMETHYLHYDROCINNAMAL': 'ICKY',
#  'ETHYL ASCORBIC ACID': 'GOODIE',
#  'ETHYL HEXANEDIOL': 'NO RATING',
#  'ETHYL LINOLEATE': 'NO RATING',
#  'ETHYL LINOLENATE': 'NO RATING',
#  'ETHYL MENTHANE CARBOXAMIDE': 'NO RATING',
#  'ETHYL OLEATE': 'NO RATING',
#  'ETHYLBISIMINOMETHYLGUAIACOL MANGANESE CHLORIDE': 'GOODIE',
#  'PROPYLENE': 'NO RATING',
#  'ETHYLHEXYL BENZOATE': 'NO RATING',
#  'ETHYLHEXYL DIMETHYL PABA': 'ICKY',
#  'ETHYLHEXYL HYDROXYSTEARATE': 'NO RATING',
#  'ETHYLHEXYL METHOXYCINNAMATE': 'NO RATING',
#  'ETHYLHEXYL PALMITATE': 'NO RATING',
#  'ETHYLHEXYL SALICYLATE': 'NO RATING',
#  'ETHYLHEXYL STEARATE': 'NO RATING',
#  'ETHYLHEXYL TRIAZONE': 'GOODIE',
#  'ETHYLHEXYLGLYCERIN': 'NO RATING',
#  'ETHYLPARABEN': 'NO RATING',
#  'EUCALYPTUS CITRIODORA OIL': 'ICKY',
#  'EUCALYPTUS ESSENTIAL OIL': 'ICKY',
#  'EUCALYPTUS GLOBULUS LEAF OIL': 'ICKY',
#  'EUCALYPTUS RADIATA LEAF OIL': 'ICKY',
#  'EUGENOL': 'ICKY',
#  'EVENING PRIMROSE OIL': 'GOODIE',
#  'EXPANCEL MICROSPHERES': 'NO RATING',
#  'FARNESOL': 'ICKY',
#  'FERMENTED BULL KELP': 'GOODIE',
#  'FERMENTED RADISH ROOT': 'NO RATING',
#  'FERMENTED SEA KELP': 'GOODIE',
#  'FERMENTED WHITE SHIITAKE': 'GOODIE',
#  'FERMENTOIL GREEN TEA SEED': 'GOODIE',
#  'FERRIC FERROCYANIDE': 'NO RATING',
#  'FERULIC ACID': 'GOODIE',
#  'FLORAZON': 'ICKY',
#  'FORM OF VITAMIN C': 'GOODIE',
#  'FORM OF VITAMIN E': 'GOODIE',
#  'FRAGONIA ESSENCTIAL OIL': 'ICKY',
#  'FRAGRANCE': 'ICKY',
#  'FRUCTOSE': 'GOODIE',
#  "FULLER'S EARTH": 'GOODIE',
#  'GHK': 'GOODIE',
#  'GHK-CU': 'GOODIE',
#  'GALACTOARABINAN': 'GOODIE',
#  'GALACTOMYCES FERMENT FILTRATE': 'GOODIE',
#  'GALAXY SUNBEAT': 'NO RATING',
#  'GALLYL GLUCOSIDE': 'GOODIE',
#  'GELATIN': 'NO RATING',
#  'GENISTEIN': 'GOODIE',
#  'GENOWHITE': 'GOODIE',
#  'GEOGARD 111A': 'NO RATING',
#  'GEOGARD 111S': 'NO RATING',
#  'GERANIOL': 'ICKY',
#  'GERANYLGERANYLACETONE': 'GOODIE',
#  'GERMAN CHAMOMILE FLOWER EXTRACT': 'GOODIE',
#  'GERMAN CHAMOMILE FLOWER OIL': 'GOODIE',
#  'GINGER ROOT EXTRACT': 'GOODIE',
#  'GLOBULARIA CORDIFOLIA CALLUS CULTURE EXTRACT': 'GOODIE',
#  'GLUCOMANNAN': 'GOODIE',
#  'GLUCONOLACTONE': 'SUPERSTAR',
#  'GLUCOSE': 'GOODIE',
#  'GLUTAMIC ACID': 'NO RATING',
#  'GLUTAMYLAMIDOETHYL IMIDAZOLE': 'GOODIE',
#  'GLYCERETH-26': 'NO RATING',
#  'GLYCERETH-7 TRIMETHYL ETHER': 'NO RATING',
#  'GLYCERIN': 'SUPERSTAR',
#  'GLYCEROL': 'SUPERSTAR',
#  'GLYCERYL ACRYLATE': 'NO RATING',
#  'ACRYLIC ACID COPOLYMER': 'NO RATING',
#  'GLYCERYL BEHENATE': 'NO RATING',
#  'EICOSADIOATE': 'NO RATING',
#  'GLYCERYL CAPRYLATE': 'NO RATING',
#  'GLYCERYL DIBEHENATE': 'NO RATING',
#  'GLYCERYL LAURATE': 'NO RATING',
#  'GLYCERYL OLEATE': 'NO RATING',
#  'GLYCERYL STEARATE': 'NO RATING',
#  'GLYCERYL STEARATE CITRATE': 'NO RATING',
#  'GLYCERYL STEARATE SE': 'NO RATING',
#  'GLYCINE': 'GOODIE',
#  'GLYCINE SOJA OIL': 'GOODIE',
#  'GLYCINE SOJA SEED EXTRACT': 'GOODIE',
#  'GLYCOL DISTEARATE': 'NO RATING',
#  'GLYCOLIC ACID': 'SUPERSTAR',
#  'GLYCYRRHIZA GLABRA  ROOT EXTRACT': 'SUPERSTAR',
#  'GOTU KOLA': 'GOODIE',
#  'GRANACTIVE RETINOID': 'GOODIE',
#  'GRAPE EXTRACT': 'GOODIE',
#  'GRAPE FRUIT EXTRACT': 'GOODIE',
#  'GRAPE JUICE EXTRACT': 'GOODIE',
#  'GRAPE SEED EXTRACT': 'GOODIE',
#  'GRAPE SEED OIL': 'GOODIE',
#  'GRAPEFRUIT PEEL OIL': 'ICKY',
#  'GREEN TEA': 'SUPERSTAR',
#  'GUAR GUM': 'NO RATING',
#  'GUARDIANT': 'GOODIE',
#  'GUM ARABIC': 'NO RATING',
#  'HEC': 'NO RATING',
#  'HADASEI 3TM': 'GOODIE',
#  'HAEMATOCOCCUS PLUVIALIS EXTRACT': 'GOODIE',
#  'HAMAMELIS VIRGINIANA  LEAF EXTRACT': 'GOODIE',
#  'HAMAMELIS VIRGINIANA BARK': 'GOODIE',
#  'LEAF': 'ICKY',
#  'TWIG EXTRACT': 'GOODIE',
#  'HAMAMELIS VIRGINIANA EXTRACT': 'GOODIE',
#  'HAMAMELIS VIRGINIANA LEAF WATER': 'NO RATING',
#  'HAMAMELIS VIRGINIANA WATER': 'GOODIE',
#  'HAZELNUT OIL': 'GOODIE',
#  'HDI': 'NO RATING',
#  'TRIMETHYLOL HEXYLLACTONE CROSSPOLYMER': 'NO RATING',
#  'HELIANTHUS ANNUUS EXTRACT': 'GOODIE',
#  'HELIANTHUS ANNUUS SEED OIL': 'GOODIE',
#  'HELIANTHUS ANNUUS SEED OIL UNSAPONIFIABLES': 'GOODIE',
#  'HELIANTHUS ANNUUS SEED WAX': 'NO RATING',
#  'HESPERIDIN': 'GOODIE',
#  'HESPERIDIN METHYL CHALCONE': 'GOODIE',
#  'HEXAMETHYLDISILOXANE': 'NO RATING',
#  'HEXANOYL DIPEPTIDE-3 NORLEUCINE ACETATE': 'GOODIE',
#  'HEXAPEPTIDE-9': 'GOODIE',
#  'HEXYL CINNAMAL': 'ICKY',
#  'HEXYL LAURATE': 'NO RATING',
#  'HEXYL NICOTINATE': 'NO RATING',
#  'HEXYLDECANOL': 'NO RATING',
#  'HEXYLENE GLYCOL': 'NO RATING',
#  'HEXYLRESORCINOL': 'GOODIE',
#  'HIPPOPHAE RHAMNOIDES FRUIT OIL': 'GOODIE',
#  'HISTIDINE': 'GOODIE',
#  'HOMOSALATE': 'NO RATING',
#  'HONEY': 'GOODIE',
#  'HONEY EXTRACT': 'GOODIE',
#  'HONEYSUCKLE EXTRACT': 'NO RATING',
#  'HORSE CHESTNUT': 'GOODIE',
#  'HORSERADISH ROOT': 'NO RATING',
#  'HOUTTUYNIA CORDATA EXTRACT': 'GOODIE',
#  'HUANGQI': 'GOODIE',
#  'HUMAN ADIPOSE DERIVED STEM CELL CONDITIONED MEDIA': 'NO RATING',
#  'HUMAN FIBROBLAST CONDITIONED MEDIA': 'NO RATING',
#  'HYALURONIC ACID': 'GOODIE',
#  'HYDROGEN DIMETHICONE': 'NO RATING',
#  'HYDROGENATED CASTOR OIL': 'NO RATING',
#  'HYDROGENATED COCO-GLYCERIDES': 'NO RATING',
#  'HYDROGENATED LECITHIN': 'GOODIE',
#  'HYDROGENATED POLYDECENE': 'NO RATING',
#  'HYDROGENATED POLYISOBUTENE': 'NO RATING',
#  'HYDROLYZED COLLAGEN': 'GOODIE',
#  'HYDROLYZED CORN STARCH': 'NO RATING',
#  'HYDROLYZED HYALURONIC ACID': 'GOODIE',
#  'HYDROLYZED MARINE COLLAGEN': 'GOODIE',
#  'HYDROLYZED PLACENTAL PROTEIN': 'GOODIE',
#  'HYDROLYZED SODIUM HYALURONATE': 'NO RATING',
#  'HYDROLYZED WHEAT PROTEIN': 'NO RATING',
#  'PVP CROSSPOLYMER': 'NO RATING',
#  'HYDROLYZED YEAST EXTRACT': 'GOODIE',
#  'HYDROXYACETOPHENONE': 'NO RATING',
#  'HYDROXYCITRONELLAL': 'ICKY',
#  'HYDROXYETHYL ACRYLATE': 'NO RATING',
#  'SODIUM ACRYLOYLDIMETHYL TAURATE COPOLYMER': 'NO RATING',
#  'HYDROXYETHYL UREA': 'GOODIE',
#  'HYDROXYETHYLCELLULOSE': 'NO RATING',
#  'HYDROXYMETHOXYPHENYL DECANONE': 'GOODIE',
#  'HYDROXYMETHOXYPHENYL PROPYLMETHYLMETHOXYBENZOFURAN': 'NO RATING',
#  'HYDROXYPALMITOYL SPHINGANINE': 'GOODIE',
#  'HYDROXYPHENOXY PROPIONIC ACID': 'GOODIE',
#  'HYDROXYPHENYL PROPAMIDOBENZOIC ACID': 'GOODIE',
#  'HYDROXYPINACOLONE RETINOATE': 'GOODIE',
#  'HYDROXYPROPYL BISPALMITAMIDE MEA': 'GOODIE',
#  'HYDROXYPROPYL CYCLODEXTRIN': 'GOODIE',
#  'HYDROXYPROPYL METHYLCELLULOSE': 'NO RATING',
#  'HYDROXYPROPYL TETRAHYDROPYRANTRIOL': 'GOODIE',
#  'IFC-CAF': 'NO RATING',
#  'ICELAND MOSS EXTRACT': 'GOODIE',
#  'IMPERATA CYLINDRICA ROOT EXTRACT': 'GOODIE',
#  'INDIAN FRANKINCENSE EXTRACT': 'NO RATING',
#  'INSULIN-LIKE GROWTH FACTOR 1': 'NO RATING',
#  'INULIN': 'GOODIE',
#  'INULIN LAURYL CARBAMATE': 'NO RATING',
#  'IODOPROPYNYL BUTYLCARBAMATE': 'NO RATING',
#  'IRISH MOSS': 'NO RATING',
#  'IRON OXIDE BLACK': 'NO RATING',
#  'IRON OXIDE RED': 'NO RATING',
#  'IRON OXIDE YELLOW': 'NO RATING',
#  'IRON OXIDES': 'NO RATING',
#  'ISCOTRIZINOL': 'NO RATING',
#  'ISOAMYL COCOATE': 'NO RATING',
#  'ISOAMYL LAURATE': 'NO RATING',
#  'ISOAMYL P-METHOXYCINNAMATE': 'NO RATING',
#  'ISOBUTANE': 'NO RATING',
#  'ISOCETETH-20': 'NO RATING',
#  'ISOCETYL STEARATE': 'NO RATING',
#  'ISOCETYL STEAROYL STEARATE': 'NO RATING',
#  'ISODECYL NEOPENTANOATE': 'NO RATING',
#  'ISODECYL SALICYLATE': 'NO RATING',
#  'ISODODECANE': 'NO RATING',
#  'ISOHEXADECANE': 'NO RATING',
#  'ISOLEUCINE': 'GOODIE',
#  'ISONONYL ISONONANOATE': 'NO RATING',
#  'ISOPENTYLDIOL': 'NO RATING',
#  'ISOPROPYL CLOPROSTENATE': 'NO RATING',
#  'ISOPROPYL ISOSTEARATE': 'NO RATING',
#  'ISOPROPYL LAUROYL SARCOSINATE': 'NO RATING',
#  'ISOPROPYL MYRISTATE': 'NO RATING',
#  'ISOPROPYL PALMITATE': 'NO RATING',
#  'ISOSTEARIC ACID': 'NO RATING',
#  'ISOSTEARYL ISOSTEARATE': 'NO RATING',
#  'ISOSTEARYL NEOPENTANOATE': 'NO RATING',
#  'JAPANESE GOLDTHREAD ROOT EXTRACT': 'GOODIE',
#  'JAPANESE HONEYSUCKLE FLOWER EXTRACT': 'GOODIE',
#  'JAPANESE HOT SPRING WATER': 'NO RATING',
#  'JAPANESE PEPPER': 'NO RATING',
#  'JOJOBA ESTERS': 'NO RATING',
#  'JOJOBA OIL': 'GOODIE',
#  'KAOLIN': 'GOODIE',
#  'KAPPAPHYCUS ALVAREZII EXTRACT': 'GOODIE',
#  'KARANJA OIL': 'NO RATING',
#  'KAVA KAVA EXTRACT': 'ICKY',
#  'KELP': 'NO RATING',
#  'KIGELIA AFRICANA FRUIT EXTRACT': 'GOODIE',
#  'KNOTGRASS EXTRACT': 'GOODIE',
#  'KOREAN PASQUE FLOWER EXTRACT': 'NO RATING',
#  'KUKUI NUT OIL': 'GOODIE',
#  'LA': 'GOODIE',
#  'LACTIC ACID': 'SUPERSTAR',
#  'LACTOBACILLUS FERMENT': 'GOODIE',
#  'LACTOBACILLUS FERMENT LYSATE FILTRATE': 'GOODIE',
#  'LACTOBACILLUS': 'GOODIE',
#  'ARUNDINARIA GIGANTEA FERMENT FILTRATE': 'GOODIE',
#  'ERIODICTYON CALIFORNICUM FERMENT EXTRACT': 'GOODIE',
#  'KELP FERMENT FILTRATE': 'GOODIE',
#  'NEREOCYSTIS LUETKEANA FERMENT FILTRATE': 'GOODIE',
#  'PUMPKIN FERMENT EXTRACT': 'GOODIE',
#  'PUNICA GRANATUM FRUIT FERMENT EXTRACT': 'GOODIE',
#  'LACTOBIONIC ACID': 'SUPERSTAR',
#  'LACTOCOCCUS FERMENT LYSATE': 'GOODIE',
#  "LADY'S THISTLE EXTRACT": 'GOODIE',
#  'LADY’S SLIPPER ORCHID EXTRACT': 'NO RATING',
#  'LAMINARIA ALGAE EXTRACT': 'GOODIE',
#  'LAMINARIA SACCHARINA EXTRACT': 'GOODIE',
#  'LANABLUE': 'GOODIE',
#  'LAURETH-23': 'NO RATING',
#  'LAURETH-7': 'NO RATING',
#  'LAURIC ACID': 'GOODIE',
#  'LAURYL GLUCOSIDE': 'NO RATING',
#  'LAURYL METHACRYLATE': 'NO RATING',
#  'SODIUM METHACRYLATE CROSSPOLYMER': 'NO RATING',
#  'LAURYL PEG-9 POLYDIMETHYLSILOXYETHYL DIMETHICONE': 'NO RATING',
#  'LAVANDULA ANGUSTIFOLIA FLOWER WATER': 'NO RATING',
#  'LAVANDULA ANGUSTIFOLIA FLOWER': 'ICKY',
#  'STEM OIL': 'ICKY',
#  'LAVANDULA ANGUSTIFOLIA OIL': 'ICKY',
#  'LAVENDER ESSENTIAL OIL': 'ICKY',
#  'LAVENDER FLOWER WATER': 'NO RATING',
#  'LECITHIN': 'GOODIE',
#  'LEMON FRUIT EXTRACT': 'NO RATING',
#  'LEMON PEEL OIL': 'ICKY',
#  'LENS ESCULENTA FRUIT EXTRACT': 'GOODIE',
#  'LENTIL FRUIT EXTRACT': 'GOODIE',
#  'LENTINUS EDODES MYCELIUM EXTRACT': 'GOODIE',
#  'LEONTOPODIUM ALPINUM CALLUS CULTURE EXTRACT': 'GOODIE',
#  'LEPTOSPERMUM SCOPARIUM BRANCH': 'GOODIE',
#  'LEUCONOSTOC FERMENT FILTRATE': 'NO RATING',
#  'LEUCONOSTOC': 'NO RATING',
#  'RADISH ROOT FERMENT FILTRATE': 'NO RATING',
#  'LEUPHASYL': 'GOODIE',
#  'LICHEN EXTRACT': 'NO RATING',
#  'LICORICE': 'GOODIE',
#  'LICORICE ROOT': 'SUPERSTAR',
#  'LILIAL': 'ICKY',
#  'LIMNANTHES ALBA SEED OIL': 'GOODIE',
#  'LIMONENE': 'ICKY',
#  'LINALOOL': 'ICKY',
#  'LINOLEIC ACID': 'GOODIE',
#  'LINOLENIC ACID': 'GOODIE',
#  'LINSEED OIL': 'GOODIE',
#  'LINUM USITATISSIMUM SEED OIL': 'GOODIE',
#  'LIPOCHROMAN-6': 'GOODIE',
#  'LIPOSOMAL PREPARATION OF APPLE STEM CELLS': 'NO RATING',
#  'LONICERA CAPRIFOLIUM EXTRACT': 'NO RATING',
#  'LONICERA JAPONICA FLOWER EXTRACT': 'GOODIE',
#  'LUMINESS ALGAE': 'NO RATING',
#  'LUTEIN': 'GOODIE',
#  'MACADAMIA INTEGRIFOLIA SEED OIL': 'GOODIE',
#  'MACADAMIA OIL': 'GOODIE',
#  'MACADAMIA TERNIFOLIA SEED OIL': 'GOODIE',
#  'MACROCYSTIS PYRIFERA': 'NO RATING',
#  'MADECASSIC ACID': 'GOODIE',
#  'MADECASSOSIDE': 'GOODIE',
#  'MAGNESIUM ALUMINUM SILICATE': 'NO RATING',
#  'MAGNESIUM ASCORBYL PHOSPHATE': 'GOODIE',
#  'MAGNESIUM CHLORIDE': 'NO RATING',
#  'MAGNESIUM SULFATE': 'NO RATING',
#  'MAJESTEM': 'GOODIE',
#  'MALIC ACID': 'GOODIE',
#  'MALTODEXTRIN': 'NO RATING',
#  'MALUS DOMESTICA FRUIT CELL CULTURE': 'NO RATING',
#  'MANDARIN ORANGE OIL': 'ICKY',
#  'MANDELIC ACID': 'GOODIE',
#  'MANGANESE VIOLET': 'NO RATING',
#  'MANGIFERA INDICA SEED OIL': 'GOODIE',
#  'MANGO SEED OIL': 'GOODIE',
#  'MANNITOL': 'GOODIE',
#  'MANNOSE': 'GOODIE',
#  'MANUKA ESSENTIAL OIL': 'GOODIE',
#  'MAQUI BERRY OIL': 'GOODIE',
#  'MARULA SEED OIL': 'GOODIE',
#  'MASTIC GUM': 'NO RATING',
#  'MATRIXYL': 'GOODIE',
#  "MATRIXYL SYNTHE'6": 'GOODIE',
#  'MEADOWFOAM OIL': 'GOODIE',
#  'MEADOWSWEET EXTRACT': 'GOODIE',
#  'MEL': 'GOODIE',
#  'MELALEUCA ALTERNIFOLIA LEAF EXTRACT': 'NO RATING',
#  'MELALEUCA ALTERNIFOLIA LEAF OIL': 'GOODIE',
#  'MELALEUCA ALTERNIFOLIA LEAF WATER': 'NO RATING',
#  'MELALEUCA LEUCADENDRON CAJUPUTI LEAF OIL': 'ICKY',
#  'MELALEUCA TERETIFOLIA BRANCH': 'ICKY',
#  'MELISSA OFFICINALIS LEAF OIL': 'ICKY',
#  'MELITANE': 'GOODIE',
#  'MENTHA PIPERITA LEAF OIL': 'ICKY',
#  'MENTHA PIPERITA OIL': 'ICKY',
#  'MENTHOL': 'ICKY',
#  'METHICONE': 'NO RATING',
#  'METHOXYCINNAMIDOPROPYL HYDROXYSULTAINE': 'NO RATING',
#  'METHYL DIISOPROPYL PROPIONAMIDE': 'NO RATING',
#  'METHYL GLUCETH-10': 'NO RATING',
#  'METHYL GLUCETH-20': 'NO RATING',
#  'METHYL GLUCOSE SESQUISTEARATE': 'NO RATING',
#  'METHYL METHACRYLATE CROSSPOLYMER': 'NO RATING',
#  'PEG': 'NO RATING',
#  'PPG-4': 'NO RATING',
#  '3 METHACRYLATE CROSSPOLYMER': 'NO RATING',
#  'METHYL TRIMETHICONE': 'NO RATING',
#  'METHYLCHLOROISOTHIAZOLINONE': 'ICKY',
#  'METHYLENE BIS-BENZOTRIAZOLYL TETRAMETHYLBUTYLPHENOL': 'GOODIE',
#  'METHYLGLUCOSIDE PHOSPHATE': 'GOODIE',
#  'METHYLHEPTYL LAURATE': 'NO RATING',
#  'METHYLISOTHIAZOLINONE': 'ICKY',
#  'METHYLPARABEN': 'NO RATING',
#  'METHYLPROPANEDIOL': 'NO RATING',
#  'MEXORYL XL': 'NO RATING',
#  'MICA': 'NO RATING',
#  'MICROCITRUS AUSTRALASICA FRUIT EXTRACT': 'NO RATING',
#  'MICROCRYSTALLINE CELLULOSE': 'NO RATING',
#  'MILK PEPTIDE COMPLEX': 'GOODIE',
#  'MILK THISTLE OIL': 'GOODIE',
#  'MIMOSA WAX': 'NO RATING',
#  'MINERAL OIL': 'NO RATING',
#  'MONTMORILLONITE': 'GOODIE',
#  'MORINGA OLEIFERA SEED OIL': 'GOODIE',
#  'MORINGA SEED OIL': 'GOODIE',
#  'MOUNTAIN ARNICA EXTRACT': 'ICKY',
#  'MU-CONOTOXIN CNIIIC': 'GOODIE',
#  'MYRISTIC ACID': 'NO RATING',
#  'MYRISTOYL HEXAPEPTIDE-16': 'GOODIE',
#  'MYRISTOYL NONAPEPTIDE-3': 'GOODIE',
#  'MYRISTOYL PENTAPEPTIDE-17': 'GOODIE',
#  'MYRISTYL MALATE PHOSPHONIC ACID': 'GOODIE',
#  'MYRISTYL MYRISTATE': 'NO RATING',
#  'MYRISTYL NICOTINATE': 'GOODIE',
#  'MYRRH': 'ICKY',
#  'MYRTLE EXTRACT': 'ICKY',
#  'MYRTUS COMMUNIS EXTRACT': 'ICKY',
#  'N-BUTYL ALCOHOL': 'NO RATING',
#  'NAN-WUWEIZI FRUIT EXTRACT': 'GOODIE',
#  'NEO HELIOPAN AP': 'GOODIE',
#  'NEOPENTYL GLYCOL DICAPRYLATE': 'NO RATING',
#  'DICAPRATE': 'NO RATING',
#  'NEOPENTYL GLYCOL DIHEPTANOATE': 'NO RATING',
#  'NETTLE LEAF EXTRACT': 'GOODIE',
#  'NEUROPEPTIDE-1': 'GOODIE',
#  'NEUROPEPTIDE-2': 'GOODIE',
#  'NIA-114': 'GOODIE',
#  'NIACINAMIDE': 'SUPERSTAR',
#  'NIGELLA SATIVA SEED OIL': 'GOODIE',
#  'NIKKOL GS‐MHL': 'NO RATING',
#  'NOVHYAL': 'GOODIE',
#  'NYLON-12': 'NO RATING',
#  'OAT KERNEL EXTRACT': 'GOODIE',
#  'OCTINOXATE': 'NO RATING',
#  'OCTOCRYLENE': 'NO RATING',
#  ...}

# %%
import pickle

# a = {'hello': 'world'}

with open('eng_rating_inci.pickle', 'wb') as handle:
    pickle.dump(rating_inci, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('eng_irritancy_inci.pickle', 'wb') as handle:
    pickle.dump(irritancy_inci, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('eng_comedogenicity_inci.pickle', 'wb') as handle:
    pickle.dump(comedogenicity_inci, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('eng_function_inci.pickle', 'wb') as handle:
    pickle.dump(function_inci, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('eng_qfacts_inci.pickle', 'wb') as handle:
    pickle.dump(qfacts_inci, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('eng_desc_inci.pickle', 'wb') as handle:
    pickle.dump(desc_inci, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('eng_desc_cosing.pickle', 'wb') as handle:
    pickle.dump(desc_cosing, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('eng_function_cosing.pickle', 'wb') as handle:
    pickle.dump(function_cosing, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('eng_rating_inci.pickle', 'rb') as handle:
    rating_inci = pickle.load(handle)

# %%
def lookup_all_english(ingredient_list, match_dict_inci, match_dict_cosing,
               df_inci, df_cosing, option=''):

    with open('eng_rating_inci.pickle', 'rb') as handle:
        rating_inci = pickle.load(handle)
    with open('eng_irritancy_inci.pickle', 'rb') as handle:
        irritancy_inci = pickle.load(handle)
    with open('eng_comedogenicity_inci.pickle', 'rb') as handle:
        comedogenicity_inci = pickle.load(handle)
    with open('eng_function_inci.pickle', 'rb') as handle:
        function_inci = pickle.load(handle)
    with open('eng_qfacts_inci.pickle', 'rb') as handle:
        qfacts_inci = pickle.load(handle)
    with open('eng_desc_inci.pickle', 'rb') as handle:
        desc_inci = pickle.load(handle)
    with open('eng_desc_cosing.pickle', 'rb') as handle:
        desc_cosing = pickle.load(handle)
    with open('eng_function_cosing.pickle', 'rb') as handle:
        function_cosing = pickle.load(handle)
        
    res = []
    
    for item in tqdm(ingredient_list):
        
        value = match_dict_inci[item]
        if value == 'unknown':
            key = match_dict_cosing.get(item, 'unknown')
            rating = 'No rating'
            irritancy = np.nan
            comedogenicity = np.nan
            functions = function_cosing.get(key, [])
            quickfacts = np.nan
            description = desc_cosing.get(key, [])        
                
        else:
            key = match_dict_inci.get(item, 'unknown')
            rating = rating_inci.get(key, 'No rating')
            irritancy = irritancy_inci.get(key, np.nan)
            comedogenicity = comedogenicity_inci.get(key, np.nan)
            functions = function_inci.get(key, [])
            quickfacts = qfacts_inci.get(key, [])
            description = desc_inci.get(key, [])
            
        if key != 'unknown':    
            if option == 'ingredient':
                res.append(key)
            elif option == 'rating':
                res.append(rating)
            elif option == 'irritancy':
                res.append(irritancy)
            elif option == 'comedogenicity':
                res.append(comedogenicity)
            elif option == 'functions':
                res.append(functions)
            elif option == 'quickfacts':
                res.append(quickfacts)
            elif option == 'description':
                res.append(description)
            else:
                res.extend([[key, functions, rating, irritancy, comedogenicity, quickfacts, description]])
            
    df_res = pd.DataFrame(res, columns=['Ingredient_name', 'Functions', 'Rating', 'Irritancy',
                                        'Comedogenicity', 'Quick_facts', 'Description'])
    
    return df_res

# %%
def lookup_all_vietnamese(ingredient_list, match_dict_cmd, match_dict_cosing,
               df_cmd, df_cosing, option=''):
    
    with open('vie_ratingscore_cmd.pickle', 'rb') as handle:
        ratingscore_cmd = pickle.load(handle)
    with open('vie_function_cmd.pickle', 'rb') as handle:
        function_cmd = pickle.load(handle)
    with open('vie_desc_cmd.pickle', 'rb') as handle:
        desc_cmd = pickle.load(handle)    
    
    with open('eng_desc_cosing.pickle', 'rb') as handle:
        desc_cosing = pickle.load(handle)
    with open('eng_function_cosing.pickle', 'rb') as handle:
        function_cosing = pickle.load(handle)
    
    res = []
    
    for item in tqdm(ingredient_list):
        
        value = match_dict_cmd[item]

        if value == 'unknown':
            key = match_dict_cosing.get(item, 'unknown')
            rating_score = 'Chưa đánh giá'
            functions = function_cosing.get(key, [])
            description = desc_cosing.get(key, [])
        else:
            key = match_dict_cmd.get(item, 'unknown')
            rating_score = ratingscore_cmd.get(key, np.nan)
            functions = function_cmd.get(key, [])
            description = desc_cmd.get(key, [])
            
        if key != 'unknown':             
            if option == 'ingredient':
                res.append(key)
            elif option == 'rating_score':
                res.append(rating_score)
            elif option == 'functions':
                res.append(functions)
            elif option == 'description':
                res.append(description)
            else:
                res.extend([[key, rating_score, functions, description]])
            
    df_res = pd.DataFrame(res, columns=['Ingredient_name', 'Rating_score', 'Functions', 'Description'])
    
    return df_res

# %%
# def lookup_all(ingredient_list, match_dict_inci, match_dict_cosing,
#                df_inci, df_cosing, option=''):

#     with open('eng_rating_inci.pickle', 'rb') as handle:
#         rating_inci = pickle.load(handle)
#     with open('eng_irritancy_inci.pickle', 'rb') as handle:
#         irritancy_inci = pickle.load(handle)
#     with open('eng_comedogenicity_inci.pickle', 'rb') as handle:
#         comedogenicity_inci = pickle.load(handle)
#     with open('eng_function_inci.pickle', 'rb') as handle:
#         function_inci = pickle.load(handle)
#     with open('eng_qfacts_inci.pickle', 'rb') as handle:
#         qfacts_inci = pickle.load(handle)
#     with open('eng_desc_inci.pickle', 'rb') as handle:
#         desc_inci = pickle.load(handle)
#     with open('eng_desc_cosing.pickle', 'rb') as handle:
#         desc_cosing = pickle.load(handle)
#     with open('eng_function_cosing.pickle', 'rb') as handle:
#         function_cosing = pickle.load(handle)
        
#     res = []
    
#     for item in tqdm(ingredient_list):
        
#         value = match_dict_inci[item]
#         if value == 'unknown':
#             key = match_dict_cosing.get(item, 'unknown')
#             rating = 'No rating'
#             irritancy = np.nan
#             comedogenicity = np.nan
#             functions = function_cosing.get(key, [])
#             quickfacts = np.nan
#             description = desc_cosing.get(key, [])        
                
#         else:
#             key = match_dict_inci.get(item, 'unknown')
#             rating = rating_inci.get(key, 'No rating')
#             irritancy = irritancy_inci.get(key, np.nan)
#             comedogenicity = comedogenicity_inci.get(key, np.nan)
#             functions = function_inci.get(key, [])
#             quickfacts = qfacts_inci.get(key, [])
#             description = desc_inci.get(key, [])
            
#         if key != 'unknown':    
#             if option == 'ingredient':
#                 res.append(key)
#             elif option == 'rating':
#                 res.append(rating)
#             elif option == 'irritancy':
#                 res.append(irritancy)
#             elif option == 'comedogenicity':
#                 res.append(comedogenicity)
#             elif option == 'functions':
#                 res.append(functions)
#             elif option == 'quickfacts':
#                 res.append(quickfacts)
#             elif option == 'description':
#                 res.append(description)
#             else:
#                 res.extend([[key, functions, rating, irritancy, comedogenicity, quickfacts, description]])
            
#     df_res = pd.DataFrame(res, columns=['Ingredient_name', 'Functions', 'Rating', 'Irritancy',
#                                         'Comedogenicity', 'Quick_facts', 'Description'])
    
#     return df_res

# %% [markdown]
# # **Function for fuzzy dict**

# %%
# Fuzzy Dict

class FuzzyDict(dict):
    "Provides a dictionary that performs fuzzy lookup"
    def __init__(self, items = None, cutoff = .6):
        """Construct a new FuzzyDict instance

        items is an dictionary to copy items from (optional)
        cutoff is the match ratio below which mathes should not be considered
        cutoff needs to be a float between 0 and 1 (where zero is no match
        and 1 is a perfect match)"""
        super(FuzzyDict, self).__init__()

        if items:
            self.update(items)
        self.cutoff =  cutoff

        # short wrapper around some super (dict) methods
        self._dict_contains = lambda key: \
            super(FuzzyDict,self).__contains__(key)

        self._dict_getitem = lambda key: \
            super(FuzzyDict,self).__getitem__(key)

    def _search(self, lookfor, stop_on_first = False):
        """Returns the value whose key best matches lookfor

        if stop_on_first is True then the method returns as soon
        as it finds the first item
        """

        # if the item is in the dictionary then just return it
        if self._dict_contains(lookfor):
            return True, lookfor, self._dict_getitem(lookfor), 1

        # set up the fuzzy matching tool
        ratio_calc = SequenceMatcher()
        ratio_calc.set_seq1(lookfor)

        # test each key in the dictionary
        best_ratio = 0
        best_match = None
        best_key = None
        for key in self:

            # if the current key is not a string
            # then we just skip it
            try:
                # set up the SequenceMatcher with other text
                ratio_calc.set_seq2(key)
            except TypeError:
                continue

            # we get an error here if the item to look for is not a
            # string - if it cannot be fuzzy matched and we are here
            # this it is defintely not in the dictionary
            try:
            # calculate the match value
                ratio = ratio_calc.ratio()
            except TypeError:
                break

            # if this is the best ratio so far - save it and the value
            if ratio > best_ratio:
                best_ratio = ratio
                best_key = key
                best_match = self._dict_getitem(key)

            if stop_on_first and ratio >= self.cutoff:
                break

        return (
            best_ratio >= self.cutoff,
            best_key,
            best_match,
            best_ratio)


    def __contains__(self, item):
        "Overides Dictionary __contains__ to use fuzzy matching"
        if self._search(item, True)[0]:
            return True
        else:
            return False

    def __getitem__(self, lookfor):
        "Overides Dictionary __getitem__ to use fuzzy matching"
        matched, key, item, ratio = self._search(lookfor)

        if not matched:
            raise KeyError(
                "'%s'. closest match: '%s' with ratio %.3f"%
                    (str(lookfor), str(key), ratio))

        return item

# %%
# Fuzzydict

from fuzzywuzzy import fuzz 

class FuzzyDict(dict):
    "Provides a dictionary that performs fuzzy lookup"
    def __init__(self, items = None, cutoff = .6):
        """Construct a new FuzzyDict instance

        items is an dictionary to copy items from (optional)
        cutoff is the match ratio below which mathes should not be considered
        cutoff needs to be a float between 0 and 1 (where zero is no match
        and 1 is a perfect match)"""
        super(FuzzyDict, self).__init__()

        if items:
            self.update(items)
        self.cutoff =  cutoff

        # short wrapper around some super (dict) methods
        self._dict_contains = lambda key: \
            super(FuzzyDict,self).__contains__(key)

        self._dict_getitem = lambda key: \
            super(FuzzyDict,self).__getitem__(key)

    def _search(self, lookfor, stop_on_first = False):
        """Returns the value whose key best matches lookfor

        if stop_on_first is True then the method returns as soon
        as it finds the first item
        """

        # if the item is in the dictionary then just return it
        if self._dict_contains(lookfor):
            return True, lookfor, self._dict_getitem(lookfor), 1

        # set up the fuzzy matching tool
        #ratio_calc = difflib.SequenceMatcher()
        #ratio_calc.set_seq1(lookfor)

        # test each key in the dictionary
        best_ratio = 0
        best_match = None
        best_key = None
        for key in self:

            # if the current key is not a string
            # then we just skip it
            if not isinstance(key, str):
                continue

            # we get an error here if the item to look for is not a
            # string - if it cannot be fuzzy matched and we are here
            # this it is defintely not in the dictionary
            try:
            # calculate the match value
                ratio = fuzz.ratio(lookfor, key)/100
            except TypeError:
                break

            # if this is the best ratio so far - save it and the value
            if ratio > best_ratio:
                best_ratio = ratio
                best_key = key
                best_match = self._dict_getitem(key)

            if stop_on_first and ratio >= self.cutoff:
                break

        return (
            best_ratio >= self.cutoff,
            best_key,
            best_match,
            best_ratio)


    def __contains__(self, item):
        "Overides Dictionary __contains__ to use fuzzy matching"
        if self._search(item, True)[0]:
            return True
        else:
            return False

    def __getitem__(self, lookfor):
        "Overides Dictionary __getitem__ to use fuzzy matching"
        matched, key, item, ratio = self._search(lookfor)

        if not matched:
            raise KeyError(
                "'%s'. closest match: '%s' with ratio %.3f"%
                    (str(lookfor), str(key), ratio))

        return item

# %%
def fuzzy_match_ingredients(ing_list, fuzdict):
    match_dict = {}
    for ing in tqdm(ing_list):
        if ing in match_dict.keys():
            continue
        upper_ing = ing.upper()
        if fuzdict.__contains__(upper_ing):
            match_dict[ing] = fuzdict[upper_ing]
        else:
            match_dict[ing] = 'unknown'
    
    return match_dict

# %% [markdown]
# # **Testing: Englist**

# %%
# df_ingredient = pd.read_csv(ingredient_df_path)
df_inci = pd.read_csv('../Database/INCI/ingredient_inci_1570.csv')
df_cosing = pd.read_csv('../Database/ingredient_cosing_37309.csv')
df_paula = pd.read_csv('../Database/PAULA/ingredient_paula_1833_new.csv')

# %%
# df_inci.rename(columns={'Ingredient_name': 'ingredient_name',
#                        'Rating': 'rating',
#                         'Irritancy': 'irritancy',
#                         'Comedogenicity': 'comedogenicity',
#                         'Rating_score': 'rating_score',
#                        'Functions': 'functions',
#                        'Quick_facts': 'quick_facts',
#                        'Details': 'description',
#                        'Link': 'link'}, inplace=True)
# df_inci['ingredient_name'] = df_inci['ingredient_name'].apply(lambda x: x.upper())

# %%
# # df_paula['rating'] = df_paula['rating'].apply(lambda x: 'Good' if x == 'GOOD' else x)
# df_paula['rating'] = df_paula['rating'].map({'Best': 'superstar',
#                                             'Good': 'goodie',
#                                              'GOOD': 'goodie',
#                                             'Poor': 'icky',
#                                             'Average': 'average'
#                                             })
# df_paula['rating_score'] = df_paula['rating'].map({'icky': 0,
#                                                  'average': 1,
#                                                  'goodie': 2,
#                                                  'superstar': 3})
# df_paula.rename(columns={'name': 'ingredient_name',
#                         'category': 'functions',
#                         }, inplace=True)
# df_paula['ingredient_name'] = df_paula['ingredient_name'].apply(lambda x: x.upper())

# %%
boxes = get_bounding_box('../text-detection-ctpn/data/res/sample5.txt')
img_path = '../Sample_images/sample5.JPG'
# img = cv2.imread('../Sample_images/sample5.JPG')
# img_ocr = preprocess_for_ocr(img)
# cv2.imshow('sample', img_ocr)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

text = ''
for box in boxes:
    croped = crop_line(img_path, box)
    string = ocr(croped)
    text = text + ' ' + str(string.strip('\n').strip('\x0c').strip())

text_result = clean_string(text)
ing_list = string_to_list(text_result)

# %%
cosing_dict = {name.strip(): name.strip() for name in df_cosing['ingredient_name']}
fd_cosing = FuzzyDict(cosing_dict, cutoff = .6)
print(len(fd_cosing))

paula_dict = {name.strip(): name.strip() for name in df_paula['ingredient_name']}
fd_paula = FuzzyDict(paula_dict, cutoff = .6)
print(len(fd_paula))

inci_dict = {name.strip(): name.strip() for name in df_inci['ingredient_name']}
fd_inci = FuzzyDict(inci_dict, cutoff = .7)
print(len(fd_inci))
# Out:
# 29908
# 1833
# 1528

# %% [markdown]
# # **End to end**

# %%
def before_ctpn(img_path):
    img = cv2.imread(img_path)
    img_ctpn = preprocess_for_ocr(img, enhance=2)
    
    return img_ctpn

# %%
def ocr_everything(img_path, boundingtxt_file, inci_path, cmd_path, cosing_path, language):
    
    boxes = get_bounding_box(boundingtxt_file)
    
    # Preprocess image for OCR:
    img = cv2.imread(img_path)
    
    # doing OCR
    text = ''
    for box in boxes:
        cropped = crop_line(img_path, box)
        string = ocr(cropped)
        text = text + ' ' + str(string.strip('\n').strip('\x0c').strip())
    
#     if debug:
#         print(text)
    
    # Cleaning result from OCR
    text_result = clean_string(text)
    ing_list = string_to_list(text_result)
    
#     if debug:
#         print("-----")
#         print(text_result)
        
    # Loading ingredient dataframe
    
    df_cosing = pd.read_csv(cosing_path) #'../Database/ingredient_cosing_37309.csv'
    # fd_cosing
    cosing_dict = {name.strip(): name.strip() for name in df_cosing['ingredient_name']}
    fd_cosing = FuzzyDict(cosing_dict, cutoff = .6)
    match_dict_cosing = fuzzy_match_ingredients(ing_list, fd_cosing)
    print('len fd cosing:', len(fd_cosing))
    # Input for later models: KNN and randomforest
    model_input = [[name for name in match_dict_cosing.values()]]
    
    # fd main
    if language == 'Vietnamese':
        df_cmd = pd.read_csv(cmd_path) # Vietnamese database
        cmd_dict = {name.strip(): name.strip() for name in df_cmd['ingredient_name']}
        fd_cmd = FuzzyDict(cmd_dict, cutoff = .7)
        match_dict_fuzzy = fuzzy_match_ingredients(ing_list, fd_cmd)
        print('len fd cmd:', len(fd_cmd))
    else:
        df_inci = pd.read_csv(inci_path) # '../Database/CALLMEDUY/ingredient_vietnamese_3818.csv'
        inci_dict = {name.strip(): name.strip() for name in df_inci['ingredient_name']}
        fd_inci = FuzzyDict(inci_dict, cutoff = .7)
        match_dict_fuzzy = fuzzy_match_ingredients(ing_list, fd_inci)
        print('len fd inci:', len(fd_inci))
    
    # Compare product ingredient list and database
    # match_dict = find_matching_ingredient(ing_list, rating, 0.55)
    
    if debug:
        print(match_dict_fuzzy)
        print(list(match_dict_fuzzy.values()))

    if debug:
        print("length match_dict_fuzzy", len(match_dict_fuzzy))
        print("length match_dict_extra", len(match_dict_cosing))
    
    # Analyzing ingredient
    if language == 'Vietnamese':
        df_res = lookup_all_vietnamese(ing_list, match_dict_fuzzy, match_dict_cosing, df_cmd, df_cosing)
    
    else:
        df_res = lookup_all_english(ing_list, match_dict_fuzzy, match_dict_cosing, df_inci, df_cosing)
        
    return df_res, model_input

# %%
def after_ctpn_english(img_path, txt_path, inci_path, cosing_path):
    # Get annotations of bounding boxes
    boxes = get_bounding_box(txt_path)
    
#     # Preprocess image for OCR:
#     img = cv2.imread(img_path)
#     #img_ocr = preprocess_for_ocr(img)
#     img_ocr = img
    
    # doing OCR
    text = ''
    for box in boxes:
        croped = crop_line(img_path, box)
        string = ocr(croped)
        text = text + ' ' + str(string.strip('\n').strip('\x0c').strip())
    
    print(text)
    
    # Cleaning result from OCR
    text_result = clean_string(text)
    ing_list = string_to_list(text_result)
    
#     print("-----")
#     print(text_result)
    
    # Loading ingredient dataframe
    df_inci = pd.read_csv(inci_path) # '../Database/CALLMEDUY/ingredient_vietnamese_3818.csv'
    df_cosing = pd.read_csv(cosing_path) #'../Database/ingredient_cosing_37309.csv'
    
#     rating_inci, irritancy_inci, comedogenicity_inci, function_inci, qfacts_inci, desc_inci, desc_cosing, function_cosing = create_dict_english(df_inci, df_cosing)
    
    # fd_cmd
    inci_dict = {name.strip(): name.strip() for name in df_inci['ingredient_name']}
    fd_inci = FuzzyDict(inci_dict, cutoff = .7)
    
    # fd_cosing
    cosing_dict = {name.strip(): name.strip() for name in df_cosing['ingredient_name']}
    fd_cosing = FuzzyDict(cosing_dict, cutoff = .6)
    
    # Compare product ingredient list and database
    match_dict_inci = fuzzy_match_ingredients(ing_list, fd_inci)
    match_dict_cosing = fuzzy_match_ingredients(ing_list, fd_cosing)
    
    model_input = [[name for name in match_dict_cosing.values()]]

    
    # Analyzing ingredient
    df_res = lookup_all(ing_list, match_dict_fuzzy, match_dict_cosing, df_inci, df_cosing)
    
    return df_res, model_input

# %%
df_res_test, model_input_test = ocr_everything('../Sample_images/sample5.JPG',
                                                '../text-detection-ctpn/data/res/sample5.txt', 
                                                '../Database/INCI/ingredient_inci_1570.csv',
                                               '../Database/CALLMEDUY/ingredient_vietnamese_3818.csv',
                                                '../Database/ingredient_cosing_37309.csv',
                                              language='English')
# Out:
# 100%|██████████| 43/43 [00:01<00:00, 40.91it/s]
# 100%|██████████| 43/43 [00:00<00:00, 431.27it/s]
# len fd cosing: 29908
# len fd inci: 1528
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2a6f84156e72> in <module>
#       4                                                '../Database/CALLMEDUY/ingredient_vietnamese_3818.csv',
#       5                                                 '../Database/ingredient_cosing_37309.csv',
# ----> 6                                               language='English')
#
# <ipython-input-36-6d3deea97095> in ocr_everything(img_path, boundingtxt_file, inci_path, cmd_path, cosing_path, language)
#      52     # match_dict = find_matching_ingredient(ing_list, rating, 0.55)
#      53
# ---> 54     if debug:
#      55         print(match_dict_fuzzy)
#      56         print(list(match_dict_fuzzy.values()))
#
# NameError: name 'debug' is not defined

# %%
with open('../Model_product_evaluator/ingredient_idx.pickle', 'rb') as handle:
    ingredient_idx = pickle.load(handle)

with open('../Model_product_evaluator/ingredient_idx_1000.pickle', 'rb') as handle:
    ingredient_idx_1000 = pickle.load(handle)

# %%
# Load random forest model for prediction
with open('../Model_product_evaluator/rf_200.pkl', 'rb') as model:
    reload_rf = pickle.load(model)

# %%
# Load KNN and dataset for product recommendation
with open('../Model_product_evaluator/recommendation.pkl', 'rb') as model:
    reload_knn = pickle.load(model)

df_recommendation = pd.read_csv('../Model_product_evaluator/recommendation_pool.csv')

# %%
def transform(X): # X: list
    M = len(X)
    N = len(ingredient_idx)
    A = np.zeros((M, N), dtype=np.uint8)
    i= 0
    for ing_list in X:
        x = np.zeros(N, dtype=np.uint8)
        for ingredient in ing_list:
            # Get the index for each ingredient
            if ingredient in ingredient_idx.keys():
                idx = ingredient_idx[ingredient]
                x[idx] = 1
            else:
                pass

        A[i, :] = x
        i += 1
    input_rf = A[:, :1000]
    input_knn = A
    
    return input_rf, input_knn

# %%
def evaluate_recommend(img_path, txt_path, inci_path, cmd_path, cosing_path, ingredient_idx, ingredient_idx_1000,
                      language):
    
    df_res, model_input = ocr_everything(img_path, txt_path, inci_path, cmd_path, cosing_path, language)
    input_rf, input_knn = transform(model_input)
    
    # evaluate score
    prediction = reload_rf.predict(input_rf)
    print(prediction)
    
    # recommendation
    distances, indices = reload_knn.kneighbors(input_knn)
    
    location = indices.tolist()[0]
    df_recommended = df_recommendation.iloc[location, :]
    
    return prediction, df_res, df_recommended

# %%
prediction, df_res, df_recommended = evaluate_recommend('../Sample_images/sample5.JPG',
                                                       '../text-detection-ctpn/data/res/sample5.txt', 
                                                       '../Database/INCI/ingredient_inci_1570.csv',
                                                    '../Database/CALLMEDUY/ingredient_vietnamese_3818.csv',
                                                       '../Database/ingredient_cosing_37309.csv',
                                                        ingredient_idx,
                                                        ingredient_idx_1000,
                                                       language='Vietnamese')
# Out:
# 100%|██████████| 43/43 [00:01<00:00, 37.17it/s]
# 100%|██████████| 43/43 [00:00<00:00, 269.13it/s]
# len fd cosing: 29908
# 100%|██████████| 43/43 [00:00<00:00, 118420.93it/s]
# len fd cmd: 3818
# [4]

# %%
# Out:
#                           Ingredient_name   Rating_score  \
# 0                            AQUA (WATER)              4
# 1            CAPRYLIC/CAPRIC TRIGLYCERIDE            NaN
# 2                           CETYL ALCOHOL              4
# 3                             PROPANEDIOL              5
# 4                         STEARYL ALCOHOL              4
# 5                                GLYCERIN              5
# 6                      SODIUM HYALURONATE              5
# 7                                ARGININE              4
# 8                           ASPARTIC ACID              4
# 9                                 GLYCINE              4
# 10                                ALANINE              4
# 11                                 SERINE              4
# 12                                 VALINE              4
# 13                             ISOLEUCINE              4
# 14                                PROLINE              4
# 15                              THREONINE              4
# 16                              HISTIDINE              4
# 17                          PHENYLALANINE              4
# 18                                GLUCOSE              4
# 19                                MALTOSE              4
# 20                               FRUCTOSE              4
# 21                              TREHALOSE              4
# 22                SODIUM ALUMINUM LACTATE  Chưa đánh giá
# 23                                   UREA              4
# 24                              ALLANTOIN              5
# 25                          LINOLEIC ACID              5
# 26                             OLEIC ACID              4
# 27          PHYTOSTERYL CANOLA GLYCERIDES              4
# 28                          PALMITIC ACID              4
# 29                           STEARIC ACID              4
# 30                               LECITHIN              5
# 31                               TRIOLEIN              5
# 32                             TOCOPHEROL              5
# 33                               CARBOMER              4
# 34                           ISOCETETH-20              5
# 35                         POLYSORBATE 20              4
# 36                        SODIUM CHLORIDE              4
# 37                            CITRIC ACID              4
# 38  TRISODIUM ETHYLENEDIAMINE DISUCCINATE              4
# 39          NEOPENTYL GLYCOL DIHEPTANOATE              4
# 40                       SODIUM HYDROXIDE              3
# 41                         PHENOXYETHANOL              4
# 42                          CHLORPHENESIN              4
#
#                                             Functions  \
# 0                                         ['Hỗn hợp']
# 1                                                  []
# 2   ['Chất dưỡng ẩm', 'Chất nhũ hóa/làm dầy kết cấ...
# 3                                  ['Chưa phân loại']
# 4   ['Chất dưỡng ẩm', 'Chất nhũ hóa/làm dầy kết cấ...
# 5               ['Chất dưỡng da', 'Chất hồi phục da']
# 6   ['Chất chống oxy hóa', 'Chất dưỡng da', 'Chất ...
# 7                              ['Chất chống oxy hóa']
# 8             ['Chất chống oxy hóa', 'Chất dưỡng da']
# 9                                   ['Chất dưỡng da']
# 10                             ['Chất chống oxy hóa']
# 11            ['Chất chống oxy hóa', 'Chất dưỡng da']
# 12            ['Chất chống oxy hóa', 'Chất dưỡng da']
# 13            ['Chất chống oxy hóa', 'Chất dưỡng da']
# 14            ['Chất chống oxy hóa', 'Chất dưỡng da']
# 15            ['Chất chống oxy hóa', 'Chất dưỡng da']
# 16                             ['Chất chống oxy hóa']
# 17            ['Chất chống oxy hóa', 'Chất dưỡng da']
# 18                                  ['Chất dưỡng da']
# 19                                        ['Hỗn hợp']
# 20                                  ['Chất dưỡng da']
# 21                            ['Cấp nước', 'Hỗn hợp']
# 22                              ASTRINGENT, BUFFERING
# 23       ['Tẩy da chết', 'Cấp nước', 'Chất dưỡng da']
# 24                                ['Chất làm dịu da']
# 25  ['Chất làm dịu da', 'Chất chống oxy hóa', 'Chấ...
# 26            ['Tạo kết cấu sản phẩm', 'Làm sạch da']
# 27  ['Làm sạch da', 'Chất nhũ hóa/làm dầy kết cấu ...
# 28  ['Làm sạch da', 'Chất dưỡng ẩm', 'Chất dưỡng da']
# 29  ['Chất dưỡng ẩm', 'Chất dưỡng da', 'Chất nhũ h...
# 30                 ['Chất dưỡng ẩm', 'Chất dưỡng da']
# 31              ['Chất dưỡng da', 'Chất hồi phục da']
# 32                  ['Chất chống oxy hóa', 'Vitamin']
# 33                           ['Tạo kết cấu sản phẩm']
# 34  ['Làm sạch da', 'Chất nhũ hóa/làm dầy kết cấu ...
# 35  ['Làm sạch da', 'Chất tạo độ trượt cho sản phẩm']
# 36                  ['Thành phần tẩy da chết vật lý']
# 37  ['Tẩy da chết', 'Chưa phân loại', 'Chất làm sá...
# 38                                        ['Hỗn hợp']
# 39        ['Tạo kết cấu sản phẩm', 'Chất làm mềm da']
# 40                 ['Làm sạch da', 'Gây kích ứng da']
# 41                                  ['Chất bảo quản']
# 42                                  ['Chất bảo quản']
#
#                                           Description
# 0   Là thành phần mỹ phẩm được sử dụng phổ biến, n...
# 1                                                  []
# 2   Cetearyl Alcohol và các loại cồn béo khác giữ ...
# 3   Propanediol là một chất tự nhiên, được dùng th...
# 4   Cồn béo được sử dụng làm chất dưỡng ẩm và giữ ...
# 5   Glycerin là một chất dưỡng da và phục hồi da, ...
# 6   Sodium Hyaluronate là dạng muối của axit hyalu...
# 7                 Chất này có khả năng chống oxy hóa.
# 8   Nghiên cứu chỉ ra rằng amino axit và dẫn xuất ...
# 9   Thành phần cơ bản của tất cả các protein trong...
# 10  alanine được biết đến có khả năng cân bằng độ ...
# 11  Một axit amin. Trong các sản phẩm chăm sóc da,...
# 12  Một axit amin. Trong các sản phẩm chăm sóc da,...
# 13  Đó là một axit amin. Trong các sản phẩm chăm s...
# 14  Một axit amin có chứng năng ngậm nước, và một ...
# 15  Một axit amin. Trong các sản phẩm chăm sóc da,...
# 16  Một axit amin. Trong các sản phẩm chăm sóc da,...
# 17  Loại amino axit. Trong các sản phẩm chăm sóc d...
# 18  Monosaccharide (đường đơn) có tính chất giữ nư...
# 19  Maltose là một loại đường. Trong mỹ phẩm, các ...
# 20  Fructose là một loại đường đơn có trong trái c...
# 21        Đường thực vật có tính dưỡng ẩm cho làn da.
# 22          Aluminum, lactate sodium complexes, basic
# 23  Với nồng độ nhỏ, urea có tính giữ nước và tẩy ...
# 24  allantoin trong mỹ phẩm nổi tiếng về khả năng ...
# 25  Linoleic Acid là một axit béo không no và là m...
# 26  Axit béo được sử dụng làm chất làm sạch và tăn...
# 27  Là một thành phần có nguồn gốc từ đậu nành hoặ...
# 28  Axit Palmitic có nhiều chức năng trong mỹ phẩm...
# 29  Axit béo được sử dụng làm chất dưỡng ẩm và chấ...
# 30  Phospholipid tìm thấy trong lòng đỏ trứng và t...
# 31  Triolein là một triester của glycerin và axit ...
# 32  Vitamin E có trong da người, nhưng có thể bị c...
# 33  Nhóm các chất tạo kết cấu sản phẩm tổng hợp đư...
# 34  Một thành phần trợ giúp tiện dụng hoạt động nh...
# 35  Thuật ngữ được sử dụng để mô tả một loạt các t...
# 36  Được sử dụng chủ yếu như thành phần liên kết t...
# 37  Axit chiết xuất từ trái cây họ cam chanh quýt ...
# 38  Tương tự như tetraodium EDTA. Được sử dụng làm...
# 39  có chức năng như chất làm mềm da không chứa nư...
# 40  Còn được gọi là dung dịch kiềm, sodium hydroxi...
# 41  Phenoxyethanol, còn được gọi là Ethylene Glyco...
# 42  Chlorphenesin là một chất bảo quản tổng hợp đư...

# %% [raw]
# df_res

# %%
df_recommended
# Out:
#       cat_name                   subcat_name  \
# 1755      Skin  Facial Moisturizer/Treatment
# 14058     Skin               Facial Cleanser
# 10734     Skin               Facial Cleanser
# 5233      Skin                    Hand Cream
# 13269     Skin                   Moisturizer
#
#                                              product_url product_brand  \
# 1755   https://www.ewg.org/skindeep/products/879430-T...  The Ordinary
# 14058  https://www.ewg.org/skindeep/products/922934-P...      Pacifica
# 10734  https://www.ewg.org/skindeep/products/917207-P...      Pacifica
# 5233   https://www.ewg.org/skindeep/products/878116-D...          Duke
# 13269  https://www.ewg.org/skindeep/products/846427-A...        Aveeno
#
#                                             product_name product_score  \
# 1755                   Natural Moisturizing Factors + HA            03
# 14058                    Cosmic Hemp Balancing Face Wash            04
# 10734                    Cosmic Hemp Balancing Face Wash            04
# 5233             Cannon Bloody Knuckles Hand Repair Balm            03
# 13269  Active Naturals Sheer Hydration Daily Moisturi...            02
#
#                                              product_img  \
# 1755   https://static.ewg.org/skindeep_images/8794/87...
# 14058  https://static.ewg.org/skindeep_images/9229/92...
# 10734  https://static.ewg.org/skindeep_images/9172/91...
# 5233   https://static.ewg.org/skindeep_images/8781/87...
# 13269  https://static.ewg.org/skindeep_images/8464/84...
#
#                                          ingredient_list  \
# 1755   Aqua (Water), Caprylic/Capric Triglyceride, Ce...
# 14058  AQUA, DISODIUM COCOAMPHODIACETATE, HEMP EXTRAC...
# 10734  AQUA, DISODIUM COCOAMPHODIACETATE, HEMP EXTRAC...
# 5233   WATER, GLYCERIN, STEARIC ACID, BUTYROSPERMUM P...
# 13269  WATER, DICAPRYLYL ETHER, GLYCERIN, CAPRYLIC/CA...
#
#                                             new_ing_list  \
# 1755   ['CAVIAR WATER', 'CAPRIC TRIGLYCERIDE', 'CETYL...
# 14058  ['WATER', 'DISODIUM COCOAMPHODIACETATE', 'SHRI...
# 10734  ['WATER', 'DISODIUM COCOAMPHODIACETATE', 'SHRI...
# 5233   ['WATER', 'GLYCERIN', 'STEARIC ACID', 'BUTYROS...
# 13269  ['WATER', 'DICAPRYLYL ETHER', 'GLYCERIN', 'CAP...
#
#                                       new_ing_list_fixed  new_product_score
# 1755   WATER, CAPRIC TRIGLYCERIDE, CETYL ALCOHOL, PRO...                  4
# 14058  WATER, DISODIUM COCOAMPHODIACETATE, SHRIMP EXT...                  5
# 10734  WATER, DISODIUM COCOAMPHODIACETATE, SHRIMP EXT...                  5
# 5233   WATER, GLYCERIN, STEARIC ACID, BUTYROSPERMUM P...                  4
# 13269  WATER, DICAPRYLYL ETHER, GLYCERIN, CAPRIC TRIG...                  3

# %%
df_res
# Out:
#                           Ingredient_name  \
# 0                                   WATER
# 1           CAPRYLIC/ CAPRIC TRIGLYCERIDE
# 2                           CETYL ALCOHOL
# 3                             PROPANEDIOL
# 4                         STEARYL ALCOHOL
# 5                                GLYCERIN
# 6                      SODIUM HYALURONATE
# 7                                ARGININE
# 8                           ASPARTIC ACID
# 9                                 GLYCINE
# 10                                ALANINE
# 11                                 SERINE
# 12                                 VALINE
# 13                             ISOLEUCINE
# 14                                PROLINE
# 15                              THREONINE
# 16                              HISTIDINE
# 17                          PHENYLALANINE
# 18                                GLUCOSE
# 19                                MANNOSE
# 20                               FRUCTOSE
# 21                              TREHALOSE
# 22                SODIUM ALUMINUM LACTATE
# 23                                   UREA
# 24                              ALLANTOIN
# 25                          LINOLEIC ACID
# 26                             OLEIC ACID
# 27          PHYTOSTERYL CANOLA GLYCERIDES
# 28                          PALMITIC ACID
# 29                           STEARIC ACID
# 30                               LECITHIN
# 31                              TRETINOIN
# 32                             TOCOPHEROL
# 33                               CARBOMER
# 34                           ISOCETETH-20
# 35                         POLYSORBATE 60
# 36                        SODIUM CHLORIDE
# 37                            CITRIC ACID
# 38  TRISODIUM ETHYLENEDIAMINE DISUCCINATE
# 39          NEOPENTYL GLYCOL DIHEPTANOATE
# 40                       SODIUM HYDROXIDE
# 41                         PHENOXYETHANOL
# 42                          CHLORPHENESIN
#
#                                             Functions     Rating Irritancy  \
# 0        {'solvent': '/ingredient-functions/solvent'}  No rating       NaN
# 1                                                  []  No rating       NaN
# 2   {'emollient': '/ingredient-functions/emollient...  No rating         2
# 3   {'solvent': '/ingredient-functions/solvent', '...  No rating       NaN
# 4   {'emollient': '/ingredient-functions/emollient...  No rating         2
# 5   {'skin-identical ingredient': '/ingredient-fun...  superstar         0
# 6   {'skin-identical ingredient': '/ingredient-fun...     goodie         0
# 7   {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 8   {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 9   {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 10  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 11  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 12  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 13  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 14  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 15  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 16  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 17  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 18  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 19  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 20  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 21  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 22                              ASTRINGENT, BUFFERING  No rating       NaN
# 23  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 24     {'soothing': '/ingredient-functions/soothing'}     goodie         0
# 25  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 26  {'emollient': '/ingredient-functions/emollient...  No rating       NaN
# 27               HAIR CONDITIONING, SKIN CONDITIONING  No rating       NaN
# 28  {'skin-identical ingredient': '/ingredient-fun...  No rating         0
# 29  {'emollient': '/ingredient-functions/emollient...  No rating         0
# 30  {'emollient': '/ingredient-functions/emollient...     goodie       NaN
# 31  {'cell-communicating ingredient': '/ingredient...  superstar       NaN
# 32  {'antioxidant': '/ingredient-functions/antioxi...     goodie       0-3
# 33  {'viscosity controlling': '/ingredient-functio...  No rating         0
# 34  {'emulsifying': '/ingredient-functions/emulsif...  No rating       NaN
# 35  {'emulsifying': '/ingredient-functions/emulsif...  No rating       NaN
# 36  {'viscosity controlling': '/ingredient-functio...  No rating       NaN
# 37   {'buffering': '/ingredient-functions/buffering'}  No rating       NaN
# 38   {'chelating': '/ingredient-functions/chelating'}  No rating       NaN
# 39   {'emollient': '/ingredient-functions/emollient'}  No rating       NaN
# 40   {'buffering': '/ingredient-functions/buffering'}  No rating       NaN
# 41  {'preservative': '/ingredient-functions/preser...  No rating       NaN
# 42  {'preservative': '/ingredient-functions/preser...  No rating       NaN
#
#          Comedogenicity                                        Quick_facts  \
# 0                   NaN                                                NaN
# 1                   NaN                                                 []
# 2                     2                                                NaN
# 3                   NaN                                                NaN
# 4                     2                                                NaN
# 5                     0  ['A natural moisturizer that’s also in our ski...
# 6                     0                                                NaN
# 7                   NaN                                                NaN
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN                                                NaN
# 15                  NaN                                                NaN
# 16                  NaN                                                NaN
# 17                  NaN                                                NaN
# 18                  NaN                                                NaN
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                  NaN                                                NaN
# 22                  NaN                                                NaN
# 23                  NaN                                                NaN
# 24                    0                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27                  NaN                                                NaN
# 28                    2                                                NaN
# 29  2020-02-03 00:00:00                                                NaN
# 30                  NaN                                                NaN
# 31                  NaN  ["Tretinoin (a metabolite of vitamin A) is the...
# 32                  0-3  ['Primary fat-soluble antioxidant in our skin ...
# 33                    1                                                NaN
# 34                  NaN                                                NaN
# 35                  NaN                                                NaN
# 36                  NaN                                                NaN
# 37                  NaN                                                NaN
# 38                  NaN                                                NaN
# 39                  NaN                                                NaN
# 40                  NaN                                                NaN
# 41                  NaN                                                NaN
# 42                  NaN                                                NaN
#
#                                           Description
# 0   ['Good old water, aka H2O. The most common ski...
# 1                                                  []
# 2   ['A so-called\xa0fatty (the good, non-drying k...
# 3   ["Propanediol is a natural alternative for the...
# 4   ['A handy multi-tasker,\xa0white to light yell...
# 5   ['Glycerin doesn’t sound very glamorous but it...
# 6   ["It’s the - sodium form - cousin of the famou...
# 7   ["A semi-essential (infants cannot synthesize ...
# 8   ['A non-essential\xa0amino acid \xa0(important...
# 9   ['A non-essential amino acid (the building blo...
# 10  ['A non-essential amino acid (a building block...
# 11  ["Serine is an amino acid that most often come...
# 12  ['An essential amino acid (a building block of...
# 13  ["A branch-chained, essential amino acid that ...
# 14  ["A non-essential amino acid (meaning that our...
# 15  ["An\xa0essential amino acid that's also a key...
# 16  ['A semi-essential amino acid meaning that eno...
# 17  ['An essential amino acid that the body cannot...
# 18  ['A so-called\xa0"Fermentoil" that is created ...
# 19  ['Mannose is one of the many sugar molecules o...
# 20  ['Fancy name for fruit sugar. It has nice wate...
# 21  ['A type of sugar that has\xa0water-binding\xa...
# 22          Aluminum, lactate sodium complexes, basic
# 23  ["Yes, it's the thing that can be found natura...
# 24  ["Super common soothing ingredient. It can be ...
# 25  ['The famous\xa0omega-6 fatty acid,\xa0the mot...
# 26  ['A common fatty acid that can be found in lot...
# 27  Glycerides, canola oil, reaction products with...
# 28  ["A fatty acid that can be found naturally in ...
# 29  ['A common multi-tasker fatty acid. It makes y...
# 30  ["A very common ingredient that can be found i...
# 31  ["If you wanna get the best possible anti-agin...
# 32  ['Vitamin E is the major fat-soluble antioxida...
# 33  ['A big molecule created from repeated subunit...
# 34  ['A handy helper ingredient that works as an e...
# 35  ['A common little helper ingredient that\xa0he...
# 36  ['Sodium chloride is the fancy name of salt. N...
# 37  ['Citric acid comes from citrus fruits and is ...
# 38  ["A helper ingredient that helps to neutralize...
# 39  ["A clear, odorless, very light emollient este...
# 40  ['The unfancy name for it is lye. It’s a solid...
# 41  ['It’s pretty much the current IT-preservative...
# 42  ["A little helper ingredient that works as a p...

# %%
input_rf, input_knn = transform(model_input)

# %%
Your code here
with open('../Model_product_evaluator/rf_200.pkl', 'rb') as model:
    reload_rf = pickle.load(model)

predictions = reload_rf.predict(input_rf)
print(predictions)
# print(f'Accuracy score: {accuracy_score(y_test, predictions)}')
# Out:
# [4]

# %% [markdown]
# # **Recommendation**
