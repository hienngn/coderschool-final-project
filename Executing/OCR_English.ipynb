# %%
import re
import cv2
import numpy as np
import pandas as pd
import shutil
import os
import random
import pytesseract
from pytesseract import Output
from matplotlib import pyplot as plt
# from google.colab.patches import cv2_imshow
try:
    from PIL import Image, ImageEnhance
except ImportError:
    import Image

    import re

import operator
import itertools
import gc
import pickle

from difflib import SequenceMatcher
from ast import literal_eval
from collections import Counter
from tqdm import tqdm

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.GaussianBlur(image, (5,5), 0)

# thresholding
def thresholding(image):
    return cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 7, 4)
                            
# return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# dilation: enhance the bright area
def dilate(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.dilate(image, kernel, iterations=1)

# erosion: enhance the dark area
def erode(image):
  kernel = np.ones((5,5), np.unint8)
  return cv2.erode(image, kernel, iterations=1)

# opening: erosion follow by a dilation
def opening(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

# closing: Dilation followed by Erosion. Removing black holes inside the object 
def closing(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.morphologyEx(opening(image), cv2.MORPH_CLOSE, kernel)

# canny
def canny(image):
      return cv2.Canny(image, 100, 200)

# deskew image
def deskew(image):
    coords = np.column_stack(np.where(image>0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

# template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

# %%
def preprocess_for_ocr(img, enhance=1):
    """
    @param img: image to which the pre-processing steps being applied
    """
    if enhance > 1:
        img = Image.fromarray(img)

        contrast = ImageEnhance.Contrast(img)

        img = contrast.enhance(enhance)

        img = np.asarray(img)
    
    
    gray = get_grayscale(img)
    blur = remove_noise(gray)
    res = thresholding(blur)

    img = cv2.cvtColor(res, cv2.COLOR_GRAY2BGR)

    return img

# %%
def get_bounding_box(txt):
    annotation = txt
    with open(annotation, "r") as file1:
        bounding_boxes = file1.read()
        
    bounding_boxes = bounding_boxes.split('\n')[:-1]
    boxes = [i.split(',')[:-1] for i in bounding_boxes]

    new_boxes = []
    for box in boxes:
        new_box = []
        for i, each in enumerate(box):
            num = int(each)
            if i in [0, 1, 3, 6]:
                num -= 3
            else: 
                num += 3
            new_box.append(num)
        new_boxes.append(new_box)
    new_boxes.sort(key=lambda x: x[1])
    
    return new_boxes

# %%
def crop_line(img_path, box):
    img = cv2.imread(img_path)
    img, (rh, rw) = resize_image(img)
    # points for test.jpg
    cnt = np.array([
            [[box[0], box[1]]],
            [[box[2], box[3]]],
            [[box[4], box[5]]],
            [[box[6], box[7]]]
        ])
    # print("shape of cnt: {}".format(cnt.shape))
    rect = cv2.minAreaRect(cnt)
#     print("rect: {}".format(rect))

    # the order of the box points: bottom left, top left, top right,
    # bottom right
    box = cv2.boxPoints(rect)
    box = np.int0(box)

    # print("bounding box: {}".format(box))
    cv2.drawContours(img, [box], 0, (0, 0, 255), 2)

    # get width and height of the detected rectangle
    width = int(rect[1][0])
    height = int(rect[1][1])
    angle = rect[2]

    src_pts = box.astype("float32")
    # coordinate of the points in box points after the rectangle has been
    # straightened
    dst_pts = np.array([[0, height+2],
                        [0, 0],
                        [width, 0],
                        [width, height+2]], dtype="float32")

    # the perspective transformation matrix
    M = cv2.getPerspectiveTransform(src_pts, dst_pts)

    # directly warp the rotated rectangle to get the straightened rectangle
    warped = cv2.warpPerspective(img, M, (width, height))

    # cv2.imwrite("crop_img.jpg", warped)
    
    # cv2.waitKey(0)
    if angle < -45:
      warped = np.transpose(warped,(1,0,2))
      warped = warped[::-1]

#     cv2.imshow('croped', warped)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()


    return warped

# %%
def resize_image(img):
    img_size = img.shape
    im_size_min = np.min(img_size[0:2])
    im_size_max = np.max(img_size[0:2])

    im_scale = float(600) / float(im_size_min)
    if np.round(im_scale * im_size_max) > 1200:
        im_scale = float(1200) / float(im_size_max)
    new_h = int(img_size[0] * im_scale)
    new_w = int(img_size[1] * im_scale)

    new_h = new_h if new_h // 16 == 0 else (new_h // 16 + 1) * 16
    new_w = new_w if new_w // 16 == 0 else (new_w // 16 + 1) * 16

    re_im = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_LINEAR)
    return re_im, (new_h / img_size[0], new_w / img_size[1])

def crop_rect(img, rect):
    # get the parameter of the small rectangle
    center, size, angle = rect[0], rect[1], rect[2]
    center, size = tuple(map(int, center)), tuple(map(int, size))

    # get row and col num in img
    height, width = img.shape[0], img.shape[1]

    # calculate the rotation matrix
    M = cv2.getRotationMatrix2D(center, angle, 1)
    # rotate the original image
    img_rot = cv2.warpAffine(img, M, (width, height))

    # now rotated rectangle becomes vertical, and we crop it
    img_crop = cv2.getRectSubPix(img_rot, size, center)

    return img_crop, img_rot

# %%
def ocr(img, oem=3, psm=6):
    """
    @param img: The image to be OCR'd
    @param oem: for specifying the type of Tesseract engine( default=1 for LSTM OCR Engine)
    """
    config = ('-l eng --oem {oem} --psm {psm}'.format(oem=oem,psm=psm))
    # config = ('-l eng --tessdata-dir "/usr/share/tesseract-ocr/tessdata" --oem {oem} -- psm {psm}'.format(oem=oem,psm=psm))

    try:
#         img = Image.fromarray(img)
        text = pytesseract.image_to_string(img, config=config)

        return text
    except:
        
        return ""

# %%
def ocr_metrics(predicts, ground_truth, norm_accentuation=False, norm_punctuation=False):
    """Calculate Character Error Rate (CER), Word Error Rate (WER) and Sequence Error Rate (SER)"""
    
    import string
    import unicodedata
    import editdistance

    if len(predicts) == 0 or len(ground_truth) == 0:
        return (1, 1, 1)

    cer, wer, ser = [], [], []

    for (pd, gt) in zip(predicts, ground_truth):

        if norm_accentuation:
            pd = unicodedata.normalize("NFKD", pd).encode("ASCII", "ignore").decode("ASCII")
            gt = unicodedata.normalize("NFKD", gt).encode("ASCII", "ignore").decode("ASCII")

        if norm_punctuation:
            pd = pd.translate(str.maketrans("", "", string.punctuation))
            gt = gt.translate(str.maketrans("", "", string.punctuation))

        pd_cer, gt_cer = list(pd.lower()), list(gt.lower())
        dist = editdistance.eval(pd_cer, gt_cer)
        cer.append(dist / (max(len(pd_cer), len(gt_cer))))

        pd_wer, gt_wer = pd.lower().split(), gt.lower().split()
        dist = editdistance.eval(pd_wer, gt_wer)
        wer.append(dist / (max(len(pd_wer), len(gt_wer))))

        pd_ser, gt_ser = [pd], [gt]
        dist = editdistance.eval(pd_ser, gt_ser)
        ser.append(dist / (max(len(pd_ser), len(gt_ser))))

    cer_f = sum(cer) / len(cer)
    wer_f = sum(wer) / len(wer)
    ser_f = sum(ser) / len(ser)
    
    evaluate = (cer_f, wer_f, ser_f)
    
    e_corpus = "\n".join([
    "Metrics:",
    "Character Error Rate: {}".format(evaluate[0]),
    "Word Error Rate:      {}".format(evaluate[1]),
    "Sequence Error Rate:  {}".format(evaluate[2]),
    ])

    return print(e_corpus)

# %%
def clean_string(string):
#     string = string + ' ' + str(string.strip('\n').strip('\x0c').strip())
    text = string.replace('INACTIVE INGREDIENTS:', '') # added
    text = text.replace('ACTIVE INGREDIENTS:', '') # added
    text = text.split(':')[1]
    text = text.strip()

    return text

def string_to_list(text):
    pattern = "[\|\*\_\'\{}]".format('"')
    text = re.sub(pattern, "", text)  
    split = [remove_water(x) for x in text.split(',')]
    
    return split

# %%
def remove_water(string):
    water = ['WATER (AQUA)', 'AQUA', 'EAU', 'AQUA/WATER/EAU', 'AQUA / WATER / EAU', 
             'PURIFIED WATER', 'DISTILLED WATER', 'D.I. WATER', 'AQUA (WATER)', 'AQUA (PURIFIED)']
    text = string.upper()
    if text in water:
        text = 'WATER'
    text = text.strip('  ')
    
    return text

# %%
def clean_string_name(string):
    text = string.replace(' Size: 4 oz. * USDA Certified Organic Ingredient ** None remains after saponifying oils into soap and glycerin', '')
    pattern = "[\|\*\_\'\{}&]".format('"')
    regex1 = re.compile('\[.*]')
    regex2 = re.compile('\[.*}')
    text = re.sub(pattern, "", text)
    text = re.sub(regex1, "", text)
    text = re.sub(regex2, "", text)
    text = text.strip('\x0c')
    text = text.strip(' ')
    text = text.upper()
    text = text.replace('INACTIVE INGREDIENTS:', '')
    text = text.replace('ACTIVE INGREDIENTS:', '')

    return text

# %%
def find_matching_ingredient(my_ingredients, fd, thresh=0.25): # rating_dict, category_dict, 
    ''' my_ingredients: list of product's ingredients
        Loop thru each ingredient in the ingredient list of the products
        then check if that ingredient appears in our ingredient list
        Calculate match_metric using SequenceMatcher and return the highest score and the best match
        Compare the match_metric with thresh > append to match_dict
    '''
    match_dict = {}
    for ingredient in tqdm(my_ingredients):
        if ingredient in match_dict.keys():
            continue
#         match_metric = {key: SequenceMatcher(None, key, ingredient).ratio() for key in rating_dict.keys()}
        match_metric = {key: SequenceMatcher(None, key, ingredient).ratio() for key in fd}
        best_match, best_metric = max(match_metric.items(), key=operator.itemgetter(1)) # What is operator.itemgetter(1)
        if best_metric > thresh:
            match_dict[ingredient] = best_match
        else:
            match_dict[ingredient] = 'unknown'
    return match_dict

# %%
def create_dict_english(df_inci, df_cosing):
    rating_inci = {}
    irritancy_inci = {}
    comedogenicity_inci = {}
    function_inci = {}
    qfacts_inci = {}
    desc_inci = {}
    
    desc_cosing = {}
    function_cosing = {}
    
    for idx, row in tqdm(df_inci.iterrows()):
        for name in row['ingredient_name'].split('/'):
            chem_name = name.strip()
            rating_inci[chem_name] = row['rating']
            irritancy_inci[chem_name] = row['irritancy']
            comedogenicity_inci[chem_name] = row['comedogenicity']
            function_inci[chem_name] = row['functions']
            qfacts_inci[chem_name] = row['quick_facts']
            desc_inci[chem_name] = row['description']
            
    for idx, row in tqdm(df_cosing.iterrows()):
        for name in row['ingredient_name'].split('/'):
            desc_cosing[name] = row['description']
            function_cosing[name] = row['functions']    
    
    return rating_inci, irritancy_inci, comedogenicity_inci, function_inci, qfacts_inci, desc_inci, desc_cosing, function_cosing

# %%
rating_inci, irritancy_inci, comedogenicity_inci, function_inci, qfacts_inci, desc_inci, desc_cosing, function_cosing = create_dict_english(df_inci, df_cosing)
# Out:
# 1570it [00:00, 3647.06it/s]
# 37309it [00:08, 4371.06it/s]

# %%
irritancy_inci
# Out:
# {'OUBAKU EKISU': nan,
#  'TYPE OF CLAY': '0',
#  '18:2 CIS-9': nan,
#  '3-O-ETHYL ASCORBATE': nan,
#  'ALA': nan,
#  'ATIP': nan,
#  'ACETYL GLUTAMYL HEPTAPEPTIDE-1': nan,
#  'ACETYL HEXAPEPTIDE-3': nan,
#  'ACID RED 92 PHLOXINE': '0.0',
#  'AL2O3': nan,
#  'ASCORBYL ISOTETRAPALMITATE': nan,
#  'ASCORBYL TETRAISOPALMITATE': nan,
#  'ASTRAGALI RADIX': nan,
#  'BEMOTRIZINOL': nan,
#  'BISDISULIZOLE DISODIUM': nan,
#  'BISOCTRIZOLE': nan,
#  'CHILEAN WINEBERRY OIL': nan,
#  'CHINA CLAY': '0.0',
#  'CHOPI': nan,
#  'CITRUS SINENSIS OIL': nan,
#  'COCOCIN': nan,
#  'COCONUT LIQUID ENDOSPERM': nan,
#  'COLLOIDAL OATMEAL': nan,
#  'COPPER PEPTIDE': nan,
#  'CURCUMIN': nan,
#  'D&C RED 33': '2.0',
#  'DHHB': nan,
#  'EAC': nan,
#  'EGF': nan,
#  'EPO': '2.0',
#  'EDELWEISS STEM CELL EXTRACT': nan,
#  'ELIX-IR': nan,
#  'EUSOLEX 6007': nan,
#  'FGF1': nan,
#  'FGF2': nan,
#  'FERRIC AMMONIUM FERROCYANIDE': nan,
#  'FILIPENDULA ULMARIA EXTRACT': nan,
#  'FLAXSEED OIL': nan,
#  'FORM OF RETINOIDS': nan,
#  'FORM OF VITAMIN F': nan,
#  'FORMERLY PALMITOYL PENTAPEPTIDE-3': nan,
#  'FORMERLY ALSO PALMITOYL OLIGOPEPTIDE': nan,
#  'GINSENG': nan,
#  'GLASSWORT EXTRACT': nan,
#  'GOLD-OF-PLEASURE OIL': nan,
#  'GOLDEN EYE-GRASS ROOT EXTRACT': nan,
#  'HDBM': nan,
#  'HPR': nan,
#  'IGF-1': nan,
#  'INDIAN FIG': nan,
#  'IRON BLUE': nan,
#  'JAPANESE BLOODGRASS ROOT EXTRACT': nan,
#  'KINNIKINNICK': nan,
#  'KOLLAREN': nan,
#  'KOREAN GINSENG': nan,
#  'KOREAN PEPPER': nan,
#  'L-ASCORBIC ACID': nan,
#  'LC-6': nan,
#  'LEMON BALM LEAF OIL': nan,
#  'MAP': nan,
#  'MANGO SEED BUTTER': nan,
#  'MARIGOLD EXTRACT': nan,
#  'MELALEUCA MINOR': nan,
#  'MEXORYL SX': nan,
#  'NEO HELIOPAN E1000': nan,
#  'NEROLI FLOWER WATER': nan,
#  'NEROLI OIL': nan,
#  'NEUROMATRIX': nan,
#  'NEUROVAX': nan,
#  'NOPAL': nan,
#  'OCTISALATE': '0.0',
#  'OCTYL DIMETHYL PABA': nan,
#  'OCTYL METHOXYCINNAMATE': '0.0',
#  'OCTYLTRIAZONE': nan,
#  'PAL-GHK': nan,
#  'PAL-GQPR': nan,
#  'PAL-KTTKS': nan,
#  'PALMITOYL OLIGOPEPTIDE (OLD NAME)': nan,
#  'PARFUM': nan,
#  'PERSEA AMERICANA OIL': '0.0',
#  'PHYTO RETINOL': nan,
#  'PONGAMIA PINNATA OIL': nan,
#  'POREAWAY': nan,
#  'POTASSIUM ALUMINUM SULFATE': nan,
#  'PREVIOUSLY PALMITOYL TETRAPEPTIDE-3': nan,
#  'RED 27': '0.0',
#  'RED 27 LAKE': '0.0',
#  'RED 28 LAKE': '0.0',
#  'RED 33 LAKE': '2.0',
#  'RED SEAWEED': nan,
#  'RENOVAGE': nan,
#  'RETINALDEHYDE': nan,
#  'RETINOL ESTER': nan,
#  'RETINOL-8': nan,
#  'ROSA EGLANTERIA SEED OIL': nan,
#  'ROSA MOSQUETA SEED OIL': nan,
#  'ROSE HYDROSOL': nan,
#  'ROSEHIP SEED OIL': nan,
#  'SAP': nan,
#  'SANSHŌ': nan,
#  'SATSUMA ORANGE': nan,
#  'SEAWEED EXTRACT': nan,
#  'SIAM BENZOIN': nan,
#  'SNAIL MUCIN': nan,
#  'STARFLOWER SEED OIL': nan,
#  'THBG': nan,
#  'TTO': nan,
#  'TANGOR OIL': nan,
#  'TIGER GRASS': nan,
#  'TIN DIOXIDE': nan,
#  'TRI HYDROXY BENZOIC ACID ALPHA-GLUCOSIDES': nan,
#  'UVASORB HEB': nan,
#  'VEGF': nan,
#  'VASELINE': nan,
#  'VIRGIN PRUNUS OIL': nan,
#  'YELLOW 5': nan,
#  'NICOTINAMIDE': nan,
#  'OMEGA-3 FATTY ACID': nan,
#  'OMEGA-6 FATTY ACID': nan,
#  'PAL-VGVAPG': nan,
#  'PART OF BIO-PLACENTA': nan,
#  'RH-OLIGOPEPTIDE-1': nan,
#  'RH-OLIGOPEPTIDE-2': nan,
#  'RH-POLYPEPTIDE-1': nan,
#  'RH-POLYPEPTIDE-11': nan,
#  'RH-POLYPEPTIDE-9': nan,
#  '1,2-HEXANEDIOL': nan,
#  '12': nan,
#  '4-METHYLBENZYLIDENE CAMPHOR': nan,
#  '4-T-BUTYLCYCLOHEXANOL': nan,
#  'ACACIA DECURRENS FLOWER WAX': nan,
#  'ACACIA DECURRENS': nan,
#  'JOJOBA': nan,
#  'SUNFLOWER SEED WAX POLYGLYCERYL-3 ESTERS': nan,
#  'ACACIA SENEGAL GUM': nan,
#  'ACER SACCHARUM EXTRACT': nan,
#  'ACETAMIDOETHOXYETHANOL': nan,
#  'ACETIC ACID': nan,
#  'ACETUM': nan,
#  'ACETYL DIPEPTIDE-1 CETYL ESTER': nan,
#  'ACETYL GLUCOSAMINE': nan,
#  'ACETYL GLYCYL BETA-ALANINE': nan,
#  'ACETYL HEXAPEPTIDE-1': nan,
#  'ACETYL HEXAPEPTIDE-8': nan,
#  'ACETYL OCTAPEPTIDE-3': nan,
#  'ACETYL TETRAPEPTIDE-2': nan,
#  'ACETYL TETRAPEPTIDE-3': nan,
#  'ACETYL TETRAPEPTIDE-5': nan,
#  'ACETYLARGINYLTRYPTOPHYL DIPHENYLGLYCINE': nan,
#  'ACIDIC FIBROBLAST GROWTH FACTOR': nan,
#  'ACRYLATES COPOLYMER': nan,
#  'ACRYLATES': nan,
#  'C10-30 ALKYL ACRYLATE CROSSPOLYMER': nan,
#  'C12-22 ALKYL METHACRYLATE COPOLYMER': nan,
#  'DIMETHICONE COPOLYMER': nan,
#  'ETHYLHEXYL ACRYLATE CROSSPOLYMER': nan,
#  'ACRYLONITRILE': nan,
#  'METHYL METHACRYLATE': nan,
#  'VINYLIDENE CHLORIDE COPOLYMER': nan,
#  'ACTICIRE': nan,
#  'ADANSONIA DIGITATA SEED OIL': nan,
#  'ADENOSINE': nan,
#  'ADIPIC ACID': nan,
#  'NEOPENTYL GLYCOL CROSSPOLYMER': nan,
#  "ADIPOFILL'IN": nan,
#  'AESCULUS HIPPOCASTANUM SEED EXTRACT': nan,
#  'AGONIS FRAGRANS BRANCH': nan,
#  'LEAF OIL': nan,
#  'AHNFELTIA CONCINNA EXTRACT': nan,
#  'ALANINE': nan,
#  'ALCOHOL': nan,
#  'ALCOHOL DENAT.': nan,
#  'ALEURITES MOLUCCANA SEED OIL': nan,
#  'ALGAE EXTRACT': nan,
#  'ALGIN': '4',
#  'ALL-TRANS-RETINOIC ACID': nan,
#  'ALLANTOIN': '0',
#  'ALLIUM CEPA BULB EXTRACT': nan,
#  'ALOE BARBADENSIS LEAF EXTRACT': nan,
#  'ALOE BARBADENSIS LEAF JUICE': nan,
#  'ALOE BARBADENSIS LEAF JUICE POWDER': nan,
#  'ALOE LEAF EXTRACT': nan,
#  'ALOE VERA': nan,
#  'ALPHA-ARBUTIN': nan,
#  'ALPHA-BISABOLOL': nan,
#  'ALPHA-GLUCAN OLIGOSACCHARIDE': nan,
#  'ALPHA-ISOMETHYL IONONE': nan,
#  'ALPHA-LIPOIC ACID': nan,
#  'ALPHAFLOW': nan,
#  'ALTEROMONAS FERMENT EXTRACT': nan,
#  'ALTEROMONAS FERMENT FILTRATE': nan,
#  'ALUMINA': nan,
#  'ALUMINUM HYDROXIDE': nan,
#  'ALUMINUM OXIDE': nan,
#  'ALUMINUM STARCH OCTENYLSUCCINATE': nan,
#  'AMARANTH SEED EXTRACT': nan,
#  'AMARANTHUS CAUDATUS SEED EXTRACT': nan,
#  'AMILOXATE': nan,
#  'AMINOMETHYL PROPANOL': nan,
#  'AMINOPROPYL ASCORBYL PHOSPHATE': nan,
#  'AMMONIUM ACRYLOYLDIMETHYLTAURATE': nan,
#  'VP COPOLYMER': nan,
#  'AMMONIUM GLYCOLATE': nan,
#  'AMMONIUM LAURYL SULFATE': nan,
#  'AMMONIUM POLYACRYLOYLDIMETHYL TAURATE': nan,
#  'AMMONIUM XYLENESULFONATE': nan,
#  'AMODIMETHICONE': nan,
#  'AMORPHOPHALLUS KONJAC ROOT POWDER': nan,
#  'AMUR CORK TREE BARK EXTRACT': nan,
#  'ANANAS SATIVUS FRUIT EXTRACT': nan,
#  'ANHYDROXYLITOL': nan,
#  'ANNATTO': nan,
#  'ANTHEMIS NOBILIS FLOWER EXTRACT': nan,
#  'ANTHEMIS NOBILIS FLOWER OIL': nan,
#  'ANTHOCYANINS': nan,
#  'APHANIZOMENON FLOS-AQUAE EXTRACT': nan,
#  'APPLE FRUIT EXTRACT': nan,
#  'APRICOT KERNEL OIL': '0',
#  'AQUA': nan,
#  'ARACHIDYL ALCOHOL': nan,
#  'ARACHIDYL GLUCOSIDE': nan,
#  'ARBUTIN': nan,
#  'ARCTIUM LAPPA ROOT EXTRACT': nan,
#  'ARCTOSTAPHYLOS UVA-URSI LEAF EXTRACT': nan,
#  'ARGAN OIL': nan,
#  'ARGANIA SPINOSA KERNEL OIL': nan,
#  'ARGININE': nan,
#  'ARGIRELINE': nan,
#  'ARISTOFLEX AVC': nan,
#  'ARISTOTELIA CHILENSIS OIL': nan,
#  'ARNICA EXTRACT': nan,
#  'ARNICA MONTANA EXTRACT': nan,
#  'ARNICA MONTANA FLOWER EXTRACT': nan,
#  'ARONIA MELANOCARPA FRUIT EXTRACT': nan,
#  'ASCORBIC ACID': nan,
#  'ASCORBYL GLUCOSIDE': nan,
#  'ASCORBYL PALMITATE': '0',
#  'ASIATIC ACID': nan,
#  'ASIATICOSIDE': nan,
#  'ASPARTIC ACID': nan,
#  'ASTAXANTHIN': nan,
#  'ASTRAGALUS MEMBRANACEUS ROOT EXTRACT': nan,
#  'AVENA SATIVA KERNEL EXTRACT': nan,
#  'AVENA SATIVA KERNEL FLOUR': nan,
#  'AVOBENZONE': nan,
#  'AVOCADO OIL': '0.0',
#  'AVOCADO OIL UNSAPONIFIABLES': nan,
#  'AZELAIC ACID': nan,
#  'BHA': nan,
#  'BHT': nan,
#  "BAKER'S YEAST": nan,
#  'BAKUCHIOL': nan,
#  'BALM MINT LEAF OIL': nan,
#  'BAMBOO ISOFLAVONES': nan,
#  'BAOBAB SEED OIL': nan,
#  'BARBERRY ROOT EXTRACT': nan,
#  'BAROSMA BETULINA LEAF EXTRACT': nan,
#  'BASIC FIBROBLAST GROWTH FACTOR': nan,
#  'BEARBERRY': nan,
#  'BEESWAX': '0',
#  'BEET ROOT EXTRACT': nan,
#  'BEHENTRIMONIUM METHOSULFATE': nan,
#  'BEHENYL ALCOHOL': nan,
#  'BENTONITE': '0',
#  'BENZOIC ACID': nan,
#  'BENZOIN RESIN': nan,
#  'BENZOPHENONE-3': '0',
#  'BENZOPHENONE-4': nan,
#  'BENZOPHENONE-5': nan,
#  'BENZOYL PEROXIDE': nan,
#  'BENZYL ALCOHOL': nan,
#  'BENZYL BENZOATE': nan,
#  'BENZYL SALICYLATE': nan,
#  'BERACLAY LIGHT RED': nan,
#  'BERBERIS VULGARIS ROOT EXTRACT': nan,
#  'BERGAMOT ESSENTIAL OIL': nan,
#  'BERGAMOT FRUIT OIL': nan,
#  'BETA VULGARIS ROOT EXTRACT': nan,
#  'BETA-ARBUTIN': nan,
#  'BETA-GLUCAN': nan,
#  'BETAINE': nan,
#  'BETAINE SALICYLATE': nan,
#  'BETULA ALBA BARK EXTRACT': nan,
#  'BIFIDA FERMENT LYSATE': nan,
#  'BIOPEPTIDE EL': nan,
#  'BIOSACCHARIDE GUM-1': nan,
#  'BIOSACCHARIDE GUM-2': nan,
#  'BIOTIN': nan,
#  'BIOTINOYL TRIPEPTIDE-1': nan,
#  'BIRCH BARK EXTRACT': nan,
#  'BIS STEARYL ETHYLENEDIAMINE': nan,
#  'NEOPENTYL GLYCOL': nan,
#  'STEARYL HYDROGENATED DIMER DILINOLEATE COPOLYMER': nan,
#  'BIS-DIGLYCERYL POLYACYLADIPATE-2': nan,
#  'BIS-ETHYLHEXYL HYDROXYDIMETHOXY BENZYLMALONATE': nan,
#  'BIS-ETHYLHEXYLOXYPHENOL METHOXYPHENYL TRIAZINE': nan,
#  'BIS-PEG-18 METHYL ETHER DIMETHYL SILANE': nan,
#  'BIS-PEG': nan,
#  'PPG-14': nan,
#  '14 DIMETHICONE': nan,
#  'BISABOLOL': nan,
#  'BISMUTH OXYCHLORIDE': nan,
#  'BITTER ORANGE FLOWER OIL': nan,
#  'BITTER ORANGE FLOWER WATER': nan,
#  'BLACK CHOKEBERRY': nan,
#  'BLACK CUMIN OIL': nan,
#  'BLACK TRUFFLE EXTRACT': nan,
#  'BLACKBERRY SEED OIL': nan,
#  'BLUE 1': nan,
#  'BONT-L PEPTIDE': nan,
#  'BORAGE LEAF EXTRACT': nan,
#  'BORAGE SEED OIL': nan,
#  'BORAGO OFFICINALIS LEAF EXTRACT': nan,
#  'BORAGO OFFICINALIS SEED OIL': nan,
#  'BORON NITRIDE': nan,
#  'BOSWELLIA SERRATA EXTRACT': nan,
#  'BRIGHTENYL': nan,
#  'BUCHU LEAF EXTRACT': nan,
#  'BUDDLEJA DAVIDII MERISTEM CELL CULTURE': nan,
#  'BURDOCK ROOT': nan,
#  'BUTANE': nan,
#  'BUTCHER’S BROOM EXTRACT': nan,
#  'BUTYL METHOXYDIBENZOYLMETHANE': nan,
#  'BUTYLATED HYDROXY ANISOLE': nan,
#  'BUTYLATED HYDROXY TOLUENE': nan,
#  'BUTYLENE GLYCOL': '0',
#  'BUTYLENE': nan,
#  'ETHYLENE': nan,
#  'STYRENE COPOLYMER': nan,
#  'BUTYLOCTYL SALICYLATE': nan,
#  'BUTYLPHENYL METHYLPROPIONAL': nan,
#  'BUTYROSPERMUM PARKII BUTTER': nan,
#  'C10-30 CHOLESTEROL': nan,
#  'LANOSTEROL ESTERS': nan,
#  'C12-14 PARETH-12': nan,
#  'C12-15 ALKYL BENZOATE': nan,
#  'C12-20 ALKYL GLUCOSIDE': nan,
#  'C13-14 ISOPARAFFIN': nan,
#  'C13-15 ALKANE': nan,
#  'C14-22 ALCOHOLS': nan,
#  'C20-40 PARETH-10': nan,
#  'C30-45 ALKYL DIMETHICONE': nan,
#  'CI 77019': nan,
#  'CI 77861': nan,
#  'CI 77947': nan,
#  'CAFFEINE': nan,
#  'CAFFEYL GLUCOSIDE': nan,
#  'CAJEPUT ESSENTIAL OIL': nan,
#  'CALENDULA EXTRACT': nan,
#  'CALENDULA OFFICINALIS EXTRACT': nan,
#  'CALENDULA OFFICINALIS FLOWER EXTRACT': nan,
#  'CALMOSENSINE': nan,
#  'CALOPHYLLUM INOPHYLLUM SEED OIL': nan,
#  'CALOPHYLLUM TACAMAHACA OIL': nan,
#  'CAMELINA OIL': nan,
#  'CAMELINA SATIVA SEED OIL': nan,
#  'CAMELLIA OLEIFERA  LEAF EXTRACT': nan,
#  'CAMELLIA OLEIFERA SEED OIL': nan,
#  'CAMELLIA SINENSIS LEAF EXTRACT': nan,
#  'CANANGA ODORATA FLOWER OIL': nan,
#  'CANDELILLA CERA': '0',
#  'CANDELILLA WAX': '0',
#  'CANDELILLA': nan,
#  'RICE BRAN POLYGLYCERYL-3 ESTERS': nan,
#  'CANDLE TREE LEAF EXTRACT': nan,
#  'CAPE CHAMOMILE OIL': nan,
#  'CAPROOYL TETRAPEPTIDE-3': nan,
#  'CAPRYLHYDROXAMIC ACID': nan,
#  'CAPRYLIC': nan,
#  'CAPRIC TRIGLYCERIDE': nan,
#  'CAPRIC': nan,
#  'MYRISTIC': nan,
#  'STEARIC TRIGLYCERIDE': nan,
#  'CAPRYLOYL GLYCERIN': nan,
#  'SEBACIC ACID COPOLYMER': nan,
#  'CAPRYLYL CAPRYLATE': nan,
#  'CAPRATE': nan,
#  'CAPRYLYL GLYCOL': nan,
#  'CAPRYLYL METHICONE': nan,
#  'CAPSICUM FRUTESCENS FRUIT EXTRACT': nan,
#  'CARAMEL': nan,
#  'CARBAMIDE': nan,
#  'CARBOMER': '0',
#  'CARBOXYMETHYL CELLULOSE': '0',
#  'CARMINE': '0',
#  'CARNAUBA WAX': '0',
#  'CARNOSINE': nan,
#  'CARRAGEENAN': nan,
#  'CARRAGEENAN EXTRACT': nan,
#  'CARROT ROOT OIL': nan,
#  'CARROT SEED OIL': nan,
#  'CARTHAMUS TINCTORIUS OLEOSOMES': nan,
#  'CARTHAMUS TINCTORIUS SEED OIL': '0',
#  'CASSIA ALATA LEAF EXTRACT': nan,
#  'CASTOR OIL': '0',
#  'CAVIAR LIME FRUIT EXTRACT': nan,
#  'CAYENNE PEPPER FRUIT EXTRACT': nan,
#  'CELLULOSE': nan,
#  'CELLULOSE GUM': '0',
#  'CENTAUREA CYANUS FLOWER WATER': nan,
#  'CENTELLA ASIATICA EXTRACT': nan,
#  'CERA ALBA': '0',
#  'CERAMIDE 1': nan,
#  'CERAMIDE 2': nan,
#  'CERAMIDE 3': nan,
#  'CERAMIDE 6 II': nan,
#  'CERAMIDE AP': nan,
#  'CERAMIDE EOP': nan,
#  'CERAMIDE NG': nan,
#  'CERAMIDE NP': nan,
#  'CERESIN': '0',
#  'CETEARETH-20': '3',
#  'CETEARYL ALCOHOL': '1',
#  'CETEARYL ETHYLHEXANOATE': nan,
#  'CETEARYL GLUCOSIDE': nan,
#  'CETEARYL ISONONANOATE': nan,
#  'CETEARYL NONANOATE': nan,
#  'CETEARYL OCTANOATE': nan,
#  'CETEARYL OLIVATE': nan,
#  'CETRARIA ISLANDICA THALLUS EXTRACT': nan,
#  'CETYL ALCOHOL': '2',
#  'CETYL DIMETHICONE': nan,
#  'CETYL DIMETHICONE COPOLYOL': nan,
#  'CETYL ETHYLHEXANOATE': nan,
#  'CETYL HYDROXYETHYLCELLULOSE': nan,
#  'CETYL PEG': nan,
#  'PPG-10': nan,
#  '1 DIMETHICONE': nan,
#  'CETYL PALMITATE': '0',
#  'CETYL PHOSPHATE': nan,
#  'CETYLHYDROXYPROLINE PALMITAMIDE': nan,
#  'CHAMOMILLA RECUTITA FLOWER EXTRACT': '0',
#  'CHAMOMILLA RECUTITA FLOWER OIL': nan,
#  'CHIA SEED OIL': nan,
#  'CHLOROPHYLL': nan,
#  'CHLORPHENESIN': nan,
#  'CHOLESTEROL': '0',
#  'CHOLESTERYL NONANOATE': nan,
#  'CHOLESTERYL OLEYL CARBONATE': nan,
#  'CHOLESTERYL STEARATE': nan,
#  'CHONDRUS CRISPUS': nan,
#  'CHONDRUS CRISPUS EXTRACT': nan,
#  'CHRONOLINE': nan,
#  'CHROMIUM OXIDE GREEN': nan,
#  'CHROMIUM OXIDE GREENS': nan,
#  'CHRONOCYCLIN': nan,
#  'CI 14700': nan,
#  'CI 17200': '2',
#  'CI 19140': nan,
#  'CI 42090': nan,
#  'CI 45410': '0',
#  'CI 75120': nan,
#  'CI 75470': '0',
#  'CI 77007': '0',
#  'CI 77163': nan,
#  'CI 77288': nan,
#  'CI 77289': nan,
#  'CI 77491': '0',
#  '77492': '0',
#  '77499': '0',
#  'CI 77492': '0',
#  'CI 77499': '0',
#  'CI 77510': nan,
#  'CI 77742': nan,
#  'CI 77891': '0',
#  'CITRAL': nan,
#  'CITRIC ACID': nan,
#  'CITRONELLOL': nan,
#  'CITRULLUS LANATUS FRUIT EXTRACT': nan,
#  'CITRUS AURANTIUM AMARA FLOWER OIL': nan,
#  'CITRUS AURANTIUM AMARA FLOWER WATER': nan,
#  'CITRUS AURANTIUM BERGAMIA FRUIT OIL': nan,
#  'CITRUS AURANTIUM BERGAMIA PEEL OIL': nan,
#  'CITRUS AURANTIUM DULCIS FRUIT EXTRACT': nan,
#  'CITRUS AURANTIUM DULCIS OIL': nan,
#  'CITRUS AURANTIUM DULCIS PEEL OIL': nan,
#  'CITRUS GRANDIS PEEL OIL': nan,
#  'CITRUS LIMON FRUIT EXTRACT': nan,
#  'CITRUS LIMON PEEL OIL': nan,
#  'CITRUS NOBILIS OIL': nan,
#  'CITRUS NOBILIS PEEL OIL': nan,
#  'CITRUS PARADISI PEEL OIL': nan,
#  'CITRUS RETICULATA PEEL OIL': nan,
#  'CITRUS UNSHIU EXTRACT': nan,
#  'CITRUS UNSHIU PEEL EXTRACT': nan,
#  'COCAMIDE DEA': nan,
#  'COCAMIDE MEA': nan,
#  'COCAMIDOPROPYL BETAINE': nan,
#  'COCAMIDOPROPYL DIMETHYLAMINE': nan,
#  'COCAMIDOPROPYL HYDROXYSULTAINE': nan,
#  'COCAMIDOPROPYLAMINE OXIDE': nan,
#  'COCETH-7': nan,
#  'COCHLEARIA ARMORACIA ROOT EXTRACT': nan,
#  'COCO-CAPRYLATE': nan,
#  'COCO-GLUCOSIDE': nan,
#  'COCOA SEED BUTTER': '0',
#  'COCONUT ALKANES': nan,
#  'COCONUT ENDOSPERM': nan,
#  'COCONUT FRUIT EXTRACT': nan,
#  'COCONUT OIL': '0',
#  'COCONUT SHELL POWDER': nan,
#  'COCONUT WATER': nan,
#  'COCOS NUCIFERA FRUIT EXTRACT': nan,
#  'COCOS NUCIFERA FRUIT JUICE': nan,
#  'COCOS NUCIFERA OIL': '0',
#  'COCOS NUCIFERA SHELL POWDER': nan,
#  'COCOS NUCIFERA WATER': nan,
#  'COENZYME Q10': nan,
#  'COGON GRASS ROOT EXTRACT': nan,
#  'COLLAGEN': nan,
#  'COLLAGEN AMINO ACIDS': nan,
#  'COMFREY ROOT EXTRACT': nan,
#  'COMMIPHORA MYRRHA RESIN EXTRACT': nan,
#  'COPERNICIA CERIFERA WAX': '0',
#  'COPPER CHLOROPHYLL': nan,
#  'COPPER GLUCONATE': nan,
#  'COPPER LYSINATE': nan,
#  'PROLINATE': nan,
#  'COPPER TRIPEPTIDE-1': nan,
#  'COPTIS JAPONICA ROOT EXTRACT': nan,
#  'CORN STARCH': nan,
#  'CORNFLOWER FLOWER WATER': nan,
#  'CORYLUS AVELLANA  SEED OIL': nan,
#  'COUMARIN': nan,
#  'CRAMBE ABYSSINICA SEED OIL': nan,
#  'CRAMBE OIL': nan,
#  'CRANBERRY SEED OIL': nan,
#  'CUCUMBER FRUIT EXTRACT': nan,
#  'CUCUMBER OIL': nan,
#  'CUCUMIS SATIVUS FRUIT EXTRACT': nan,
#  'CUCUMIS SATIVUS SEED OIL': nan,
#  'CURCULIGO ORCHIOIDES ROOT EXTRACT': nan,
#  'CURCULIGO ROOT EXTRACT': nan,
#  'CURCUMA LONGA ROOT EXTRACT': nan,
#  'CYAMOPSIS TETRAGONOLOBA GUM': nan,
#  'CYCLOASTRAGENOL': nan,
#  'CYCLOHEXASILOXANE': nan,
#  'CYCLOMETHICONE': '0',
#  'CYCLOPENTASILOXANE': nan,
#  'CYCLOTETRASILOXANE': nan,
#  'CYPRIPEDIUM PUBESCENS EXTRACT': nan,
#  'DAMASK ROSE FLOWER OIL': nan,
#  'DAMASK ROSE FLOWER WATER': nan,
#  'DANDELION LEAF EXTRACT': nan,
#  'DAUCUS CAROTA SATIVA ROOT EXTRACT': nan,
#  'DAUCUS CAROTA SATIVA SEED OIL': nan,
#  'DECAPEPTIDE-22': nan,
#  'DECYL GLUCOSIDE': nan,
#  'DEHYDROACETIC ACID': nan,
#  'DEXTRIN': nan,
#  'DIAZOLIDINYL UREA': nan,
#  'DIBUTYL ADIPATE': nan,
#  'DIBUTYL ETHYLHEXANOYL GLUTAMIDE': nan,
#  'DIBUTYL LAUROYL GLUTAMIDE': nan,
#  'DICAPRYLYL CARBONATE': nan,
#  'DICAPRYLYL ETHER': nan,
#  'DIETHYLAMINO HYDROXYBENZOYL HEXYL BENZOATE': nan,
#  'DIETHYLHEXYL 2,6-NAPHTHALATE': nan,
#  'DIETHYLHEXYL BUTAMIDO TRIAZONE': nan,
#  'DIETHYLHEXYL CARBONATE': nan,
#  'DIETHYLHEXYL SYRINGYLIDENEMALONATE': nan,
#  'DIGLUCOSYL GALLIC ACID': nan,
#  'DIGLYCERIN': nan,
#  'DIHEPTYL SUCCINATE': nan,
#  'DIISOPROPYL ADIPATE': '0',
#  'DIISOPROPYL SEBACATE': nan,
#  'DIISOSTEAROYL POLYGLYCERYL-3 DIMER DILINOLEATE': nan,
#  'DIMETHICONE': nan,
#  'DIMETHICONE CROSSPOLYMER': nan,
#  'PEG-10': nan,
#  '15 CROSSPOLYMER': nan,
#  'VINYL DIMETHICONE CROSSPOLYMER': nan,
#  'DIMETHICONOL': nan,
#  'DIMETHYL ISOSORBIDE': nan,
#  'DIMETHYLACRYLAMIDE': nan,
#  'ACRYLIC ACID': nan,
#  'POLYSTYRENE ETHYL METHACRYLATE COPOLYMER': nan,
#  'DIMETHYLMETHOXY CHROMANOL': nan,
#  'DIPENTAERYTHRITYL HEXACAPRYLATE': nan,
#  'HEXACAPRATE': nan,
#  'DIPEPTIDE DIAMINOBUTYROYL BENZYLAMIDE DIACETATE': nan,
#  'DIPEPTIDE-2': nan,
#  'DIPOTASSIUM GLYCYRRHIZATE': nan,
#  'DIPROPYLENE GLYCOL': nan,
#  'DIPROPYLENE GLYCOL DIBENZOATE': nan,
#  'DISILOXANE': nan,
#  'DISODIUM ACETYL GLUCOSAMINE PHOSPHATE': nan,
#  'DISODIUM CETEARYL SULFOSUCCINATE': nan,
#  'DISODIUM COCO-GLUCOSIDE CITRATE': nan,
#  'DISODIUM COCOAMPHODIACETATE': nan,
#  'DISODIUM COCOAMPHODIPROPIONATE': nan,
#  'DISODIUM EDTA': nan,
#  'DISODIUM LAURETH SULFOSUCCINATE': nan,
#  'DISODIUM LAURIMINODIPROPIONATE TOCOPHERYL PHOSPHATES': nan,
#  'DISODIUM LAURYL SULFOSUCCINATE': nan,
#  'DISODIUM PHENYL DIBENZIMIDAZOLE TETRASULFONATE': nan,
#  'DISODIUM URIDINE PHOSPHATE': nan,
#  'DISTEARDIMONIUM HECTORITE': nan,
#  'DMDM HYDANTOIN': nan,
#  'DMPA': nan,
#  'ISOPHTHALIC ACID': nan,
#  'SMDI COPOLYMER': nan,
#  'DODECANE': nan,
#  'DOG-ROSE SEED OIL': nan,
#  'DROMETRIZOLE TRISILOXANE': nan,
#  'EDDS': nan,
#  'EDTA': nan,
#  'EGCG': nan,
#  'EUK-134': nan,
#  'EYESERYL': nan,
#  'ECAMSULE': nan,
#  'ELFAMOIST AC': nan,
#  'ENSULIZOLE': nan,
#  'ENZACAMENE': nan,
#  'EPIDERMAL GROWTH FACTOR': nan,
#  'EPIGALLOCATECHIN GALLATE': nan,
#  'EPIGALLOCATECHIN GALLATYL GLUCOSIDE': nan,
#  'EPSOM SALT': nan,
#  'ERIOCEPHALUS PUNCTULATUS OIL': nan,
#  'ERYTHRULOSE': nan,
#  'ETHANOL': nan,
#  'ETHOXYDIGLYCOL': '0',
#  'ETHYL 2,2-DIMETHYLHYDROCINNAMAL': nan,
#  'ETHYL ASCORBIC ACID': nan,
#  'ETHYL HEXANEDIOL': nan,
#  'ETHYL LINOLEATE': nan,
#  'ETHYL LINOLENATE': nan,
#  'ETHYL MENTHANE CARBOXAMIDE': nan,
#  'ETHYL OLEATE': nan,
#  'ETHYLBISIMINOMETHYLGUAIACOL MANGANESE CHLORIDE': nan,
#  'PROPYLENE': nan,
#  'ETHYLHEXYL BENZOATE': nan,
#  'ETHYLHEXYL DIMETHYL PABA': nan,
#  'ETHYLHEXYL HYDROXYSTEARATE': nan,
#  'ETHYLHEXYL METHOXYCINNAMATE': '0',
#  'ETHYLHEXYL PALMITATE': '0',
#  'ETHYLHEXYL SALICYLATE': '0',
#  'ETHYLHEXYL STEARATE': nan,
#  'ETHYLHEXYL TRIAZONE': nan,
#  'ETHYLHEXYLGLYCERIN': nan,
#  'ETHYLPARABEN': nan,
#  'EUCALYPTUS CITRIODORA OIL': nan,
#  'EUCALYPTUS ESSENTIAL OIL': nan,
#  'EUCALYPTUS GLOBULUS LEAF OIL': nan,
#  'EUCALYPTUS RADIATA LEAF OIL': nan,
#  'EUGENOL': nan,
#  'EVENING PRIMROSE OIL': '2.0',
#  'EXPANCEL MICROSPHERES': nan,
#  'FARNESOL': nan,
#  'FERMENTED BULL KELP': nan,
#  'FERMENTED RADISH ROOT': nan,
#  'FERMENTED SEA KELP': nan,
#  'FERMENTED WHITE SHIITAKE': nan,
#  'FERMENTOIL GREEN TEA SEED': nan,
#  'FERRIC FERROCYANIDE': nan,
#  'FERULIC ACID': nan,
#  'FLORAZON': nan,
#  'FORM OF VITAMIN C': nan,
#  'FORM OF VITAMIN E': nan,
#  'FRAGONIA ESSENCTIAL OIL': nan,
#  'FRAGRANCE': nan,
#  'FRUCTOSE': nan,
#  "FULLER'S EARTH": nan,
#  'GHK': nan,
#  'GHK-CU': nan,
#  'GALACTOARABINAN': nan,
#  'GALACTOMYCES FERMENT FILTRATE': nan,
#  'GALAXY SUNBEAT': nan,
#  'GALLYL GLUCOSIDE': nan,
#  'GELATIN': nan,
#  'GENISTEIN': nan,
#  'GENOWHITE': nan,
#  'GEOGARD 111A': nan,
#  'GEOGARD 111S': nan,
#  'GERANIOL': nan,
#  'GERANYLGERANYLACETONE': nan,
#  'GERMAN CHAMOMILE FLOWER EXTRACT': '0',
#  'GERMAN CHAMOMILE FLOWER OIL': nan,
#  'GINGER ROOT EXTRACT': nan,
#  'GLOBULARIA CORDIFOLIA CALLUS CULTURE EXTRACT': nan,
#  'GLUCOMANNAN': nan,
#  'GLUCONOLACTONE': nan,
#  'GLUCOSE': nan,
#  'GLUTAMIC ACID': nan,
#  'GLUTAMYLAMIDOETHYL IMIDAZOLE': nan,
#  'GLYCERETH-26': '0',
#  'GLYCERETH-7 TRIMETHYL ETHER': nan,
#  'GLYCERIN': '0',
#  'GLYCEROL': '0',
#  'GLYCERYL ACRYLATE': nan,
#  'ACRYLIC ACID COPOLYMER': nan,
#  'GLYCERYL BEHENATE': nan,
#  'EICOSADIOATE': nan,
#  'GLYCERYL CAPRYLATE': nan,
#  'GLYCERYL DIBEHENATE': nan,
#  'GLYCERYL LAURATE': nan,
#  'GLYCERYL OLEATE': nan,
#  'GLYCERYL STEARATE': '0',
#  'GLYCERYL STEARATE CITRATE': nan,
#  'GLYCERYL STEARATE SE': '2',
#  'GLYCINE': nan,
#  'GLYCINE SOJA OIL': '0',
#  'GLYCINE SOJA SEED EXTRACT': nan,
#  'GLYCOL DISTEARATE': nan,
#  'GLYCOLIC ACID': nan,
#  'GLYCYRRHIZA GLABRA  ROOT EXTRACT': nan,
#  'GOTU KOLA': nan,
#  'GRANACTIVE RETINOID': nan,
#  'GRAPE EXTRACT': nan,
#  'GRAPE FRUIT EXTRACT': nan,
#  'GRAPE JUICE EXTRACT': nan,
#  'GRAPE SEED EXTRACT': nan,
#  'GRAPE SEED OIL': nan,
#  'GRAPEFRUIT PEEL OIL': nan,
#  'GREEN TEA': nan,
#  'GUAR GUM': nan,
#  'GUARDIANT': nan,
#  'GUM ARABIC': nan,
#  'HEC': nan,
#  'HADASEI 3TM': nan,
#  'HAEMATOCOCCUS PLUVIALIS EXTRACT': nan,
#  'HAMAMELIS VIRGINIANA  LEAF EXTRACT': nan,
#  'HAMAMELIS VIRGINIANA BARK': nan,
#  'LEAF': nan,
#  'TWIG EXTRACT': nan,
#  'HAMAMELIS VIRGINIANA EXTRACT': nan,
#  'HAMAMELIS VIRGINIANA LEAF WATER': nan,
#  'HAMAMELIS VIRGINIANA WATER': nan,
#  'HAZELNUT OIL': nan,
#  'HDI': nan,
#  'TRIMETHYLOL HEXYLLACTONE CROSSPOLYMER': nan,
#  'HELIANTHUS ANNUUS EXTRACT': nan,
#  'HELIANTHUS ANNUUS SEED OIL': '0',
#  'HELIANTHUS ANNUUS SEED OIL UNSAPONIFIABLES': nan,
#  'HELIANTHUS ANNUUS SEED WAX': nan,
#  'HESPERIDIN': nan,
#  'HESPERIDIN METHYL CHALCONE': nan,
#  'HEXAMETHYLDISILOXANE': nan,
#  'HEXANOYL DIPEPTIDE-3 NORLEUCINE ACETATE': nan,
#  'HEXAPEPTIDE-9': nan,
#  'HEXYL CINNAMAL': nan,
#  'HEXYL LAURATE': nan,
#  'HEXYL NICOTINATE': nan,
#  'HEXYLDECANOL': nan,
#  'HEXYLENE GLYCOL': '0-1',
#  'HEXYLRESORCINOL': nan,
#  'HIPPOPHAE RHAMNOIDES FRUIT OIL': nan,
#  'HISTIDINE': nan,
#  'HOMOSALATE': nan,
#  'HONEY': nan,
#  'HONEY EXTRACT': nan,
#  'HONEYSUCKLE EXTRACT': nan,
#  'HORSE CHESTNUT': nan,
#  'HORSERADISH ROOT': nan,
#  'HOUTTUYNIA CORDATA EXTRACT': nan,
#  'HUANGQI': nan,
#  'HUMAN ADIPOSE DERIVED STEM CELL CONDITIONED MEDIA': nan,
#  'HUMAN FIBROBLAST CONDITIONED MEDIA': nan,
#  'HYALURONIC ACID': nan,
#  'HYDROGEN DIMETHICONE': nan,
#  'HYDROGENATED CASTOR OIL': '0',
#  'HYDROGENATED COCO-GLYCERIDES': nan,
#  'HYDROGENATED LECITHIN': nan,
#  'HYDROGENATED POLYDECENE': nan,
#  'HYDROGENATED POLYISOBUTENE': '2',
#  'HYDROLYZED COLLAGEN': nan,
#  'HYDROLYZED CORN STARCH': nan,
#  'HYDROLYZED HYALURONIC ACID': nan,
#  'HYDROLYZED MARINE COLLAGEN': nan,
#  'HYDROLYZED PLACENTAL PROTEIN': nan,
#  'HYDROLYZED SODIUM HYALURONATE': nan,
#  'HYDROLYZED WHEAT PROTEIN': nan,
#  'PVP CROSSPOLYMER': nan,
#  'HYDROLYZED YEAST EXTRACT': nan,
#  'HYDROXYACETOPHENONE': nan,
#  'HYDROXYCITRONELLAL': nan,
#  'HYDROXYETHYL ACRYLATE': nan,
#  'SODIUM ACRYLOYLDIMETHYL TAURATE COPOLYMER': nan,
#  'HYDROXYETHYL UREA': nan,
#  'HYDROXYETHYLCELLULOSE': nan,
#  'HYDROXYMETHOXYPHENYL DECANONE': nan,
#  'HYDROXYMETHOXYPHENYL PROPYLMETHYLMETHOXYBENZOFURAN': nan,
#  'HYDROXYPALMITOYL SPHINGANINE': nan,
#  'HYDROXYPHENOXY PROPIONIC ACID': nan,
#  'HYDROXYPHENYL PROPAMIDOBENZOIC ACID': nan,
#  'HYDROXYPINACOLONE RETINOATE': nan,
#  'HYDROXYPROPYL BISPALMITAMIDE MEA': nan,
#  'HYDROXYPROPYL CYCLODEXTRIN': nan,
#  'HYDROXYPROPYL METHYLCELLULOSE': '0',
#  'HYDROXYPROPYL TETRAHYDROPYRANTRIOL': nan,
#  'IFC-CAF': nan,
#  'ICELAND MOSS EXTRACT': nan,
#  'IMPERATA CYLINDRICA ROOT EXTRACT': nan,
#  'INDIAN FRANKINCENSE EXTRACT': nan,
#  'INSULIN-LIKE GROWTH FACTOR 1': nan,
#  'INULIN': nan,
#  'INULIN LAURYL CARBAMATE': nan,
#  'IODOPROPYNYL BUTYLCARBAMATE': nan,
#  'IRISH MOSS': nan,
#  'IRON OXIDE BLACK': '0',
#  'IRON OXIDE RED': '0',
#  'IRON OXIDE YELLOW': '0',
#  'IRON OXIDES': '0',
#  'ISCOTRIZINOL': nan,
#  'ISOAMYL COCOATE': nan,
#  'ISOAMYL LAURATE': nan,
#  'ISOAMYL P-METHOXYCINNAMATE': nan,
#  'ISOBUTANE': nan,
#  'ISOCETETH-20': nan,
#  'ISOCETYL STEARATE': nan,
#  'ISOCETYL STEAROYL STEARATE': nan,
#  'ISODECYL NEOPENTANOATE': nan,
#  'ISODECYL SALICYLATE': nan,
#  'ISODODECANE': nan,
#  'ISOHEXADECANE': nan,
#  'ISOLEUCINE': nan,
#  'ISONONYL ISONONANOATE': nan,
#  'ISOPENTYLDIOL': nan,
#  'ISOPROPYL CLOPROSTENATE': nan,
#  'ISOPROPYL ISOSTEARATE': '0',
#  'ISOPROPYL LAUROYL SARCOSINATE': nan,
#  'ISOPROPYL MYRISTATE': '3',
#  'ISOPROPYL PALMITATE': '1',
#  'ISOSTEARIC ACID': nan,
#  'ISOSTEARYL ISOSTEARATE': '1',
#  'ISOSTEARYL NEOPENTANOATE': '3',
#  'JAPANESE GOLDTHREAD ROOT EXTRACT': nan,
#  'JAPANESE HONEYSUCKLE FLOWER EXTRACT': nan,
#  'JAPANESE HOT SPRING WATER': nan,
#  'JAPANESE PEPPER': nan,
#  'JOJOBA ESTERS': nan,
#  'JOJOBA OIL': '0',
#  'KAOLIN': '0',
#  'KAPPAPHYCUS ALVAREZII EXTRACT': nan,
#  'KARANJA OIL': nan,
#  'KAVA KAVA EXTRACT': nan,
#  'KELP': nan,
#  'KIGELIA AFRICANA FRUIT EXTRACT': nan,
#  'KNOTGRASS EXTRACT': nan,
#  'KOREAN PASQUE FLOWER EXTRACT': nan,
#  'KUKUI NUT OIL': nan,
#  'LA': nan,
#  'LACTIC ACID': nan,
#  'LACTOBACILLUS FERMENT': nan,
#  'LACTOBACILLUS FERMENT LYSATE FILTRATE': nan,
#  'LACTOBACILLUS': nan,
#  'ARUNDINARIA GIGANTEA FERMENT FILTRATE': nan,
#  'ERIODICTYON CALIFORNICUM FERMENT EXTRACT': nan,
#  'KELP FERMENT FILTRATE': nan,
#  'NEREOCYSTIS LUETKEANA FERMENT FILTRATE': nan,
#  'PUMPKIN FERMENT EXTRACT': nan,
#  'PUNICA GRANATUM FRUIT FERMENT EXTRACT': nan,
#  'LACTOBIONIC ACID': nan,
#  'LACTOCOCCUS FERMENT LYSATE': nan,
#  "LADY'S THISTLE EXTRACT": nan,
#  'LADY’S SLIPPER ORCHID EXTRACT': nan,
#  'LAMINARIA ALGAE EXTRACT': nan,
#  'LAMINARIA SACCHARINA EXTRACT': nan,
#  'LANABLUE': nan,
#  'LAURETH-23': '0',
#  'LAURETH-7': nan,
#  'LAURIC ACID': '1',
#  'LAURYL GLUCOSIDE': nan,
#  'LAURYL METHACRYLATE': nan,
#  'SODIUM METHACRYLATE CROSSPOLYMER': nan,
#  'LAURYL PEG-9 POLYDIMETHYLSILOXYETHYL DIMETHICONE': nan,
#  'LAVANDULA ANGUSTIFOLIA FLOWER WATER': nan,
#  'LAVANDULA ANGUSTIFOLIA FLOWER': nan,
#  'STEM OIL': nan,
#  'LAVANDULA ANGUSTIFOLIA OIL': nan,
#  'LAVENDER ESSENTIAL OIL': nan,
#  'LAVENDER FLOWER WATER': nan,
#  'LECITHIN': nan,
#  'LEMON FRUIT EXTRACT': nan,
#  'LEMON PEEL OIL': nan,
#  'LENS ESCULENTA FRUIT EXTRACT': nan,
#  'LENTIL FRUIT EXTRACT': nan,
#  'LENTINUS EDODES MYCELIUM EXTRACT': nan,
#  'LEONTOPODIUM ALPINUM CALLUS CULTURE EXTRACT': nan,
#  'LEPTOSPERMUM SCOPARIUM BRANCH': nan,
#  'LEUCONOSTOC FERMENT FILTRATE': nan,
#  'LEUCONOSTOC': nan,
#  'RADISH ROOT FERMENT FILTRATE': nan,
#  'LEUPHASYL': nan,
#  'LICHEN EXTRACT': nan,
#  'LICORICE': nan,
#  'LICORICE ROOT': nan,
#  'LILIAL': nan,
#  'LIMNANTHES ALBA SEED OIL': nan,
#  'LIMONENE': nan,
#  'LINALOOL': nan,
#  'LINOLEIC ACID': nan,
#  'LINOLENIC ACID': nan,
#  'LINSEED OIL': nan,
#  'LINUM USITATISSIMUM SEED OIL': nan,
#  'LIPOCHROMAN-6': nan,
#  'LIPOSOMAL PREPARATION OF APPLE STEM CELLS': nan,
#  'LONICERA CAPRIFOLIUM EXTRACT': nan,
#  'LONICERA JAPONICA FLOWER EXTRACT': nan,
#  'LUMINESS ALGAE': nan,
#  'LUTEIN': nan,
#  'MACADAMIA INTEGRIFOLIA SEED OIL': nan,
#  'MACADAMIA OIL': nan,
#  'MACADAMIA TERNIFOLIA SEED OIL': nan,
#  'MACROCYSTIS PYRIFERA': nan,
#  'MADECASSIC ACID': nan,
#  'MADECASSOSIDE': nan,
#  'MAGNESIUM ALUMINUM SILICATE': '0',
#  'MAGNESIUM ASCORBYL PHOSPHATE': nan,
#  'MAGNESIUM CHLORIDE': nan,
#  'MAGNESIUM SULFATE': nan,
#  'MAJESTEM': nan,
#  'MALIC ACID': nan,
#  'MALTODEXTRIN': nan,
#  'MALUS DOMESTICA FRUIT CELL CULTURE': nan,
#  'MANDARIN ORANGE OIL': nan,
#  'MANDELIC ACID': nan,
#  'MANGANESE VIOLET': nan,
#  'MANGIFERA INDICA SEED OIL': nan,
#  'MANGO SEED OIL': nan,
#  'MANNITOL': nan,
#  'MANNOSE': nan,
#  'MANUKA ESSENTIAL OIL': nan,
#  'MAQUI BERRY OIL': nan,
#  'MARULA SEED OIL': nan,
#  'MASTIC GUM': nan,
#  'MATRIXYL': nan,
#  "MATRIXYL SYNTHE'6": nan,
#  'MEADOWFOAM OIL': nan,
#  'MEADOWSWEET EXTRACT': nan,
#  'MEL': nan,
#  'MELALEUCA ALTERNIFOLIA LEAF EXTRACT': nan,
#  'MELALEUCA ALTERNIFOLIA LEAF OIL': nan,
#  'MELALEUCA ALTERNIFOLIA LEAF WATER': nan,
#  'MELALEUCA LEUCADENDRON CAJUPUTI LEAF OIL': nan,
#  'MELALEUCA TERETIFOLIA BRANCH': nan,
#  'MELISSA OFFICINALIS LEAF OIL': nan,
#  'MELITANE': nan,
#  'MENTHA PIPERITA LEAF OIL': nan,
#  'MENTHA PIPERITA OIL': nan,
#  'MENTHOL': nan,
#  'METHICONE': nan,
#  'METHOXYCINNAMIDOPROPYL HYDROXYSULTAINE': nan,
#  'METHYL DIISOPROPYL PROPIONAMIDE': nan,
#  'METHYL GLUCETH-10': nan,
#  'METHYL GLUCETH-20': nan,
#  'METHYL GLUCOSE SESQUISTEARATE': nan,
#  'METHYL METHACRYLATE CROSSPOLYMER': nan,
#  'PEG': nan,
#  'PPG-4': nan,
#  '3 METHACRYLATE CROSSPOLYMER': nan,
#  'METHYL TRIMETHICONE': nan,
#  'METHYLCHLOROISOTHIAZOLINONE': nan,
#  'METHYLENE BIS-BENZOTRIAZOLYL TETRAMETHYLBUTYLPHENOL': nan,
#  'METHYLGLUCOSIDE PHOSPHATE': nan,
#  'METHYLHEPTYL LAURATE': nan,
#  'METHYLISOTHIAZOLINONE': nan,
#  'METHYLPARABEN': '0',
#  'METHYLPROPANEDIOL': nan,
#  'MEXORYL XL': nan,
#  'MICA': nan,
#  'MICROCITRUS AUSTRALASICA FRUIT EXTRACT': nan,
#  'MICROCRYSTALLINE CELLULOSE': nan,
#  'MILK PEPTIDE COMPLEX': nan,
#  'MILK THISTLE OIL': nan,
#  'MIMOSA WAX': nan,
#  'MINERAL OIL': '0',
#  'MONTMORILLONITE': nan,
#  'MORINGA OLEIFERA SEED OIL': nan,
#  'MORINGA SEED OIL': nan,
#  'MOUNTAIN ARNICA EXTRACT': nan,
#  'MU-CONOTOXIN CNIIIC': nan,
#  'MYRISTIC ACID': '0',
#  'MYRISTOYL HEXAPEPTIDE-16': nan,
#  'MYRISTOYL NONAPEPTIDE-3': nan,
#  'MYRISTOYL PENTAPEPTIDE-17': nan,
#  'MYRISTYL MALATE PHOSPHONIC ACID': nan,
#  'MYRISTYL MYRISTATE': '2',
#  'MYRISTYL NICOTINATE': nan,
#  'MYRRH': nan,
#  'MYRTLE EXTRACT': nan,
#  'MYRTUS COMMUNIS EXTRACT': nan,
#  'N-BUTYL ALCOHOL': nan,
#  'NAN-WUWEIZI FRUIT EXTRACT': nan,
#  'NEO HELIOPAN AP': nan,
#  'NEOPENTYL GLYCOL DICAPRYLATE': nan,
#  'DICAPRATE': '0',
#  'NEOPENTYL GLYCOL DIHEPTANOATE': nan,
#  'NETTLE LEAF EXTRACT': nan,
#  'NEUROPEPTIDE-1': nan,
#  'NEUROPEPTIDE-2': nan,
#  'NIA-114': nan,
#  'NIACINAMIDE': nan,
#  'NIGELLA SATIVA SEED OIL': nan,
#  'NIKKOL GS‐MHL': nan,
#  'NOVHYAL': nan,
#  'NYLON-12': nan,
#  'OAT KERNEL EXTRACT': nan,
#  'OCTINOXATE': '0.0',
#  'OCTOCRYLENE': nan,
#  ...}

# %%
def lookup_all(ingredient_list, match_dict, match_dict_extra,
               df_inci, df_cosing, option=''):

    rating_inci, irritancy_inci, comedogenicity_inci, function_inci, qfacts_inci, desc_inci, desc_cosing, function_cosing = create_dict_english(df_inci, df_cosing)
    
    res = []
    
    for item in tqdm(ingredient_list):
        
        value = match_dict[item]
        key = match_dict.get(item, 'unknown')
        if value == 'unknown':
            key = match_dict_extra.get(item, 'unknown')
            rating = 'unknown'
            irritancy = 'unknown'
            comedigenicity = 'unknown'
            functions = function_cosing.get(key, [])
            quickfacts = 'unknown'
            description = desc_cosing.get(key, [])
        else:
            rating = rating_inci.get(key, 'unknown')
            irritancy = irritancy_inci.get(key, 'unknown')
            comedogenicity = comedogenicity_inci.get(key, 'unknown')
            functions = function_inci.get(key, [])
            quickfacts = qfacts_inci.get(key, [])
            description = desc_inci.get(key, [])
            
        if option == 'ingredient':
            res.append(key)
        elif option == 'rating':
            res.append(rating)
        elif option == 'irritancy':
            res.append(irritancy)
        elif option == 'comedogenicity':
            res.append(comedogenicity)
        elif option == 'functions':
            res.append(functions)
        elif option == 'quickfacts':
            res.append(quickfacts)
        elif option == 'description':
            res.append(description)
        else:
            res.extend([[key, functions, rating, irritancy, comedogenicity, quickfacts, description]])
            
    df_res = pd.DataFrame(res, columns=['Ingredient_name', 'Functions', 'Rating', 'Irritancy',
                                        'Comedogenicity', 'Quick_facts', 'Description'])
    
    return df_res

# %% [markdown]
# # **Function for fuzzy dict**

# %%
# Fuzzydict

from fuzzywuzzy import fuzz 

class FuzzyDict(dict):
    "Provides a dictionary that performs fuzzy lookup"
    def __init__(self, items = None, cutoff = .6):
        """Construct a new FuzzyDict instance

        items is an dictionary to copy items from (optional)
        cutoff is the match ratio below which mathes should not be considered
        cutoff needs to be a float between 0 and 1 (where zero is no match
        and 1 is a perfect match)"""
        super(FuzzyDict, self).__init__()

        if items:
            self.update(items)
        self.cutoff =  cutoff

        # short wrapper around some super (dict) methods
        self._dict_contains = lambda key: \
            super(FuzzyDict,self).__contains__(key)

        self._dict_getitem = lambda key: \
            super(FuzzyDict,self).__getitem__(key)

    def _search(self, lookfor, stop_on_first = False):
        """Returns the value whose key best matches lookfor

        if stop_on_first is True then the method returns as soon
        as it finds the first item
        """

        # if the item is in the dictionary then just return it
        if self._dict_contains(lookfor):
            return True, lookfor, self._dict_getitem(lookfor), 1

        # set up the fuzzy matching tool
        #ratio_calc = difflib.SequenceMatcher()
        #ratio_calc.set_seq1(lookfor)

        # test each key in the dictionary
        best_ratio = 0
        best_match = None
        best_key = None
        for key in self:

            # if the current key is not a string
            # then we just skip it
            if not isinstance(key, str):
                continue

            # we get an error here if the item to look for is not a
            # string - if it cannot be fuzzy matched and we are here
            # this it is defintely not in the dictionary
            try:
            # calculate the match value
                ratio = fuzz.ratio(lookfor, key)/100
            except TypeError:
                break

            # if this is the best ratio so far - save it and the value
            if ratio > best_ratio:
                best_ratio = ratio
                best_key = key
                best_match = self._dict_getitem(key)

            if stop_on_first and ratio >= self.cutoff:
                break

        return (
            best_ratio >= self.cutoff,
            best_key,
            best_match,
            best_ratio)


    def __contains__(self, item):
        "Overides Dictionary __contains__ to use fuzzy matching"
        if self._search(item, True)[0]:
            return True
        else:
            return False

    def __getitem__(self, lookfor):
        "Overides Dictionary __getitem__ to use fuzzy matching"
        matched, key, item, ratio = self._search(lookfor)

        if not matched:
            raise KeyError(
                "'%s'. closest match: '%s' with ratio %.3f"%
                    (str(lookfor), str(key), ratio))

        return item

# %%
def fuzzy_match_ingredients(ing_list, fuzdict):
    match_dict = {}
    for ing in tqdm(ing_list):
        if ing in match_dict.keys():
            continue
        upper_ing = ing.upper()
        if fuzdict.__contains__(upper_ing):
            match_dict[ing] = fuzdict[upper_ing]
        else:
            match_dict[ing] = 'unknown'
    
    return match_dict

# %% [markdown]
# # **Testing: Englist**

# %%
# df_ingredient = pd.read_csv(ingredient_df_path)
df_inci = pd.read_csv('../Database/INCI/ingredient_inci_1570.csv')
df_cosing = pd.read_csv('../Database/ingredient_cosing_37309.csv')
df_paula = pd.read_csv('../Database/PAULA/ingredient_paula_1833_new.csv')

# %%
# df_inci.rename(columns={'Ingredient_name': 'ingredient_name',
#                        'Rating': 'rating',
#                         'Irritancy': 'irritancy',
#                         'Comedogenicity': 'comedogenicity',
#                         'Rating_score': 'rating_score',
#                        'Functions': 'functions',
#                        'Quick_facts': 'quick_facts',
#                        'Details': 'description',
#                        'Link': 'link'}, inplace=True)
# df_inci['ingredient_name'] = df_inci['ingredient_name'].apply(lambda x: x.upper())

# %%
# # df_paula['rating'] = df_paula['rating'].apply(lambda x: 'Good' if x == 'GOOD' else x)
# df_paula['rating'] = df_paula['rating'].map({'Best': 'superstar',
#                                             'Good': 'goodie',
#                                              'GOOD': 'goodie',
#                                             'Poor': 'icky',
#                                             'Average': 'average'
#                                             })
# df_paula['rating_score'] = df_paula['rating'].map({'icky': 0,
#                                                  'average': 1,
#                                                  'goodie': 2,
#                                                  'superstar': 3})
# df_paula.rename(columns={'name': 'ingredient_name',
#                         'category': 'functions',
#                         }, inplace=True)
# df_paula['ingredient_name'] = df_paula['ingredient_name'].apply(lambda x: x.upper())

# %%
boxes = get_bounding_box('../text-detection-ctpn/data/res/sample5.txt')
img_path = '../Sample_images/sample5.JPG'
# img = cv2.imread('../Sample_images/sample5.JPG')
# img_ocr = preprocess_for_ocr(img)
# cv2.imshow('sample', img_ocr)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

text = ''
for box in boxes:
    croped = crop_line(img_path, box)
    string = ocr(croped)
    text = text + ' ' + str(string.strip('\n').strip('\x0c').strip())

text_result = clean_string(text)
ing_list = string_to_list(text_result)

# %%
print(text_result)
# Out:
# AQUA (WATER), CAPRYLIC/CAPRIC. TRIGLYCERIDE, CETYL ALCOHOL, PROPANEDIOL, STEARYL ALCOHOL, GLYCERIN, SODIUM HYALURONATE, ARGININE, ASPARTIC ACID, GLYCINE, ALANINE, SERINE, VALINE, ISOLEUCINE, PROLINE, THREONINE, HISTIDINE, PHENYLALANINE, GLUCOSE, MALTOSE, FRUCTOSE, TREHALOSE, SODIUM PCA. PCA. SODIUM LACTATE, UREA, ALLANTOIN, LINOLEIC ACID, OLEIC ACID, PHYTOSTERYL CANOLA GLYCERIDES, PALMITIC ACID, STEARIC ACID, LECITHIN, TRIOLEIN, TOCOPHEROL, CARBOMER, ISOCETETH-20, POLYSORBATE 60, SODIUM CHLORIDE, CITRIC ACID, TRISODIUM ETHYLENEDIAMINE DISUCCINATE, PENTYLENE GLYCOL. TRIETHANOLAMINE, SODIUM HYDROXIDE, PHENOXYETHANOL, CHLORPHENESIN. eee ere

# %%
print(ing_list)
# Out:
# ['WATER', 'CAPRYLIC/CAPRIC. TRIGLYCERIDE', 'CETYL ALCOHOL', 'PROPANEDIOL', 'STEARYL ALCOHOL', 'GLYCERIN', 'SODIUM HYALURONATE', 'ARGININE', 'ASPARTIC ACID', 'GLYCINE', 'ALANINE', 'SERINE', 'VALINE', 'ISOLEUCINE', 'PROLINE', 'THREONINE', 'HISTIDINE', 'PHENYLALANINE', 'GLUCOSE', 'MALTOSE', 'FRUCTOSE', 'TREHALOSE', 'SODIUM PCA. PCA. SODIUM LACTATE', 'UREA', 'ALLANTOIN', 'LINOLEIC ACID', 'OLEIC ACID', 'PHYTOSTERYL CANOLA GLYCERIDES', 'PALMITIC ACID', 'STEARIC ACID', 'LECITHIN', 'TRIOLEIN', 'TOCOPHEROL', 'CARBOMER', 'ISOCETETH-20', 'POLYSORBATE 60', 'SODIUM CHLORIDE', 'CITRIC ACID', 'TRISODIUM ETHYLENEDIAMINE DISUCCINATE', 'PENTYLENE GLYCOL. TRIETHANOLAMINE', 'SODIUM HYDROXIDE', 'PHENOXYETHANOL', 'CHLORPHENESIN. EEE ERE']

# %%
cosing_dict = {name.strip(): name.strip() for name in df_cosing['ingredient_name']}
fd_cosing = FuzzyDict(cosing_dict, cutoff = .6)
print(len(fd_cosing))

paula_dict = {name.strip(): name.strip() for name in df_paula['ingredient_name']}
fd_paula = FuzzyDict(paula_dict, cutoff = .6)
print(len(fd_paula))

inci_dict = {name.strip(): name.strip() for name in df_inci['ingredient_name']}
fd_inci = FuzzyDict(inci_dict, cutoff = .7)
print(len(fd_inci))
# Out:
# 29908
# 1833
# 1528

# %%
match_dict_fuzzy = fuzzy_match_ingredients(ing_list, fd_inci)
# Out:
# 100%|██████████| 43/43 [00:00<00:00, 314.86it/s]

# %%
match_dict_fuzzy
# Out:
# {'WATER': 'WATER',
#  'CAPRYLIC/CAPRIC. TRIGLYCERIDE': 'CAPRYLIC/ CAPRIC TRIGLYCERIDE',
#  'CETYL ALCOHOL': 'CETYL ALCOHOL',
#  'PROPANEDIOL': 'PROPANEDIOL',
#  'STEARYL ALCOHOL': 'STEARYL ALCOHOL',
#  'GLYCERIN': 'GLYCERIN',
#  'SODIUM HYALURONATE': 'SODIUM HYALURONATE',
#  'ARGININE': 'ARGININE',
#  'ASPARTIC ACID': 'ASPARTIC ACID',
#  'GLYCINE': 'GLYCINE',
#  'ALANINE': 'ALANINE',
#  'SERINE': 'SERINE',
#  'VALINE': 'VALINE',
#  'ISOLEUCINE': 'ISOLEUCINE',
#  'PROLINE': 'PROLINE',
#  'THREONINE': 'THREONINE',
#  'HISTIDINE': 'HISTIDINE',
#  'PHENYLALANINE': 'PHENYLALANINE',
#  'GLUCOSE': 'GLUCOSE',
#  'MALTOSE': 'MANNOSE',
#  'FRUCTOSE': 'FRUCTOSE',
#  'TREHALOSE': 'TREHALOSE',
#  'SODIUM PCA. PCA. SODIUM LACTATE': 'unknown',
#  'UREA': 'UREA',
#  'ALLANTOIN': 'ALLANTOIN',
#  'LINOLEIC ACID': 'LINOLEIC ACID',
#  'OLEIC ACID': 'OLEIC ACID',
#  'PHYTOSTERYL CANOLA GLYCERIDES': 'unknown',
#  'PALMITIC ACID': 'PALMITIC ACID',
#  'STEARIC ACID': 'STEARIC ACID',
#  'LECITHIN': 'LECITHIN',
#  'TRIOLEIN': 'TRETINOIN',
#  'TOCOPHEROL': 'TOCOPHEROL',
#  'CARBOMER': 'CARBOMER',
#  'ISOCETETH-20': 'ISOCETETH-20',
#  'POLYSORBATE 60': 'POLYSORBATE 60',
#  'SODIUM CHLORIDE': 'SODIUM CHLORIDE',
#  'CITRIC ACID': 'CITRIC ACID',
#  'TRISODIUM ETHYLENEDIAMINE DISUCCINATE': 'TRISODIUM ETHYLENEDIAMINE DISUCCINATE',
#  'PENTYLENE GLYCOL. TRIETHANOLAMINE': 'NEOPENTYL GLYCOL DIHEPTANOATE',
#  'SODIUM HYDROXIDE': 'SODIUM HYDROXIDE',
#  'PHENOXYETHANOL': 'PHENOXYETHANOL',
#  'CHLORPHENESIN. EEE ERE': 'CHLORPHENESIN'}

# %%
match_dict_fuzzy.values
missing_ing = []
for key, value in match_dict_fuzzy.items():
    if value == 'unknown':
        missing_ing.append(key)
missing_ing

match_dict_extra = fuzzy_match_ingredients(missing_ing, fd_cosing)
match_dict_extra
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  9.14it/s]
# {'SODIUM PCA. PCA. SODIUM LACTATE': 'SODIUM ALUMINUM LACTATE',
#  'PHYTOSTERYL CANOLA GLYCERIDES': 'PHYTOSTERYL CANOLA GLYCERIDES'}

# %% [markdown]
# # **End to end**

# %%
def before_ctpn(img_path):
    img = cv2.imread(img_path)
    img_ctpn = preprocess_for_ocr(img, enhance=2)
    
    return img_ctpn

# %%
def after_ctpn_english(img_path, txt_path, inci_path, cosing_path):
    # Get annotations of bounding boxes
    boxes = get_bounding_box(txt_path)
    
#     # Preprocess image for OCR:
#     img = cv2.imread(img_path)
#     #img_ocr = preprocess_for_ocr(img)
#     img_ocr = img
    
    # doing OCR
    text = ''
    for box in boxes:
        croped = crop_line(img_path, box)
        string = ocr(croped)
        text = text + ' ' + str(string.strip('\n').strip('\x0c').strip())
    
    print(text)
    
    # Cleaning result from OCR
    text_result = clean_string(text)
    ing_list = string_to_list(text_result)
    
    print("-----")
    print(text_result)
    
    # Loading ingredient dataframe
    df_inci = pd.read_csv(inci_path) # '../Database/CALLMEDUY/ingredient_vietnamese_3818.csv'
    df_cosing = pd.read_csv(cosing_path) #'../Database/ingredient_cosing_37309.csv'
    
#     rating_inci, irritancy_inci, comedogenicity_inci, function_inci, qfacts_inci, desc_inci, desc_cosing, function_cosing = create_dict_english(df_inci, df_cosing)
    
    # fd_cmd
    inci_dict = {name.strip(): name.strip() for name in df_inci['ingredient_name']}
    fd_inci = FuzzyDict(inci_dict, cutoff = .7)
    
    # fd_cosing
    cosing_dict = {name.strip(): name.strip() for name in df_cosing['ingredient_name']}
    fd_cosing = FuzzyDict(cosing_dict, cutoff = .6)
    
    # Compare product ingredient list and database
    # match_dict = find_matching_ingredient(ing_list, rating, 0.55)
    match_dict_fuzzy = fuzzy_match_ingredients(ing_list, fd_inci)

    missing_ing = []
    for key, value in match_dict_fuzzy.items():
        if value == 'unknown':
            missing_ing.append(key)

    match_dict_extra = fuzzy_match_ingredients(missing_ing, fd_cosing)
    print(len(match_dict_fuzzy))
    print(len(match_dict_extra))
    
    # Analyzing ingredient
    df_res = lookup_all(ing_list, match_dict_fuzzy, match_dict_extra, df_inci, df_cosing)
    
    return df_res

# %%
df_res = after_ctpn_english('../Sample_images/sample5.JPG',
                               '../text-detection-ctpn/data/res/sample5.txt', 
                               '../Database/INCI/ingredient_inci_1570.csv',
                               '../Database/ingredient_cosing_37309.csv')
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]
#  Ingredients / Ingrédients: AQUA (WATER), CAPRYLIC/CAPRIC. TRIGLYCERIDE, CETYL ALCOHOL, PROPANEDIOL, STEARYL ALCOHOL, GLYCERIN, SODIUM HYALURONATE, ARGININE, ASPARTIC ACID, GLYCINE, ALANINE, SERINE, VALINE, ISOLEUCINE, PROLINE, THREONINE, HISTIDINE, PHENYLALANINE, GLUCOSE, MALTOSE, FRUCTOSE, TREHALOSE, SODIUM PCA. PCA. SODIUM LACTATE, UREA, ALLANTOIN, LINOLEIC ACID, OLEIC ACID, PHYTOSTERYL CANOLA GLYCERIDES, PALMITIC ACID, STEARIC ACID, LECITHIN, TRIOLEIN, TOCOPHEROL, CARBOMER, ISOCETETH-20, POLYSORBATE 60, SODIUM CHLORIDE, CITRIC ACID, TRISODIUM ETHYLENEDIAMINE DISUCCINATE, PENTYLENE GLYCOL. TRIETHANOLAMINE, SODIUM HYDROXIDE, PHENOXYETHANOL, CHLORPHENESIN. eee ere
# -----
# AQUA (WATER), CAPRYLIC/CAPRIC. TRIGLYCERIDE, CETYL ALCOHOL, PROPANEDIOL, STEARYL ALCOHOL, GLYCERIN, SODIUM HYALURONATE, ARGININE, ASPARTIC ACID, GLYCINE, ALANINE, SERINE, VALINE, ISOLEUCINE, PROLINE, THREONINE, HISTIDINE, PHENYLALANINE, GLUCOSE, MALTOSE, FRUCTOSE, TREHALOSE, SODIUM PCA. PCA. SODIUM LACTATE, UREA, ALLANTOIN, LINOLEIC ACID, OLEIC ACID, PHYTOSTERYL CANOLA GLYCERIDES, PALMITIC ACID, STEARIC ACID, LECITHIN, TRIOLEIN, TOCOPHEROL, CARBOMER, ISOCETETH-20, POLYSORBATE 60, SODIUM CHLORIDE, CITRIC ACID, TRISODIUM ETHYLENEDIAMINE DISUCCINATE, PENTYLENE GLYCOL. TRIETHANOLAMINE, SODIUM HYDROXIDE, PHENOXYETHANOL, CHLORPHENESIN. eee ere
# 100%|██████████| 43/43 [00:00<00:00, 302.55it/s]
# 100%|██████████| 2/2 [00:00<00:00,  5.15it/s]
# 261it [00:00, 2609.14it/s]
# 43
# 2
# 1570it [00:00, 3223.57it/s]
# 37309it [00:06, 5734.61it/s]
# 100%|██████████| 43/43 [00:00<00:00, 76812.21it/s]

# %%
df_res
# Out:
#                           Ingredient_name  \
# 0                                   WATER
# 1           CAPRYLIC/ CAPRIC TRIGLYCERIDE
# 2                           CETYL ALCOHOL
# 3                             PROPANEDIOL
# 4                         STEARYL ALCOHOL
# 5                                GLYCERIN
# 6                      SODIUM HYALURONATE
# 7                                ARGININE
# 8                           ASPARTIC ACID
# 9                                 GLYCINE
# 10                                ALANINE
# 11                                 SERINE
# 12                                 VALINE
# 13                             ISOLEUCINE
# 14                                PROLINE
# 15                              THREONINE
# 16                              HISTIDINE
# 17                          PHENYLALANINE
# 18                                GLUCOSE
# 19                                MANNOSE
# 20                               FRUCTOSE
# 21                              TREHALOSE
# 22                SODIUM ALUMINUM LACTATE
# 23                                   UREA
# 24                              ALLANTOIN
# 25                          LINOLEIC ACID
# 26                             OLEIC ACID
# 27          PHYTOSTERYL CANOLA GLYCERIDES
# 28                          PALMITIC ACID
# 29                           STEARIC ACID
# 30                               LECITHIN
# 31                              TRETINOIN
# 32                             TOCOPHEROL
# 33                               CARBOMER
# 34                           ISOCETETH-20
# 35                         POLYSORBATE 60
# 36                        SODIUM CHLORIDE
# 37                            CITRIC ACID
# 38  TRISODIUM ETHYLENEDIAMINE DISUCCINATE
# 39          NEOPENTYL GLYCOL DIHEPTANOATE
# 40                       SODIUM HYDROXIDE
# 41                         PHENOXYETHANOL
# 42                          CHLORPHENESIN
#
#                                             Functions     Rating Irritancy  \
# 0        {'solvent': '/ingredient-functions/solvent'}  No rating       NaN
# 1                                                  []    unknown   unknown
# 2   {'emollient': '/ingredient-functions/emollient...  No rating         2
# 3   {'solvent': '/ingredient-functions/solvent', '...  No rating       NaN
# 4   {'emollient': '/ingredient-functions/emollient...  No rating         2
# 5   {'skin-identical ingredient': '/ingredient-fun...  superstar         0
# 6   {'skin-identical ingredient': '/ingredient-fun...     goodie         0
# 7   {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 8   {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 9   {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 10  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 11  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 12  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 13  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 14  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 15  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 16  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 17  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 18  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 19  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 20  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 21  {'moisturizer/humectant': '/ingredient-functio...     goodie       NaN
# 22                              ASTRINGENT, BUFFERING    unknown   unknown
# 23  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 24     {'soothing': '/ingredient-functions/soothing'}     goodie         0
# 25  {'skin-identical ingredient': '/ingredient-fun...     goodie       NaN
# 26  {'emollient': '/ingredient-functions/emollient...  No rating       NaN
# 27               HAIR CONDITIONING, SKIN CONDITIONING    unknown   unknown
# 28  {'skin-identical ingredient': '/ingredient-fun...  No rating         0
# 29  {'emollient': '/ingredient-functions/emollient...  No rating         0
# 30  {'emollient': '/ingredient-functions/emollient...     goodie       NaN
# 31  {'cell-communicating ingredient': '/ingredient...  superstar       NaN
# 32  {'antioxidant': '/ingredient-functions/antioxi...     goodie       0-3
# 33  {'viscosity controlling': '/ingredient-functio...  No rating         0
# 34  {'emulsifying': '/ingredient-functions/emulsif...  No rating       NaN
# 35  {'emulsifying': '/ingredient-functions/emulsif...  No rating       NaN
# 36  {'viscosity controlling': '/ingredient-functio...  No rating       NaN
# 37   {'buffering': '/ingredient-functions/buffering'}  No rating       NaN
# 38   {'chelating': '/ingredient-functions/chelating'}  No rating       NaN
# 39   {'emollient': '/ingredient-functions/emollient'}  No rating       NaN
# 40   {'buffering': '/ingredient-functions/buffering'}  No rating       NaN
# 41  {'preservative': '/ingredient-functions/preser...  No rating       NaN
# 42  {'preservative': '/ingredient-functions/preser...  No rating       NaN
#
#          Comedogenicity                                        Quick_facts  \
# 0                   NaN                                                NaN
# 1               unknown                                                 []
# 2                     2                                                NaN
# 3                   NaN                                                NaN
# 4                     2                                                NaN
# 5                     0  ['A natural moisturizer that’s also in our ski...
# 6                     0                                                NaN
# 7                   NaN                                                NaN
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN                                                NaN
# 15                  NaN                                                NaN
# 16                  NaN                                                NaN
# 17                  NaN                                                NaN
# 18                  NaN                                                NaN
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                  NaN                                                NaN
# 22                  NaN                                            unknown
# 23                  NaN                                                NaN
# 24                    0                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27                  NaN                                            unknown
# 28                    2                                                NaN
# 29  2020-02-03 00:00:00                                                NaN
# 30                  NaN                                                NaN
# 31                  NaN  ["Tretinoin (a metabolite of vitamin A) is the...
# 32                  0-3  ['Primary fat-soluble antioxidant in our skin ...
# 33                    1                                                NaN
# 34                  NaN                                                NaN
# 35                  NaN                                                NaN
# 36                  NaN                                                NaN
# 37                  NaN                                                NaN
# 38                  NaN                                                NaN
# 39                  NaN                                                NaN
# 40                  NaN                                                NaN
# 41                  NaN                                                NaN
# 42                  NaN                                                NaN
#
#                                           Description
# 0   ['Good old water, aka H2O. The most common ski...
# 1                                                  []
# 2   ['A so-called\xa0fatty (the good, non-drying k...
# 3   ["Propanediol is a natural alternative for the...
# 4   ['A handy multi-tasker,\xa0white to light yell...
# 5   ['Glycerin doesn’t sound very glamorous but it...
# 6   ["It’s the - sodium form - cousin of the famou...
# 7   ["A semi-essential (infants cannot synthesize ...
# 8   ['A non-essential\xa0amino acid \xa0(important...
# 9   ['A non-essential amino acid (the building blo...
# 10  ['A non-essential amino acid (a building block...
# 11  ["Serine is an amino acid that most often come...
# 12  ['An essential amino acid (a building block of...
# 13  ["A branch-chained, essential amino acid that ...
# 14  ["A non-essential amino acid (meaning that our...
# 15  ["An\xa0essential amino acid that's also a key...
# 16  ['A semi-essential amino acid meaning that eno...
# 17  ['An essential amino acid that the body cannot...
# 18  ['A so-called\xa0"Fermentoil" that is created ...
# 19  ['Mannose is one of the many sugar molecules o...
# 20  ['Fancy name for fruit sugar. It has nice wate...
# 21  ['A type of sugar that has\xa0water-binding\xa...
# 22          Aluminum, lactate sodium complexes, basic
# 23  ["Yes, it's the thing that can be found natura...
# 24  ["Super common soothing ingredient. It can be ...
# 25  ['The famous\xa0omega-6 fatty acid,\xa0the mot...
# 26  ['A common fatty acid that can be found in lot...
# 27  Glycerides, canola oil, reaction products with...
# 28  ["A fatty acid that can be found naturally in ...
# 29  ['A common multi-tasker fatty acid. It makes y...
# 30  ["A very common ingredient that can be found i...
# 31  ["If you wanna get the best possible anti-agin...
# 32  ['Vitamin E is the major fat-soluble antioxida...
# 33  ['A big molecule created from repeated subunit...
# 34  ['A handy helper ingredient that works as an e...
# 35  ['A common little helper ingredient that\xa0he...
# 36  ['Sodium chloride is the fancy name of salt. N...
# 37  ['Citric acid comes from citrus fruits and is ...
# 38  ["A helper ingredient that helps to neutralize...
# 39  ["A clear, odorless, very light emollient este...
# 40  ['The unfancy name for it is lye. It’s a solid...
# 41  ['It’s pretty much the current IT-preservative...
# 42  ["A little helper ingredient that works as a p...

# %%
ing_list = df_res.iloc[:, 0].to_list()
ing_list
# Out:
# ['WATER',
#  'CAPRYLIC/ CAPRIC TRIGLYCERIDE',
#  'CETYL ALCOHOL',
#  'PROPANEDIOL',
#  'STEARYL ALCOHOL',
#  'GLYCERIN',
#  'SODIUM HYALURONATE',
#  'ARGININE',
#  'ASPARTIC ACID',
#  'GLYCINE',
#  'ALANINE',
#  'SERINE',
#  'VALINE',
#  'ISOLEUCINE',
#  'PROLINE',
#  'THREONINE',
#  'HISTIDINE',
#  'PHENYLALANINE',
#  'GLUCOSE',
#  'MANNOSE',
#  'FRUCTOSE',
#  'TREHALOSE',
#  'SODIUM ALUMINUM LACTATE',
#  'UREA',
#  'ALLANTOIN',
#  'LINOLEIC ACID',
#  'OLEIC ACID',
#  'PHYTOSTERYL CANOLA GLYCERIDES',
#  'PALMITIC ACID',
#  'STEARIC ACID',
#  'LECITHIN',
#  'TRETINOIN',
#  'TOCOPHEROL',
#  'CARBOMER',
#  'ISOCETETH-20',
#  'POLYSORBATE 60',
#  'SODIUM CHLORIDE',
#  'CITRIC ACID',
#  'TRISODIUM ETHYLENEDIAMINE DISUCCINATE',
#  'NEOPENTYL GLYCOL DIHEPTANOATE',
#  'SODIUM HYDROXIDE',
#  'PHENOXYETHANOL',
#  'CHLORPHENESIN']

# %%
with open('../Model_product_evaluator/ingredient_idx_1000.pickle', 'rb') as handle:
    ingredient_idx = pickle.load(handle)

# %%
match_dict_token = fuzzy_match_ingredients(ing_list, fd_cosing)
token = [[value for value in match_dict_token.values()]]
# Out:
# 100%|██████████| 43/43 [00:00<00:00, 69.23it/s]

# %%
toke = IngredientTokenizer()
a = toke.transform(token)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class IngredientTokenizer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X): # X: nested list
        M = len(X)
        N = 1000
        A = np.zeros((M, N), dtype=np.uint8)
        i= 0
        for ing_list in X:
            x = np.zeros(N, dtype=np.uint8)
            for ingredient in ing_list:
                # Get the index for each ingredient
                if ingredient in ingredient_idx.keys():
                    idx = ingredient_idx[ingredient]
                    x[idx] = 1
                else:
                    pass
            
            A[i, :] = x
            i += 1
        return A
