# %%
from difflib import SequenceMatcher
from ast import literal_eval
from collections import Counter
from tqdm import tqdm

import pandas as pd
import numpy as np
import re
import operator
import itertools
import gc
import pickle
import os.path

# %% [markdown]
# ## **Preparing ingredient list**
#
# **Read ingredients database and convert to dataframe**

# %%
cols = ['name','category','rating']
ingredient_df = pd.read_csv('../web_scraper/ingredients.csv', usecols=cols, converters={"category": literal_eval})
ingredient_df['name'] = ingredient_df['name'].str.strip()
ingredient_df['rating'].replace('GOOD','Good',inplace=True)
ingredient_df['rating_num'] = ingredient_df['rating'].map({'Poor':0, 'Average':1, 'Good':2, 'Best':3})
print("number of ingredient:",ingredient_df.shape[0])
ingredient_df.to_csv('ingredient_cleaned.csv', index=False)
ingredient_df.head()

# %%
columns = ['name', 'category', 'rating']
ingredient_df = pd.read_csv('ingredient_paula_nodescription.csv', usecols=columns, converters={'category': literal_eval})
ingredient_df.head()
# Out:
#                         name  \
# 0            1, 2-Hexanediol
# 1    10-Hydroxydecanoic Acid
# 2      4-T-butylcyclohexanol
# 3  Acacia farnesiana extract
# 4         acacia senegal gum
#
#                                             category rating
# 0                                    [Preservatives]   Good
# 1                                       [Emollients]   Good
# 2                        [Emollients, Skin-Soothing]   Good
# 3  [Plant Extracts, Fragrance: Synthetic and Frag...   Poor
# 4  [Texture Enhancer, Plant Extracts, Skin-Soothing]   Good

# %%
ingredient_df['name'] = ingredient_df['name'].str.strip()
ingredient_df['rating'].replace('GOOD', 'Good', inplace=True)
ingredient_df['rating_score'] = ingredient_df['rating'].map({'Poor': 0,
                                                            'Average': 1,
                                                            'Good': 2,
                                                            'Best': 3})
ingredient_df.head()
# Out:
#                         name  \
# 0            1, 2-Hexanediol
# 1    10-Hydroxydecanoic Acid
# 2      4-T-butylcyclohexanol
# 3  Acacia farnesiana extract
# 4         acacia senegal gum
#
#                                             category rating  rating_score
# 0                                    [Preservatives]   Good             2
# 1                                       [Emollients]   Good             2
# 2                        [Emollients, Skin-Soothing]   Good             2
# 3  [Plant Extracts, Fragrance: Synthetic and Frag...   Poor             0
# 4  [Texture Enhancer, Plant Extracts, Skin-Soothing]   Good             2

# %% [markdown]
# **Import cleaned data to as 'ingredient_paula_nodescription_cleaned.csv'**

# %%
ingredient_df.to_csv('ingredient_paula_nodescription_cleaned', index=False)

# %%
print('Number of ingredient: ', ingredient_df.shape[0])
# Out:
# Number of ingredient:  1833

# %% [markdown]
# ## **Comparing ingredients**
#
# Create a class where we can check if an ingredient matches our existing ingredient dictionary. if there is a match, find the ingredient's rating and category.
#
# * Initialize the class with ingredient rating dictionary and category dictionary.
# * Given a list of ingredient, find best matching ingredient that rating and category are avaliable. This is done by evaluating the similarity metric between the name of all existing ingredient and the name of given ingredient (use python function SequenceMatcher). If the similarity is below a thresh, then the given ingredient is labeled as 'unknown'.
# * After building up the matching dictionary, we can find an ingredient's matching, rating and category by calling the lookup function.

# %%
class look_up_ingredient():
    
    def __init__(self, rating_dict, category_dict):
        self.rating_dict = rating_dict
        self.rating_dict['unknown'] = np.nan
        
        self.category_dict = category_dict
        self.category_dict['unknown'] = [] # Why this one is an empty list???
        
        self.rating = set([value for value in self.rating_dict.values()])
        self.category = set([value for values in self.category_dict.values() for value in values]) 
        # category can be a list of many functions that ingredient belongs to
        
        self.match_dict = {} # result after comparing
    
    def find_matching_ingredient(self, my_ingredients, thresh=0.25):
        ''' Loop thru each ingredient in the ingredient list of the products
            then check if that ingredient appears in our ingredient list
            Calculate match_metric using SequenceMatcher and return the highest score and the best match
            Compare the match_metric with thresh > append to match_dict
        '''
        for ingredient in tqdm(my_ingredients):
            if ingredient in self.match_dict.keys():
                continue
            match_metric = {key: SequenceMatcher(None, key, ingredient).ratio() for key in self.rating_dict.keys()}
            best_match, best_metric = max(match_metric.items(), key=operator.itemgetter(1)) # What is operator.itemgetter(1)
            if best_metric > thresh:
                self.match_dict[ingredient] = best_match
            else:
                self.match_dict[ingredient] = 'unknown'
    
    def lookup(self, ingredient, option=''):
        ''' Return the information we want
        '''
        key = self.match_dict.get(ingredient, 'unknown') # get the key and values of 'unknown'
        rating = self.rating_dict.get(key, -1) #key is the ingredient
        category = self.category_dict.get(key, [])
        
        if option == 'ingredient':
            return key
        elif option == 'rating':
            return rating
        elif option == 'category':
            return category
        else:
            return key, rating, category
    
    def save_match_dict(self, dictfile='ingredient_match_dict.pickle'):
        ''' Save result after comparing to a pickle file'''
        pickle_out = open(dictfile, 'wb') # wb: open and writing in binary mode
        pickle.dump(self.match_dict, pickle_out)
        pickle_out.close()
    
    def load_match_dict(self, dictfle='ingredient_match_dict.pickle'):
        ''' Read pickle file that we saved'''
        if os.path.isfile(dictfile):
            pickle_in = open(dictfile, 'rb')
            self.match_dict = pickle.load(pickle_in)

# %% [markdown]
# Create ingredient class, note for ingredient with alias we will duplicate the record.
#
# For example, for "PEG/PPG-18/18 dimethicone" we will create three dict items, with different keys but same value.

# %%
# Ingredient_rating_dict: key is ingredient name, value is the rating_score
ingredient_rating_dict = {name: row['rating_score'] for (idx, row) in ingredient_df.iterrows() for name in row['name'].split('/')}
ingredient_rating_dict
# Out:
# {'1, 2-Hexanediol': 2,
#  '10-Hydroxydecanoic Acid': 2,
#  '4-T-butylcyclohexanol': 2,
#  'Acacia farnesiana extract': 0,
#  'acacia senegal gum': 2,
#  'acai': 3,
#  'acetic acid': 0,
#  'acetone': 0,
#  'acetylated castor oil': 2,
#  'acetylated hydrogenated cottonseed glyceride': 2,
#  'acetylated lanolin': 2,
#  'acetylated lanolin alcohol': 2,
#  'acetylated palm kernel glycerides': 2,
#  'acetyl carnitine HCL': 3,
#  'acetyl glucosamine': 3,
#  'acetyl glyceryl ricinoleate': 2,
#  'acetyl hexapeptide-1': 3,
#  'acetyl hexapeptide-37': 3,
#  'acetyl hexapeptide-8': 2,
#  'acetyl octapeptide-3': 2,
#  'acetyl tetrapeptide-11': 3,
#  'acetyl tetrapeptide-5': 3,
#  'acetyl tetrapeptide-9': 3,
#  'acetyl tributyl citrate': 1,
#  'acetyl tyrosine': 2,
#  'Achillea millefolium': 0,
#  'acid': 1,
#  'acne soap': 0,
#  'acrylate': 2,
#  'acrylates': 2,
#  'C10-30 alkyl acrylate crosspolymer': 2,
#  'dimethicone copolymer': 2,
#  'steareth-20 methacrylate copolymer': 2,
#  'acrylates copolymer': 2,
#  'Actaea racemosa': 1,
#  'Actinidia chinensis (kiwi fruit) extract': 3,
#  'adenosine': 3,
#  'adenosine phosphate': 3,
#  'adenosine triphosphate': 3,
#  'adipic acid': 2,
#  'neopentyl glycol': 2,
#  'trimellitic anhydride copolymer': 2,
#  'advanced glycation endproduct (AGE)': 0,
#  'Aerocarpus santalinus': 0,
#  'Aesculus hippocastanum': 2,
#  'agar': 2,
#  'Agastache mexicana (hyssop) flower': 2,
#  'leaf': 2,
#  'stem extract': 3,
#  'AGE': 0,
#  'Agrimonia eupatoria leaf extract': 1,
#  'AHA': 3,
#  'Ahnfeltia concinna extract': 2,
#  'ahnfeltia extract': 2,
#  'Ahnfeltiopsis concinna extract': 2,
#  'alanine': 2,
#  'Alaria esculenta': 2,
#  'albumin': 0,
#  'alcloxa': 0,
#  'alcohol': 1,
#  'Aleurites moluccana seed oil': 3,
#  'alfalfa extract': 3,
#  'algae': 3,
#  'algae extract': 3,
#  'algin': 2,
#  'aliphatic hydrocarbon': 2,
#  'alkaline': 0,
#  'alkyloamides': 1,
#  'allantoin': 3,
#  'allyl methacrylates crosspolymer': 2,
#  'almond': 3,
#  'borage': 3,
#  'linseed': 3,
#  'olive acids glycerides': 3,
#  'almond oil': 3,
#  'Aloe barbadensis': 2,
#  'aloe barbadensis leaf juice extract': 2,
#  'aloe barbadensis leaf juice powder': 2,
#  'aloe extract': 2,
#  'aloe juice': 2,
#  'aloe vera': 2,
#  'alpha bisabolol': 3,
#  'alpha glucan oligosaccharide': 3,
#  'alpha hydroxy acid': 3,
#  'alpha isomethyl ionone': 0,
#  'alpha lipoic acid': 3,
#  'alpha-tocopherol': 3,
#  'Alteromonas ferment extract': 2,
#  'Althaea rosea': 2,
#  'Althea officinalis': 3,
#  'alumina': 2,
#  'aluminum': 2,
#  'Aluminum hydroxide': 2,
#  'aluminum magnesium silicate': 2,
#  'aluminum powder': 2,
#  'aluminum silicate': 2,
#  'aluminum starch octenylsuccinate': 2,
#  'aluminum stearate': 2,
#  'aluminum sulfate': 0,
#  'amino acids': 3,
#  'aminobutyric acid': 1,
#  'aminomethyl propanediol': 2,
#  'aminomethyl propanol': 2,
#  'ammonium acryloyldimethyltaurate': 2,
#  'VP copolymer': 2,
#  'ammonium chloride': 0,
#  'ammonium glycolate': 3,
#  'ammonium hydroxide': 1,
#  'ammonium laureth sulfate': 2,
#  'ammonium lauryl sulfate': 2,
#  'amodimethicone': 2,
#  'amygdalic acid': 2,
#  'amyl cinnamate': 0,
#  'amyl salicylate': 0,
#  'amyris oil': 0,
#  'Anacyclus pyrethrum': 0,
#  'Anacystis nidulans extract': 2,
#  'Ananas sativus fruit extract': 2,
#  'Anastatica hierochuntica extract': 3,
#  'andiroba oil': 2,
#  'Anethum graveolens': 1,
#  'Angelica archangelica root oil': 0,
#  'Angelica polymorpha sinensis root extract': 0,
#  'anhydroxylitol': 2,
#  'anisaldehyde': 0,
#  'anise': 0,
#  'annato extract': 2,
#  'Anthemis nobilis flower extract': 3,
#  'anthocyanin': 3,
#  'antioxidant': 3,
#  'apple fruit extract': 3,
#  'apricot kernel': 1,
#  'apricot kernel oil': 3,
#  'arachidic acid': 2,
#  'arachidyl alcohol': 2,
#  'arachidyl glucoside': 2,
#  'arachidyl propionate': 2,
#  'Arachis hypogaea extract': 3,
#  'arbutin': 3,
#  'Arctium lappa': 3,
#  'Arctium majus': 3,
#  'Arctostaphylos uva ursi leaf': 3,
#  'Argania spinosa': 3,
#  'Argania spinosa kernel oil': 3,
#  'argan oil': 3,
#  'arginine': 2,
#  'Argireline': 2,
#  'Aristotelia chilensis (maqui)': 3,
#  'arnica extract': 0,
#  'aroma': 1,
#  'flavor': 1,
#  'arrowroot': 1,
#  'artemia extract': 2,
#  'Artemisia absinthium extract': 1,
#  'Artemisia vulgaris': 1,
#  'Ascophyllum nodosum': 2,
#  'ascorbic acid': 3,
#  'ascorbyl glucosamine': 3,
#  'ascorbyl glucoside': 3,
#  'ascorbyl methylsilanol pectinate': 3,
#  'ascorbyl palmitate': 3,
#  'asparagine': 2,
#  'Asparagopsis armata extract': 2,
#  'aspartic acid': 2,
#  'astaxanthin': 3,
#  'astaxanthin extract': 3,
#  'Astragalus membranaceus': 3,
#  'Astragalus sinicus': 2,
#  'Astrocaryum murumuru seed butter': 2,
#  'ATP': 3,
#  'atractylodes macrocephala root powder': 3,
#  'Atractyloydes lancea root extract': 1,
#  'Avena sativa': 3,
#  'avobenzone': 3,
#  'avocado oil': 3,
#  'awapuhi': 0,
#  'Azadirachta indica': 1,
#  'azelaic acid': 3,
#  'azelaoyl bis-dipeptide-10': 3,
#  'Azelex': 3,
#  'azuki beans': 1,
#  'azulene': 1,
#  'babassu oil': 3,
#  'bakuchiol': 3,
#  'balm mint extract': 0,
#  'balsam peru': 0,
#  'Bambusa vulgaris (bamboo) leaf': 3,
#  'banana extract': 1,
#  'barberry': 3,
#  'barium sulfate': 2,
#  'barley extract': 1,
#  'batyl alcohol': 2,
#  'bay leaf oil': 0,
#  'bearberry extract': 2,
#  'bee pollen': 0,
#  'beeswax': 2,
#  'beet root extract': 2,
#  'beheneth-5': 2,
#  'behenic acid': 2,
#  'behentrimonium chloride': 2,
#  'behenyl alcohol': 2,
#  'behenyl behenate': 2,
#  'Bellis perennis': 0,
#  'bentonite': 2,
#  'benzalkonium chloride': 1,
#  'benzephenone-3': 2,
#  'benzoic acid': 2,
#  'benzoin extract': 0,
#  'benzophenone': 2,
#  'benzothonium chloride': 2,
#  'benzoyl peroxide': 3,
#  'benzyl alcohol': 2,
#  'benzyl salicylate': 0,
#  'Berberis aristata': 3,
#  'bergamot oil': 0,
#  'Bertholletia excelsa extract': 2,
#  'beta-carotene': 2,
#  'beta-glucan': 3,
#  'beta hydroxy acid': 3,
#  'betaine': 2,
#  'betaine salicylate': 2,
#  'beta-sitosterol': 3,
#  'Beta vulgaris root extract': 2,
#  'Betula alba': 2,
#  'Betula alba (birch) juice': 2,
#  'BHA (beta hydroxy acid)': 3,
#  'BHT': 1,
#  'bifida ferment lysate': 3,
#  'bilberry extract': 3,
#  'bioflavonoid': 3,
#  'biotin': 3,
#  'folic acid': 2,
#  'cyanocobalamin': 2,
#  'niacinamide': 3,
#  'pantothenic acid': 3,
#  'pyridoxine': 3,
#  'riboflavin': 1,
#  'thiamine': 3,
#  'yeast polypeptides': 3,
#  'birch bark extract': 2,
#  'birch leaf extract': 2,
#  'bisabolol': 3,
#  'bis-diglyceryl polyacyladipate': 2,
#  'bismuth oxychloride': 1,
#  'bis-PEG-18 methyl ether dimethyl silane': 2,
#  'bis-phenylpropyl dimethicone': 2,
#  'bitter orange flower': 0,
#  'blackberry': 3,
#  'black cohosh': 1,
#  'black currant oil': 3,
#  'black elderberry': 3,
#  'black locust extract': 0,
#  'black mulberry': 2,
#  'black pepper extract and oil': 0,
#  'black raspberry': 3,
#  'black tea': 3,
#  'bladderwrack extract': 3,
#  'bloodwort': 0,
#  'blue 1': 2,
#  'blue 1 lake': 2,
#  'Boerhavia diffusa root extract': 3,
#  'bois de rose oil': 0,
#  'bois oil': 0,
#  'borage seed extract': 3,
#  'borage seed oil': 3,
#  'Borago officinalis extract': 3,
#  'Borago officinalis seed oil': 3,
#  'borate': 0,
#  'borax': 0,
#  'boric acid': 2,
#  'boron nitride': 2,
#  'Boswellia carterii': 0,
#  'Boswellia serrata extract': 1,
#  'botanicals': 1,
#  'boysenberry': 3,
#  'Brassica campestris': 3,
#  'Brazil nut extract': 2,
#  'broad spectrum': 2,
#  'bromelain': 2,
#  'bronopol': 0,
#  'bronze powder': 2,
#  'Buddleja davidii extract': 3,
#  'bumetrizole': 2,
#  'Bupleurum falcatum extract': 1,
#  'burdock root': 3,
#  'butyl acetate': 2,
#  'butylene glycol': 2,
#  'butyl methoxydibenzoylmethane': 3,
#  'butylparaben': 2,
#  'butylphenyl methylpropional': 0,
#  'Butyrospermum fruit': 3,
#  'Butyrospermum parkii': 3,
#  'Butyrosperum parkii (shea) butter extract': 3,
#  'Buxus chinensis': 3,
#  'C10-30 cholesterol': 3,
#  'lanosterol esters': 3,
#  'C11-15 pareth-7': 2,
#  'C12-15 alkyl benzoate': 2,
#  'C12-16 pareth-9': 2,
#  'C12-18 acid triglyceride': 2,
#  'C13-14 isoparaffin': 2,
#  'C13-15 alkane': 2,
#  'C18-36 acid triglyceride': 2,
#  'C20-40 pareth-40': 2,
#  'caffeic acid': 3,
#  'caffeine': 1,
#  'cajeputi oil': 0,
#  'calamine': 0,
#  'calcium aluminum borosilicate': 2,
#  'calcium ascorbate': 3,
#  'calcium carbonate': 2,
#  'calcium d-pantetheine-s-sulfonate': 2,
#  'calcium gluconate': 2,
#  'calcium pantothenate': 2,
#  'calcium PCA': 3,
#  'calendula extract': 2,
#  'Calendula officinalis flower extract': 2,
#  'Calluna vulgaris flower extract': 3,
#  'Calophyllum inophyllum seed oil': 2,
#  'Camellia japonica flower extract': 3,
#  'Camellia oleifera': 3,
#  'Camellia sinensis': 3,
#  'camphor': 0,
#  'cananga extract': 0,
#  'Cananga odorata': 0,
#  'candelilla': 3,
#  'jojoba': 3,
#  'rice bran polyglyceryl-3 esters': 3,
#  'candelilla wax': 2,
#  'cannabidiol': 3,
#  'Cannabis sativa oil': 3,
#  'canola oil': 3,
#  'caprooyl phytosphingosine': 3,
#  'caprooyl sphingosine': 3,
#  'caprooyl tetrapeptide-3': 3,
#  'caprylic': 3,
#  'capric triglyceride': 3,
#  'capryloyl glycerin': 2,
#  'sebacic acid copolymer': 2,
#  'capryloyl glycine': 2,
#  'capryloyl salicylic acid': 3,
#  'caprylyl caprylate': 2,
#  'caprate': 2,
#  'caprylyl glycol': 2,
#  'caprylyl methicone': 2,
#  'capsaicin': 0,
#  'capsicum': 0,
#  'capsicum oleoresin': 0,
#  'caramel': 2,
#  'carbomer': 2,
#  'carbopol': 2,
#  'carboxylic acid': 3,
#  'cardamom': 0,
#  'carmine': 2,
#  'carnauba wax': 2,
#  'carnitine': 3,
#  'carnosic acid': 3,
#  'carnosine': 3,
#  'carnosol acid': 3,
#  'carrageenan': 2,
#  'carrot oil': 3,
#  'Carthamus tinctorius oil': 3,
#  'carvone': 0,
#  'Carya illinoensis oil': 2,
#  'casein': 2,
#  'Cassia angustifolia seed polysaccharide': 3,
#  'Castanea sativa seed extract': 2,
#  'castor isostearate succinate': 2,
#  'castor oil': 2,
#  'catalase': 3,
#  'Caulerpa taxifolia extract': 2,
#  'cedarwood': 0,
#  'Cedrus atlantica bark extract': 0,
#  'cellulose': 2,
#  'Cellulose gum': 2,
#  'Centaurea cyanus': 3,
#  'Centella asiatica': 3,
#  'cephalin': 3,
#  'Cera alba': 2,
#  'cera microcristallina': 2,
#  'ceramide AP': 3,
#  'ceramide EOP': 3,
#  'ceramide EOS': 3,
#  'ceramide NG': 3,
#  'ceramide NP': 3,
#  'ceramide NS': 3,
#  'ceramides': 3,
#  'ceresin': 2,
#  'ceteareth-20': 2,
#  'ceteareth-25': 2,
#  'ceteareth-6 olivate': 2,
#  'cetearyl alcohol': 2,
#  'cetearyl ethylhexanoate': 2,
#  'cetearyl glucoside': 2,
#  'cetearyl octanoate': 2,
#  'cetearyl olivate': 2,
#  'cetyl acetate': 2,
#  'cetyl alcohol': 2,
#  'cetyl dimethicone': 2,
#  'cetyl dimethicone copolyol': 2,
#  'cetyl esters': 2,
#  'cetyl hydroxyethylcellulose': 2,
#  'cetyl palmitate': 2,
#  'cetyl PEG': 2,
#  'PPG-10': 2,
#  '1-dimethicone': 2,
#  'chamomile': 3,
#  'Chamomilla recutita flower extract': 3,
#  'charcoal': 2,
#  'charcoal powder': 2,
#  'chelating agent': 2,
#  'cherry extract': 3,
#  'China clay': 2,
#  'chitosan': 3,
#  'chlorella': 2,
#  'chlorophene': 2,
#  'chloroxylenol': 2,
#  'chlorphenesin': 2,
#  'cholecalciferol': 2,
#  'cholesterol': 3,
#  'choline': 3,
#  'chondroitin sulfate': 3,
#  'Chondrus crispus (algae) extract': 3,
#  'chromium hydroxide green': 2,
#  'chromium oxide green': 2,
#  'Chrysanthellum indicum (golden chamomile) extract': 3,
#  'chrysanthemum extract': 3,
#  'Chrysanthemum parthenium extract': 1,
#  'Cichorium intybus': 2,
#  'Cimicifuga racemosa root extract': 1,
#  'Cinnamomum': 0,
#  'Cinnamomum camphora': 0,
#  'cinnamon': 0,
#  'cinnamyl alcohol': 0,
#  'citrate buffer': 2,
#  'citric acid': 2,
#  'citronellol': 0,
#  'Citrullus colocynthis': 0,
#  'Citrus amara': 0,
#  'Citrus aurantifolia': 0,
#  'Citrus aurantium': 0,
#  'Citrus aurantium extract': 0,
#  'Citrus medica limonium': 0,
#  'Citrus unshiu': 1,
#  'Citrus unshiu peel extract': 1,
#  'clary oil': 0,
#  'clary sage': 2,
#  'clay': 2,
#  'Clitoria ternatea (butterfly pea) flower extract': 3,
#  'clove leaf': 0,
#  'clove oil': 0,
#  'clover blossom': 0,
#  'clover leaf oil': 0,
#  'cocamide DEA and MEA': 1,
#  'cocamidopropyl betaine': 2,
#  'cocamidopropyl dimethylamine': 2,
#  'cocamidopropyl hydroxysultaine': 2,
#  'Coccinia indica (ivy gourd) fruit extract': 3,
#  'cocoa butter': 3,
#  'cocoa extract': 3,
#  'coco-caprylate': 2,
#  'coco caprylate': 2,
#  'coco-glucoside': 2,
#  'cocoglycerides': 2,
#  'coconut': 2,
#  'coconut acid': 2,
#  'coconut oil': 3,
#  'cocos nucifera (coconut) fruit extract': 3,
#  'cocoyl proline': 2,
#  'Cocus nucifera': 3,
#  'Codium tomentosum extract': 2,
#  'coenzyme Q10': 3,
#  'Coffea arabica (coffee) fruit extract': 3,
#  'Coffea arabica (coffee) seed oil': 3,
#  'Coffea arabica seed extract': 3,
#  'Cola acuminata seed extract': 1,
#  'Coleus barbatus': 0,
#  'collagen amino acids': 2,
#  'colloidal oatmeal': 3,
#  'colloidal silver': 0,
#  'comfrey extract': 0,
#  'Commiphora myrrha extract': 0,
#  'coneflower': 2,
#  'Copaifera officinalis': 0,
#  'Copernicia cerifera wax': 2,
#  'copper gluconate': 2,
#  'copper lysinate': 2,
#  'prolinate': 2,
#  'copper PCA': 2,
#  'copper peptides': 2,
#  'copper sulfate': 1,
#  'Corallina officinalis extract': 2,
#  'coriander': 2,
#  'cornflower': 3,
#  'cornmint': 0,
#  'corn oil': 3,
#  'cornstarch': 2,
#  'Cornus extract': 2,
#  'Corylus americana': 2,
#  'Corylus avellana': 2,
#  'coumarin': 2,
#  'cranberry seed extract': 3,
#  'cranberry seed oil': 3,
#  'Crataegus monogina extract': 1,
#  'creatine': 3,
#  'cucumber extract': 2,
#  'Cucumis melo (melon) fruit extract': 3,
#  'Cucumis sativus extract': 2,
#  'Cucurbita pepo seed extract': 3,
#  'Cucurbitea peponis': 3,
#  'Curcuma longa root': 3,
#  'curcumin': 3,
#  'Cyamopsis tetragonoloba': 2,
#  'cyclamen aldehyde': 0,
#  'cyclohexasiloxane': 2,
#  'cyclomethicone': 2,
#  'cyclopentasiloxane': 2,
#  'cyclotetrasiloxane': 2,
#  'Cymbopogon citrates': 0,
#  'Cymbopogon martini': 0,
#  'cysteine': 2,
#  'cystine': 2,
#  'D&C': 2,
#  'D&C colors': 2,
#  'daisy flower extract': 0,
#  'd-alpha-tocopherol': 3,
#  'Daucus carota': 0,
#  'DEA oleth-10 phosphate': 2,
#  'decarboxy carnosine HCL': 3,
#  'decylene glycol': 2,
#  'decyl glucoside': 2,
#  'decyl oleate': 2,
#  'dehydroacetic acid': 2,
#  'dehydroepiandrosterone': 1,
#  'deionized': 2,
#  'demineralized water': 2,
#  'denatured alcohol': 0,
#  'deoxyribonucleic acid': 1,
#  'detergent cleansing agent': 2,
#  'deuterium oxide': 1,
#  'dextran': 2,
#  'dextrin': 2,
#  'DHA': 2,
#  'diatomaceous earth': 1,
#  'diazolidinyl urea': 1,
#  'dibutyl phthalate': 1,
#  'dicaprylyl carbonate': 2,
#  'dicetyl phosphate': 2,
#  'diethylhexyl carbonate': 2,
#  'diethylhexyl malate': 2,
#  'diethylhexyl syringylidenemalonate': 2,
#  'diheptyl succinate': 3,
#  'dihydrocholeth-30': 2,
#  'dihydroxyacetone': 2,
#  'diisopropyl adipate': 2,
#  'diisopropyl dimer dilinoleate': 2,
#  'diisostearoyl trimethylolpropane siloxy silicate': 2,
#  'diisostearyl dimer dilinoleate': 2,
#  'diisostearyl malate': 2,
#  'diisostearyl polyglyceryl-3 dimer dilinoleate': 2,
#  'dimer dilinoleyl dimer dilinoleate': 2,
#  'dimethicone': 2,
#  'PEG-10': 2,
#  '15 crosspolymer': 2,
#  'vinyl dimethicone crosspolymer': 2,
#  'dimethicone copolyol': 2,
#  'dimethicone crosspolymer': 2,
#  'dimethiconol': 2,
#  'dimethyl capramide': 2,
#  'dimethyl ether': 0,
#  'dimethyl isosorbide': 2,
#  'dimethyl MEA': 1,
#  'Dioscorea villosa extract': 1,
#  'dipentaerythrityl hexacaprylate': 2,
#  'hexacaprate': 2,
#  'dipeptide-2': 3,
#  'dipotassium glycyrrhizate': 3,
#  'dipotassium glycyrrhizinate': 3,
#  'dipotassium phosphate': 2,
#  'di-PPG-3 myristyl ether adipate': 2,
#  'dipropylene glycol': 2,
#  'disodium cocoamphodiacetate': 2,
#  'disodium cocoyl glutamate': 2,
#  'disodium diglyceryl phosphate': 2,
#  'disodium EDTA': 2,
#  'disodium glyceryl phosphate': 2,
#  'disodium lauraminopropionate': 2,
#  'disodium lauriminodipropionate tocopheryl phosphates': 2,
#  'disodium rutinyl disulfate': 2,
#  'disteardimonium hectorite': 2,
#  'DMAE': 1,
#  'DMDM hydantoin': 1,
#  'docosahexaenoic acid': 2,
#  'dog rose': 2,
#  'dogwood': 2,
#  'Dromiceius oil': 2,
#  'dulse': 2,
#  'Dunaliella salina extract': 3,
#  'durian': 2,
#  'Durvillaea antarctica extract': 2,
#  'ecamsule': 3,
#  'Echium plantagineum seed oil': 3,
#  'Eclipta prostrata extract': 3,
#  'ectoin': 3,
#  'EDTA': 2,
#  'egg yolk': 3,
#  'eicosapentaenoic acid': 3,
#  'Elaeis guineensis': 3,
#  'elderberry': 3,
#  'elecampane': 0,
#  'ellagic acid': 3,
#  'Emblica officinalis (gooseberry) fruit extract': 3,
#  'emollient': 2,
#  'emulsifier': 2,
#  'emu oil': 2,
#  'English ivy extract': 0,
#  'Enteromorpha compressa extract': 2,
#  'environmental damage': 0,
#  'enzymes': 2,
#  'epigallocatechin gallate': 3,
#  'Epilobium angustifolium extract': 3,
#  'Epilobium fleischeri (willowherb) extract': 3,
#  'Equisetum arvense': 0,
#  'ergocalciferol': 2,
#  'ergothioneine': 3,
#  'Eriobotrya japonica': 3,
#  'erythrulose': 2,
#  'esculin': 0,
#  'essential oil': 0,
#  'ester': 2,
#  'Ester-C': 3,
#  'ethanol': 0,
#  'ethoxydiglycol': 2,
#  'ethyl alcohol': 0,
#  'ethyl hexanediol': 1,
#  'ethylhexylglycerin': 2,
#  'ethylhexyl methoxycinnamate': 3,
#  'ethylhexyl olivate': 3,
#  'ethylhexyl palmitate': 2,
#  'ethylhexyl stearate': 2,
#  'ethyl macadamiate': 2,
#  'ethylparaben': 2,
#  'ethyl vanillin': 2,
#  'eucalyptus extract': 0,
#  'eucalyptus oil': 0,
#  'Eugenia aromatica': 0,
#  'Eugenia caryophyllus': 0,
#  'eugenol': 0,
#  'Euphorbia cerifera wax': 2,
#  'Euphrasia officinalis': 1,
#  'Euterpe oleracea (acai) sterols': 3,
#  'Euterpe oleracea fruit extract': 3,
#  'evening primrose oil': 3,
#  'Evodia rutaecarpa extract': 2,
#  'Ext. D&C': 2,
#  'eyebright': 1,
#  'faex': 2,
#  'farnesol': 1,
#  'farnesyl acetate': 1,
#  'fatty acid': 3,
#  'fatty alcohol': 2,
#  'FD&C': 2,
#  'FD&C colors': 2,
#  'fennel oil': 0,
#  'fennel seed extract': 0,
#  'ferric ammonium ferrocyanide': 2,
#  'ferric ferrocyanide': 2,
#  'Ferula galbaniflua': 0,
#  'ferulic acid': 3,
#  'feverfew extract': 2,
#  'fibronectin': 2,
#  'Ficus carica (fig) fruit extract': 3,
#  'fig': 3,
#  'Filipendula glaberrima': 3,
#  'Filipendula rubra': 3,
#  'film-forming agent': 2,
#  'fireweed extract': 3,
#  'fir needle oil': 0,
#  'fish cartilage extract': 1,
#  'flavonoid': 3,
#  'flax': 3,
#  'flaxseed oil': 3,
#  'floralozone': 0,
#  'Foeniculum vulgare extract': 0,
#  'formaldehyde-releasing preservative': 1,
#  'Fragaria vesca (strawberry) fruit extract': 3,
#  'fragrance': 0,
#  'frankincense extract': 0,
#  'fructose': 2,
#  'fruit acid': 1,
#  'Fucus vesiculosus extract': 3,
#  'Fu ling': 3,
#  "fuller's earth": 2,
#  'galactoarabinan': 2,
#  'galbanum': 0,
#  'gamma linolenic acid (GLA)': 3,
#  'Ganoderma lucidum (mushroom) extract': 3,
#  'Garcinia mangostana (mangosteen) peel extract': 3,
#  'Gardenia florida extract': 0,
#  'gelatin': 2,
#  'gellan gum': 2,
#  'Gellidiela acerosa extract': 2,
#  'genistein': 3,
#  'Gentiana lutea (Gentian) root extract': 3,
#  'geraniol': 1,
#  'geranium extract': 3,
#  'geranium oil': 0,
#  'Geranium pretense': 0,
#  'Germaben II': 2,
#  'ginger extract': 2,
#  'ginger oil': 0,
#  'Ginkgo biloba leaf extract': 3,
#  'ginseng': 3,
#  'GLA': 3,
#  'glabridin': 3,
#  'glucomannan': 3,
#  'gluconolactone': 3,
#  'glucosamine HCL': 3,
#  'glucose': 2,
#  'glucose oxidase': 2,
#  'glucosylceramides': 3,
#  'glucosyl hesperidin': 3,
#  'glutamic acid': 2,
#  'glutamine': 3,
#  'glutathione': 3,
#  'gluten ingredients': 2,
#  'glycereth-26': 2,
#  'glycereth-26 phosphate': 2,
#  'glycereth-6 laurate': 2,
#  'glycerin': 3,
#  'glycerine': 3,
#  'glycerol': 3,
#  'glycerol monostearate': 2,
#  'glycerol triacetate': 2,
#  'glycerol trioleate': 2,
#  'glyceryl ascorbate': 3,
#  'glyceryl behanate': 2,
#  'glyceryl behenate': 2,
#  'eicosadioate': 2,
#  'glyceryl cocoate': 2,
#  'glyceryl dibehanate': 2,
#  'glyceryl dipalmitate': 2,
#  'glyceryl distearate': 2,
#  'glyceryl ester': 2,
#  'glyceryl isopalmitate': 2,
#  'glyceryl isostearate': 2,
#  'glyceryl myristate': 2,
#  'glyceryl oleate': 2,
#  'glyceryl palmitate': 2,
#  'glyceryl polymethacrylate': 2,
#  'glyceryl rosinate': 2,
#  'glyceryl stearate': 2,
#  'glyceryl stearate citrate': 2,
#  'glyceryl stearate SE': 2,
#  'glycine': 2,
#  'Glycine soja oil': 3,
#  'Glycine soja seed extract': 3,
#  'Glycine soja sterols': 3,
#  'glycogen': 2,
#  'glycolic acid': 3,
#  'glycolipid': 3,
#  'glycol stearate': 2,
#  'glycoproteins': 3,
#  'glycosaminoglycans': 3,
#  'glycosphingolipid': 3,
#  'glycyrrhetic acid': 3,
#  'glycyrrhetinic acid': 3,
#  'Glycyrrhiza glabra': 3,
#  'Glycyrrhiza uralensis root extract': 3,
#  'goji fruit extract': 3,
#  'gold': 0,
#  'Gossypium herbacuem seed oil': 2,
#  'gotu kola': 3,
#  'grapefruit oil': 0,
#  'grapefruit peel extract': 0,
#  'grapefruit seed extract': 0,
#  'grape seed extract': 3,
#  'grape seed oil': 3,
#  'green tea': 3,
#  'gromwell': 3,
#  'guarana': 0,
#  'guar gum': 2,
#  'guar hydroxypropyltrimonium chloride': 2,
#  'guava': 3,
#  'gums': 2,
#  'Haematococcus pluvialis extract': 3,
#  'Hamamelis virginiana': 0,
#  'hamamelitannin': 0,
#  'Haslea ostrearia extract': 2,
#  'hayflower extract': 0,
#  'hazelnut oil': 2,
#  'hectorite': 2,
#  'Hedera helix': 0,
#  'hedione': 0,
#  'Helianthus annuus (sunflower) seed oil': 3,
#  'Helianthus oil': 3,
#  'hemp seed oil': 3,
#  'hesperidin': 3,
#  'hesperidin methyl chalcone': 2,
#  'hexanoyl dipeptide-3 norleucine acetate': 3,
#  'hexyl cinnamal': 0,
#  'hexyldecanol': 2,
#  'hexylene glycol': 2,
#  'hexyl laurate': 2,
#  'hexylresorcinol': 1,
#  'hibiscus': 2,
#  'Himanthalia elongate extract': 2,
#  'Hippophae rhamnoides': 3,
#  'Hippophae Rhamnoides (seaberry) fruit extract': 3,
#  'histidine': 2,
#  'hoelen': 3,
#  'homosalate': 3,
#  'honey': 3,
#  'honey extract': 3,
#  'honeysuckle flower extract': 3,
#  'hops': 1,
#  'Hordeum vulgare extract': 1,
#  'horse chestnut extract': 2,
#  'horse elder': 0,
#  'horseradish': 0,
#  'horsetail extract': 1,
#  'Hortonia floribunda leaf extract': 1,
#  'Huang qi': 2,
#  'Humulus lupulus extract': 1,
#  'hyaluronic acid': 3,
#  'Hydnocarpus anthelmintica': 0,
#  'Hydrastis canadenis': 0,
#  'hydrocotyl extract': 3,
#  'hydrogenated coco-glyceride': 2,
#  'hydrogenated didecene': 2,
#  'hydrogenated lecithin': 3,
#  'hydrogenated olive oil': 3,
#  'hydrogenated palm glycerides': 2,
#  'hydrogenated polydecene': 2,
#  'hydrogenated polyisobutene': 2,
#  'hydrogenated soybean oil': 3,
#  'hydrogenated starch hydrolysate': 2,
#  'hydrogenated vegetable glycerides citrate': 2,
#  'hydrogen peroxide': 0,
#  'hydrolyzed acacia macrostachya seed extract': 2,
#  'hydrolyzed algae extract': 3,
#  'hydrolyzed corn starch': 2,
#  'hydrolyzed eruca sativa (arugula) leaf': 3,
#  'hydrolyzed glycosaminoglycans': 3,
#  'hydrolyzed jojoba esters': 3,
#  'hydrolyzed jojoba protein': 2,
#  'hydrolyzed pumpkin seedcake': 3,
#  'hydrolyzed rhodophycea (red algae) extract': 3,
#  'hydrolyzed silk': 2,
#  'hydrolyzed soy protein': 3,
#  'hydrolyzed vegetable protein': 2,
#  'hydrolyzed wheat protein': 2,
#  'hydroquinone': 3,
#  'hydroxyacetophenone': 2,
#  'hydroxyethyl acrylate': 2,
#  'sodium acryloyl dimethyl taurate copolymer': 2,
#  'hydroxyethylcellulose': 2,
#  'hydroxyethylpiperazine ethane sulfonic acid': 1,
#  'hydroxyethyl urea': 2,
#  'hydroxylated lecithin': 3,
#  'hydroxypropyl cyclodextrin': 2,
#  'hydroxypropyl guar': 2,
#  'hydroxypropyl starch phosphate': 2,
#  'Hypericum extract': 2,
#  'hyssop': 3,
#  'idebenone': 3,
#  'Ilex paraguariensis': 3,
#  'Illicium vernum': 0,
#  'illite': 2,
#  'imidazolidinyl urea': 1,
#  'inactive ingredient': 2,
#  'inositol': 3,
#  'Inula helenium': 0,
#  'iodopropynyl butylcarbamate': 2,
#  'Iris florentina extract': 0,
#  'Irish moss extract': 2,
#  'iron oxides': 2,
#  'iron powder': 1,
#  'isoamyl cocoate': 2,
#  'isoamyl laurate': 2,
#  'isobutyl acetate': 2,
#  'isobutylparaben': 2,
#  'isocetyl salicylate': 1,
#  'isododecane': 2,
#  'isoflavone': 3,
#  'isohexadecane': 2,
#  'isoleucine': 2,
#  'isononyl isononanoate': 2,
#  'isoparaffin': 2,
#  'isopropyl alcohol': 0,
#  'isopropyl isostearate': 2,
#  'isopropyl lanolate': 2,
#  'isopropyl myristate': 2,
#  'isopropyl palmitate': 2,
#  'isopropyl titanium triisostearate': 2,
#  'isopropyl titanium triisostearte': 2,
#  'triethoxycaprylylsilane crosspolymer': 2,
#  'isostearamide DEA': 2,
#  'isostearic acid': 2,
#  'ivy extract': 0,
#  'Japan wax': 2,
#  'jasmine oil': 0,
#  'Jasminium grandiflorum': 0,
#  'jojoba butter': 3,
#  'jojoba esters': 3,
#  'jojoba oil': 3,
#  'jojoba wax': 3,
#  'jonquil extract': 0,
#  'Ju hua': 2,
#  'jujube fruit extract': 2,
#  'juniper berry': 0,
#  'Juniperus communis': 0,
#  'kaolin': 2,
#  'Kathon CG': 0,
#  'kava-kava extract': 0,
#  'kawa extract': 0,
#  'kelp extract': 2,
#  'Kigelia africana extract': 1,
#  'kiwi fruit extract': 3,
#  'kojic acid': 2,
#  'kojic dipalmitate': 2,
#  'kola nut': 1,
#  'kudzu root': 3,
#  'kukui nut oil': 3,
#  'lactic acid': 3,
#  'Lactobacillus': 3,
#  'rye flour ferment': 3,
#  'Lactobacillus ferment': 3,
#  'lactobionate': 2,
#  'lactobionic acid': 3,
#  'lactoperoxidase': 3,
#  "lady's mantle extract": 0,
#  "lady's thistle (milk thistle) extract": 3,
#  'Lagerstroemia indica extract': 1,
#  'Laminaria digitata': 2,
#  'Laminaria longicruris': 2,
#  'Laminaria ochroleuca extract': 2,
#  'Laminaria sacharrina': 2,
#  'Lamium album flower extract': 3,
#  'lanolin': 2,
#  'lanolin alcohol': 2,
#  'lappa extract': 2,
#  'Larrea divaricata extract': 2,
#  'Larrea tridentata': 2,
#  'L-ascorbic acid': 3,
#  'lauramphocarboxyglycinate': 2,
#  'laurdimonium hydroxypropyl hydrolyzed soy protein': 2,
#  'laurdimonium hydroxypropyl hydrolyzed wheat protein': 2,
#  'laureth-23': 2,
#  'laureth-4': 2,
#  'laureth-7': 2,
#  'laureths': 2,
#  'lauric acid': 3,
#  'lauroyl lysine': 2,
#  'Laurus nobilis': 0,
#  'lauryl alcohol': 2,
#  'lauryl glucoside': 2,
#  'lauryl lactate': 2,
#  'lauryl laurate': 3,
#  'lauryl PEG-9 polydimethylsiloxyethyl dimethicone': 2,
#  'lavandin oil': 0,
#  'Lavandula angustifolia': 0,
#  'Lavandula officinalis': 0,
#  'lavender extract and oil': 0,
#  'L-cysteine': 2,
#  'lecithin': 3,
#  'lemon': 0,
#  'lemon balm': 0,
#  'lemongrass extract': 0,
#  'lemongrass oil': 0,
#  'lemon juice': 0,
#  'lemon oil': 0,
#  'lentil fruit extract': 2,
#  'Lentinus edodes extract': 1,
#  'Leontopodium alpinum (edelweiss) extract': 3,
#  'Leptospermum scoparium oil': 2,
#  'leucine': 2,
#  'leuconostoc': 2,
#  'radish root ferment filtrate': 2,
#  'Levisticum officinale root extract': 0,
#  'licorice extract': 3,
#  'licorice root': 3,
#  'Lilium candidum bulb extract': 1,
#  'lime oil and extract': 0,
#  'Limnanthes alba': 2,
#  'Limnanthes alba (meadowfoam) seed oil': 3,
#  'Limnanthes alba seed oil': 2,
#  'limonene': 0,
#  'linalool': 0,
#  'linden flower extract': 3,
#  'linoleic acid': 3,
#  'linolenic acid': 3,
#  'Linum usitatissimum (linseed) seed oil': 3,
#  'Linum usitatissimum extract': 3,
#  'lipid': 3,
#  'liposomes': 2,
#  'lithium magnesium sodium silicate': 2,
#  'Lithospermum erythrorhizon': 3,
#  'Litsea cubeba': 0,
#  'locust bean': 2,
#  ...}

# %%
# Ingredient_category_dict: key is ingredient name, value is the list of category
ingredient_category_dict = {name: row['category'] for (idx, row) in ingredient_df.iterrows() for name in row['name'].split('/')}
ingredient_category_dict
# Out:
# {'1, 2-Hexanediol': ['Preservatives'],
#  '10-Hydroxydecanoic Acid': ['Emollients'],
#  '4-T-butylcyclohexanol': ['Emollients', 'Skin-Soothing'],
#  'Acacia farnesiana extract': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'acacia senegal gum': ['Texture Enhancer', 'Plant Extracts', 'Skin-Soothing'],
#  'acai': ['Antioxidants', 'Plant Extracts'],
#  'acetic acid': ['Sensitizing'],
#  'acetone': ['Sensitizing'],
#  'acetylated castor oil': ['Texture Enhancer', 'Emollients'],
#  'acetylated hydrogenated cottonseed glyceride': ['Texture Enhancer',
#   'Emollients'],
#  'acetylated lanolin': ['Emollients'],
#  'acetylated lanolin alcohol': ['Emollients'],
#  'acetylated palm kernel glycerides': ['Texture Enhancer', 'Emollients'],
#  'acetyl carnitine HCL': ['Antioxidants'],
#  'acetyl glucosamine': ['Skin-Replenishing',
#   'Antioxidants',
#   'Skin-Soothing',
#   'Hydration'],
#  'acetyl glyceryl ricinoleate': ['Texture Enhancer', 'Emollients'],
#  'acetyl hexapeptide-1': ['Skin-Restoring'],
#  'acetyl hexapeptide-37': ['Skin-Restoring'],
#  'acetyl hexapeptide-8': ['Skin-Restoring'],
#  'acetyl octapeptide-3': ['Skin-Restoring'],
#  'acetyl tetrapeptide-11': ['Skin-Restoring'],
#  'acetyl tetrapeptide-5': ['Skin-Restoring'],
#  'acetyl tetrapeptide-9': ['Skin-Restoring'],
#  'acetyl tributyl citrate': ['Film-Forming/Holding Agents'],
#  'acetyl tyrosine': ['Hydration'],
#  'Achillea millefolium': ['Skin-Soothing', 'Plant Extracts'],
#  'acid': ['Miscellaneous'],
#  'acne soap': ['Cleansing Agents'],
#  'acrylate': ['Texture Enhancer'],
#  'acrylates': ['Texture Enhancer'],
#  'C10-30 alkyl acrylate crosspolymer': ['Texture Enhancer'],
#  'dimethicone copolymer': ['Silicones', 'Texture Enhancer'],
#  'steareth-20 methacrylate copolymer': ['Texture Enhancer'],
#  'acrylates copolymer': ['Film-Forming/Holding Agents'],
#  'Actaea racemosa': ['Plant Extracts'],
#  'Actinidia chinensis (kiwi fruit) extract': ['Antioxidants',
#   'Plant Extracts'],
#  'adenosine': ['Skin-Soothing', 'Skin-Restoring'],
#  'adenosine phosphate': ['Skin-Restoring', 'Skin-Soothing'],
#  'adenosine triphosphate': ['Skin-Soothing', 'Skin-Restoring'],
#  'adipic acid': ['Texture Enhancer'],
#  'neopentyl glycol': ['Texture Enhancer'],
#  'trimellitic anhydride copolymer': ['Texture Enhancer'],
#  'advanced glycation endproduct (AGE)': ['Miscellaneous'],
#  'Aerocarpus santalinus': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Aesculus hippocastanum': ['Skin-Soothing', 'Plant Extracts'],
#  'agar': ['Antioxidants', 'Plant Extracts', 'Emollients', 'Texture Enhancer'],
#  'Agastache mexicana (hyssop) flower': ['Antioxidants', 'Plant Extracts'],
#  'leaf': ['Antioxidants', 'Plant Extracts'],
#  'stem extract': ['Uncategorized'],
#  'AGE': ['Miscellaneous'],
#  'Agrimonia eupatoria leaf extract': ['Antioxidants', 'Plant Extracts'],
#  'AHA': ['Exfoliant'],
#  'Ahnfeltia concinna extract': ['Antioxidants',
#   'Texture Enhancer',
#   'Plant Extracts',
#   'Emollients'],
#  'ahnfeltia extract': ['Antioxidants',
#   'Emollients',
#   'Texture Enhancer',
#   'Plant Extracts'],
#  'Ahnfeltiopsis concinna extract': ['Emollients',
#   'Antioxidants',
#   'Plant Extracts',
#   'Texture Enhancer'],
#  'alanine': ['Antioxidants'],
#  'Alaria esculenta': ['Antioxidants',
#   'Emollients',
#   'Plant Extracts',
#   'Texture Enhancer'],
#  'albumin': ['Texture Enhancer'],
#  'alcloxa': ['Uncategorized'],
#  'alcohol': ['Emollients', 'Cleansing Agents'],
#  'Aleurites moluccana seed oil': ['Plant Extracts', 'Antioxidants'],
#  'alfalfa extract': ['Antioxidants', 'Plant Extracts'],
#  'algae': ['Antioxidants', 'Emollients', 'Texture Enhancer', 'Plant Extracts'],
#  'algae extract': ['Antioxidants',
#   'Emollients',
#   'Texture Enhancer',
#   'Plant Extracts'],
#  'algin': ['Antioxidants', 'Texture Enhancer', 'Emollients', 'Plant Extracts'],
#  'aliphatic hydrocarbon': ['Uncategorized'],
#  'alkaline': ['Uncategorized'],
#  'alkyloamides': ['Texture Enhancer'],
#  'allantoin': ['Skin-Soothing'],
#  'allyl methacrylates crosspolymer': ['Texture Enhancer'],
#  'almond': ['Antioxidants', 'Skin-Replenishing', 'Hydration'],
#  'borage': ['Antioxidants', 'Skin-Replenishing', 'Hydration'],
#  'linseed': ['Antioxidants', 'Skin-Replenishing', 'Hydration'],
#  'olive acids glycerides': ['Antioxidants', 'Skin-Replenishing', 'Hydration'],
#  'almond oil': ['Emollients', 'Skin-Replenishing'],
#  'Aloe barbadensis': ['Skin-Soothing', 'Plant Extracts'],
#  'aloe barbadensis leaf juice extract': ['Skin-Soothing', 'Plant Extracts'],
#  'aloe barbadensis leaf juice powder': ['Plant Extracts'],
#  'aloe extract': ['Skin-Soothing', 'Plant Extracts'],
#  'aloe juice': ['Skin-Soothing', 'Plant Extracts'],
#  'aloe vera': ['Skin-Soothing', 'Plant Extracts'],
#  'alpha bisabolol': ['Skin-Soothing', 'Plant Extracts'],
#  'alpha glucan oligosaccharide': ['Emollients'],
#  'alpha hydroxy acid': ['Exfoliant'],
#  'alpha isomethyl ionone': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'alpha lipoic acid': ['Antioxidants'],
#  'alpha-tocopherol': ['Antioxidants', 'Vitamins'],
#  'Alteromonas ferment extract': ['Plant Extracts'],
#  'Althaea rosea': ['Skin-Soothing', 'Texture Enhancer', 'Plant Extracts'],
#  'Althea officinalis': ['Skin-Soothing', 'Plant Extracts'],
#  'alumina': ['Texture Enhancer', 'Scrub Agents', 'Absorbent'],
#  'aluminum': ['Uncategorized'],
#  'Aluminum hydroxide': ['Texture Enhancer', 'Absorbent'],
#  'aluminum magnesium silicate': ['Absorbent'],
#  'aluminum powder': ['Coloring Agents/Pigments'],
#  'aluminum silicate': ['Absorbent', 'Scrub Agents'],
#  'aluminum starch octenylsuccinate': ['Texture Enhancer', 'Absorbent'],
#  'aluminum stearate': ['Texture Enhancer'],
#  'aluminum sulfate': ['Absorbent', 'Antioxidants'],
#  'amino acids': ['Antioxidants', 'Skin-Replenishing'],
#  'aminobutyric acid': ['Skin-Soothing'],
#  'aminomethyl propanediol': ['Uncategorized'],
#  'aminomethyl propanol': ['Uncategorized', 'Miscellaneous'],
#  'ammonium acryloyldimethyltaurate': ['Texture Enhancer'],
#  'VP copolymer': ['Texture Enhancer'],
#  'ammonium chloride': ['Absorbent'],
#  'ammonium glycolate': ['Exfoliant'],
#  'ammonium hydroxide': ['Uncategorized'],
#  'ammonium laureth sulfate': ['Cleansing Agents'],
#  'ammonium lauryl sulfate': ['Cleansing Agents'],
#  'amodimethicone': ['Silicones', 'Emollients', 'Texture Enhancer'],
#  'amygdalic acid': ['Exfoliant', 'Antioxidants'],
#  'amyl cinnamate': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'amyl salicylate': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'amyris oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Anacyclus pyrethrum': ['Plant Extracts'],
#  'Anacystis nidulans extract': ['Antioxidants',
#   'Plant Extracts',
#   'Texture Enhancer',
#   'Emollients'],
#  'Ananas sativus fruit extract': ['Plant Extracts', 'Exfoliant'],
#  'Anastatica hierochuntica extract': ['Antioxidants', 'Plant Extracts'],
#  'andiroba oil': ['Skin-Soothing', 'Plant Extracts'],
#  'Anethum graveolens': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Angelica archangelica root oil': ['Antioxidants',
#   'Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Angelica polymorpha sinensis root extract': ['Antioxidants',
#   'Plant Extracts'],
#  'anhydroxylitol': ['Hydration'],
#  'anisaldehyde': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'anise': ['Antioxidants', 'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'annato extract': ['Plant Extracts'],
#  'Anthemis nobilis flower extract': ['Skin-Soothing', 'Antioxidants'],
#  'anthocyanin': ['Antioxidants', 'Plant Extracts'],
#  'antioxidant': ['Antioxidants'],
#  'apple fruit extract': ['Antioxidants', 'Plant Extracts'],
#  'apricot kernel': ['Scrub Agents'],
#  'apricot kernel oil': ['Plant Extracts', 'Emollients'],
#  'arachidic acid': ['Texture Enhancer', 'Emollients'],
#  'arachidyl alcohol': ['Texture Enhancer', 'Emollients'],
#  'arachidyl glucoside': ['Cleansing Agents'],
#  'arachidyl propionate': ['Texture Enhancer', 'Emollients'],
#  'Arachis hypogaea extract': ['Skin-Soothing', 'Emollients', 'Plant Extracts'],
#  'arbutin': ['Plant Extracts'],
#  'Arctium lappa': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'Arctium majus': ['Plant Extracts', 'Antioxidants', 'Skin-Soothing'],
#  'Arctostaphylos uva ursi leaf': ['Antioxidants', 'Plant Extracts'],
#  'Argania spinosa': ['Antioxidants', 'Plant Extracts'],
#  'Argania spinosa kernel oil': ['Emollients',
#   'Antioxidants',
#   'Plant Extracts'],
#  'argan oil': ['Antioxidants', 'Emollients', 'Plant Extracts'],
#  'arginine': ['Antioxidants'],
#  'Argireline': ['Skin-Restoring'],
#  'Aristotelia chilensis (maqui)': ['Antioxidants', 'Plant Extracts'],
#  'arnica extract': ['Plant Extracts'],
#  'aroma': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'flavor': ['Miscellaneous'],
#  'arrowroot': ['Texture Enhancer'],
#  'artemia extract': ['Antioxidants',
#   'Plant Extracts',
#   'Emollients',
#   'Texture Enhancer'],
#  'Artemisia absinthium extract': ['Plant Extracts'],
#  'Artemisia vulgaris': ['Plant Extracts'],
#  'Ascophyllum nodosum': ['Antioxidants',
#   'Emollients',
#   'Plant Extracts',
#   'Texture Enhancer'],
#  'ascorbic acid': ['Antioxidants', 'Vitamins'],
#  'ascorbyl glucosamine': ['Antioxidants', 'Vitamins'],
#  'ascorbyl glucoside': ['Antioxidants', 'Vitamins'],
#  'ascorbyl methylsilanol pectinate': ['Antioxidants',
#   'Texture Enhancer',
#   'Vitamins'],
#  'ascorbyl palmitate': ['Antioxidants', 'Vitamins'],
#  'asparagine': ['Antioxidants'],
#  'Asparagopsis armata extract': ['Antioxidants',
#   'Emollients',
#   'Plant Extracts',
#   'Texture Enhancer'],
#  'aspartic acid': ['Antioxidants', 'Skin-Replenishing'],
#  'astaxanthin': ['Antioxidants'],
#  'astaxanthin extract': ['Antioxidants'],
#  'Astragalus membranaceus': ['Antioxidants', 'Plant Extracts'],
#  'Astragalus sinicus': ['Antioxidants', 'Plant Extracts'],
#  'Astrocaryum murumuru seed butter': ['Emollients', 'Plant Extracts'],
#  'ATP': ['Skin-Soothing', 'Skin-Restoring'],
#  'atractylodes macrocephala root powder': ['Antioxidants',
#   'Skin-Soothing',
#   'Plant Extracts'],
#  'Atractyloydes lancea root extract': ['Plant Extracts'],
#  'Avena sativa': ['Skin-Soothing', 'Plant Extracts'],
#  'avobenzone': ['Sunscreen Actives'],
#  'avocado oil': ['Antioxidants', 'Emollients'],
#  'awapuhi': ['Plant Extracts'],
#  'Azadirachta indica': ['Plant Extracts', 'Antioxidants'],
#  'azelaic acid': ['Skin-Soothing', 'Antioxidants', 'Exfoliant'],
#  'azelaoyl bis-dipeptide-10': ['Skin-Restoring'],
#  'Azelex': ['Uncategorized'],
#  'azuki beans': ['Scrub Agents'],
#  'azulene': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'babassu oil': ['Plant Extracts', 'Emollients', 'Antioxidants'],
#  'bakuchiol': ['Antioxidants', 'Plant Extracts'],
#  'balm mint extract': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'balsam peru': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Bambusa vulgaris (bamboo) leaf': ['Uncategorized'],
#  'banana extract': ['Antioxidants', 'Plant Extracts'],
#  'barberry': ['Skin-Soothing'],
#  'barium sulfate': ['Coloring Agents/Pigments'],
#  'barley extract': ['Plant Extracts'],
#  'batyl alcohol': ['Emollients'],
#  'bay leaf oil': ['Antioxidants',
#   'Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'bearberry extract': ['Antioxidants'],
#  'bee pollen': ['Uncategorized'],
#  'beeswax': ['Texture Enhancer', 'Emollients'],
#  'beet root extract': ['Antioxidants',
#   'Coloring Agents/Pigments',
#   'Plant Extracts'],
#  'beheneth-5': ['Thickeners/Emulsifiers'],
#  'behenic acid': ['Texture Enhancer', 'Cleansing Agents'],
#  'behentrimonium chloride': ['Texture Enhancer', 'Emollients'],
#  'behenyl alcohol': ['Texture Enhancer'],
#  'behenyl behenate': ['Hydration', 'Emollients'],
#  'Bellis perennis': ['Plant Extracts'],
#  'bentonite': ['Absorbent'],
#  'benzalkonium chloride': ['Antioxidants'],
#  'benzephenone-3': ['Sunscreen Actives'],
#  'benzoic acid': ['Preservatives'],
#  'benzoin extract': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'benzophenone': ['Sunscreen Actives'],
#  'benzothonium chloride': ['Preservatives'],
#  'benzoyl peroxide': ['Anti-Acne'],
#  'benzyl alcohol': ['Preservatives'],
#  'benzyl salicylate': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Berberis aristata': ['Plant Extracts', 'Antioxidants'],
#  'bergamot oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Bertholletia excelsa extract': ['Antioxidants', 'Plant Extracts'],
#  'beta-carotene': ['Antioxidants'],
#  'beta-glucan': ['Skin-Soothing', 'Antioxidants'],
#  'beta hydroxy acid': ['Skin-Soothing', 'Antioxidants', 'Exfoliant'],
#  'betaine': ['Hydration'],
#  'betaine salicylate': ['Exfoliant'],
#  'beta-sitosterol': ['Skin-Soothing', 'Plant Extracts', 'Skin-Replenishing'],
#  'Beta vulgaris root extract': ['Antioxidants',
#   'Coloring Agents/Pigments',
#   'Plant Extracts'],
#  'Betula alba': ['Antioxidants', 'Plant Extracts'],
#  'Betula alba (birch) juice': ['Antioxidants', 'Plant Extracts'],
#  'BHA (beta hydroxy acid)': ['Skin-Soothing', 'Exfoliant', 'Anti-Acne'],
#  'BHT': ['Antioxidants'],
#  'bifida ferment lysate': ['Miscellaneous', 'Hydration'],
#  'bilberry extract': ['Plant Extracts'],
#  'bioflavonoid': ['Antioxidants'],
#  'biotin': ['Skin-Softening'],
#  'folic acid': ['Antioxidants', 'Vitamins'],
#  'cyanocobalamin': ['Vitamins'],
#  'niacinamide': ['Skin-Soothing',
#   'Skin-Restoring',
#   'Antioxidants',
#   'Vitamins'],
#  'pantothenic acid': ['Vitamins'],
#  'pyridoxine': ['Skin-Softening'],
#  'riboflavin': ['Vitamins'],
#  'thiamine': ['Skin-Softening'],
#  'yeast polypeptides': ['Skin-Softening'],
#  'birch bark extract': ['Antioxidants', 'Plant Extracts'],
#  'birch leaf extract': ['Antioxidants', 'Plant Extracts'],
#  'bisabolol': ['Skin-Soothing', 'Plant Extracts'],
#  'bis-diglyceryl polyacyladipate': ['Texture Enhancer', 'Emollients'],
#  'bismuth oxychloride': ['Texture Enhancer', 'Absorbent'],
#  'bis-PEG-18 methyl ether dimethyl silane': ['Silicones',
#   'Cleansing Agents',
#   'Texture Enhancer',
#   'Emollients'],
#  'bis-phenylpropyl dimethicone': ['Silicones', 'Texture Enhancer'],
#  'bitter orange flower': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'blackberry': ['Antioxidants', 'Plant Extracts'],
#  'black cohosh': ['Plant Extracts'],
#  'black currant oil': ['Plant Extracts'],
#  'black elderberry': ['Antioxidants', 'Plant Extracts'],
#  'black locust extract': ['Antioxidants', 'Plant Extracts'],
#  'black mulberry': ['Plant Extracts'],
#  'black pepper extract and oil': ['Plant Extracts'],
#  'black raspberry': ['Antioxidants', 'Plant Extracts'],
#  'black tea': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'bladderwrack extract': ['Antioxidants', 'Plant Extracts'],
#  'bloodwort': ['Plant Extracts'],
#  'blue 1': ['Coloring Agents/Pigments'],
#  'blue 1 lake': ['Coloring Agents/Pigments'],
#  'Boerhavia diffusa root extract': ['Skin-Soothing',
#   'Plant Extracts',
#   'Antioxidants'],
#  'bois de rose oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'bois oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'borage seed extract': ['Skin-Soothing', 'Plant Extracts'],
#  'borage seed oil': ['Skin-Soothing',
#   'Emollients',
#   'Antioxidants',
#   'Plant Extracts'],
#  'Borago officinalis extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Emollients',
#   'Plant Extracts'],
#  'Borago officinalis seed oil': ['Skin-Soothing',
#   'Plant Extracts',
#   'Emollients',
#   'Antioxidants'],
#  'borate': ['Preservatives'],
#  'borax': ['Preservatives'],
#  'boric acid': ['Preservatives'],
#  'boron nitride': ['Absorbent'],
#  'Boswellia carterii': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Boswellia serrata extract': ['Skin-Soothing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Plant Extracts'],
#  'botanicals': ['Plant Extracts'],
#  'boysenberry': ['Antioxidants', 'Plant Extracts'],
#  'Brassica campestris': ['Antioxidants', 'Emollients'],
#  'Brazil nut extract': ['Antioxidants', 'Plant Extracts'],
#  'broad spectrum': ['Sunscreen Actives'],
#  'bromelain': ['Plant Extracts', 'Exfoliant'],
#  'bronopol': ['Preservatives'],
#  'bronze powder': ['Coloring Agents/Pigments'],
#  'Buddleja davidii extract': ['Antioxidants', 'Plant Extracts'],
#  'bumetrizole': ['Sunscreen Actives'],
#  'Bupleurum falcatum extract': ['Plant Extracts'],
#  'burdock root': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'butyl acetate': ['Film-Forming Agents', 'Texture Enhancer'],
#  'butylene glycol': ['Texture Enhancer'],
#  'butyl methoxydibenzoylmethane': ['Sunscreen Actives'],
#  'butylparaben': ['Preservatives'],
#  'butylphenyl methylpropional': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Butyrospermum fruit': ['Plant Extracts', 'Emollients'],
#  'Butyrospermum parkii': ['Plant Extracts', 'Emollients', 'Skin-Replenishing'],
#  'Butyrosperum parkii (shea) butter extract': ['Emollients',
#   'Antioxidants',
#   'Plant Extracts'],
#  'Buxus chinensis': ['Plant Extracts', 'Skin-Replenishing', 'Emollients'],
#  'C10-30 cholesterol': ['Emollients'],
#  'lanosterol esters': ['Emollients'],
#  'C11-15 pareth-7': ['Cleansing Agents', 'Emulsifiers'],
#  'C12-15 alkyl benzoate': ['Texture Enhancer', 'Emollients'],
#  'C12-16 pareth-9': ['Cleansing Agents', 'Emulsifiers'],
#  'C12-18 acid triglyceride': ['Texture Enhancer', 'Emollients'],
#  'C13-14 isoparaffin': ['Texture Enhancer'],
#  'C13-15 alkane': ['Skin-Softening', 'Miscellaneous'],
#  'C18-36 acid triglyceride': ['Texture Enhancer', 'Emollients'],
#  'C20-40 pareth-40': ['Cleansing Agents'],
#  'caffeic acid': ['Antioxidants'],
#  'caffeine': ['Antioxidants', 'Plant Extracts'],
#  'cajeputi oil': ['Plant Extracts'],
#  'calamine': ['Sensitizing'],
#  'calcium aluminum borosilicate': ['Thickeners/Emulsifiers',
#   'Texture Enhancer'],
#  'calcium ascorbate': ['Antioxidants', 'Vitamins'],
#  'calcium carbonate': ['Absorbent'],
#  'calcium d-pantetheine-s-sulfonate': ['Vitamins'],
#  'calcium gluconate': ['Skin-Soothing'],
#  'calcium pantothenate': ['Vitamins'],
#  'calcium PCA': ['Hydration', 'Skin-Replenishing'],
#  'calendula extract': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'Calendula officinalis flower extract': ['Antioxidants', 'Plant Extracts'],
#  'Calluna vulgaris flower extract': ['Skin-Soothing', 'Plant Extracts'],
#  'Calophyllum inophyllum seed oil': ['Plant Extracts'],
#  'Camellia japonica flower extract': ['Antioxidants', 'Plant Extracts'],
#  'Camellia oleifera': ['Antioxidants', 'Plant Extracts'],
#  'Camellia sinensis': ['Antioxidants', 'Plant Extracts'],
#  'camphor': ['Plant Extracts'],
#  'cananga extract': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Cananga odorata': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'candelilla': ['Thickeners/Emulsifiers'],
#  'jojoba': ['Thickeners/Emulsifiers'],
#  'rice bran polyglyceryl-3 esters': ['Thickeners/Emulsifiers'],
#  'candelilla wax': ['Plant Extracts', 'Emollients', 'Texture Enhancer'],
#  'cannabidiol': ['Skin-Restoring', 'Skin-Soothing'],
#  'Cannabis sativa oil': ['Plant Extracts', 'Emollients'],
#  'canola oil': ['Skin-Soothing', 'Skin-Replenishing', 'Plant Extracts'],
#  'caprooyl phytosphingosine': ['Skin-Replenishing', 'Skin-Restoring'],
#  'caprooyl sphingosine': ['Skin-Replenishing', 'Skin-Restoring'],
#  'caprooyl tetrapeptide-3': ['Skin-Restoring'],
#  'caprylic': ['Plant Extracts', 'Emollients', 'Texture Enhancer'],
#  'capric triglyceride': ['Plant Extracts', 'Emollients', 'Texture Enhancer'],
#  'capryloyl glycerin': ['Film-Forming/Holding Agents', 'Texture Enhancer'],
#  'sebacic acid copolymer': ['Film-Forming/Holding Agents', 'Texture Enhancer'],
#  'capryloyl glycine': ['Hydration'],
#  'capryloyl salicylic acid': ['Skin-Soothing', 'Exfoliant'],
#  'caprylyl caprylate': ['Emollients', 'Skin-Softening'],
#  'caprate': ['Cleansing Agents', 'Thickeners/Emulsifiers', 'Texture Enhancer'],
#  'caprylyl glycol': ['Plant Extracts', 'Preservatives'],
#  'caprylyl methicone': ['Silicones', 'Emollients'],
#  'capsaicin': ['Plant Extracts'],
#  'capsicum': ['Plant Extracts'],
#  'capsicum oleoresin': ['Plant Extracts'],
#  'caramel': ['Coloring Agents/Pigments'],
#  'carbomer': ['Texture Enhancer'],
#  'carbopol': ['Texture Enhancer'],
#  'carboxylic acid': ['Antioxidants'],
#  'cardamom': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'carmine': ['Coloring Agents/Pigments'],
#  'carnauba wax': ['Plant Extracts', 'Absorbent', 'Texture Enhancer'],
#  'carnitine': ['Antioxidants'],
#  'carnosic acid': ['Antioxidants', 'Plant Extracts'],
#  'carnosine': ['Antioxidants', 'Plant Extracts'],
#  'carnosol acid': ['Antioxidants', 'Plant Extracts'],
#  'carrageenan': ['Plant Extracts', 'Texture Enhancer'],
#  'carrot oil': ['Plant Extracts', 'Skin-Replenishing', 'Emollients'],
#  'Carthamus tinctorius oil': ['Plant Extracts', 'Emollients'],
#  'carvone': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Carya illinoensis oil': ['Plant Extracts', 'Emollients'],
#  'casein': ['Uncategorized'],
#  'Cassia angustifolia seed polysaccharide': ['Emollients', 'Plant Extracts'],
#  'Castanea sativa seed extract': ['Plant Extracts'],
#  'castor isostearate succinate': ['Emollients'],
#  'castor oil': ['Plant Extracts', 'Emollients'],
#  'catalase': ['Antioxidants'],
#  'Caulerpa taxifolia extract': ['Antioxidants',
#   'Texture Enhancer',
#   'Emollients',
#   'Plant Extracts'],
#  'cedarwood': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Cedrus atlantica bark extract': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'cellulose': ['Plant Extracts', 'Texture Enhancer'],
#  'Cellulose gum': ['Plant Extracts', 'Texture Enhancer'],
#  'Centaurea cyanus': ['Skin-Soothing', 'Plant Extracts'],
#  'Centella asiatica': ['Skin-Soothing', 'Antioxidants'],
#  'cephalin': ['Texture Enhancer', 'Emollients'],
#  'Cera alba': ['Texture Enhancer'],
#  'cera microcristallina': ['Emollients'],
#  'ceramide AP': ['Skin-Replenishing'],
#  'ceramide EOP': ['Skin-Replenishing'],
#  'ceramide EOS': ['Skin-Replenishing'],
#  'ceramide NG': ['Skin-Replenishing'],
#  'ceramide NP': ['Skin-Replenishing'],
#  'ceramide NS': ['Skin-Replenishing'],
#  'ceramides': ['Skin-Restoring', 'Skin-Replenishing'],
#  'ceresin': ['Texture Enhancer'],
#  'ceteareth-20': ['Texture Enhancer'],
#  'ceteareth-25': ['Emulsifiers', 'Texture Enhancer'],
#  'ceteareth-6 olivate': ['Emollients', 'Emulsifiers', 'Texture Enhancer'],
#  'cetearyl alcohol': ['Texture Enhancer', 'Emollients'],
#  'cetearyl ethylhexanoate': ['Texture Enhancer', 'Emollients'],
#  'cetearyl glucoside': ['Texture Enhancer'],
#  'cetearyl octanoate': ['Texture Enhancer', 'Skin-Replenishing', 'Emollients'],
#  'cetearyl olivate': ['Slip Agents', 'Emulsifiers', 'Texture Enhancer'],
#  'cetyl acetate': ['Emollients'],
#  'cetyl alcohol': ['Thickeners/Emulsifiers', 'Emollients'],
#  'cetyl dimethicone': ['Silicones'],
#  'cetyl dimethicone copolyol': ['Silicones', 'Emollients'],
#  'cetyl esters': ['Texture Enhancer', 'Emollients'],
#  'cetyl hydroxyethylcellulose': ['Texture Enhancer', 'Emollients'],
#  'cetyl palmitate': ['Emollients'],
#  'cetyl PEG': ['Texture Enhancer', 'Silicones'],
#  'PPG-10': ['Texture Enhancer', 'Silicones'],
#  '1-dimethicone': ['Texture Enhancer', 'Silicones'],
#  'chamomile': ['Antioxidants', 'Plant Extracts'],
#  'Chamomilla recutita flower extract': ['Antioxidants', 'Plant Extracts'],
#  'charcoal': ['Absorbent'],
#  'charcoal powder': ['Absorbent'],
#  'chelating agent': ['Uncategorized'],
#  'cherry extract': ['Plant Extracts', 'Antioxidants'],
#  'China clay': ['Absorbent'],
#  'chitosan': ['Skin-Soothing', 'Antioxidants'],
#  'chlorella': ['Antioxidants',
#   'Texture Enhancer',
#   'Emollients',
#   'Plant Extracts'],
#  'chlorophene': ['Preservatives'],
#  'chloroxylenol': ['Preservatives'],
#  'chlorphenesin': ['Preservatives'],
#  'cholecalciferol': ['Antioxidants', 'Vitamins'],
#  'cholesterol': ['Emollients', 'Skin-Replenishing'],
#  'choline': ['Vitamins'],
#  'chondroitin sulfate': ['Skin-Replenishing'],
#  'Chondrus crispus (algae) extract': ['Antioxidants',
#   'Plant Extracts',
#   'Hydration'],
#  'chromium hydroxide green': ['Coloring Agents/Pigments'],
#  'chromium oxide green': ['Coloring Agents/Pigments'],
#  'Chrysanthellum indicum (golden chamomile) extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'chrysanthemum extract': ['Skin-Soothing', 'Plant Extracts'],
#  'Chrysanthemum parthenium extract': ['Plant Extracts'],
#  'Cichorium intybus': ['Antioxidants', 'Plant Extracts'],
#  'Cimicifuga racemosa root extract': ['Plant Extracts'],
#  'Cinnamomum': ['Antioxidants',
#   'Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Cinnamomum camphora': ['Plant Extracts'],
#  'cinnamon': ['Antioxidants',
#   'Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'cinnamyl alcohol': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'citrate buffer': ['Miscellaneous'],
#  'citric acid': ['Uncategorized'],
#  'citronellol': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Citrullus colocynthis': ['Plant Extracts'],
#  'Citrus amara': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Citrus aurantifolia': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Citrus aurantium': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Citrus aurantium extract': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Citrus medica limonium': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Citrus unshiu': ['Antioxidants', 'Plant Extracts'],
#  'Citrus unshiu peel extract': ['Antioxidants', 'Plant Extracts'],
#  'clary oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'clary sage': ['Antioxidants'],
#  'clay': ['Absorbent'],
#  'Clitoria ternatea (butterfly pea) flower extract': ['Antioxidants',
#   'Plant Extracts'],
#  'clove leaf': ['Plant Extracts'],
#  'clove oil': ['Plant Extracts'],
#  'clover blossom': ['Plant Extracts'],
#  'clover leaf oil': ['Plant Extracts'],
#  'cocamide DEA and MEA': ['Texture Enhancer', 'Cleansing Agents'],
#  'cocamidopropyl betaine': ['Cleansing Agents'],
#  'cocamidopropyl dimethylamine': ['Cleansing Agents'],
#  'cocamidopropyl hydroxysultaine': ['Cleansing Agents'],
#  'Coccinia indica (ivy gourd) fruit extract': ['Antioxidants',
#   'Plant Extracts',
#   'Hydration'],
#  'cocoa butter': ['Plant Extracts', 'Emollients'],
#  'cocoa extract': ['Antioxidants', 'Plant Extracts'],
#  'coco-caprylate': ['Emollients', 'Hydration'],
#  'coco caprylate': ['Emollients', 'Skin-Softening'],
#  'coco-glucoside': ['Cleansing Agents'],
#  'cocoglycerides': ['Texture Enhancer', 'Emollients'],
#  'coconut': ['Plant Extracts', 'Cleansing Agents'],
#  'coconut acid': ['Cleansing Agents'],
#  'coconut oil': ['Plant Extracts', 'Emollients'],
#  'cocos nucifera (coconut) fruit extract': ['Skin-Softening'],
#  'cocoyl proline': ['Hydration'],
#  'Cocus nucifera': ['Plant Extracts', 'Emollients'],
#  'Codium tomentosum extract': ['Antioxidants',
#   'Plant Extracts',
#   'Texture Enhancer',
#   'Emollients'],
#  'coenzyme Q10': ['Skin-Soothing', 'Antioxidants'],
#  'Coffea arabica (coffee) fruit extract': ['Antioxidants', 'Plant Extracts'],
#  'Coffea arabica (coffee) seed oil': ['Antioxidants', 'Plant Extracts'],
#  'Coffea arabica seed extract': ['Antioxidants', 'Plant Extracts'],
#  'Cola acuminata seed extract': ['Plant Extracts'],
#  'Coleus barbatus': ['Plant Extracts'],
#  'collagen amino acids': ['Hydration', 'Skin-Replenishing'],
#  'colloidal oatmeal': ['Skin-Soothing'],
#  'colloidal silver': ['Uncategorized'],
#  'comfrey extract': ['Sensitizing', 'Plant Extracts'],
#  'Commiphora myrrha extract': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'coneflower': ['Skin-Soothing', 'Plant Extracts'],
#  'Copaifera officinalis': ['Plant Extracts'],
#  'Copernicia cerifera wax': ['Plant Extracts',
#   'Texture Enhancer',
#   'Absorbent'],
#  'copper gluconate': ['Antioxidants'],
#  'copper lysinate': ['Uncategorized'],
#  'prolinate': ['Uncategorized'],
#  'copper PCA': ['Uncategorized'],
#  'copper peptides': ['Antioxidants'],
#  'copper sulfate': ['Uncategorized'],
#  'Corallina officinalis extract': ['Antioxidants',
#   'Plant Extracts',
#   'Emollients',
#   'Texture Enhancer'],
#  'coriander': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'cornflower': ['Skin-Soothing', 'Plant Extracts'],
#  'cornmint': ['Plant Extracts'],
#  'corn oil': ['Plant Extracts', 'Emollients'],
#  'cornstarch': ['Plant Extracts', 'Absorbent'],
#  'Cornus extract': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'Corylus americana': ['Plant Extracts', 'Emollients'],
#  'Corylus avellana': ['Plant Extracts', 'Emollients'],
#  'coumarin': ['Antioxidants', 'Plant Extracts'],
#  'cranberry seed extract': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'cranberry seed oil': ['Antioxidants', 'Plant Extracts'],
#  'Crataegus monogina extract': ['Plant Extracts'],
#  'creatine': ['Skin-Restoring'],
#  'cucumber extract': ['Antioxidants', 'Plant Extracts'],
#  'Cucumis melo (melon) fruit extract': ['Antioxidants', 'Plant Extracts'],
#  'Cucumis sativus extract': ['Antioxidants', 'Plant Extracts'],
#  'Cucurbita pepo seed extract': ['Antioxidants', 'Plant Extracts'],
#  'Cucurbitea peponis': ['Antioxidants',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Plant Extracts',
#   'Vitamins',
#   'Skin-Restoring'],
#  'Curcuma longa root': ['Antioxidants', 'Plant Extracts'],
#  'curcumin': ['Skin-Soothing', 'Antioxidants'],
#  'Cyamopsis tetragonoloba': ['Plant Extracts', 'Texture Enhancer'],
#  'cyclamen aldehyde': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'cyclohexasiloxane': ['Emollients'],
#  'cyclomethicone': ['Emollients'],
#  'cyclopentasiloxane': ['Emollients'],
#  'cyclotetrasiloxane': ['Emollients'],
#  'Cymbopogon citrates': ['Plant Extracts'],
#  'Cymbopogon martini': ['Antioxidants', 'Plant Extracts'],
#  'cysteine': ['Skin-Replenishing'],
#  'cystine': ['Skin-Replenishing'],
#  'D&C': ['Coloring Agents/Pigments'],
#  'D&C colors': ['Coloring Agents/Pigments'],
#  'daisy flower extract': ['Plant Extracts'],
#  'd-alpha-tocopherol': ['Antioxidants', 'Vitamins'],
#  'Daucus carota': ['Antioxidants', 'Plant Extracts'],
#  'DEA oleth-10 phosphate': ['Texture Enhancer'],
#  'decarboxy carnosine HCL': ['Skin-Soothing', 'Skin-Restoring'],
#  'decylene glycol': ['Skin-Replenishing'],
#  'decyl glucoside': ['Cleansing Agents'],
#  'decyl oleate': ['Emollients'],
#  'dehydroacetic acid': ['Preservatives'],
#  'dehydroepiandrosterone': ['Uncategorized'],
#  'deionized': ['Uncategorized'],
#  'demineralized water': ['Uncategorized'],
#  'denatured alcohol': ['Sensitizing'],
#  'deoxyribonucleic acid': ['Uncategorized'],
#  'detergent cleansing agent': ['Cleansing Agents'],
#  'deuterium oxide': ['Uncategorized'],
#  'dextran': ['Skin-Replenishing'],
#  'dextrin': ['Texture Enhancer'],
#  'DHA': ['Uncategorized'],
#  'diatomaceous earth': ['Scrub Agents'],
#  'diazolidinyl urea': ['Preservatives'],
#  'dibutyl phthalate': ['Uncategorized'],
#  'dicaprylyl carbonate': ['Emollients'],
#  'dicetyl phosphate': ['Cleansing Agents'],
#  'diethylhexyl carbonate': ['Emollients'],
#  'diethylhexyl malate': ['Emollients'],
#  'diethylhexyl syringylidenemalonate': ['Antioxidants'],
#  'diheptyl succinate': ['Texture Enhancer'],
#  'dihydrocholeth-30': ['Cleansing Agents'],
#  'dihydroxyacetone': ['Uncategorized'],
#  'diisopropyl adipate': ['Texture Enhancer', 'Emollients'],
#  'diisopropyl dimer dilinoleate': ['Emollients'],
#  'diisostearoyl trimethylolpropane siloxy silicate': ['Silicones',
#   'Emollients'],
#  'diisostearyl dimer dilinoleate': ['Emollients'],
#  'diisostearyl malate': ['Emollients'],
#  'diisostearyl polyglyceryl-3 dimer dilinoleate': ['Skin-Softening',
#   'Emollients',
#   'Emulsifiers'],
#  'dimer dilinoleyl dimer dilinoleate': ['Emollients', 'Texture Enhancer'],
#  'dimethicone': ['Texture Enhancer', 'Silicones'],
#  'PEG-10': ['Silicones', 'Emollients'],
#  '15 crosspolymer': ['Silicones', 'Emollients'],
#  'vinyl dimethicone crosspolymer': ['Silicones',
#   'Cleansing Agents',
#   'Emollients'],
#  'dimethicone copolyol': ['Silicones', 'Emollients'],
#  'dimethicone crosspolymer': ['Texture Enhancer', 'Emollients', 'Silicones'],
#  'dimethiconol': ['Silicones', 'Emollients'],
#  'dimethyl capramide': ['Uncategorized'],
#  'dimethyl ether': ['Uncategorized'],
#  'dimethyl isosorbide': ['Uncategorized'],
#  'dimethyl MEA': ['Skin-Restoring'],
#  'Dioscorea villosa extract': ['Plant Extracts'],
#  'dipentaerythrityl hexacaprylate': ['Texture Enhancer', 'Emollients'],
#  'hexacaprate': ['Texture Enhancer', 'Emollients'],
#  'dipeptide-2': ['Skin-Restoring'],
#  'dipotassium glycyrrhizate': ['Skin-Soothing', 'Plant Extracts'],
#  'dipotassium glycyrrhizinate': ['Skin-Soothing', 'Plant Extracts'],
#  'dipotassium phosphate': ['Miscellaneous'],
#  'di-PPG-3 myristyl ether adipate': ['Texture Enhancer'],
#  'dipropylene glycol': ['Texture Enhancer'],
#  'disodium cocoamphodiacetate': ['Cleansing Agents'],
#  'disodium cocoyl glutamate': ['Cleansing Agents'],
#  'disodium diglyceryl phosphate': ['Texture Enhancer', 'Emollients'],
#  'disodium EDTA': ['Uncategorized'],
#  'disodium glyceryl phosphate': ['Texture Enhancer', 'Emollients'],
#  'disodium lauraminopropionate': ['Cleansing Agents'],
#  'disodium lauriminodipropionate tocopheryl phosphates': ['Uncategorized'],
#  'disodium rutinyl disulfate': ['Antioxidants'],
#  'disteardimonium hectorite': ['Uncategorized'],
#  'DMAE': ['Skin-Restoring'],
#  'DMDM hydantoin': ['Preservatives'],
#  'docosahexaenoic acid': ['Texture Enhancer', 'Emollients'],
#  'dog rose': ['Plant Extracts'],
#  'dogwood': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'Dromiceius oil': ['Emollients'],
#  'dulse': ['Antioxidants', 'Emollients', 'Plant Extracts'],
#  'Dunaliella salina extract': ['Plant Extracts', 'Antioxidants'],
#  'durian': ['Antioxidants', 'Plant Extracts'],
#  'Durvillaea antarctica extract': ['Antioxidants',
#   'Plant Extracts',
#   'Emollients'],
#  'ecamsule': ['Sunscreen Actives'],
#  'Echium plantagineum seed oil': ['Emollients'],
#  'Eclipta prostrata extract': ['Antioxidants', 'Plant Extracts'],
#  'ectoin': ['Emollients'],
#  'EDTA': ['Miscellaneous'],
#  'egg yolk': ['Emollients', 'Skin-Replenishing'],
#  'eicosapentaenoic acid': ['Skin-Replenishing', 'Emollients'],
#  'Elaeis guineensis': ['Antioxidants', 'Emollients', 'Plant Extracts'],
#  'elderberry': ['Antioxidants', 'Plant Extracts'],
#  'elecampane': ['Plant Extracts', 'Sensitizing'],
#  'ellagic acid': ['Antioxidants'],
#  'Emblica officinalis (gooseberry) fruit extract': ['Plant Extracts',
#   'Antioxidants'],
#  'emollient': ['Thickeners/Emulsifiers', 'Emollients'],
#  'emulsifier': ['Thickeners/Emulsifiers'],
#  'emu oil': ['Emollients'],
#  'English ivy extract': ['Plant Extracts', 'Sensitizing'],
#  'Enteromorpha compressa extract': ['Antioxidants',
#   'Thickeners/Emulsifiers',
#   'Plant Extracts'],
#  'environmental damage': ['Miscellaneous'],
#  'enzymes': ['Exfoliant', 'Skin-Restoring'],
#  'epigallocatechin gallate': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'Epilobium angustifolium extract': ['Skin-Soothing'],
#  'Epilobium fleischeri (willowherb) extract': ['Skin-Soothing',
#   'Plant Extracts'],
#  'Equisetum arvense': ['Antioxidants', 'Plant Extracts', 'Sensitizing'],
#  'ergocalciferol': ['Antioxidants', 'Vitamins'],
#  'ergothioneine': ['Skin-Soothing', 'Antioxidants'],
#  'Eriobotrya japonica': ['Antioxidants', 'Plant Extracts'],
#  'erythrulose': ['Miscellaneous'],
#  'esculin': ['Sensitizing'],
#  'essential oil': ['Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'ester': ['Emollients'],
#  'Ester-C': ['Vitamins'],
#  'ethanol': ['Sensitizing'],
#  'ethoxydiglycol': ['Miscellaneous'],
#  'ethyl alcohol': ['Sensitizing'],
#  'ethyl hexanediol': ['Texture Enhancer'],
#  'ethylhexylglycerin': ['Miscellaneous', 'Preservatives'],
#  'ethylhexyl methoxycinnamate': ['Sunscreen Actives'],
#  'ethylhexyl olivate': ['Emollients', 'Skin-Softening'],
#  'ethylhexyl palmitate': ['Emollients', 'Texture Enhancer'],
#  'ethylhexyl stearate': ['Thickeners/Emulsifiers',
#   'Texture Enhancer',
#   'Emollients'],
#  'ethyl macadamiate': ['Plant Extracts',
#   'Thickeners/Emulsifiers',
#   'Emollients'],
#  'ethylparaben': ['Preservatives'],
#  'ethyl vanillin': ['Antioxidants'],
#  'eucalyptus extract': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'eucalyptus oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'Eugenia aromatica': ['Plant Extracts', 'Sensitizing'],
#  'Eugenia caryophyllus': ['Plant Extracts', 'Sensitizing'],
#  'eugenol': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'Euphorbia cerifera wax': ['Plant Extracts',
#   'Emollients',
#   'Texture Enhancer',
#   'Thickeners/Emulsifiers'],
#  'Euphrasia officinalis': ['Plant Extracts', 'Sensitizing'],
#  'Euterpe oleracea (acai) sterols': ['Emollients',
#   'Skin-Soothing',
#   'Skin-Replenishing'],
#  'Euterpe oleracea fruit extract': ['Antioxidants', 'Plant Extracts'],
#  'evening primrose oil': ['Skin-Soothing', 'Emollients', 'Plant Extracts'],
#  'Evodia rutaecarpa extract': ['Skin-Soothing', 'Plant Extracts'],
#  'Ext. D&C': ['Coloring Agents/Pigments'],
#  'eyebright': ['Plant Extracts', 'Sensitizing'],
#  'faex': ['Antioxidants'],
#  'farnesol': ['Antioxidants',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Plant Extracts'],
#  'farnesyl acetate': ['Antioxidants',
#   'Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'fatty acid': ['Thickeners/Emulsifiers',
#   'Emollients',
#   'Texture Enhancer',
#   'Skin-Replenishing'],
#  'fatty alcohol': ['Thickeners/Emulsifiers', 'Texture Enhancer', 'Emollients'],
#  'FD&C': ['Coloring Agents/Pigments'],
#  'FD&C colors': ['Coloring Agents/Pigments'],
#  'fennel oil': ['Plant Extracts', 'Sensitizing'],
#  'fennel seed extract': ['Antioxidants', 'Plant Extracts', 'Sensitizing'],
#  'ferric ammonium ferrocyanide': ['Coloring Agents/Pigments'],
#  'ferric ferrocyanide': ['Coloring Agents/Pigments'],
#  'Ferula galbaniflua': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'ferulic acid': ['Antioxidants', 'Plant Extracts'],
#  'feverfew extract': ['Skin-Soothing', 'Sensitizing', 'Plant Extracts'],
#  'fibronectin': ['Skin-Replenishing'],
#  'Ficus carica (fig) fruit extract': ['Plant Extracts', 'Antioxidants'],
#  'fig': ['Plant Extracts', 'Antioxidants'],
#  'Filipendula glaberrima': ['Antioxidants', 'Plant Extracts'],
#  'Filipendula rubra': ['Skin-Soothing', 'Plant Extracts'],
#  'film-forming agent': ['Film-Forming/Holding Agents'],
#  'fireweed extract': ['Skin-Soothing', 'Plant Extracts'],
#  'fir needle oil': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'fish cartilage extract': ['Miscellaneous'],
#  'flavonoid': ['Antioxidants'],
#  'flax': ['Plant Extracts', 'Antioxidants'],
#  'flaxseed oil': ['Antioxidants', 'Plant Extracts'],
#  'floralozone': ['Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Foeniculum vulgare extract': ['Antioxidants',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'formaldehyde-releasing preservative': ['Preservatives'],
#  'Fragaria vesca (strawberry) fruit extract': ['Antioxidants',
#   'Plant Extracts'],
#  'fragrance': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'frankincense extract': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'fructose': ['Skin-Replenishing'],
#  'fruit acid': ['Miscellaneous', 'Plant Extracts'],
#  'Fucus vesiculosus extract': ['Antioxidants',
#   'Plant Extracts',
#   'Skin-Soothing',
#   'Hydration'],
#  'Fu ling': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  "fuller's earth": ['Thickeners/Emulsifiers', 'Absorbent'],
#  'galactoarabinan': ['Antioxidants', 'Hydration', 'Plant Extracts'],
#  'galbanum': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'gamma linolenic acid (GLA)': ['Antioxidants',
#   'Emollients',
#   'Skin-Restoring'],
#  'Ganoderma lucidum (mushroom) extract': ['Antioxidants', 'Plant Extracts'],
#  'Garcinia mangostana (mangosteen) peel extract': ['Antioxidants',
#   'Plant Extracts'],
#  'Gardenia florida extract': ['Antioxidants',
#   'Sensitizing',
#   'Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'gelatin': ['Thickeners/Emulsifiers'],
#  'gellan gum': ['Texture Enhancer'],
#  'Gellidiela acerosa extract': ['Antioxidants',
#   'Emollients',
#   'Plant Extracts'],
#  'genistein': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'Gentiana lutea (Gentian) root extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'geraniol': ['Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'geranium extract': ['Antioxidants', 'Plant Extracts'],
#  'geranium oil': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Geranium pretense': ['Antioxidants', 'Plant Extracts', 'Sensitizing'],
#  'Germaben II': ['Preservatives'],
#  'ginger extract': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'ginger oil': ['Antioxidants', 'Sensitizing', 'Plant Extracts'],
#  'Ginkgo biloba leaf extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'ginseng': ['Antioxidants', 'Plant Extracts'],
#  'GLA': ['Antioxidants', 'Emollients', 'Skin-Restoring'],
#  'glabridin': ['Skin-Soothing', 'Plant Extracts'],
#  'glucomannan': ['Hydration'],
#  'gluconolactone': ['Exfoliant'],
#  'glucosamine HCL': ['Skin-Soothing', 'Skin-Replenishing'],
#  'glucose': ['Skin-Replenishing'],
#  'glucose oxidase': ['Miscellaneous'],
#  'glucosylceramides': ['Skin-Restoring', 'Skin-Replenishing'],
#  'glucosyl hesperidin': ['Antioxidants', 'Plant Extracts'],
#  'glutamic acid': ['Hydration'],
#  'glutamine': ['Skin-Replenishing'],
#  'glutathione': ['Antioxidants', 'Skin-Restoring'],
#  'gluten ingredients': ['Miscellaneous'],
#  'glycereth-26': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glycereth-26 phosphate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glycereth-6 laurate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glycerin': ['Skin-Replenishing', 'Skin-Restoring'],
#  'glycerine': ['Skin-Replenishing'],
#  'glycerol': ['Skin-Replenishing'],
#  'glycerol monostearate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glycerol triacetate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glycerol trioleate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl ascorbate': ['Antioxidants'],
#  'glyceryl behanate': ['Thickeners/Emulsifiers',
#   'Emollients',
#   'Cleansing Agents'],
#  'glyceryl behenate': ['Thickeners'],
#  'eicosadioate': ['Thickeners'],
#  'glyceryl cocoate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl dibehanate': ['Emollients'],
#  'glyceryl dipalmitate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl distearate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl ester': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl isopalmitate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl isostearate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl myristate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl oleate': ['Thickeners/Emulsifiers',
#   'Emollients',
#   'Cleansing Agents'],
#  'glyceryl palmitate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glyceryl polymethacrylate': ['Thickeners/Emulsifiers',
#   'Film-Forming/Holding Agents',
#   'Texture Enhancer'],
#  'glyceryl rosinate': ['Emulsifiers', 'Emollients', 'Cleansing Agents'],
#  'glyceryl stearate': ['Thickeners/Emulsifiers',
#   'Cleansing Agents',
#   'Emollients'],
#  'glyceryl stearate citrate': ['Emulsifiers', 'Emollients'],
#  'glyceryl stearate SE': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glycine': ['Skin-Replenishing'],
#  'Glycine soja oil': ['Plant Extracts', 'Emollients', 'Antioxidants'],
#  'Glycine soja seed extract': ['Plant Extracts', 'Emollients'],
#  'Glycine soja sterols': ['Plant Extracts', 'Emollients'],
#  'glycogen': ['Skin-Replenishing', 'Hydration'],
#  'glycolic acid': ['Exfoliant'],
#  'glycolipid': ['Thickeners/Emulsifiers', 'Emollients', 'Skin-Replenishing'],
#  'glycol stearate': ['Thickeners/Emulsifiers', 'Emollients'],
#  'glycoproteins': ['Skin-Restoring', 'Hydration'],
#  'glycosaminoglycans': ['Skin-Replenishing', 'Skin-Restoring'],
#  'glycosphingolipid': ['Skin-Replenishing'],
#  'glycyrrhetic acid': ['Skin-Soothing', 'Plant Extracts'],
#  'glycyrrhetinic acid': ['Antioxidants', 'Skin-Soothing'],
#  'Glycyrrhiza glabra': ['Skin-Soothing', 'Plant Extracts'],
#  'Glycyrrhiza uralensis root extract': ['Skin-Soothing', 'Plant Extracts'],
#  'goji fruit extract': ['Antioxidants', 'Plant Extracts'],
#  'gold': ['Sensitizing', 'Miscellaneous'],
#  'Gossypium herbacuem seed oil': ['Plant Extracts'],
#  'gotu kola': ['Plant Extracts', 'Antioxidants'],
#  'grapefruit oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'grapefruit peel extract': ['Sensitizing', 'Plant Extracts'],
#  'grapefruit seed extract': ['Uncategorized'],
#  'grape seed extract': ['Antioxidants', 'Plant Extracts'],
#  'grape seed oil': ['Antioxidants', 'Plant Extracts', 'Emollients'],
#  'green tea': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'gromwell': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'guarana': ['Plant Extracts', 'Sensitizing'],
#  'guar gum': ['Plant Extracts', 'Thickeners/Emulsifiers'],
#  'guar hydroxypropyltrimonium chloride': ['Thickeners/Emulsifiers',
#   'Texture Enhancer',
#   'Miscellaneous'],
#  'guava': ['Antioxidants', 'Plant Extracts'],
#  'gums': ['Plant Extracts', 'Film-Forming/Holding Agents', 'Texture Enhancer'],
#  'Haematococcus pluvialis extract': ['Antioxidants', 'Plant Extracts'],
#  'Hamamelis virginiana': ['Antioxidants', 'Sensitizing', 'Plant Extracts'],
#  'hamamelitannin': ['Antioxidants', 'Sensitizing'],
#  'Haslea ostrearia extract': ['Antioxidants',
#   'Emollients',
#   'Texture Enhancer',
#   'Thickeners/Emulsifiers',
#   'Plant Extracts'],
#  'hayflower extract': ['Plant Extracts', 'Sensitizing'],
#  'hazelnut oil': ['Emollients'],
#  'hectorite': ['Texture Enhancer'],
#  'Hedera helix': ['Plant Extracts', 'Sensitizing'],
#  'hedione': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'Helianthus annuus (sunflower) seed oil': ['Plant Extracts',
#   'Emollients',
#   'Antioxidants'],
#  'Helianthus oil': ['Plant Extracts', 'Emollients'],
#  'hemp seed oil': ['Plant Extracts', 'Emollients'],
#  'hesperidin': ['Antioxidants', 'Plant Extracts'],
#  'hesperidin methyl chalcone': ['Antioxidants', 'Plant Extracts'],
#  'hexanoyl dipeptide-3 norleucine acetate': ['Skin-Restoring'],
#  'hexyl cinnamal': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'hexyldecanol': ['Emollients', 'Skin-Softening'],
#  'hexylene glycol': ['Slip Agents'],
#  'hexyl laurate': ['Emollients', 'Skin-Softening'],
#  'hexylresorcinol': ['Antioxidants'],
#  'hibiscus': ['Antioxidants', 'Skin-Restoring', 'Plant Extracts'],
#  'Himanthalia elongate extract': ['Antioxidants',
#   'Plant Extracts',
#   'Thickeners/Emulsifiers',
#   'Emollients'],
#  'Hippophae rhamnoides': ['Antioxidants', 'Plant Extracts'],
#  'Hippophae Rhamnoides (seaberry) fruit extract': ['Antioxidants',
#   'Plant Extracts'],
#  'histidine': ['Antioxidants'],
#  'hoelen': ['Plant Extracts', 'Preservatives'],
#  'homosalate': ['Sunscreen Actives'],
#  'honey': ['Skin-Soothing', 'Vitamins', 'Antioxidants'],
#  'honey extract': ['Skin-Soothing', 'Antioxidants', 'Vitamins'],
#  'honeysuckle flower extract': ['Skin-Soothing', 'Plant Extracts'],
#  'hops': ['Antioxidants', 'Plant Extracts'],
#  'Hordeum vulgare extract': ['Antioxidants', 'Plant Extracts'],
#  'horse chestnut extract': ['Skin-Soothing', 'Plant Extracts'],
#  'horse elder': ['Plant Extracts', 'Sensitizing'],
#  'horseradish': ['Plant Extracts', 'Sensitizing'],
#  'horsetail extract': ['Antioxidants', 'Plant Extracts'],
#  'Hortonia floribunda leaf extract': ['Plant Extracts'],
#  'Huang qi': ['Antioxidants', 'Plant Extracts'],
#  'Humulus lupulus extract': ['Plant Extracts', 'Antioxidants'],
#  'hyaluronic acid': ['Antioxidants', 'Skin-Replenishing', 'Skin-Restoring'],
#  'Hydnocarpus anthelmintica': ['Plant Extracts', 'Sensitizing'],
#  'Hydrastis canadenis': ['Plant Extracts', 'Sensitizing'],
#  'hydrocotyl extract': ['Plant Extracts'],
#  'hydrogenated coco-glyceride': ['Thickeners/Emulsifiers',
#   'Texture Enhancer',
#   'Emollients'],
#  'hydrogenated didecene': ['Thickeners/Emulsifiers', 'Texture Enhancer'],
#  'hydrogenated lecithin': ['Skin-Restoring', 'Emollients'],
#  'hydrogenated olive oil': ['Antioxidants', 'Plant Extracts', 'Emollients'],
#  'hydrogenated palm glycerides': ['Antioxidants',
#   'Skin-Replenishing',
#   'Emollients'],
#  'hydrogenated polydecene': ['Emollients'],
#  'hydrogenated polyisobutene': ['Emollients', 'Skin-Softening'],
#  'hydrogenated soybean oil': ['Antioxidants', 'Emollients'],
#  'hydrogenated starch hydrolysate': ['Film-Forming/Holding Agents',
#   'Hydration'],
#  'hydrogenated vegetable glycerides citrate': ['Emollients',
#   'Emulsifiers',
#   'Texture Enhancer'],
#  'hydrogen peroxide': ['Sensitizing'],
#  'hydrolyzed acacia macrostachya seed extract': ['Antioxidants',
#   'Plant Extracts'],
#  'hydrolyzed algae extract': ['Emollients',
#   'Antioxidants',
#   'Plant Extracts',
#   'Texture Enhancer'],
#  'hydrolyzed corn starch': ['Absorbent'],
#  'hydrolyzed eruca sativa (arugula) leaf': ['Antioxidants', 'Plant Extracts'],
#  'hydrolyzed glycosaminoglycans': ['Skin-Replenishing', 'Skin-Softening'],
#  'hydrolyzed jojoba esters': ['Plant Extracts',
#   'Emollients',
#   'Skin-Softening'],
#  'hydrolyzed jojoba protein': ['Plant Extracts', 'Emollients'],
#  'hydrolyzed pumpkin seedcake': ['Plant Extracts', 'Hydration'],
#  'hydrolyzed rhodophycea (red algae) extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Hydration'],
#  'hydrolyzed silk': ['Antioxidants', 'Slip Agents'],
#  'hydrolyzed soy protein': ['Skin-Soothing', 'Antioxidants', 'Plant Extracts'],
#  'hydrolyzed vegetable protein': ['Miscellaneous', 'Hydration'],
#  'hydrolyzed wheat protein': ['Plant Extracts',
#   'Film-Forming/Holding Agents',
#   'Texture Enhancer'],
#  'hydroquinone': ['Skin-Restoring', 'Antioxidants'],
#  'hydroxyacetophenone': ['Antioxidants', 'Hydration'],
#  'hydroxyethyl acrylate': ['Thickeners/Emulsifiers', 'Texture Enhancer'],
#  'sodium acryloyl dimethyl taurate copolymer': ['Thickeners/Emulsifiers',
#   'Texture Enhancer'],
#  'hydroxyethylcellulose': ['Plant Extracts',
#   'Film-Forming/Holding Agents',
#   'Texture Enhancer',
#   'Thickeners/Emulsifiers'],
#  'hydroxyethylpiperazine ethane sulfonic acid': ['Miscellaneous'],
#  'hydroxyethyl urea': ['Hydration', 'Skin-Replenishing'],
#  'hydroxylated lecithin': ['Emollients'],
#  'hydroxypropyl cyclodextrin': ['Miscellaneous'],
#  'hydroxypropyl guar': ['Plant Extracts', 'Thickeners/Emulsifiers'],
#  'hydroxypropyl starch phosphate': ['Thickeners/Emulsifiers'],
#  'Hypericum extract': ['Antioxidants', 'Sensitizing', 'Plant Extracts'],
#  'hyssop': ['Plant Extracts', 'Antioxidants'],
#  'idebenone': ['Antioxidants'],
#  'Ilex paraguariensis': ['Skin-Soothing', 'Antioxidants'],
#  'Illicium vernum': ['Antioxidants',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'illite': ['Thickeners', 'Absorbent'],
#  'imidazolidinyl urea': ['Preservatives'],
#  'inactive ingredient': ['Miscellaneous'],
#  'inositol': ['Skin-Replenishing'],
#  'Inula helenium': ['Plant Extracts', 'Sensitizing'],
#  'iodopropynyl butylcarbamate': ['Preservatives'],
#  'Iris florentina extract': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'Irish moss extract': ['Antioxidants',
#   'Thickeners/Emulsifiers',
#   'Plant Extracts',
#   'Emollients',
#   'Texture Enhancer'],
#  'iron oxides': ['Coloring Agents/Pigments'],
#  'iron powder': ['Absorbent'],
#  'isoamyl cocoate': ['Emollients', 'Skin-Softening'],
#  'isoamyl laurate': ['Emulsifiers', 'Skin-Softening'],
#  'isobutyl acetate': ['Miscellaneous'],
#  'isobutylparaben': ['Preservatives'],
#  'isocetyl salicylate': ['Miscellaneous'],
#  'isododecane': ['Miscellaneous', 'Texture Enhancer'],
#  'isoflavone': ['Antioxidants', 'Plant Extracts'],
#  'isohexadecane': ['Thickeners/Emulsifiers',
#   'Cleansing Agents',
#   'Texture Enhancer'],
#  'isoleucine': ['Antioxidants', 'Skin-Replenishing'],
#  'isononyl isononanoate': ['Emollients'],
#  'isoparaffin': ['Thickeners/Emulsifiers', 'Texture Enhancer'],
#  'isopropyl alcohol': ['Sensitizing'],
#  'isopropyl isostearate': ['Emollients'],
#  'isopropyl lanolate': ['Thickeners/Emulsifiers',
#   'Texture Enhancer',
#   'Emollients'],
#  'isopropyl myristate': ['Texture Enhancer', 'Emollients'],
#  'isopropyl palmitate': ['Emollients', 'Texture Enhancer'],
#  'isopropyl titanium triisostearate': ['Emulsifiers',
#   'Texture Enhancer',
#   'Emollients'],
#  'isopropyl titanium triisostearte': ['Thickeners/Emulsifiers',
#   'Silicones',
#   'Texture Enhancer'],
#  'triethoxycaprylylsilane crosspolymer': ['Silicones',
#   'Film-Forming/Holding Agents'],
#  'isostearamide DEA': ['Thickeners/Emulsifiers',
#   'Texture Enhancer',
#   'Cleansing Agents'],
#  'isostearic acid': ['Thickeners/Emulsifiers', 'Texture Enhancer'],
#  'ivy extract': ['Plant Extracts', 'Sensitizing'],
#  'Japan wax': ['Thickeners/Emulsifiers', 'Emollients', 'Texture Enhancer'],
#  'jasmine oil': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Jasminium grandiflorum': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'jojoba butter': ['Antioxidants', 'Emollients', 'Plant Extracts'],
#  'jojoba esters': ['Plant Extracts', 'Emollients', 'Scrub Agents'],
#  'jojoba oil': ['Skin-Restoring',
#   'Plant Extracts',
#   'Skin-Replenishing',
#   'Emollients'],
#  'jojoba wax': ['Plant Extracts', 'Skin-Replenishing', 'Emollients'],
#  'jonquil extract': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Ju hua': ['Skin-Soothing', 'Plant Extracts'],
#  'jujube fruit extract': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'juniper berry': ['Skin-Soothing', 'Plant Extracts', 'Sensitizing'],
#  'Juniperus communis': ['Skin-Soothing', 'Sensitizing', 'Plant Extracts'],
#  'kaolin': ['Absorbent'],
#  'Kathon CG': ['Preservatives', 'Sensitizing'],
#  'kava-kava extract': ['Skin-Soothing', 'Plant Extracts', 'Sensitizing'],
#  'kawa extract': ['Skin-Soothing', 'Plant Extracts', 'Sensitizing'],
#  'kelp extract': ['Antioxidants',
#   'Thickeners/Emulsifiers',
#   'Emollients',
#   'Plant Extracts'],
#  'Kigelia africana extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'kiwi fruit extract': ['Antioxidants', 'Plant Extracts'],
#  'kojic acid': ['Antioxidants'],
#  'kojic dipalmitate': ['Antioxidants'],
#  'kola nut': ['Plant Extracts', 'Sensitizing'],
#  'kudzu root': ['Antioxidants', 'Plant Extracts'],
#  'kukui nut oil': ['Plant Extracts', 'Emollients'],
#  'lactic acid': ['Exfoliant'],
#  'Lactobacillus': ['Hydration'],
#  'rye flour ferment': ['Hydration'],
#  'Lactobacillus ferment': ['Hydration'],
#  'lactobionate': ['Skin-Replenishing'],
#  'lactobionic acid': ['Exfoliant'],
#  'lactoperoxidase': ['Miscellaneous'],
#  "lady's mantle extract": ['Plant Extracts', 'Miscellaneous'],
#  "lady's thistle (milk thistle) extract": ['Antioxidants',
#   'Plant Extracts',
#   'Skin-Restoring'],
#  'Lagerstroemia indica extract': ['Plant Extracts'],
#  'Laminaria digitata': ['Antioxidants',
#   'Thickeners/Emulsifiers',
#   'Plant Extracts',
#   'Texture Enhancer'],
#  'Laminaria longicruris': ['Antioxidants',
#   'Texture Enhancer',
#   'Plant Extracts',
#   'Thickeners/Emulsifiers',
#   'Emollients'],
#  'Laminaria ochroleuca extract': ['Skin-Soothing', 'Plant Extracts'],
#  'Laminaria sacharrina': ['Antioxidants',
#   'Emollients',
#   'Plant Extracts',
#   'Thickeners/Emulsifiers'],
#  'Lamium album flower extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'lanolin': ['Emollients', 'Skin-Replenishing'],
#  'lanolin alcohol': ['Emollients', 'Skin-Replenishing'],
#  'lappa extract': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'Larrea divaricata extract': ['Antioxidants', 'Plant Extracts'],
#  'Larrea tridentata': ['Antioxidants', 'Plant Extracts'],
#  'L-ascorbic acid': ['Skin-Soothing', 'Vitamins', 'Antioxidants'],
#  'lauramphocarboxyglycinate': ['Cleansing Agents'],
#  'laurdimonium hydroxypropyl hydrolyzed soy protein': ['Miscellaneous'],
#  'laurdimonium hydroxypropyl hydrolyzed wheat protein': ['Miscellaneous'],
#  'laureth-23': ['Thickeners/Emulsifiers',
#   'Cleansing Agents',
#   'Texture Enhancer'],
#  'laureth-4': ['Thickeners/Emulsifiers',
#   'Texture Enhancer',
#   'Cleansing Agents'],
#  'laureth-7': ['Thickeners/Emulsifiers', 'Cleansing Agents'],
#  'laureths': ['Cleansing Agents'],
#  'lauric acid': ['Skin-Replenishing', 'Cleansing Agents'],
#  'lauroyl lysine': ['Miscellaneous'],
#  'Laurus nobilis': ['Antioxidants',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Plant Extracts'],
#  'lauryl alcohol': ['Cleansing Agents'],
#  'lauryl glucoside': ['Cleansing Agents'],
#  'lauryl lactate': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Emollients'],
#  'lauryl laurate': ['Emollients', 'Texture Enhancer'],
#  'lauryl PEG-9 polydimethylsiloxyethyl dimethicone': ['Emulsifiers',
#   'Miscellaneous',
#   'Texture Enhancer',
#   'Thickeners/Emulsifiers'],
#  'lavandin oil': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Lavandula angustifolia': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Lavandula officinalis': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'lavender extract and oil': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'L-cysteine': ['Antioxidants'],
#  'lecithin': ['Emollients', 'Skin-Replenishing'],
#  'lemon': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'lemon balm': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'lemongrass extract': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'lemongrass oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'lemon juice': ['Antioxidants', 'Sensitizing'],
#  'lemon oil': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'lentil fruit extract': ['Antioxidants', 'Plant Extracts', 'Skin-Softening'],
#  'Lentinus edodes extract': ['Plant Extracts', 'Sensitizing', 'Antioxidants'],
#  'Leontopodium alpinum (edelweiss) extract': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'Leptospermum scoparium oil': ['Plant Extracts', 'Antioxidants'],
#  'leucine': ['Skin-Replenishing'],
#  'leuconostoc': ['Plant Extracts', 'Preservatives'],
#  'radish root ferment filtrate': ['Plant Extracts', 'Preservatives'],
#  'Levisticum officinale root extract': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'licorice extract': ['Skin-Soothing', 'Plant Extracts', 'Antioxidants'],
#  'licorice root': ['Skin-Soothing', 'Plant Extracts'],
#  'Lilium candidum bulb extract': ['Plant Extracts'],
#  'lime oil and extract': ['Plant Extracts',
#   'Sensitizing',
#   'Fragrance: Synthetic and Fragrant Plant Extracts'],
#  'Limnanthes alba': ['Plant Extracts', 'Skin-Softening'],
#  'Limnanthes alba (meadowfoam) seed oil': ['Plant Extracts',
#   'Emollients',
#   'Skin-Soothing',
#   'Antioxidants'],
#  'Limnanthes alba seed oil': ['Plant Extracts'],
#  'limonene': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'linalool': ['Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'linden flower extract': ['Antioxidants', 'Plant Extracts'],
#  'linoleic acid': ['Skin-Soothing',
#   'Antioxidants',
#   'Skin-Restoring',
#   'Emollients'],
#  'linolenic acid': ['Skin-Restoring', 'Plant Extracts'],
#  'Linum usitatissimum (linseed) seed oil': ['Plant Extracts'],
#  'Linum usitatissimum extract': ['Plant Extracts'],
#  'lipid': ['Thickeners/Emulsifiers', 'Emollients', 'Skin-Replenishing'],
#  'liposomes': ['Miscellaneous'],
#  'lithium magnesium sodium silicate': ['Thickeners/Emulsifiers',
#   'Texture Enhancer',
#   'Absorbent'],
#  'Lithospermum erythrorhizon': ['Skin-Soothing',
#   'Antioxidants',
#   'Plant Extracts'],
#  'Litsea cubeba': ['Plant Extracts',
#   'Fragrance: Synthetic and Fragrant Plant Extracts',
#   'Sensitizing'],
#  'locust bean': ['Plant Extracts',
#   'Texture Enhancer',
#   'Thickeners/Emulsifiers',
#   'Film-Forming/Holding Agents'],
#  ...}

# %%
lookup = look_up_ingredient(ingredient_rating_dict, ingredient_category_dict)

# %% [markdown]
# We also make a table where ingredient belongs to multiple categories are separated into different rows, this will be useful when we examine characters of different categories.

# %%
def split_ingredient_category(ingredient_df_):
    
    ''' Split ingredients that belong to multiple categories into separated rows'''
    
    ingredient_df = ingredient_df_.copy(deep=True)
    print('Copied')
    new_df = pd.DataFrame()
    
    for idx, row in ingredient_df.iterrows():
        if len(row['category']) == 1:
            ingredient_df.loc[idx, 'category'] = ingredient_df.loc[idx, 'category'][0] # index is to remove []

        elif len(row['category']) > 1:
#             print(len(row['category']))
            new_row = row
            for category in row['category']:
                new_row['category'] = category
                new_df = new_df.append(row)
            
            ingredient_df.drop(idx, axis=0, inplace=True) #remove existed row to prepare to append result above
    ingredient_df = ingredient_df.append(new_df)
    ingredient_df = ingredient_df.sort_values('name').reset_index(drop=True)
    return ingredient_df

# %%
ingredient_single_cat = split_ingredient_category(ingredient_df)
ingredient_single_cat
# Out:
# Copied
#                          name                  category rating  rating_score
# 0             1, 2-Hexanediol             Preservatives   Good           2.0
# 1     10-Hydroxydecanoic Acid                Emollients   Good           2.0
# 2       4-T-butylcyclohexanol             Skin-Soothing   Good           2.0
# 3       4-T-butylcyclohexanol                Emollients   Good           2.0
# 4                         AGE             Miscellaneous   Poor           0.0
# ...                       ...                       ...    ...           ...
# 3428            zinc stearate  Coloring Agents/Pigments   Good           2.0
# 3429            zinc stearate    Thickeners/Emulsifiers   Good           2.0
# 3430            zinc stearate          Texture Enhancer   Good           2.0
# 3431             zinc sulfate             Preservatives   Poor           0.0
# 3432             zinc sulfate               Sensitizing   Poor           0.0
#
# [3433 rows x 4 columns]

# %% [markdown]
# Clean product data
#
#     Drop products that are not "chemical" products, like makeup brushes, cleaning devices.
#     Merge some categories.
#     Split 'size' column to a number and unit, do unit conversion as necessary
#     Compute 'price/size'
#     Basic cleaning on ingredients:
#         split inactive and active ingredient
#         convert ingredients to a list
#         find number of inactive and active ingredient
#         check if the ingredients are in alphabatical order -- most companies like to list ingredient in a descending order of their quantity in the product, some companies just list ingredients alphabatically.
#     Look up ingredients in our ingredient dictionary.
#         get a set of all unique ingredients in the products dataframe
#         find the match of all these ingredients
#         for all product, we loop over its ingredient list and look up the matching ingredient, rating and ingredient category
#         count how many ingredients in a product have a certain rating (how many ingredient rated as Good/Average etc.)
#         count how many ingredients in a product belongs to a certain category (how many antioxidants/sunscreen etc.)
#         compute average ingredient rating. For inactive ingredient, we also consider two kinds of weighted average.

# %%
# Out:
# 'Emollients'
